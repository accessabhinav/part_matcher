# %%
# %%time
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
import numpy as np
import pandas as pd
import re
from csv import reader
from fuzzywuzzy import fuzz, process

stopwords = set(stopwords.words("english"))

dictionary = pd.read_csv('E:\JS\Py\Text_similarity\Fuzzy.csv', header=None, squeeze=True).to_dict()
#sec_dict1 = pd.read_csv('E:\JS\Py\Text_similarity\Second_dict.csv', header=None, squeeze=True).to_dict()
with open('E:\JS\Py\Text_similarity\Second_dict.csv', 'r') as read_obj:
    csv_reader = reader(read_obj)
    sec_dict = list(map(tuple, csv_reader))

master_doc = []
match_doc = []

def stringsearch(string, sub_str, sub_str1, line):
    if(string.find(sub_str)!=-1 and string.find(sub_str1)!=-1):
        final_doc.append(sub_str+" "+sub_str1)
        clean_doc.remove(line)
        return (1)
        
def secondsearch(string, sub_str, line):
    r = fuzz.token_set_ratio(string, sub_str)
    #r = fuzz.token_sort_ratio(string, sub_str)
    if(r > 90):
        final_doc.append(sub_str)
        clean_doc.remove(line)
        return (1)
    
def thirdsearch(string, sub_str, line):
    #r = fuzz.token_set_ratio(string, sub_str)
    r = fuzz.token_sort_ratio(string, sub_str)
    if(r > 90):
        final_doc.append(sub_str)
        clean_doc.remove(line)
        return (1)

def listtostring(clean_line):
    return(" ".join(clean_line))

def replacer(string1):
    return(string1.replace('\bscr\b','screw').replace('\bspr\b','spring').replace('\bbd\b','band').replace('spr bd','spring band')
           .replace('\bw/h\b','wiring harness').replace('brg','bearing').replace('bkt','bracket').replace('\bwh\b','wiring harness')
           .replace('w/h','wiring harness').replace('\breinf\b','reinforcement').replace('wh','wiring harness').replace('mtg.','mounting')
           .replace('\bmtg\b','mounting').replace('\bbrkt\b','bracket').replace('\brr\b','rear').replace('frt','front').replace('\bdr\b','door')
           .replace('reinfrocement','reinforcement').replace('mountingbracket','mounting bracket').replace('nylon pipe','nylon bunch').replace('pipe bunch','nylon bunch').replace('vent tube','vent hose').replace('\bvent\b','ventilation')
           .replace('suction tube','suction hose').replace('\bcyl\b','cylinder').replace('clutch line','clutch hose').replace('suction pipe','suction hose').replace('suction line','suction hose').replace('fuel return pipe','fuel return hose')
           .replace('clutch pipe','clutch hose').replace('coolant pipe','coolant hose').replace('exh','exhaust').replace('batt','battery').replace('loadbody','load body').replace('\barb\b','anti roll bar').replace('window regulator','window winding')
           .replace('pressure line','pressure hose').replace('return line','return hose').replace('gear box','gearbox').replace('shell assy','load body').replace('\bfl\b','flanged').replace('flat bed','load body').replace('high deck','load body')
           .replace('lining','liner').replace('\bgb\b','gearbox').replace('\bstg\b','steering').replace('-conn','connector').replace('\bconn\b','connector').replace('washer tank','washer bottle'))
   
#using Lemmatization
lemma = nltk.wordnet.WordNetLemmatizer()

file_docs = []
test_doc = []
test_line = []

with open('E:\JS\Py\Text_similarity\Doc5.csv', 'r', encoding="UTF-8") as inp, open('E:\JS\Py\Text_similarity\Doc3.txt', 'w') as out:
    for line in inp:
        out.write(line + '.\n')

with open ('E:\JS\Py\Text_similarity\Doc3.txt') as f:
    tokens = sent_tokenize(f.read())
    #wtokens = word_tokenize(f.read())
    for line in tokens:
        file_docs.append(line)
        

# create a clean document after removing the stop-words and generate lemmas
clean_doc = []

for line in file_docs:
    clean_line = [word for word in line.split() if word not in stopwords]
    
    for word in line.split():
        test_line.append(lemma.lemmatize(word))
    test_doc.append(listtostring(test_line))
    test_line = []
    
    #clean_doc.append(listtostring(clean_line))
    clean_doc = test_doc

final_doc=[]
init_size = len(clean_doc)
loop_size = init_size * 0.90

while(len(clean_doc)>4000):
    
    for line in clean_doc:

        line1 = line.lower()
        string = line1.partition(",")[0].partition(";")[0].partition("(")[0].partition("[")[0].partition('for')[0].partition('with')[0].partition('w/o')[0].partition('offer')[0].partition('\bw\b')[0]

        for y in sec_dict:
            if (stringsearch(replacer(string.lower()),y[0].lower(),y[1].lower(), line) == 1):
                print(line, " is ::-->")
                break
        if(len(final_doc)!=0):
            print(final_doc)
        final_doc = [] 
    
print(len(clean_doc))
# Out:
# SUCTION LINE ASSY .  is ::-->
# ['suction hose']
# RETURN LINE ASSY .  is ::-->
# ['return hose']
# "WIRING HARNESS,AEBS FRAME (52WB) (282154621601)" .  is ::-->
# ['wiring harness ']
# "DRUM BRAKE ASSEMBLY WITH DC, RR LH (140mm)" .  is ::-->
# ['drum  brake']
# RADIATOR & INTERCOOLER ASSY .  is ::-->
# ['radiator ']
# FAN SHROUD ASSY .  is ::-->
# ['fan shroud']
# BRACKET .  is ::-->
# ['bracket ']
# "L-BRACKET,EXHAUST PIPE MTG" .  is ::-->
# ['bracket ']
# BRACKET ASSY CABLE ANCHORING SHIFT .  is ::-->
# ['bracket ']
# GEAR SHIFTER ASSYÂ (M/s Excel) .  is ::-->
# ['gear shifter ']
# WHEEL RIM ASSY WITH VALVE (205 PCD) .  is ::-->
# ['wiring harness ']
# "PIPE ASSY,JOINT TO JOINT (29WB)" .  is ::-->
# ['pipe assy ']
# Holder Parking Sensor .  is ::-->
# ['parking sensor']
# "PLATE,SPARE WHEEL MTG" .  is ::-->
# ['plate ']
# CLAMP PIPE .  is ::-->
# ['clamp ']
# PROPELLER SHAFT ASSY DRIVE .  is ::-->
# ['propeller shaft']
# PIPE BUNCH ASSY .  is ::-->
# ['nylon bunch']
# PIPE BUNCH ASSY .  is ::-->
# ['nylon bunch']
# LONG MEMBER RH .  is ::-->
# ['long member']
# HOSE .  is ::-->
# ['hose ']
# WATER FILLER PIPE AWT TO RADIATOR .  is ::-->
# ['pipe ']
# PIPE RETARDER TO ENGINE .  is ::-->
# ['pipe ']
# PIPE RADIATOR TO RETARDER .  is ::-->
# ['pipe ']
# SUPPORT BRACKET .  is ::-->
# ['bracket ']
# SUBFRAME ASSY .  is ::-->
# ['subframe assy ']
# SPACER RUBBER .  is ::-->
# ['rubber spacer']
# BRACKET MUDGUARD MTG LH .  is ::-->
# ['bracket ']
# BALATA .  is ::-->
# ['balata ']
# BALATA .  is ::-->
# ['balata ']
# DUST COVER .  is ::-->
# ['cover ']
# REFLECTIVE TAPE .  is ::-->
# ['reflective tape']
# REFLECTIVE TAPE .  is ::-->
# ['reflective tape']
# Fender Extension Assy RH .  is ::-->
# ['fender ']
# "LEAF SPRING ASSY,FRONT-RH" .  is ::-->
# ['leaf spring ']
# FLAT BED ASSY .  is ::-->
# ['load body ']
# FRONT SEAT ASSY LH 2W ODS .  is ::-->
# ['front seat']
# 100% Rear Seat with ISOFIX .  is ::-->
# ['rear seat']
# "COVER ASSY,DISPLAY,LOWER" .  is ::-->
# ['cover ']
# "STRUCTURAL PAD,HOOD,FRONT" .  is ::-->
# ['structural pad']
# "COVER ASSY,CLUSTER" .  is ::-->
# ['cover ']
# "WHEEL ARCH LINER ASSY,REAR-RH" .  is ::-->
# ['wiring harness ']
# Rear Door Rub Rail LH .  is ::-->
# ['rub rail ']
# Rear Door Rub Rail RH .  is ::-->
# ['rub rail ']
# ALLOY PIANO JETBLACK + BRIGHT CROME T LOGO (M/S JAI HIND AUTO PVT LTD) .  is ::-->
# ['logo ']
# "BRACKET ASSY,AC PIPE MTG" .  is ::-->
# ['bracket ']
# COCKPIT ASSY .  is ::-->
# ['cockpit ']
# HEAD LINING ASSY .  is ::-->
# ['liner ']
# DUAL BRAKE VALVE WITH SWITCH .  is ::-->
# ['brake valve']
# FUEL SUCTION PIPE ASSY .  is ::-->
# ['suction hose']
# RETURN FUEL PIPE ASSY .  is ::-->
# ['pipe assy ']
# FUEL PIPE ASSY .  is ::-->
# ['pipe assy ']
# FRONT PIPE ASSY .  is ::-->
# ['pipe assy ']
# EXHAUST TAIL PIPE .  is ::-->
# ['exhaust pipe']
# HOSE .  is ::-->
# ['hose ']
# TUBE .  is ::-->
# ['tube ']
# HOSE .  is ::-->
# ['hose ']
# HOSE .  is ::-->
# ['hose ']
# SWITCH EXHAUST BRAKE FOR 3L ENGINE .  is ::-->
# ['switch ']
# WIRING HARNESS SWITCH .  is ::-->
# ['wiring harness ']
# WIRING HARNESS SCR PIGTAL .  is ::-->
# ['wiring harness ']
# PLATE .  is ::-->
# ['plate ']
# INSTRUMENT CLUSTER ASSY .  is ::-->
# ['instrument cluster']
# "LONG MEMBER, LH" .  is ::-->
# ['long member']
# "PROPELLER SHAFT ASSY,COUPLING" .  is ::-->
# ['propeller shaft']
# "PROPELLER SHAFT ASSY,MONOTRON" .  is ::-->
# ['propeller shaft']
# FUEL FILTER ASSY WITH BRACKET .  is ::-->
# ['fuel filter']
# FUEL FILTER ASSY WITH BRACKET .  is ::-->
# ['fuel filter']
# BRACKET CENTER BRG MTG .  is ::-->
# ['bracket ']
# BRACKET ASSY UREA TANK MTG .  is ::-->
# ['bracket ']
# BRAKE CHAMBER RH .  is ::-->
# ['brake chamber']
# "LONG MEMBER,LH" .  is ::-->
# ['long member']
# NYLON PIPE BUNCH ASSY .  is ::-->
# ['nylon bunch']
# WIRING HARNESS TAIL .  is ::-->
# ['wiring harness ']
# ASSY A/C COMPRESSOR TCCI Make .  is ::-->
# ['compressor ']
# SUPPORT BRACKET ASSY .  is ::-->
# ['bracket ']
# "METAL PIPE ASSY, JOINT 1 TO JOINT 2" .  is ::-->
# ['metal pipe']
# "METAL PIPE ASSY, JOINT 3 TO DDU" .  is ::-->
# ['metal pipe']
# FUEL TANK ASSY 60L .  is ::-->
# ['fuel tank']
# "WIRING HARNESS,ABS FRAME" .  is ::-->
# ['wiring harness ']
# "BRACKET,CENTER BRG MTG" .  is ::-->
# ['bracket ']
# EMS W/H CONNECTOR SUPPORT BKT .  is ::-->
# ['bracket ']
# FRAME ASSY WITH FITMENT .  is ::-->
# ['frame assy ']
# "LONG MEMBER,LH" .  is ::-->
# ['long member']
# METAL PIPE ASSY HOSE TO INT JOINT .  is ::-->
# ['hose ']
# NYLON PIPE BUNCH ASSY CABIN .  is ::-->
# ['nylon bunch']
# SUCTION NYLON TUBE FEED PUMP TO FILTER .  is ::-->
# ['nylon tube']
# SUCTION PIPE ASSY FILTER TO FIP .  is ::-->
# ['suction hose']
# RETURN LINE PIPE ENGINE TO FILTER .  is ::-->
# ['return hose']
# PIPE ASSY DPS SENSOR INTAKE .  is ::-->
# ['intake pipe']
# KIT-HEATER HOSE .  is ::-->
# ['heater hose']
# CLUTCH PEDAL ASSY WITH MTG BKT .  is ::-->
# ['clutch pedal']
# BUNDY TUBE ASSY MIDDLE .  is ::-->
# ['bundy tube']
# SUPPORT BRACKET ACCELERATOR PEDAL .  is ::-->
# ['bracket ']
# LONG MEMBER LH .  is ::-->
# ['long member']
# STUB AXLE ASSY LH .  is ::-->
# ['stub axle']
# KIT-POWER STEERING GEAR BOX .  is ::-->
# ['power steering gearbox']
# SUCTION LINE ASSY .  is ::-->
# ['suction hose']
# RETURN LINE ASSY .  is ::-->
# ['return hose']
# DASHBOARD ASSY WITH HVAC .  is ::-->
# ['dashboard ']
# DRIVER SEAT ASSY .  is ::-->
# ['driver seat']
# W/H ROOF .  is ::-->
# ['wiring harness ']
# WIRING HARNESS FLOOR .  is ::-->
# ['floor wiring harness']
# WIRING HARNESS FRONT CHASSIS .  is ::-->
# ['front wiring harness']
# WIRING HARNESS ABS FRAME 29WB .  is ::-->
# ['wiring harness ']
# BRACKET ASSY ENGINE WIRING HARNESS MTG .  is ::-->
# ['bracket ']
# FB Sticker Maxifuse assembly .  is ::-->
# ['sticker ']
# PLATE FUEL FILTER MTG .  is ::-->
# ['plate ']
# BRACKET OIL COOLER ASSY .  is ::-->
# ['bracket ']
# CLAMP ASSY EGP MTG .  is ::-->
# ['clamp ']
# DRUM BRAKE ASSY WITH DC FRONT-LH .  is ::-->
# ['drum  brake']
# PARABOLIC LEAF SPRING ASSY FRONT .  is ::-->
# ['parabolic leaf spring']
# U-BOLT .  is ::-->
# ['u bolt']
# U-BOLT .  is ::-->
# ['u bolt']
# PIPE ASSY WITH CRIMPED HOSE .  is ::-->
# ['pipe assy ']
# BRACKET ASSY EGP MTG .  is ::-->
# ['bracket ']
# REVERSE GUIDING SENSOR SYSTEM .  is ::-->
# ['sensor ']
# REVERSE PARK ASSISTANCE SENSOR .  is ::-->
# ['sensor ']
# Z-BRACKET CONNECTOR MTG .  is ::-->
# ['bracket ']
# DRUM BRAKE ASSY WITH DC FRONT-RH .  is ::-->
# ['drum  brake']
# LONG MEMBER REAR-RH .  is ::-->
# ['long member']
# BED PLATE SEMIFINISHED .  is ::-->
# ['bed plate']
# RAW PART CRANKSHAFT (INDUCTION HARDE .  is ::-->
# ['crank shaft']
# GEAR SHIFT ASSY WITH CABLE ASSY .  is ::-->
# ['gear ']
# COUNTER SHAFT ASSY .  is ::-->
# ['counter shaft']
# SEMIFINISHED CRANKCASE EDGE .  is ::-->
# ['crankcase ']
# VACUUM PUMP ASSY .  is ::-->
# ['vacuum pump']
# "COVER ASSY WITH BUSH,REAR" .  is ::-->
# ['cover ']
# ADAPTER PLATE .  is ::-->
# ['adapter plate']
# "ADAPTER PLATE,OIL SUMP" .  is ::-->
# ['adapter plate']
# DRIVE SHAFT - NA .  is ::-->
# ['drive shaft']
# "GEAR,1ST SPEED" .  is ::-->
# ['gear ']
# "REV GEAR/SHIFTER SLEEVE,1ST/2ND SPEE" .  is ::-->
# ['sleeve ']
# "PIPE ASSY,EGR COOLER TO AIR INTAKE E" .  is ::-->
# ['pipe assy ']
# CONNECTING ROD ASSY WITH BUSH .  is ::-->
# ['connecting rod']
# FRAME ASSY .  is ::-->
# ['frame assy ']
# "SHELL ASSY,LOAD BODY" .  is ::-->
# ['load body ']
# "WIRING HARNESS,CHASSIS" .  is ::-->
# ['wiring harness ']
# "TUBELESS TYRE,FRONT" .  is ::-->
# ['tubeless tyre']
# GRANIT_BLACK-DRIVER SEAT ASSY .  is ::-->
# ['driver seat']
# "SIDE WALL ASSY,OUTER-FRONT-RH" .  is ::-->
# ['side wall']
# GRANIT_BLACK-CO-DRIVER SEAT ASSY .  is ::-->
# ['co-driver seat']
# FRONT WALL ASSY .  is ::-->
# ['front wall']
# PROPELLER SHAFT ASSY .  is ::-->
# ['propeller shaft']
# FUEL TANK ASSY .  is ::-->
# ['fuel tank']
# "LEAF SPRING ASSY,REAR" .  is ::-->
# ['leaf spring ']
# "SET-CLUTCH ASSY,DIA 190" .  is ::-->
# ['clutch ']
# REAR MOUNT ASSY .  is ::-->
# ['a mount']
# "HEADLAMP ASSY WITH LEVEL MOTOR,RH" .  is ::-->
# ['head lamp']
# FLOOR CARPET .  is ::-->
# ['carpet ']
# "INNER PANEL ASSY,FRT DOOR-RH,STAGE I" .  is ::-->
# ['panel ']
# ANTI ROLL BAR ASSY WITH LINK .  is ::-->
# ['anti roll bar ']
# "FLOOR,MIDDLE" .  is ::-->
# ['floor ']
# WHEEL RIM ASSY .  is ::-->
# ['wiring harness ']
# FUEL FILTER ASSY .  is ::-->
# ['fuel filter']
# SNORKEL ASSY .  is ::-->
# ['snorkel ']
# "BRACKET ASSY,CLUTCH & BRAKE PEDAL MT" .  is ::-->
# ['bracket ']
# "OUTER PANEL,FRONT DOOR,LH" .  is ::-->
# ['panel ']
# "CLRPRT_ASY_1-DOOR TRIM ASSY,FRT DR M" .  is ::-->
# ['door trim']
# CROSS MEMBER ASSY .  is ::-->
# ['cross member']
# "SIDE WALL,LH" .  is ::-->
# ['side wall']
# "SHOCK ABSORBER ASSY,REAR" .  is ::-->
# ['shock absorber ']
# ROOF .  is ::-->
# ['roof ']
# "ACCESS COVER,ENGINE" .  is ::-->
# ['cover ']
# "B-PILLAR ASSY,INNER-RH" .  is ::-->
# ['a pillar']
# STARTER CABLE .  is ::-->
# ['cable ']
# "HOSE,IC OUTLET TO PIPE" .  is ::-->
# ['hose ']
# "INSULATION,LOAD BODY COVER" .  is ::-->
# ['insulation ']
# "WHEEL ARCH ASSY,OUTER-RH" .  is ::-->
# ['wiring harness ']
# "COVER ASSY,FRONT WHEEL ARCH,LH" .  is ::-->
# ['cover ']
# "ACCESS COVER,RADIATOR" .  is ::-->
# ['cover ']
# BRACKET ASSY .  is ::-->
# ['bracket ']
# BRACKET .  is ::-->
# ['bracket ']
# OUTRIGGER ASSY FRONT-LH .  is ::-->
# ['outrigger ']
# OUTRIGGER ASSY .  is ::-->
# ['outrigger ']
# OUTRIGGER ASSY MIDDLE DOOR .  is ::-->
# ['door ']
# OUTRIGGER ASSY FRONT-LH .  is ::-->
# ['outrigger ']
# OUTRIGGER ASSY FRONT-RH .  is ::-->
# ['outrigger ']
# LONG MEMBER HUMP REAR-RH .  is ::-->
# ['long member']
# LONG MEMBER LH .  is ::-->
# ['long member']
# LONG MEMBER REAR-LH .  is ::-->
# ['long member']
# SUPPORT PLATE LH .  is ::-->
# ['plate ']
# GUSSET ASSY .  is ::-->
# ['gusset ']
# CROSS MEMBER ASSY .  is ::-->
# ['cross member']
# PACKING PLATE .  is ::-->
# ['packing plate']
# CROSS MEMBER REAR(REAR SUSPENSION) .  is ::-->
# ['cross member']
# END CROSS MEMBER .  is ::-->
# ['cross member']
# SUSPENSION SUPPORT ASSY WHEEL ARC LH .  is ::-->
# ['wiring harness ']
# BRACKET AIR BELLOW MTG FRONT-LH .  is ::-->
# ['bracket ']
# WHEEL ARCH MTG ASSY .  is ::-->
# ['wiring harness ']
# SUSPENSION SUPPORT ASSY WHEEL ARC LH .  is ::-->
# ['wiring harness ']
# BRACKET ASSY BODY MTG LH .  is ::-->
# ['bracket ']
# BRACKET ASSY AC COMPRESSOR MTG .  is ::-->
# ['bracket ']
# BRACKET ASSY ANTI ROLL BAR MTG FRONT .  is ::-->
# ['bracket ']
# SHOCK ABSORBER ASSY FRONT .  is ::-->
# ['shock absorber ']
# BOLT M20X1.5X130-10.9 .  is ::-->
# ['bolt ']
# LEVER ASSY .  is ::-->
# ['lever ']
# BRACKET CENTER BRG MTG .  is ::-->
# ['bracket ']
# BRACKET CENTER BRG MTG .  is ::-->
# ['bracket ']
# PROPELLER SHAFT ASSY COUPLING .  is ::-->
# ['propeller shaft']
# PROPELLER SHAFT ASSY DRIVE .  is ::-->
# ['propeller shaft']
# PROPELLER SHAFT ASSY COUPLING .  is ::-->
# ['propeller shaft']
# PROPELLER SHAFT ASSY DRIVE .  is ::-->
# ['propeller shaft']
# PIPE ASSY .  is ::-->
# ['pipe assy ']
# HOSE ASSY WITH O-RING NIPPLE .  is ::-->
# ['hose ']
# BRACKET ASSY .  is ::-->
# ['bracket ']
# STEERING GEAR BOX ASSY .  is ::-->
# ['steering gearbox']
# PRESSURE LINE ASSY .  is ::-->
# ['hose ']
# RETURN LINE ASSY .  is ::-->
# ['return hose']
# PITMAN ARM .  is ::-->
# ['pitman arm']
# DRAG LINK ASSY .  is ::-->
# ['drag link ']
# BRACKET ASSY RADIATOR MTG TOP-RH .  is ::-->
# ['bracket ']
# PLATE RADIATOR MTG BRACKET .  is ::-->
# ['bracket ']
# VENT TUBE AUX WATER TANK TO ENGINE .  is ::-->
# ['hose ']
# L-BRACKET .  is ::-->
# ['bracket ']
# BRACKET .  is ::-->
# ['bracket ']
# BRACKET .  is ::-->
# ['bracket ']
# FILLER PIPE RADIATOR .  is ::-->
# ['pipe ']
# PLATE FASCIA SWITCH MTG .  is ::-->
# ['plate ']
# WIRING HARNESS TAIL .  is ::-->
# ['wiring harness ']
# WIRING HARNESS PANEL .  is ::-->
# ['wiring harness ']
# WIRING HARNESS ESC .  is ::-->
# ['wiring harness ']
# OUTRIGGER ASSY COWL MTG .  is ::-->
# ['outrigger ']
# DRIVER STATION ASSY W/O PAINTED .  is ::-->
# ['driver station ']
# BRACKET .  is ::-->
# ['bracket ']
# BRACKET .  is ::-->
# ['bracket ']
# WIRING HARNESS PANEL .  is ::-->
# ['wiring harness ']
# BRACKET - Z TYPE (CABLE SHIFT) .  is ::-->
# ['bracket ']
# BRACKET ASSY AIR FILTER MTG .  is ::-->
# ['bracket ']
# BRACKETENG MTGREAR-RH .  is ::-->
# ['bracket ']
# BRACKET .  is ::-->
# ['bracket ']
# ALLOY PIANO JETBLACK + BRIGHT CROME T LOGO (M/S JAI HIND AUTO PVT LTD) .  is ::-->
# ['logo ']
# BRACKET .  is ::-->
# ['bracket ']
# GASKET .  is ::-->
# ['gasket ']
# BRACKET ASSY FUEL TANK MTG .  is ::-->
# ['bracket ']
# RUBBER PACKING .  is ::-->
# ['rubber packing']
# FUEL PIPE ASSY TANK TO FILTER .  is ::-->
# ['pipe assy ']
# PIPE ASSY WITH COUPLING NUT & FERRULE .  is ::-->
# ['pipe assy ']
# BRACKET (DAUBLE Z SHAPE) .  is ::-->
# ['bracket ']
# BRACKET FRONT GRILL MTG RH .  is ::-->
# ['bracket ']
# PROPELLER SHAFT ASSY COUPLING .  is ::-->
# ['propeller shaft']
# RADIATOR & INTERCOOLER ASSY .  is ::-->
# ['radiator ']
# CLAMP ASSY EGP MTG .  is ::-->
# ['clamp ']
# FRONT SPRING ASSY .  is ::-->
# ['o ring']
# GEAR SHIFTER ASSY (MAXICAB BUS) .  is ::-->
# ['gear shifter ']
# DUAL BRAKE VALVE .  is ::-->
# ['brake valve']
# Load Body with Mountings .  is ::-->
# ['load body ']
# WIRING HARNESS ENGINE .  is ::-->
# ['engine wiring harness']
# SUPPORT BRACKET .  is ::-->
# ['bracket ']
# SUPPORT BRACKET (570614113719) .  is ::-->
# ['bracket ']
# BRACKET POWER STEERING PUMP MTG .  is ::-->
# ['bracket ']
# "SWITCH, HILL ASSIST 24V" .  is ::-->
# ['switch ']
# GEAR SHIFT LEVER ASSY WITH TURNING TUBE .  is ::-->
# ['gear shift lever']
# LONG MEMBER LH .  is ::-->
# ['long member']
# BRACKET ASSY RADIATOR MTG RH .  is ::-->
# ['bracket ']
# BRACKET ASSY LONG MEMBER .  is ::-->
# ['bracket ']
# SUPPORT ASSY ENGINE CROSS MEMBER LH .  is ::-->
# ['cross member']
# BRACKET ASSY CROSS MEMBER MTG LH .  is ::-->
# ['bracket ']
# BRACKET CENTER BRG MTG .  is ::-->
# ['bracket ']
# PROPELLER SHAFT ASSY COUPLING .  is ::-->
# ['propeller shaft']
# PIPE BUNCH ASSY .  is ::-->
# ['nylon bunch']
# EXHAUST PIPE ASSY INT .  is ::-->
# ['exhaust pipe']
# BRACKET ASSY .  is ::-->
# ['bracket ']
# BRACKET .  is ::-->
# ['bracket ']
# TUBE .  is ::-->
# ['tube ']
# HOSE Old Part Number - 570601175833 .  is ::-->
# ['hose ']
# HOSE - Old Part number - 570601175835 .  is ::-->
# ['hose ']
# BRACKET .  is ::-->
# ['bracket ']
# "DRUM BRAKE ASSEMBLY WITH DC, FRLH" .  is ::-->
# ['drum  brake']
# "DRUM BRAKE ASSEMBLY WITH DC, RRRH" .  is ::-->
# ['drum  brake']
# BRACKET WITH SPACER .  is ::-->
# ['bracket ']
# SUPPORT BKT (AIR COMP PIPE SUPPORT) .  is ::-->
# ['bracket ']
# BOLT M14X1.5X45 - 10.9 .  is ::-->
# ['bolt ']
# SWITCH DUMMY KNOB .  is ::-->
# ['switch ']
# MOUNTING PIN .  is ::-->
# ['pin ']
# BOLT M16X1.5X80 - 10.9 .  is ::-->
# ['bolt ']
# BOLT M20X1.5X70 - 10.9 .  is ::-->
# ['bolt ']
# NUT M20X1.5 - 10 ISO12126 .  is ::-->
# ['nut ']
# BRACKET ASSY APDA MTG .  is ::-->
# ['bracket ']
# HARNESS BKT TRANSMISSION .  is ::-->
# ['bracket ']
# LONG MEMBER REAR MODULE RH .  is ::-->
# ['long member']
# BOXING PLATE ASSY RH .  is ::-->
# ['plate ']
# SUPPORT PLATE RH .  is ::-->
# ['plate ']
# BOXING PLATE ASSY LH .  is ::-->
# ['plate ']
# SUPPORT PLATE LH .  is ::-->
# ['plate ']
# SUPPORT BRACKET ASSY ENGINE SIDE RH .  is ::-->
# ['bracket ']
# BASE PLATE .  is ::-->
# ['plate ']
# HEAT SHIELD ASSY .  is ::-->
# ['heat shield']
# OUTRIGGER ASSY .  is ::-->
# ['outrigger ']
# OUTRIGGER ASSY .  is ::-->
# ['outrigger ']
# BRAKE DRUM FRONT .  is ::-->
# ['brake drum ']
# "WIRING HARNESS,AEBS FRAME (45WB) G401162" .  is ::-->
# ['wiring harness ']
# "WIRING HARNESS, MAIN " .  is ::-->
# ['wiring harness ']
# "DRUM BRAKE ASSEMBLY WITH DC, FR LH (140mm)" .  is ::-->
# ['drum  brake']
# "DRUM BRAKE ASSY WITH DC,REAR-LH - TL70 (120mm)" .  is ::-->
# ['drum  brake']
# "DRUM BRAKE ASSY WITH DC,FRONT-LH - TL70 (120mm)" .  is ::-->
# ['drum  brake']
# BRACKET (Nylon pipe routing) .  is ::-->
# ['bracket ']
# TAIL PIPE (36WB) .  is ::-->
# ['tail pipe']
# "ASSY ANTI ROLL BAR,FRONT" .  is ::-->
# ['anti roll bar ']
# ANTI ROLL BAR ASSY WITH LINK .  is ::-->
# ['anti roll bar ']
# WIRING HARNESS TAIL .  is ::-->
# ['wiring harness ']
# CABLE ASSY STARTER MOTOR -VE .  is ::-->
# ['cable ']
# HOSE THERMOSTAT TO RADIATOR .  is ::-->
# ['hose ']
# ECU .  is ::-->
# ['ecu ']
# BRACKET .  is ::-->
# ['bracket ']
# PIPE ASSY .  is ::-->
# ['pipe assy ']
# BRACKET STG GEAR BOX MTG .  is ::-->
# ['bracket ']
# BALATA PACKING .  is ::-->
# ['balata ']
# COBRA BRACKET ASSY .  is ::-->
# ['bracket ']
# BRACKET ASSY FRONT SPRING HANGER REAR .  is ::-->
# ['bracket ']
# BRACKET SPRING HANGER FRONT-FRONT .  is ::-->
# ['bracket ']
# TUBELESS TYRE .  is ::-->
# ['tubeless tyre']
# CLUTCH HOSE ASSY .  is ::-->
# ['clutch hose']
# VALVE EXTENSION .  is ::-->
# ['valve ']
# LAMP STOP/TAIL - 12V .  is ::-->
# ['tail lamp']
# CLUTCH RELEASE YOKE .  is ::-->
# ['yoke ']
# RUBBER BUFFER FRONT AXLE .  is ::-->
# ['rubber buffer']
# BUMP STOPPER .  is ::-->
# ['stopper ']
# THREADED PIN .  is ::-->
# ['threaded pin']
# PIPE .  is ::-->
# ['pipe ']
# VENT HOSETHERMOSTAT TO RADIATOR .  is ::-->
# ['hose ']
# HOSETHERMOSTAT TO PIPE CONNECTOR .  is ::-->
# ['hose ']
# INSTRUMENT CLUSTER ASSY .  is ::-->
# ['instrument cluster']
# "INSULATION,HEADLINER,FRONT" .  is ::-->
# ['insulation ']
# "INSULATION,FRONT DOOR,LH" .  is ::-->
# ['insulation ']
# "INSULATION,REAR DOOR,LH" .  is ::-->
# ['insulation ']
# "INSULATION,HEADLINER,REAR - Sunroof" .  is ::-->
# ['insulation ']
# "INSULATION,FLOOR,REAR" .  is ::-->
# ['insulation ']
# FIREWALL INSULATION .  is ::-->
# ['insulation ']
# ASTRUCTURAL FOAM PAD .  is ::-->
# ['structural foam']
# ASTRUCTURAL FOAM PAD .  is ::-->
# ['structural foam']
# UREA PIPE ASSY Supply Pressure Line nylon (Old Part - 264249200129) .  is ::-->
# ['urea hose']
# CRPANHDSCREWM3X16IS7483SS8451-8C .  is ::-->
# ['screw ']
# L BRACKET(PSTG PIPE LINE) .  is ::-->
# ['bracket ']
# HEX FL BOLT M10X60 TS17130-8.8-SS8451-8C .  is ::-->
# ['bolt ']
# HEX FL BOLT M12X50TS17130 10.9SS8451-8CH .  is ::-->
# ['bolt ']
# HEXFLBOLTM6X25TS17130-8.8-SS8451S2-B (Old -11073596019) .  is ::-->
# ['bolt ']
# H/FL SCREW M5X18 TS17130-8.8-SS8451S2-Y (Old - 11343505185) .  is ::-->
# ['screw ']
# BATTERY LINK .  is ::-->
# ['battery ']
# NOX SENSOR (LPO -NAC) .  is ::-->
# ['nox sensor']
# Hose .  is ::-->
# ['hose ']
# Hose .  is ::-->
# ['hose ']
# Hose .  is ::-->
# ['hose ']
# Tube .  is ::-->
# ['tube ']
# Hose LP NAC .  is ::-->
# ['lp hose']
# Hose LP NAC .  is ::-->
# ['lp hose']
# Hose LP NAC .  is ::-->
# ['lp hose']
# Tube LP NAC .  is ::-->
# ['tube ']
# UREA PIPE ASSY 550749200197 .  is ::-->
# ['pipe assy ']
# REAR AXLE BEAM ASSY .  is ::-->
# ['rear axle beam']
# TAIL PIPE .  is ::-->
# ['tail pipe']
# HEX SCREW M10X70 IS1364P2-8.8-SS8451-8C .  is ::-->
# ['screw ']
# ASSY DIAGNOSTIC CONNECTOR PARKING BKT .  is ::-->
# ['bracket ']
# CR PAN HD SCREW M5X16 IS7483 SS8451S2-Y .  is ::-->
# ['screw ']
# RUBBER HOSE .  is ::-->
# ['rubber hose']
# Regeneration Inhibit Switch .  is ::-->
# ['switch ']
# HEX FLANGE BOLT .  is ::-->
# ['bolt ']
# BRACKET ASSY CROSS MEMBER MTG FRONT-LH .  is ::-->
# ['bracket ']
# BRACKET GB INLINE CONNECTOR MTG .  is ::-->
# ['bracket ']
# Urea Pipe Assy .  is ::-->
# ['pipe assy ']
# "Pipe Assy, urea return" .  is ::-->
# ['pipe assy ']
# Urea Pipe Assy .  is ::-->
# ['pipe assy ']
# GASKET .  is ::-->
# ['gasket ']
# BRACKET ASSY .  is ::-->
# ['bracket ']
# SUPPORT BRACKET .  is ::-->
# ['bracket ']
# Heat Shield .  is ::-->
# ['heat shield']
# Fuel injector .  is ::-->
# ['fuel injector']
# Fuel Filter .  is ::-->
# ['fuel filter']
# Air filter snorkel 1st piece .  is ::-->
# ['snorkel ']
# Air intake elbow .  is ::-->
# ['elbow ']
# Alternator .  is ::-->
# ['alternator ']
# Crank angle sensor .  is ::-->
# ['sensor ']
# Oil pressure sensor .  is ::-->
# ['pressure sensor']
# Oil pump driven gear .  is ::-->
# ['gear ']
# Oil filter .  is ::-->
# ['oil filter']
# Oil pump and oil filter housing .  is ::-->
# ['oil filter']
# Water pump housing .  is ::-->
# ['water pump']
# Engine A mount .  is ::-->
# ['engine mount']
# Engine B mount .  is ::-->
# ['engine mount']
# Engine C mount .  is ::-->
# ['engine mount']
# Clutch plate .  is ::-->
# ['plate ']
# Clutch release bearing .  is ::-->
# ['bearing ']
# Brake and Clutch pedal mounting bracket .  is ::-->
# ['bracket ']
# Clutch pedal .  is ::-->
# ['clutch pedal']
# Clutch cable holding bracket on gear box .  is ::-->
# ['bracket ']
# Front suspension .  is ::-->
# ['front suspension']
# Front suspension lower link (RH) .  is ::-->
# ['front suspension']
# Rear suspension .  is ::-->
# ['rear suspension']
# Rear coil spring LH and RH .  is ::-->
# ['oil ring']
# Front Brake Caliper Assy .  is ::-->
# ['brake caliper']
# Brake pipe from master cylinder primary port to T joint .  is ::-->
# ['brake pipe']
# Brake pipe from T connector to rear RH wheel flexible hose .  is ::-->
# ['wiring harness ']
# Rear brake drum RH .  is ::-->
# ['brake drum ']
# Rear anchor plate RH .  is ::-->
# ['plate ']
# Parking brake cable from parking brake lever to equalizer .  is ::-->
# ['brake cable']
# Master cylinder assembly .  is ::-->
# ['cylinder ']
# Steering column assembly .  is ::-->
# ['steering column']
# Fuel tank .  is ::-->
# ['fuel tank']
# Fuel pump with float unit .  is ::-->
# ['fuel pump']
# Exhaust silencer .  is ::-->
# ['silencer ']
# Battery mounting clamp bottom/top .  is ::-->
# ['clamp ']
# Tail lamp LH .  is ::-->
# ['tail lamp']
# Horn (single or LH) .  is ::-->
# ['horn ']
# Instrument cluster .  is ::-->
# ['instrument cluster']
# Battery positive cable .  is ::-->
# ['battery cable']
# Dashboard wiring harness .  is ::-->
# ['wiring harness ']
# Windscreen glass .  is ::-->
# ['glass ']
# Rear glass .  is ::-->
# ['glass ']
# Steering nacelle upper .  is ::-->
# ['nacelle ']
# Glove box .  is ::-->
# ['glove box']
# Cross car beam .  is ::-->
# ['cross car beam']
# Roof liner /Head liner .  is ::-->
# ['roof liner']
# Load body I .  is ::-->
# ['load body ']
# Front door upper hinge RH .  is ::-->
# ['door ']
# Front door window glass .  is ::-->
# ['glass ']
# Front door glass channel seal .  is ::-->
# ['seal ']
# Front door seal on body shell RH .  is ::-->
# ['seal ']
# ORVM RH .  is ::-->
# ['orvm ']
# Wiper blade (I) .  is ::-->
# ['wiper blade ']
# Windscreen washer sprinkler motor .  is ::-->
# ['washer ']
# Front upper grill .  is ::-->
# ['grill ']
# Front LH wheel arch mud liner .  is ::-->
# ['front wiring harness']
# Front RH seat assembly .  is ::-->
# ['front seat']
# Front RH seat belt with ELR unit assembly .  is ::-->
# ['seat belt']
# Frame Assy.  is ::-->
# ['frame assy ']
# WASHER 10.5 .  is ::-->
# ['washer ']
# ASSY.BRACKET (HOSE MTG.ON REAR AXLE) .  is ::-->
# ['bracket ']
# PIPE AIR INTAKE .  is ::-->
# ['air intake pipe']
# PIPE INTERCOOLER TO TURBOCHARGER .  is ::-->
# ['pipe ']
# PIPE INTERCOOLER TO INTAKE MANIFOLD .  is ::-->
# ['intake pipe']
# "PIPE,TC TO IC" .  is ::-->
# ['pipe ']
# PIPE INTERCOOLER TO TURBOCHARGER .  is ::-->
# ['pipe ']
# Anti Roll Bar .  is ::-->
# ['anti roll bar ']
# Assy leaf spring .  is ::-->
# ['leaf spring ']
# Assy leaf spring .  is ::-->
# ['leaf spring ']
# SUCTION LINE ASSY .  is ::-->
# ['suction hose']
# RETURN LINE ASSY .  is ::-->
# ['return hose']
# "DRUM BRAKE ASSEMBLY WITH DC, RR LH (140mm)" .  is ::-->
# ['drum  brake']
# BRACKET ASSY RESERVOIR HOLDING .  is ::-->
# ['bracket ']
# "BRACKET,EXHAUST PIPE MTG" .  is ::-->
# ['bracket ']
# "BRACKET ASSY,TAIL PIPE MTG" .  is ::-->
# ['bracket ']
# GEAR SHIFTER ASSY WITH CABLE (M/s Kongsberg) .  is ::-->
# ['gear shifter ']
# WHEEL RIM ASSY WITH VALVE (205 PCD) .  is ::-->
# ['wiring harness ']
# "PIPE ASSY,JOINT TO JOINT (29WB)" .  is ::-->
# ['pipe assy ']
# Holder Parking Sensor .  is ::-->
# ['parking sensor']
# "PLATE,SPARE WHEEL MTG" .  is ::-->
# ['plate ']
# CLAMP PIPE .  is ::-->
# ['clamp ']
# BRACKET(FOR 1ST CENTRE BEARING M/S DANA) .  is ::-->
# ['bracket ']
# Metal pipe assy .  is ::-->
# ['metal pipe']
# PIPE ASSY AIR DRYER TO PURGE TANK .  is ::-->
# ['pipe assy ']
# LONG MEMBER LH .  is ::-->
# ['long member']
# Load body II .  is ::-->
# ['load body ']
# BRACKET ASSY .  is ::-->
# ['bracket ']
# PIPE RADIATOR TO RETARDER .  is ::-->
# ['pipe ']
# PIPE RETARDER TO ENGINE .  is ::-->
# ['pipe ']
# HOSE HUMP TURBOCHARGER ADAPTER TO PIPE .  is ::-->
# ['hose ']
# "LEAF SPRING ASSY,FRONT-LH" .  is ::-->
# ['leaf spring ']
# Spray Suppression 580*800 .  is ::-->
# ['spray suppression']
# Front bump stopper bracket (LH and RH) .  is ::-->
# ['bracket ']
# Spare wheel rim .  is ::-->
# ['wiring harness ']
# Dashboard skin .  is ::-->
# ['dashboard skin ']
# ORVM RH .  is ::-->
# ['orvm ']
# Group No 91_Front Seat (Driver Seat) .  is ::-->
# ['front seat']
# FUEL PIPE ASSY TANK TO FILTER .  is ::-->
# ['pipe assy ']
# "Wiring Harness, ABS" .  is ::-->
# ['wiring harness ']
# "Wiring Harness, ABS" .  is ::-->
# ['wiring harness ']
# Vent hose (RADIATOR TO AUX.  is ::-->
# ['hose ']
# "PIPE ASSY,ENGINE TO AUX WATER TANK" .  is ::-->
# ['pipe assy ']
# SUPPORT BRACKET ASSY .  is ::-->
# ['bracket ']
# SUPPORT BRACKET ASSY .  is ::-->
# ['bracket ']
# Assy Intercooler pipe .  is ::-->
# ['pipe ']
# RADIATOR & INTERCOOLER ASSY .  is ::-->
# ['radiator ']
# BRACKET ASSY ENGINE MTG FRONT-LH .  is ::-->
# ['bracket ']
# WHEEL RIM ASSY WITH VALVE .  is ::-->
# ['wiring harness ']
# BELT AC COMPRESSOR .  is ::-->
# ['belt ']
# CROSS SHAFT ASSY WITH LEVER .  is ::-->
# ['shaft ']
# BRACKET .  is ::-->
# ['bracket ']
# BRACKET (CLUTCH BOOSTER MOUNTING) .  is ::-->
# ['bracket ']
# MODULATOR VALVE ABS (12V) .  is ::-->
# ['modulator valve']
# BRACKET MAXI FUSE & MIDI FUSE MTG.  is ::-->
# ['bracket ']
# HEAD LAMP LEVELLING SWITCH FOR 12V-M/S.MINDARIKA .  is ::-->
# ['switch ']
# HEAD LAMP LEVELLING SWITCH FOR 24V-M/S.MINDARIKA .  is ::-->
# ['switch ']
# BKT.  is ::-->
# ['bracket ']
# LIFTING HOOK-FRONT .  is ::-->
# ['lifting hook']
# D.A.TANK (DIA28.6)(BANCO) .  is ::-->
# ['tank ']
# COOLENT HOSE FOR CNG REGULATOR - 1000 MM .  is ::-->
# ['hose ']
# LEAF SPRING ASSY FRONT - 552932101604 .  is ::-->
# ['leaf spring ']
# BRACKET ASSY SHOCK ABSORBER MTG FRONT .  is ::-->
# ['bracket ']
# BRACKET ANTI ROLL BAR MTG .  is ::-->
# ['bracket ']
# BRACKET SPRING HANGER REAR-FRONT .  is ::-->
# ['bracket ']
# LEAF SPRING ASSY REAR - 552932401604 .  is ::-->
# ['leaf spring ']
# BUMP STOPPER ASSY .  is ::-->
# ['stopper ']
# ANTI ROLL BAR ASSY .  is ::-->
# ['anti roll bar ']
# FRONT PIPE ASSY .  is ::-->
# ['pipe assy ']
# BRKT AMBIENT SENSOR MTG .  is ::-->
# ['sensor ']
# "HEATER HOSE ASSY,ENGINE TO HVAC" .  is ::-->
# ['heater hose']
# "BRACKET ASSY,HEATER HOSE MTG" .  is ::-->
# ['bracket ']
# Assy Adaptor with tube .  is ::-->
# ['pto ']
# "BRACKET ASSY,BATTERY CUT OFF SWITCH MTG" .  is ::-->
# ['bracket ']
# "BATTERY CABLE +VE,EBCS TO MEGA FUSE" .  is ::-->
# ['battery cable']
# SPRING CLIP .  is ::-->
# ['clip ']
# LONG MEMBER ASSY FRONT-RH .  is ::-->
# ['long member']
# LONG MEMBER ASSY MIDDLE-LH .  is ::-->
# ['long member']
# LONG MEMBER ASSY FRONT-LH .  is ::-->
# ['long member']
# BRACKET ASSY VACUUM PIPE CLAMPING .  is ::-->
# ['bracket ']
# CROSS MEMBER ASSY FRONT .  is ::-->
# ['cross member']
# BATTERY TRAY ASSY .  is ::-->
# ['battery tray']
# BUMP STOPPER ASSY FRONT .  is ::-->
# ['stopper ']
# ANTI ROLL BAR ASSY WITH LINK .  is ::-->
# ['anti roll bar ']
# GUIDE PLATE ASSY REAR-LH .  is ::-->
# ['guide plate']
# FRONT AXLE ASSY .  is ::-->
# ['front axle']
# PROPELLER SHAFT ASSY .  is ::-->
# ['propeller shaft']
# TUBE ASSY ADAPTER TO REAR BRAKE HOSE LH .  is ::-->
# ['brake hose']
# TUBE ASSY T-CONN TO ADAPTER .  is ::-->
# ['adapter ']
# VACUUM PIPE ENGINE END .  is ::-->
# ['pipe ']
# PARKING BRAKE CABLE ASSY REAR-RH .  is ::-->
# ['brake cable']
# BRACKET ASSY CLAMP MTG .  is ::-->
# ['bracket ']
# LP HOSE ASSY FILTER TO ENGINE .  is ::-->
# ['lp hose']
# BATTERY CABLE +VE .  is ::-->
# ['battery cable']
# BRACKET WIRING HARNESS MTG .  is ::-->
# ['bracket ']
# FRONT FLOOR ASSY .  is ::-->
# ['front floor']
# WHEEL ARCH ASSY INNER-LH .  is ::-->
# ['wiring harness ']
# LINER REAR WALL .  is ::-->
# ['rear wall']
# KIT-LOCK SET ASSY .  is ::-->
# ['lock ']
# BELLOW ASSY WITH BOOT RING .  is ::-->
# ['bellow ']
# CLUTCH CABLE ASSY .  is ::-->
# ['clutch cable']
# LEAF SPRING ASSY FRONT .  is ::-->
# ['leaf spring ']
# GUIDE PLATE ASSY .  is ::-->
# ['guide plate']
# LEAF SPRING ASSY REAR .  is ::-->
# ['leaf spring ']
# FRONT AXLE ASSY .  is ::-->
# ['front axle']
# TUBE ASSY SPARE WHEEL CARRIER .  is ::-->
# ['wiring harness ']
# PROPELLER SHAFT ASSY .  is ::-->
# ['propeller shaft']
# "BRACKET ASSY,PARKING BRAKE LEVER" .  is ::-->
# ['bracket ']
# "PARKING CABLE ASSY REAR, LH" .  is ::-->
# ['cable ']
# BOOSTER ASSY-OFFER DRG .  is ::-->
# ['booster ']
# TUBE ASSY REAR HOSE TO BRAKE ASSY LH .  is ::-->
# ['brake hose']
# TUBE ASSY TMC SECONDARY TO T-CONN .  is ::-->
# ['tube assy ']
# RUBBER BELLOW STG COLUMN .  is ::-->
# ['rubber bellow']
# STEERING GEAR BOX ASSY WITH PITMAN ARM .  is ::-->
# ['steering gearbox']
# "WIRING HARNESS ASSY,ENGINE" .  is ::-->
# ['wiring harness ']
# RELAY COVER .  is ::-->
# ['cover ']
# "WIRING HARNESS,CABIN" .  is ::-->
# ['wiring harness ']
# CLAMP JACK HANDLE .  is ::-->
# ['clamp ']
# CROSS MEMBER ASSY REAR .  is ::-->
# ['cross member']
# REAR FLOOR ASSY RH .  is ::-->
# ['rear floor']
# B-PILLAR ASSY INNER-LH .  is ::-->
# ['a pillar']
# REAR WALL ASSY .  is ::-->
# ['rear wall']
# CARPET RADIATOR ACCESS COVER .  is ::-->
# ['cover ']
# "CARPET, FLOOR, RH" .  is ::-->
# ['carpet ']
# DASHBOARD ASSY WITH HVAC .  is ::-->
# ['dashboard ']
# LINER REAR WALL .  is ::-->
# ['rear wall']
# KIT-LOCK SET ASSY .  is ::-->
# ['lock ']
# WIPER ARM ASSY WITH BLADE DRIVER SIDE .  is ::-->
# ['wiper arm ']
# WIPER LINK ASSY WITH MOTOR .  is ::-->
# ['wiper link ']
# "KIT-SEAT BELT WITH ELR & LAP BELT, FRONT" .  is ::-->
# ['seat belt']
# OIL FILTER .  is ::-->
# ['oil filter']
# ASSY TUBE DIPSTICK .  is ::-->
# ['dipstick ']
# SPARE WHEEL CARRIER ASSY .  is ::-->
# ['wiring harness ']
# "METAL PIPE ASSY,INT JOINT TO INT JOINT" .  is ::-->
# ['metal pipe']
# "HEAT SHIELD ASSY,EXHAUST SYSTEM" .  is ::-->
# ['heat shield']
# ASSY WIPER SYSTEM 24V NRW LHD .  is ::-->
# ['wiper system']
# ASSY WIPER ARM BLADE CO DRIVER NRW LHD .  is ::-->
# ['wiper arm ']
# CO-DRIVER SEAT ASSY (Twin Head Rest) .  is ::-->
# ['co-driver seat']
# POWER STEERING GEAR BOX ASSY .  is ::-->
# ['power steering gearbox']
# PITMAN ARM .  is ::-->
# ['pitman arm']
# WIRING HARNESS ABS FRAME .  is ::-->
# ['wiring harness ']
# Z-BRACKET .  is ::-->
# ['bracket ']
# ENGAGING GEAR 5TH/REVERSE SPEED .  is ::-->
# ['gear ']
# FRONT SPRING ASSY .  is ::-->
# ['o ring']
# SUPD ASSY LH .  is ::-->
# ['supd ']
# SUPD ASSY .  is ::-->
# ['supd ']
# "PROPELLER SHAFT ASSY,REAR" .  is ::-->
# ['propeller shaft']
# FRAME ASSY WITH TOP COAT .  is ::-->
# ['frame assy ']
# "LONG MEMBER,LH" .  is ::-->
# ['long member']
# "WIRING HARNESS,ABS FRAME" .  is ::-->
# ['wiring harness ']
# "SUPD ASSY,LH" .  is ::-->
# ['supd ']
# "WIRING HARNESS,REAR CHASSIS" .  is ::-->
# ['wiring harness ']
# METAL PIPE WITH CRIMPED HOSE .  is ::-->
# ['metal pipe']
# MONOTRON PROPELLER SHAFT ASSY .  is ::-->
# ['propeller shaft']
# Assy.Cyl.Crankcase (CYL BLOCK) .  is ::-->
# ['crankcase ']
# Cam shaft gear (Exhaust) .  is ::-->
# ['cam shaft']
# Chassis wiring harness .  is ::-->
# ['wiring harness ']
# Engine wiring harness (On engine) .  is ::-->
# ['engine wiring harness']
# Flywheel .  is ::-->
# ['wiring harness ']
# Gear shifter and selector cable holding bracket on gear box .  is ::-->
# ['bracket ']
# Head lamp LH .  is ::-->
# ['head lamp']
# Intake valve .  is ::-->
# ['intake valve ']
# Leaf spring rear shackle bush LH and RH .  is ::-->
# ['bush ']
# Leaf spring U bolt lower mounting plate (LH and RH) .  is ::-->
# ['mounting bolt']
# Registration plate lamp RH .  is ::-->
# ['plate ']
# Tail lamp LH .  is ::-->
# ['tail lamp']
# "HOSE,HEATER,OUTLET-HVAC TO CYL HEAD" .  is ::-->
# ['hose ']
# HEATER HOSE-HVAC TO BYPASS TUBE (INLET) .  is ::-->
# ['heater hose']
# SUPPORT BRACKET- HEATER HOSES .  is ::-->
# ['bracket ']
# SUPD HAT SECTION .  is ::-->
# ['supd ']
# HINGE PIN .  is ::-->
# ['hinge ']
# SUPD ASSY LH .  is ::-->
# ['supd ']
# U-BOLT .  is ::-->
# ['u bolt']
# PLATE FLEXIBLE MTG .  is ::-->
# ['plate ']
# SERVICE BRAKE ASSY ABS .  is ::-->
# ['brake ']
# PARKING BRAKE LEVER ASSY COMPLETE (200) .  is ::-->
# ['parking brake lever']
# HEATER HOSE ASSY .  is ::-->
# ['heater hose']
# FASCIA SWITCH .  is ::-->
# ['fascia switch']
# LONG MEMBER ASSY REAR-LH .  is ::-->
# ['long member']
# REAR FLOOR REAR .  is ::-->
# ['rear floor']
# FRONT STRUT ASSY LH-OFFER DRG .  is ::-->
# ['front strut']
# ASSY TOP ROD VERTICAL MEMBER .  is ::-->
# ['vertical member']
# ANTI ROLL BAR FRONT SUSPENSION .  is ::-->
# ['anti roll bar ']
# BUSH ANTI ROLL BAR .  is ::-->
# ['bush ']
# SHOCK ABSORBER ASSY REAR .  is ::-->
# ['shock absorber ']
# CARPET ASSY REAR WHEEL ARCH RH .  is ::-->
# ['wiring harness ']
# CARPET REAR WHEEL ARCH LH .  is ::-->
# ['wiring harness ']
# INSULATION FIREWALL .  is ::-->
# ['insulation ']
# ASSY SPACER[FOR EMER RECEPTACLE MTG] .  is ::-->
# ['spacer ']
# MALE CONNECTOR 1/4 NPT (M/S SWAGELOK) .  is ::-->
# ['connector ']
# ASSY RECEPTACLE CAP (M/S MINDA) .  is ::-->
# ['cap ']
# HP TUBE ASSY .  is ::-->
# ['hp tube ']
# VENTILATION HOSE (M/S.MINDA) .  is ::-->
# ['ventilation hose']
# ASSY CYLINDER +CYL VALVE(MOON) .  is ::-->
# ['cylinder ']
# VENTILATION HOSE (M/S.MINDA) .  is ::-->
# ['ventilation hose']
# HP TUBE ASSY .  is ::-->
# ['hp tube ']
# SLEEVE (FOR CNG PIPE) .  is ::-->
# ['sleeve ']
# HP TUBE ASSY .  is ::-->
# ['hp tube ']
# MALE CONNECTOR 1/4 NPT (M/S SWAGELOK) .  is ::-->
# ['connector ']
# LP HOSE ASSY HP REGULATOR TO LP FILTER .  is ::-->
# ['lp hose']
# CYLINDER CRANKCASE ASSY WITH LINER .  is ::-->
# ['cylinder ']
# VALVE SEAT INTAKE .  is ::-->
# ['valve seat ']
# VALVE SEAT INTAKE TC .  is ::-->
# ['valve seat ']
# VALVE SEAT EXHAUST .  is ::-->
# ['valve seat ']
# VALVE SEAT INSERT NORMAL-I(EXHAUST) TC .  is ::-->
# ['valve seat ']
# INTAKE VALVE TC .  is ::-->
# ['intake valve ']
# EXHAUST VALVE .  is ::-->
# ['exhaust valve']
# FUEL RAIL ASSY .  is ::-->
# ['fuel rail']
# ROTATIONAL SPEED SENSOR .  is ::-->
# ['speed sensor']
# PRESSURE/TEMPERATURE SENSOR .  is ::-->
# ['pressure sensor']
# "DECAL,REAR QUARTER,LOWER,LH" .  is ::-->
# ['decal ']
# "DECAL,REAR QUARTER,UPPER,LH" .  is ::-->
# ['decal ']
# CNG tank .  is ::-->
# ['tank ']
# CNG tank arrester strap upper LH .  is ::-->
# ['tank ']
# CNG tank arrester strap lower LH .  is ::-->
# ['tank ']
# Delivery pipe from CNG tank to intermediate adaptor .  is ::-->
# ['pipe ']
# Delivery pipe from intermediate adaptor to solenoid switch .  is ::-->
# ['pipe ']
# Pressure regulator valve .  is ::-->
# ['valve ']
# Solenoid switch .  is ::-->
# ['switch ']
# CNG RECEPTACLE .  is ::-->
# ['receptacle ']
# "FUEL RETURN PIPE ASSY,ENG TO FUEL" .  is ::-->
# ['return hose']
# "STICKER,MAXI FUSE BOX" .  is ::-->
# ['sticker ']
# Bracket assy .  is ::-->
# ['bracket ']
# PIPE UNION BOLT FLANGE TYPE .  is ::-->
# ['u bolt']
# SPACER .  is ::-->
# ['spacer ']
# SCREW (FOR A/C COMP TENSIONER) .  is ::-->
# ['screw ']
# PISTON ASSY .  is ::-->
# ['piston ']
# PISTON .  is ::-->
# ['piston ']
# AUX HOSE .  is ::-->
# ['hose ']
# RUBBER HOSE INTERCOOLER TO PIPE .  is ::-->
# ['rubber hose']
# INTERNAL CIRCLIP- 3.19 THK.  is ::-->
# ['clip ']
# INTERNAL CIRCLIP- 3.29 THK.  is ::-->
# ['clip ']
# CIRCLIP DRIVE SHAFT (2.5 THK) .  is ::-->
# ['clip ']
# EXTERNAL CIRCLIP(ENG.  is ::-->
# ['clip ']
# EXTERNAL CIRCLIP(ENG.  is ::-->
# ['clip ']
# CIRCLIP(2.46 THK) .  is ::-->
# ['clip ']
# CIRCLIP(2.62 THK) .  is ::-->
# ['clip ']
# MAGNETIC DRAIN PLUG .  is ::-->
# ['drain plug ']
# MAGNETIC DRAIN PLUG .  is ::-->
# ['drain plug ']
# BRACKET ASSY REAR LEAF SPRING .  is ::-->
# ['bracket ']
# WASHER .  is ::-->
# ['washer ']
# BRACKET ASSY ANTI ROLL BAR MTG REAR-RH .  is ::-->
# ['bracket ']
# REAR SPRING SEAT TOP .  is ::-->
# ['rear seat']
# HUB PIN FRONT .  is ::-->
# ['pin ']
# BRACKET BUNDY TUBE MTG .  is ::-->
# ['bracket ']
# SPACER RING TAIL PINION 8.90 THK.  is ::-->
# ['spacer ring']
# SPACER RING TAIL PINION 8.95 THK.  is ::-->
# ['spacer ring']
# SPACER RING TAIL PINION 9.42 THICK .  is ::-->
# ['spacer ring']
# SPACER RING TAIL PINION 9.36 THICK .  is ::-->
# ['spacer ring']
# SPACER RING TAIL PINION 9.26 THICK .  is ::-->
# ['spacer ring']
# SPACER RING TAIL PINION 9.30THICK .  is ::-->
# ['spacer ring']
# SPACER RING TAIL PINION 9.14 THICK .  is ::-->
# ['spacer ring']
# SPACER RING TAIL PINION 9.48 THK.  is ::-->
# ['spacer ring']
# SPACER RING TAIL PINION 9.46 THK.  is ::-->
# ['spacer ring']
# SPACER RING TAIL PINION 9.40 THICK .  is ::-->
# ['spacer ring']
# SPACER RING TAIL PINION 9.56 THK.  is ::-->
# ['spacer ring']
# SPACER RING TAIL PINION 9.34 THICK .  is ::-->
# ['spacer ring']
# SPACER RING TAIL PINION 9.00 THK.  is ::-->
# ['spacer ring']
# SPACER RING TAIL PINION 9.10 THICK .  is ::-->
# ['spacer ring']
# SPACER RING TAIL PINION 9.28THICK .  is ::-->
# ['spacer ring']
# SPACER RING TAIL PINION 9.16 THICK .  is ::-->
# ['spacer ring']
# SHIM (0.05 THK) .  is ::-->
# ['shim ']
# DUST COVER .  is ::-->
# ['cover ']
# BRACKET-RH FOR MTG.ABS CABLE ON LCRV BKT.-RA .  is ::-->
# ['bracket ']
# EYE BOLT .  is ::-->
# ['bolt ']
# ABS SENSOR WITH CABLE & CONNECTOR .  is ::-->
# ['sensor ']
# BRACKET ASSY EGP MTG MIDDLE .  is ::-->
# ['bracket ']
# L-BRACKET EXHAUST PIPE MTG .  is ::-->
# ['bracket ']
# SPACER UREA TANK MTG BKT .  is ::-->
# ['bracket ']
# BASE PLATE RADIATOR MTG BRACKET LH .  is ::-->
# ['bracket ']
# NEUTRAL SWITCH ASSY .  is ::-->
# ['switch ']
# HEXAGONAL KEY 8 .  is ::-->
# ['key ']
# FRONT STRUT ASSY WITH ABS RH .  is ::-->
# ['front strut']
# SPRING REAR SUSPENSION .  is ::-->
# ['rear suspension']
# COIL SPRING FRONT SUSPENSION .  is ::-->
# ['oil ring']
# "DRUM BRAKE ASSY,REAR-RH" .  is ::-->
# ['drum  brake']
# TELEMATICS ECU .  is ::-->
# ['ecu ']
# "CABLE,PDU TO HV BATTERY" .  is ::-->
# ['cable ']
# "CABLE,HV GND TRACTION MOTOR TO CHASSIS GND" .  is ::-->
# ['cable ']
# "CABLE,HV GND OBC TO CHASSIS GND" .  is ::-->
# ['cable ']
# "CABLE,HV GND BATTERY TO CHASSIS GND" .  is ::-->
# ['cable ']
# "W/H, FRONT LIMBER XZ+" .  is ::-->
# ['wiring harness ']
# "WIRING HARNESS,BATTERY CABLE XZ+, XM, XM(O)" .  is ::-->
# ['wiring harness ']
# "W/H, COCKPIT LIMBER XZ+" .  is ::-->
# ['wiring harness ']
# "W/H, FLOOR RH LIMBER XZ+" .  is ::-->
# ['wiring harness ']
# "W/H, FLOOR LH LIMBER XZ+" .  is ::-->
# ['wiring harness ']
# "W/H, EV-LV LIMBER XZ+, XM, XM(O)" .  is ::-->
# ['wiring harness ']
# "CROSS MEMBER ASSY,REAR FLOOR,MIDDLE" .  is ::-->
# ['cross member']
# "LONG MEMBER EXTENSION,FRONT-RH" .  is ::-->
# ['long member']
# "FRAME ASSY,FRONT FLOOR" .  is ::-->
# ['frame assy ']
# "COVER,BATTERY" .  is ::-->
# ['cover ']
# "WHEEL ARCH ASSY,OUTER-LH" .  is ::-->
# ['wiring harness ']
# A-MOUNT ASSY .  is ::-->
# ['a mount']
# RADIATOR SEALING ASSY RH .  is ::-->
# ['seal ']
# CONDENSER ASSY .  is ::-->
# ['condenser ']
# DRIVE SHAFT ASSY RH .  is ::-->
# ['drive shaft']
# HOSES AND CLAMP ASSEMBLY .  is ::-->
# ['clamp ']
# SUCTION PIPE COMPRESSOR END .  is ::-->
# ['suction hose']
# LIQUID TUBE ASSY HVAC INTAKE .  is ::-->
# ['tube assy ']
# SUCTION PIPE HVAC END .  is ::-->
# ['suction hose']
# HVAC UNIT ASSY XM and XM - O .  is ::-->
# ['hvac ']
# ASSY PASSENGER COMPARTMENT CARPET .  is ::-->
# ['carpet ']
# HOSE BKT .  is ::-->
# ['bracket ']
# BRACKET .  is ::-->
# ['bracket ']
# BRACKET ASSY .  is ::-->
# ['bracket ']
# TRUNKLID GARNISH ASSY BASE Without Camera Cutout XM and XM (O) .  is ::-->
# ['garnish ']
# AERO UNDER TRAY CENTER REAR .  is ::-->
# ['tray ']
# FRONT BUMPER ASSY XM and XM(O) .  is ::-->
# ['front bumper']
# COVER UNDER HOOD .  is ::-->
# ['cover ']
# SPINDLE BRAKE DRUM .  is ::-->
# ['spindle ']
# Structure_BEZEL SWITCH MTG .  is ::-->
# ['switch ']
# ALLOY WHEEL RIM .  is ::-->
# ['wiring harness ']
# HOSE ASSY .  is ::-->
# ['hose ']
# HOSE ASSY .  is ::-->
# ['hose ']
# SEALING FEM BOTTOM .  is ::-->
# ['seal ']
# RADIATOR SEALING LH .  is ::-->
# ['seal ']
# HOSE PIPE .  is ::-->
# ['hose ']
# 1.2 XETA ECU MTG BKT .  is ::-->
# ['bracket ']
# AUX WATER TANK ASSY WITH PRESSURE CAP .  is ::-->
# ['aux tank']
# TRAILING ARM RH .  is ::-->
# ['trailing arm']
# BRACKET ASSY AUX TANK MTG .  is ::-->
# ['bracket ']
# TUBE ASSY hose to rear Wc RH .  is ::-->
# ['hose ']
# VACUUM HOSE ASSLY - V pump end .  is ::-->
# ['vacuum hose']
# "CALIPER ASSY,FRONT-RH" .  is ::-->
# ['caliper ']
# "Front seat assy RH, 4W, J2 structure (XZ+)" .  is ::-->
# ['front seat']
# "Front seat assy RH, 4W, J2 structure (XM/XM(O)" .  is ::-->
# ['front seat']
# "Rear seat assy, Armrest with 2 Cup holder, 100% Fixed (XZ+)" .  is ::-->
# ['rear seat']
# "REAR WHEEL ARCH,FRONT-LH" .  is ::-->
# ['wiring harness ']
# ScuffP lateTrimAssyTrunklid .  is ::-->
# ['trim ']
# Exhaust Valve Seat Insert .  is ::-->
# ['valve seat ']
# Intake Valve seat insert .  is ::-->
# ['valve seat ']
# CARPET ASSY LUGGAGE COMPARTMENT .  is ::-->
# ['carpet ']
# CARPET ASSY REAR WHEEL ARCH LH .  is ::-->
# ['wiring harness ']
# INSULATION FIREWALL .  is ::-->
# ['insulation ']
# "DRUM BRAKE ASSY,REAR-LH" .  is ::-->
# ['drum  brake']
# W/H ENGINE TIAGO & TIGOR CNG ALL .  is ::-->
# ['engine wiring harness']
# W/H FRONT TIAGO CNG XT .  is ::-->
# ['front wiring harness']
# W/H FRONT TIGOR CNG XM COMMERCIAL .  is ::-->
# ['front wiring harness']
# W/H COCKPIT TIAGO CNG XZ .  is ::-->
# ['cockpit wiring harness']
# W/H COCKPIT TIGOR CNG XZ .  is ::-->
# ['cockpit wiring harness']
# W/H COCKPIT TIGOR CNG XE COMMERCIAL .  is ::-->
# ['cockpit wiring harness']
# "W/H FLOOR LH TIGOR CNG XZ, CNG XM COMMERCIAL" .  is ::-->
# ['floor wiring harness']
# CYLINDER HEAD ASSY.  is ::-->
# ['cylinder head']
# CLRPRT_ASY_3-ASSY HORN PAD AIRBAG STEERI .  is ::-->
# ['horn pad']
# CLRPRT_ASY_1-DRIVER AIRBAG ASSY .  is ::-->
# ['airbag ']
# CLRPRT_ASY_1-HORN PAD ASSY WITH DAB MODU .  is ::-->
# ['horn pad']
# LP Hose Assy ( Regulator to LP filter) .  is ::-->
# ['lp hose']
# HP tube Assy (Receptacle to T-connector) .  is ::-->
# ['hp tube ']
# HP tube assy (T-connector to U/B joint) .  is ::-->
# ['hp tube ']
# HP tube Assy (T-connector to cylinder) .  is ::-->
# ['hp tube ']
# HP Tube assy (U/B joint to Firewall Joint) .  is ::-->
# ['hp tube ']
# HP tube assy (T-connector to Regulator) .  is ::-->
# ['hp tube ']
# "LONG MEMBER ASSY,REAR-RH" .  is ::-->
# ['long member']
# "LONG MEMBER ASSY,REAR-RH" .  is ::-->
# ['long member']
# Injector .  is ::-->
# ['injector ']
# Intake Valve .  is ::-->
# ['intake valve ']
# PT Sensor .  is ::-->
# ['sensor ']
# Thrust washer .  is ::-->
# ['thrust washer']
# Front LH leaf spring .  is ::-->
# ['leaf spring ']
# Rear RH damper .  is ::-->
# ['rear damper']
# Leaf spring assembly LH .  is ::-->
# ['leaf spring ']
# Leaf spring U bolt upper guide plate with bump stopper (LH and RH) .  is ::-->
# ['u bolt']
# BRACKET ASSY WITH RIB .  is ::-->
# ['bracket ']
# HOSE .  is ::-->
# ['hose ']
# WIRING HARNESS MAIN .  is ::-->
# ['main wiring harness']
# FES Assembly in white .  is ::-->
# ['wiring harness ']
# MAIN WIRING HARNESS .  is ::-->
# ['main wiring harness']
# WIRING HARNESS REAR DOORS LH .  is ::-->
# ['door wiring harness']
# WIRING HARNESS FRONT DOORS LH .  is ::-->
# ['door wiring harness']
# "WIRING HARNESS,BATTERY +VE CABLE" .  is ::-->
# ['wiring harness ']
# "WIRING HARNESS,ENGINE TO BIW EARTH BRAID" .  is ::-->
# ['wiring harness ']
# WH TAILGATE LOWER PETROL & DIESEL XE/XM/XT .  is ::-->
# ['wiring harness ']
# "WIRING HARNESS,FRONT" .  is ::-->
# ['wiring harness ']
# "TUBE ASSY, CROSS MEMBER" .  is ::-->
# ['tube assy ']
# TAB WASHER B 28 IS 8068 .  is ::-->
# ['washer ']
# "BRACKET,AC COMPRESSOR MTG" .  is ::-->
# ['bracket ']
# "CLUTCH DISC ASSY,DIA 330" .  is ::-->
# ['clutch disc']
# "CLUTCH COVER ASSY,DIA 330" .  is ::-->
# ['clutch cover']
# "CLUTCH COVER ASSY,DIA 330" .  is ::-->
# ['clutch cover']
# IGNITION SWITCH ASSY WITH ILLU RING .  is ::-->
# ['ignition switch']
# SWITCH HEADLAMP LEVELLING .  is ::-->
# ['switch ']
# SWITCH HEAVY MODE .  is ::-->
# ['switch ']
# SPARE WHEEL CARRIER ASSY .  is ::-->
# ['wiring harness ']
# SWITCH HEAVY MODE .  is ::-->
# ['switch ']
# PIPE TURBOCHARGER TO INTERCOOLER .  is ::-->
# ['pipe ']
# AIR INTAKE PIPE ASSY AIR COMP .  is ::-->
# ['air intake pipe']
# WIRING HARNESS PIGTAIL NEUTRAL SWITCH .  is ::-->
# ['pigtail wiring harness']
# FLYWHEEL ASSY WITH RING GEAR & PIN .  is ::-->
# ['wiring harness ']
# BRACKET TURBOCHARGER MTG .  is ::-->
# ['bracket ']
# BRACKET CATCON MTG .  is ::-->
# ['bracket ']
# STARTER MOTOR ASSY .  is ::-->
# ['starter motor']
# OIL RETURN LINE ASSY .  is ::-->
# ['return hose']
# CONTAINER ECU ASSY .  is ::-->
# ['ecu ']
# RIBBED HOSE ASSY HFM TO TC .  is ::-->
# ['ribbed hose']
# BRACKET C-MOUNT .  is ::-->
# ['bracket ']
# CLUTCH HOUSING .  is ::-->
# ['clutch ']
# PIN (GEARBOX HOUSING JOINT) .  is ::-->
# ['pin ']
# SHIFTER SHAFT ASSY 3RD/4TH SPEED .  is ::-->
# ['shifter shaft']
# COVER ASSY FRONT .  is ::-->
# ['cover ']
# LOCK PLATE .  is ::-->
# ['plate ']
# SHIFTER LEVER ASSY .  is ::-->
# ['lever ']
# SHIFTING FINGER .  is ::-->
# ['finger ']
# LEVER ASSY SELECTION .  is ::-->
# ['lever ']
# CAPTIVE DETENT (SHIFTER) INA .  is ::-->
# ['cap ']
# SELECTOR SHIFTER SHAFT ASSY .  is ::-->
# ['shifter shaft']
# COVER ASSY REAR .  is ::-->
# ['cover ']
# VEHICLE SPEED SENSOR .  is ::-->
# ['speed sensor']
# VACUUM BOOSTER ASSY .  is ::-->
# ['vacuum booster']
# SUPPORT BRACKET CCB .  is ::-->
# ['bracket ']
# BRACKET ASSY CLUTCH PEDAL MTG .  is ::-->
# ['bracket ']
# CLUTCH MASTER CYLINDER WITH HOSE .  is ::-->
# ['clutch master cylinder']
# SHACKLE ASSY .  is ::-->
# ['shackle ']
# U-BOLT FRONT SPRING .  is ::-->
# ['u bolt']
# LEAF SPRING ASSY REAR .  is ::-->
# ['leaf spring ']
# U-CLAMP REAR .  is ::-->
# ['clamp ']
# FRONT AXLE ASSY .  is ::-->
# ['front axle']
# HEX NUT (TAIL PINION COUPLING FLANGE) .  is ::-->
# ['nut ']
# CALIPER ASSY FRONT RH .  is ::-->
# ['caliper ']
# REAR AXLE ASSY WITH BRAKE .  is ::-->
# ['rear axle assy']
# WHEEL RIM ASSY-OFFER DRG .  is ::-->
# ['wiring harness ']
# PROPELLER SHAFT ASSY .  is ::-->
# ['propeller shaft']
# DRUM BRAKE ASSY REAR-LH .  is ::-->
# ['drum  brake']
# VACUUM PIPE ASSY .  is ::-->
# ['pipe assy ']
# PARKING BRAKE CABLE ASSY FRONT .  is ::-->
# ['brake cable']
# PARKING BRAKE CABLE ASSY REAR-RH .  is ::-->
# ['brake cable']
# TUBE ASSY T-CONN TO BRAKE HOSE FRT-RH .  is ::-->
# ['brake hose']
# TUBE ASSY T-CONN TO LCRV .  is ::-->
# ['tube assy ']
# TUBE ASSY REAR HOSE TO BRAKE ASSY RH .  is ::-->
# ['brake hose']
# TUBE ASSY TMC PRIMARY TO T-CONN .  is ::-->
# ['tube assy ']
# TUBE ASSY TMC SECONDARY TO T-CONN .  is ::-->
# ['tube assy ']
# BRACKET ASSY BRAKE PIPE MTG .  is ::-->
# ['bracket ']
# BRACKET - BRAKE PIPE CLAMPING .  is ::-->
# ['bracket ']
# STEERING COLUMN ASSY EPAS .  is ::-->
# ['steering column']
# PIPE ASSY UCL TO RADIATOR .  is ::-->
# ['pipe assy ']
# RUBBER HOSE AUX TANK TO WATER PUMP .  is ::-->
# ['rubber hose']
# PIPE ASSY THERMOSTAT TO EGR COOLER .  is ::-->
# ['egr pipe']
# HOSE EGR COOLER OUTLET .  is ::-->
# ['hose ']
# HOSE OIL COOLER OUTLET .  is ::-->
# ['hose ']
# BRACKET EGR COOLER PIPE MTG .  is ::-->
# ['bracket ']
# WIRING HARNESS CABIN .  is ::-->
# ['cabin wiring harness']
# BEZEL .  is ::-->
# ['bezel ']
# MUDGUARD .  is ::-->
# ['mud guard']
# SUCTION PIPE ASSY REAR CAB .  is ::-->
# ['suction hose']
# SPLASH GUARD ASSY WHEEL ARCH FRONT-RH .  is ::-->
# ['front wiring harness']
# FOOT STEP ASSY RH .  is ::-->
# ['foot step']
# "Bracket assy, blow by pipe" .  is ::-->
# ['bracket ']
# "Bracket Assy, Spring Hanger, Front-Rear" .  is ::-->
# ['bracket ']
# FUEL PIPE ASSY TANK TO FILTER .  is ::-->
# ['pipe assy ']
# FUEL RETURN PIPE ASSY .  is ::-->
# ['return hose']
# Combination Switch .  is ::-->
# ['combi switch']
# Fuel Level Sensor .  is ::-->
# ['fuel sensor']
# GASKET .  is ::-->
# ['gasket ']
# "SPOILER,CABIN ROOF,RH" .  is ::-->
# ['spoiler ']
# "RUBBER PAD,SPOILER,MIDDLE" .  is ::-->
# ['rubber pad']
# "OUTER BELT ASSY,FRONT DOOR,LH" .  is ::-->
# ['belt ']
# "OUTER BELT ASSY,FRONT DOOR,RH" .  is ::-->
# ['belt ']
# LATCH FLAP ASSY CENTER-RH .  is ::-->
# ['latch ']
# FUEL TANK MTG .  is ::-->
# ['fuel tank']
# "BRACKET,JUMPER CABLE MTG" .  is ::-->
# ['bracket ']
# ASSY TOP COVER .  is ::-->
# ['cover ']
# "PROPELLER SHAFT ASSY,COUPLING" .  is ::-->
# ['propeller shaft']
# "BRACKET,SPRING HANGER,REAR" .  is ::-->
# ['bracket ']
# GUSSET REAR (LONG MEMBER) .  is ::-->
# ['gusset ']
# ASSY OUTRIGGER CHASSIS SIDE WELDED LH .  is ::-->
# ['outrigger ']
# "TOE PANEL ASSY,RH" .  is ::-->
# ['toe panel']
# MOULDED ROOF LINING .  is ::-->
# ['roof liner']
# "BRACKET ASSY,ORVM MTG" .  is ::-->
# ['bracket ']
# "MOUNTING BRACKET ASSY,REAR" .  is ::-->
# ['bracket ']
# "MOUNTING BRACKET ASSY,FRONT" .  is ::-->
# ['bracket ']
# "MOUNTING BRACKET ASSY,REAR-RH" .  is ::-->
# ['bracket ']
# CLUTCH RELEASE BEARING ASSY .  is ::-->
# ['bearing ']
# "AXLE BEAM ASSY,REAR-RWD" .  is ::-->
# ['axle beam']
# REAR AXLE BEAM ASSY .  is ::-->
# ['rear axle beam']
# CROWN WHEEL .  is ::-->
# ['wiring harness ']
# SPINDLE AXLE BEAM .  is ::-->
# ['spindle ']
# ASSY TOE PANEL LH RHD .  is ::-->
# ['toe panel']
# SUBFRAME ASSY .  is ::-->
# ['subframe assy ']
# ASSY COMBINATION SWITCH M0 .  is ::-->
# ['combi switch']
# "BRACKET ASSY,AERO CORNER MTG" .  is ::-->
# ['bracket ']
# "BRACKET,B-PILLAR TRIM MTG,RH" .  is ::-->
# ['bracket ']
# "SIDE WALL ASSY,OUTER-LH" .  is ::-->
# ['side wall']
# PANEL_DOOR_APERTURE_LH .  is ::-->
# ['door panel']
# BKT TOP TRIM ROOF SIDE FLAT .  is ::-->
# ['bracket ']
# "CARPET,REAR" .  is ::-->
# ['carpet ']
# "BEZEL ASSY,SWITCH BANK,RH" .  is ::-->
# ['bezel ']
# "HANDLE ASSY WITH LOCK,GLOVE BOX" .  is ::-->
# ['handle ']
# FOAM .  is ::-->
# ['foam ']
# STEERING WHEEL ASSY W/O SWITCH .  is ::-->
# ['wiring harness ']
# "COVER,ECU,BOTTOM" .  is ::-->
# ['cover ']
# "CAP,CONSOLE MID MTG SCREW" .  is ::-->
# ['cap ']
# "COVER,DASHBOARD DRIVER SIDE,LH" .  is ::-->
# ['cover ']
# "CAP,CENTER CONSOLE,LOWER" .  is ::-->
# ['cap ']
# ASSY TRIM A PILLAR RH .  is ::-->
# ['pillar trim']
# ASSY TRIM QUARTER LOWER RH .  is ::-->
# ['quarter trim']
# "DOOR PULL SUPPORT,LH" .  is ::-->
# ['door ']
# "CAP,DOOR TRIM,RH" .  is ::-->
# ['cap ']
# "BRACKET ASSY,SIDE HEADBOX,LOWER-LH" .  is ::-->
# ['bracket ']
# "BRACKET ASSY,HEADBOX MTG,LH" .  is ::-->
# ['bracket ']
# "BRACKET ASSY,HEADBOX MTG,LH" .  is ::-->
# ['bracket ']
# "LOCATING PIN,HEADBOX" .  is ::-->
# ['pin ']
# "HEADLAMP ACCESS COVER,RH" .  is ::-->
# ['lamp cover']
# "FOOT STEP ASSY,FENDER,RH" .  is ::-->
# ['foot step']
# "FOOT STEP ASSY,FENDER,RH" .  is ::-->
# ['foot step']
# "GRILL ASSY,HEADLAMP,RH" .  is ::-->
# ['grill ']
# "CYLINDER ASSY,CAB TILT" .  is ::-->
# ['cylinder ']
# ASSY HEAT SHIELD COMPLETE TURBOCHARGER .  is ::-->
# ['heat shield']
# "PANEL ASSY,BERTH,LOWER-FRONT" .  is ::-->
# ['panel ']
# WASHER .  is ::-->
# ['washer ']
# STAR WASHER .  is ::-->
# ['washer ']
# ...
# Air filter resonator outlet seal .  is ::-->
# ['seal ']
# Turbocharger mounting stud .  is ::-->
# ['turbocharger ']
# Oil pressure control valve solenoid mounting bolt .  is ::-->
# ['mounting bolt']
# Thermostat housing elbow mounting bolt .  is ::-->
# ['mounting bolt']
# Input shaft bearing lock .  is ::-->
# ['bearing ']
# Gear shifter and selector unit mounting bolt .  is ::-->
# ['mounting bolt']
# Clutch slave cylinder cum release bearing mounting bolt .  is ::-->
# ['mounting bolt']
# ABS Unit to bracket mounting bush (1) .  is ::-->
# ['bracket ']
# Master cylinder piston locking seal (1) .  is ::-->
# ['seal ']
# Radiator drain plug .  is ::-->
# ['drain plug ']
# Horn mounting bolt .  is ::-->
# ['mounting bolt']
# Co-driver side passenger air bag mounting nut (I) .  is ::-->
# ['mounting nut ']
# Instrument cluster & Music system cover trim mounting screw .  is ::-->
# ['mounting screw ']
# Front door latch assembly mounting screw 1 .  is ::-->
# ['mounting screw ']
# Rear door window glass winding mechanism mounting nut .  is ::-->
# ['mounting nut ']
# HVAC unit mounting nut .  is ::-->
# ['mounting nut ']
# Rear bumper locating bracket mounting screw RH and RH side .  is ::-->
# ['mounting screw ']
# Front RH seat sliding motor mounting screw .  is ::-->
# ['mounting screw ']
# NYLON PIPE BUNCH ASSY RR AIR SUSPENSION .  is ::-->
# ['nylon bunch']
# Alternator .  is ::-->
# ['alternator ']
# Pressure plate .  is ::-->
# ['plate ']
# Brake pedal foot pad .  is ::-->
# ['brake pedal']
# Rear damper upper bush LH & RH .  is ::-->
# ['bush ']
# Rear LH wheel assembly .  is ::-->
# ['wiring harness ']
# Front brake calliper assembly (LH) .  is ::-->
# ['brake ']
# Brake pipe from ABS unit to front RH wheel (To hose) .  is ::-->
# ['front wiring harness']
# Parking brake cable RH .  is ::-->
# ['brake cable']
# Brake oil reservoir .  is ::-->
# ['brake ']
# Radiator .  is ::-->
# ['radiator ']
# Head lamp LH .  is ::-->
# ['head lamp']
# Combination switch mounting housing .  is ::-->
# ['combi switch']
# Parking brake switch .  is ::-->
# ['switch ']
# Gearbox earthing cable .  is ::-->
# ['cable ']
# Rear wheel speed sensor LH .  is ::-->
# ['wiring harness ']
# Dashboard lower trim RH .  is ::-->
# ['dashboard ']
# 'B' pillar upper trim LH .  is ::-->
# ['pillar trim']
# Rear grab handle (rear RH) .  is ::-->
# ['grab handle']
# Front door weather strip inner RH .  is ::-->
# ['door ']
# Rear door outer opening handle RH .  is ::-->
# ['outer handle']
# Rear door shell hinge upper LH .  is ::-->
# ['door ']
# Rear wiper motor assembly .  is ::-->
# ['wiper motor']
# AC compressor .  is ::-->
# ['ac compressor']
# Front bumper side garnish LH .  is ::-->
# ['garnish ']
# Leaf screen .  is ::-->
# ['leaf screen']
# Front LH seat belt with ELR unit assembly .  is ::-->
# ['seat belt']
# Engine ECU bracket (I) mounting bolt (I) .  is ::-->
# ['bracket ']
# Pressure plate mounting bolt .  is ::-->
# ['mounting bolt']
# Brake pedal pivot bolt .  is ::-->
# ['bolt ']
# Front suspension lower link ball joint assembly mounting nut (LH & RH) .  is ::-->
# ['mounting nut ']
# Valve cap .  is ::-->
# ['cap ']
# Front Brake bleeding nipple RH .  is ::-->
# ['brake ']
# Brake bleeding nipple .  is ::-->
# ['brake ']
# Brake oil reservoir to master cylinder body mounting screw .  is ::-->
# ['mounting screw ']
# Fuel neck and breather pipe mounting bracket .  is ::-->
# ['bracket ']
# Radiator top locating rubber .  is ::-->
# ['radiator ']
# Tail lamp mounting nut (LH and RH) .  is ::-->
# ['mounting nut ']
# Horn mounting bracket rubber bush .  is ::-->
# ['bracket ']
# Drive selector switch mounting screw .  is ::-->
# ['mounting screw ']
# Firewall harness routine clamp 2 .  is ::-->
# ['clamp ']
# Centre console arm rest lower cover mounting spring .  is ::-->
# ['cover ']
# Dashboard LH side wiring harness cover mounting screw .  is ::-->
# ['mounting screw ']
# Front door window glass mounting screw .  is ::-->
# ['mounting screw ']
# Rear door outer opening handle mounting screw seal 1 .  is ::-->
# ['mounting screw ']
# Hatchback/trunk lid inner trim mounting button 1 .  is ::-->
# ['trim ']
# Wiper blade mounting nut .  is ::-->
# ['mounting nut ']
# Rear wiper blade mounting nut cap .  is ::-->
# ['mounting nut ']
# Front bumper upper mounting bolt .  is ::-->
# ['mounting bolt']
# Bonnet stay rod holding clamp .  is ::-->
# ['clamp ']
# Front RH seat belt anchor height adjustment to body mounting bolt .  is ::-->
# ['mounting bolt']
# Rear RH seat belt lower mounting lock washer .  is ::-->
# ['washer ']
# "BRACKET ASSY,PARKING BRAKE CABLE MTG" .  is ::-->
# ['bracket ']
# CLRPRT_ASY_9-REAR BUMPER ASSY WITH R .  is ::-->
# ['rear bumper']
# "CABLE,HV INV TO HV JUNCTION BOX" .  is ::-->
# ['cable ']
# Bracket Tail Gate Mtg .  is ::-->
# ['bracket ']
# BRACKET MEGA FUSE MTG .  is ::-->
# ['bracket ']
# TUBE .  is ::-->
# ['tube ']
# BRACKET TAIL PIPE .  is ::-->
# ['bracket ']
# PRESSURE REDUCTION VALVE .  is ::-->
# ['valve ']
# MUDGUARD FRONT RH .  is ::-->
# ['mud guard']
# GUSSET BOTTOM (CENTER BRG.MTG.)  is ::-->
# ['gusset ']
# SUPD ASSY LH .  is ::-->
# ['supd ']
# RELAY VALVE .  is ::-->
# ['relay valve']
# COOLANT HOSE (OUTLET) .  is ::-->
# ['coolant hose']
# DRUM BRAKE ASSY WITH DC FRONT-RH .  is ::-->
# ['drum  brake']
# DRUM BRAKE ASSY WITH DC REAR-RH .  is ::-->
# ['drum  brake']
# ASSY.CLAMP .  is ::-->
# ['clamp ']
# KIT-LOAD BODY .  is ::-->
# ['load body ']
# DRUM BRAKE ASSY WITH DC REAR-RH .  is ::-->
# ['drum  brake']
# SPEED SENSOR .  is ::-->
# ['speed sensor']
# BRACKET ASSY FENDER MTG REAR-LH .  is ::-->
# ['bracket ']
# WIRING HARNESS PANEL .  is ::-->
# ['wiring harness ']
# PIPE .  is ::-->
# ['pipe ']
# TUBE .  is ::-->
# ['tube ']
# WH FLOOR RH - VAVE .  is ::-->
# ['floor wiring harness']
# "HOSE ASSY,TURBOCHARGER OUTLET" .  is ::-->
# ['hose ']
# "WIRING HARNESS,SENSOR" .  is ::-->
# ['wiring harness ']
# BRACKET CAB MTG LH .  is ::-->
# ['bracket ']
# EXHAUST PIPE ASSY WITH FLEX BELLOW FRONT .  is ::-->
# ['exhaust pipe']
# LONGMEMBER;RH .  is ::-->
# ['long member']
# BUNDY TUBE ASSY LONG MEMBER .  is ::-->
# ['bundy tube']
# FUEL PIPE ASSY .  is ::-->
# ['pipe assy ']
# "OIL SUMP ASSY,LOWER PART" .  is ::-->
# ['oil sump ']
# VENT TUBE ASSY .  is ::-->
# ['hose ']
# GUARD BASE FUEL TANK .  is ::-->
# ['fuel tank']
# LINER;REAR WALL .  is ::-->
# ['liner ']
# LONG MEMBER ASSY;FRONT-LH .  is ::-->
# ['long member']
# "BRACKET,INLINE CONNECTOR MTG" .  is ::-->
# ['bracket ']
# "BRACKET,ALTERNATOR MTG" .  is ::-->
# ['bracket ']
# MASCOT ASSY .  is ::-->
# ['mascot ']
# BRACKET ASSY WITH WELD NUT .  is ::-->
# ['bracket ']
# METAL PIPE JOINT TO DDU .  is ::-->
# ['metal pipe']
# "BRACKET,CENTER BRG MTG" .  is ::-->
# ['bracket ']
# FUEL TANK ASSY .  is ::-->
# ['fuel tank']
# PLATE ASSY .  is ::-->
# ['plate ']
# WIRING HARNESS ABS .  is ::-->
# ['wiring harness ']
# LOAD BODY ASSY .  is ::-->
# ['load body ']
# "BRACKET,CENTER BRG MTG" .  is ::-->
# ['bracket ']
# A-MOUNT ASSY .  is ::-->
# ['a mount']
# "WIRING HARNESS,FRONT" .  is ::-->
# ['wiring harness ']
# DAYTONA_GREY-KIT-OUTER HANDLE;LH .  is ::-->
# ['outer handle']
# BRACKET ASSY AIR FILTER MTG .  is ::-->
# ['bracket ']
# "W/H, FRONT TIAGO MCE PETROL XZ..." .  is ::-->
# ['wiring harness ']
# "W/H, CO DRIVER DOOR TIGOR MCE ..." .  is ::-->
# ['wiring harness ']
# BATTERY SUPPORT ASSY .  is ::-->
# ['battery ']
# MASCOT ASSY .  is ::-->
# ['mascot ']
# KIT-NYLON PIPES .  is ::-->
# ['nylon bunch']
# RUBBER GROMMET .  is ::-->
# ['grommet ']
# Piston oil control ring 2... .  is ::-->
# ['oil ring']
# FUEL SUCTION PIPE ASSY FILTER TO ENGINE .  is ::-->
# ['suction hose']
# REAR AXLE BEAM ASSY .  is ::-->
# ['rear axle beam']
# "BRACKET,CENTER BRG MTG" .  is ::-->
# ['bracket ']
# "WIRING HARNESS,ENGINE" .  is ::-->
# ['wiring harness ']
# Exhaust valve rocker arm lifte... .  is ::-->
# ['exhaust valve']
# HIGH PRESSURE LINE ASSY .  is ::-->
# ['hose ']
# "BRACKET ASSY,BOTTOM NOISE SHIELD" .  is ::-->
# ['bracket ']
# BRACKET .  is ::-->
# ['bracket ']
# Breather hose .  is ::-->
# ['breather hose']
# LOAD BODY WITH MOUNTINGS .  is ::-->
# ['load body ']
# WIRING HARNESS TAIL .  is ::-->
# ['wiring harness ']
# BRACKET ASSY .  is ::-->
# ['bracket ']
# DRUM BRAKE ASSY WITH DC;REAR-RH .  is ::-->
# ['drum  brake']
# AIR PROCESSING UNIT .  is ::-->
# ['air processing unit ']
# WIRING HARNESS;TAIL .  is ::-->
# ['wiring harness ']
# AIR PROCESSING UNIT .  is ::-->
# ['air processing unit ']
# BRACKET ASSY .  is ::-->
# ['bracket ']
# Frame Assy .  is ::-->
# ['frame assy ']
# FUEL SUCTION PIPE ASSY TANK TO W/SEP .  is ::-->
# ['suction hose']
# METAL PIPE ASSY .  is ::-->
# ['metal pipe']
# PIPE ASSY .  is ::-->
# ['pipe assy ']
# "WIRING HARNESS,ABS FRAME" .  is ::-->
# ['wiring harness ']
# LONG MEMBER RH .  is ::-->
# ['long member']
# WIRING HARNESS TAIL .  is ::-->
# ['wiring harness ']
# "PROPELLER SHAFT ASSY,DRIVE" .  is ::-->
# ['propeller shaft']
# "LONG MEMBER,LH" .  is ::-->
# ['long member']
# Accessories belt tensioner uni... .  is ::-->
# ['belt ']
# "BRACKET ASSY,LH" .  is ::-->
# ['bracket ']
# "WIRING HARNESS,ABS FRAME" .  is ::-->
# ['wiring harness ']
# FRAME ASSY .  is ::-->
# ['frame assy ']
# FUEL SUCTION PIPE ASSY .  is ::-->
# ['suction hose']
# FUEL SUCTION PIPE ASSY .  is ::-->
# ['suction hose']
# BUNDY TUBE ASSY LONG MEMBER .  is ::-->
# ['bundy tube']
# "WIRING HARNESS,TAIL" .  is ::-->
# ['wiring harness ']
# FRAME ASSY WITH FITMENT .  is ::-->
# ['frame assy ']
# Tube Assy .  is ::-->
# ['tube assy ']
# EXHAUST PIPE ASSY WITH FLEX BELLOW .  is ::-->
# ['exhaust pipe']
# Clutch release fork locking circlip .  is ::-->
# ['clutch ']
# Front brake hose holding bracket RH .  is ::-->
# ['bracket ']
# Radiator mounting bolt .  is ::-->
# ['mounting bolt']
# Gear box assembly mounting stud .  is ::-->
# ['gearbox ']
# Wheel mounting Nut Front/Rear (LH and RH) .  is ::-->
# ['mounting nut ']
# Jack locator bracket mounting bolt on chassis LH and RH .  is ::-->
# ['mounting bolt']
# CHANNEL SEC SEAL FRT SIDE RR DOOR LH .  is ::-->
# ['seal ']
# BRACKET ASSY FENDER MTG RH .  is ::-->
# ['bracket ']
# hose for battery cooling -- EPDM .  is ::-->
# ['hose ']
# REFLECTIVE TAPE - SUPD LH .  is ::-->
# ['reflective tape']
# Fuel pump mounting washer .  is ::-->
# ['mounting washer ']
# Turbocharger lubricating oil return pipe to ladder frame adoptor washer .  is ::-->
# ['washer ']
# AC compressor bracket (1) to (2) mounting nut (2) .  is ::-->
# ['bracket ']
# Gearbox housing rear & front half mounting nut .  is ::-->
# ['mounting nut ']
# Front damper upper mounting nut LH and RH .  is ::-->
# ['mounting nut ']
# Differential sun gear thrust washer .  is ::-->
# ['thrust washer']
# Parking brake cable mounting bolt on body shell .  is ::-->
# ['mounting bolt']
# Steering gearbox assembly mounting Washer (2) .  is ::-->
# ['mounting washer ']
# Exhaust pre silencer to post silencer mounting bolt .  is ::-->
# ['mounting bolt']
# Headlamp side cover trim mounting bolt (LH and RH) .  is ::-->
# ['mounting bolt']
# Front door check strap to door mounting bolt .  is ::-->
# ['mounting bolt']
# Fresh air duct (LH and RH) mounting nut .  is ::-->
# ['air duct']
# Front fender LH & RH (upper) mounting bolt .  is ::-->
# ['fender ']
# WH EMS SUPPORT BKT 1 .  is ::-->
# ['bracket ']
# Cam shaft (exhaust) .  is ::-->
# ['cam shaft']
# Water pump cover (elbow) .  is ::-->
# ['cover ']
# Rear door outer key lock barrel cover to door shell mounting screw .  is ::-->
# ['mounting screw ']
# Clutch cable holding bracket (I) on gearbox .  is ::-->
# ['bracket ']
# Fuel injector .  is ::-->
# ['fuel injector']
# Piston gudgeon pin .  is ::-->
# ['piston ']
# AMT gearbox ECU bracket mounting bolt .  is ::-->
# ['mounting bolt']
# Water pump pipe mounting bolt (From pump to thermostat) .  is ::-->
# ['mounting bolt']
# Third and fourth gear selector fork .  is ::-->
# ['gear ']
# Dust cover on wheel hub .  is ::-->
# ['cover ']
# Rear anchor plate RH .  is ::-->
# ['plate ']
# Radiator lower hose (At engine) .  is ::-->
# ['hose ']
# Front scuff plate LH .  is ::-->
# ['plate ']
# Front door trim mounting bracket mounting screw .  is ::-->
# ['mounting screw ']
# Hinge mounting bolt on body .  is ::-->
# ['mounting bolt']
# Third and fourth gear shifter sleeve to engaging gear locking detainer (input shaft) .  is ::-->
# ['sleeve ']
# Star gear .  is ::-->
# ['gear ']
# Brake pedal mounting bracket .  is ::-->
# ['bracket ']
# Steering column assembly .  is ::-->
# ['steering column']
# Rear inner Scuff plate RH .  is ::-->
# ['plate ']
# Rear door glass guide channel rear .  is ::-->
# ['glass guide ']
# Rear bumper locating bracket RH .  is ::-->
# ['bracket ']
# Front RH seat recliner motor wiring harness .  is ::-->
# ['front wiring harness']
# Piston connecting rod big end cap mounting bolt .  is ::-->
# ['mounting bolt']
# Intake manifold mounting nut .  is ::-->
# ['mounting nut ']
# Piston cooling nozzle mounting bolt .  is ::-->
# ['mounting bolt']
# Brake pedal pivot bush .  is ::-->
# ['pivot bush']
# Front Brake bleeding nipple cap .  is ::-->
# ['cap ']
# Vacuum hose 4 (from intake manifold T connector to Vacuum pipe 3) mounting clip .  is ::-->
# ['vacuum hose']
# Head lamp LH & RH lower bracket mounting bolt .  is ::-->
# ['mounting bolt']
# Horn ring resting spring (1) .  is ::-->
# ['horn ring']
# Gearbox earthing cable to gearbox mounting bolt .  is ::-->
# ['mounting bolt']
# Front door seal on door RH mounting button .  is ::-->
# ['seal ']
# AC expansion valve mounting bolt (to fire wall) .  is ::-->
# ['mounting bolt']
# Rear RH seat belt ELR unit bracket mounting bolt (2) .  is ::-->
# ['mounting bolt']
# Exhaust lambda sensor (I) .  is ::-->
# ['lambda sensor']
# Gear shift knob .  is ::-->
# ['gear shift knob']
# Rear Wheel hub Assy RH .  is ::-->
# ['wiring harness ']
# Rear anchor plate RH .  is ::-->
# ['plate ']
# Coolant no loss tank .  is ::-->
# ['tank ']
# Boot / luggage compartment lamp .  is ::-->
# ['lamp ']
# Front door wiring harness .  is ::-->
# ['door wiring harness']
# Fire wall insulation (inner side) .  is ::-->
# ['insulation ']
# Front door lower hinge RH .  is ::-->
# ['door ']
# Rear door outer garnish .  is ::-->
# ['garnish ']
# Front bumper upper grill .  is ::-->
# ['front bumper']
# Rear wheel arch mud liner RH (front side) .  is ::-->
# ['wiring harness ']
# Heat shield on catalytic converter front & rear mounting bolt .  is ::-->
# ['mounting bolt']
# Gear shifter lever bracket mounting bolt .  is ::-->
# ['mounting bolt']
# Rear damper lower mounting nut LH and RH .  is ::-->
# ['mounting nut ']
# Rear Brake pipe holding clamp 2 .  is ::-->
# ['clamp ']
# Parking brake cable holding bracket mounting bolt on body .  is ::-->
# ['mounting bolt']
# Fuel float unit access cover mounting screw .  is ::-->
# ['mounting screw ']
# Bonnet switch mounting screw .  is ::-->
# ['mounting screw ']
# Firewall outer insulation plenum area panel nut/button .  is ::-->
# ['nut ']
# Front door hinge to body mounting bolt LH .  is ::-->
# ['mounting bolt']
# Front windscreen washer tank mounting bolt (I) .  is ::-->
# ['mounting bolt']
# Front bumper bottom cover mounting button .  is ::-->
# ['cover ']
# Rear LH seat belt ELR unit mounting bolt .  is ::-->
# ['mounting bolt']
# CLAMP ASSY .  is ::-->
# ['clamp ']
# FLOOR CARPET .  is ::-->
# ['carpet ']
# TURNING TUBE ASSY .  is ::-->
# ['tube assy ']
# DRUM BRAKE ASSY WITH DC REAR-RH .  is ::-->
# ['drum  brake']
# WIRING HARNESS REVERSE PARK ASSIST .  is ::-->
# ['wiring harness ']
# TUBE .  is ::-->
# ['tube ']
# HP PIPE ASSY .  is ::-->
# ['pipe assy ']
# BRACKET ASSY EGP MTG .  is ::-->
# ['bracket ']
# WH .  is ::-->
# ['wiring harness ']
# REAR WALL ASSY .  is ::-->
# ['rear wall']
# SUCTION PIPE ASSY FILTER TO ENGINE .  is ::-->
# ['suction hose']
# INSULATION .  is ::-->
# ['insulation ']
# "HOSE,SOLENOID VALVE TO EGR VALVE" .  is ::-->
# ['hose ']
# "WIRING HARNESS,FRONT" .  is ::-->
# ['wiring harness ']
# "W/H, COCKPIT TIAGO MCE XE" .  is ::-->
# ['wiring harness ']
# PRESSURE LINE SM TO DM .  is ::-->
# ['hose ']
# Connecting rod... .  is ::-->
# ['connecting rod']
# BUNDY TUBE ASSY;LONG MEMBER .  is ::-->
# ['bundy tube']
# BRACKET .  is ::-->
# ['bracket ']
# LOAD BODY WITH MOUNTINGS .  is ::-->
# ['load body ']
# AIR TANK ASSY .  is ::-->
# ['air tank']
# BRACKET .  is ::-->
# ['bracket ']
# DIFFERENTIAL PINION - OFFER .  is ::-->
# ['pinion ']
# SILENCER ASSY WITH HOOKS .  is ::-->
# ['silencer ']
# Frame Assy .  is ::-->
# ['frame assy ']
# PIPE ASSY .  is ::-->
# ['pipe assy ']
# LONG MEMBER LH .  is ::-->
# ['long member']
# SUCTION LINE ASSY .  is ::-->
# ['suction hose']
# "LONG MEMBER,LH" .  is ::-->
# ['long member']
# METAL PIPE ASSY .  is ::-->
# ['metal pipe']
# USB CHARGER .  is ::-->
# ['usb charger']
# FUEL RETURN PIPE ASSY .  is ::-->
# ['return hose']
# CROSS MEMBER ASSY .  is ::-->
# ['cross member']
# FRAME ASSY WITH FITMENT .  is ::-->
# ['frame assy ']
# 3910
# Wall time: 4min 5s

# %%
len(clean_doc)
# Out:
# 3910

# %%
##second loop of search and filtering (fuzzy search)
#fuzzydict = dict((k, v.lower()) for k, v in dictionary.items())
fuzzydict = []
for x in dictionary:
    fuzzydict.append(dictionary[x].lower())

for line in clean_doc:
    
    line1 = line.lower()
    string = line1.partition(",")[0].partition(";")[0].partition("(")[0].partition("[")[0].partition('for')[0].partition('with')[0].partition('w/o')[0].partition('offer')[0].partition('\bw\b')[0]

    closest_match = process.extract(replacer(string).lower(), fuzzydict, scorer=fuzz.token_sort_ratio, limit = 5)
    
    #if(closest_match[1] >= 75):
    print("\n",line, " is ::-->")
    for item in closest_match:
        print(item)
    clean_doc.remove(line)

print(len(clean_doc))
# Out:
#  PLUG (STUB AXLE-TOP) .  is ::-->
# ('hole plug ', 62)
# ('core plug ', 62)
# ('plenum', 60)
# ('drain plug ', 57)
# ('logo', 50)
#
#  RESILIENCE MTG .  is ::-->
# ('silencer', 64)
# ('trailing arm', 54)
# ('tensioner', 52)
# ('mounting screw', 50)
# ('front wiring harness', 47)
#
#  Bezal .  is ::-->
# ('bezel ', 80)
# ('seal ', 67)
# ('belt ', 67)
# ('beam ', 67)
# ('label ', 60)
#
#  Assy.  is ::-->
# ('glass ', 67)
# ('tube assy ', 62)
# ('pipe assy ', 62)
# ('frame assy ', 57)
# ('boss', 50)
#
#  ADJUSTER .  is ::-->
# ('adapter', 67)
# ('outer handle', 60)
# ('auto slack adjuster', 59)
# ('washer ', 57)
# ('rubber pad', 56)
#
#  FRONT MTG ASSY LH .  is ::-->
# ('frame assy ', 59)
# ('front hub', 54)
# ('subframe assy', 53)
# ('front wall', 52)
# ('front seat', 52)
#
#  DC TO DC CONVERTER .  is ::-->
# ('connector ', 52)
# ('counter shaft', 52)
# ('side valance cover', 50)
# ('catalytic converter', 49)
# ('integrated pedal', 47)
#
#  REAR HALF ASSY .  is ::-->
# ('rear axle assy', 86)
# ('frame assy ', 67)
# ('rear axle', 61)
# ('subframe assy', 59)
# ('rear axle beam', 57)
#
#  REINFORCEMENT ASSY .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  REINFORCEMENT ASSY LH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  REINFORCEMENT TOW HOOK MTG .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  HEX.  is ::-->
# ('hose ', 57)
# ('hinge', 50)
# ('washer ', 44)
# ('handle ', 44)
# ('lp hose', 40)
#
#  PACKING .  is ::-->
# ('packing plate', 70)
# ('rubber packing', 67)
# ('parking brake', 60)
# ('pin', 60)
# ('bearing ', 57)
#
#  ENGINE MTG ASSY REAR-LH .  is ::-->
# ('rear axle assy', 59)
# ('suspension tower', 51)
# ('engine mount', 51)
# ('engine wiring harness', 50)
# ('rear axle beam', 49)
#
#  H/FL SCR M6X20-TS17130-10.9-SS8451S2-YH .  is ::-->
# ('oil pressure switch', 28)
# ('floor wiring harness', 27)
# ('fascia switch', 27)
# ('clutch master cylinder', 26)
# ('cross car beam', 26)
#
#  ALUMINIUM FOIL .  is ::-->
# ('exhaust manifold', 53)
# ('air filter', 50)
# ('intake manifold', 48)
# ('anti roll bar ', 44)
# ('tail lamp', 43)
#
#  FL.  is ::-->
# ('floor', 57)
# ('baffle ', 50)
# ('filter ', 50)
# ('flywheel ', 40)
# ('fog lamp', 40)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#  FL.  is ::-->
# ('floor', 57)
# ('baffle ', 50)
# ('filter ', 50)
# ('flywheel ', 40)
# ('fog lamp', 40)
#
#  FL.  is ::-->
# ('floor', 57)
# ('baffle ', 50)
# ('filter ', 50)
# ('flywheel ', 40)
# ('fog lamp', 40)
#
#  FL.  is ::-->
# ('floor', 57)
# ('baffle ', 50)
# ('filter ', 50)
# ('flywheel ', 40)
# ('fog lamp', 40)
#
#  ASSY FOR PARALLEL ROD MGT .  is ::-->
# ('glass ', 67)
# ('tube assy ', 62)
# ('pipe assy ', 62)
# ('frame assy ', 57)
# ('boss', 50)
#
#  REINFORCEMENT FRONT-RH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  EXTENSION PIECE ASSY EXTENSION FRONT-LH .  is ::-->
# ('suspension tower', 44)
# ('front axle beam', 41)
# ('speed sensor', 39)
# ('steering wheel', 38)
# ('sunroof sensor', 38)
#
#  C-REINFORCEMENT RH .  is ::-->
# ('o ring', 67)
# ('coil spring', 59)
# ('oil ring', 57)
# ('engine cover', 56)
# ('screw', 55)
#
#  REINFORCEMENT RH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  ASSY.  is ::-->
# ('glass ', 67)
# ('tube assy ', 62)
# ('pipe assy ', 62)
# ('frame assy ', 57)
# ('boss', 50)
#
#  PACKING .  is ::-->
# ('packing plate', 70)
# ('rubber packing', 67)
# ('parking brake', 60)
# ('pin', 60)
# ('bearing ', 57)
#
#  UREA SOLUTION 32.5% 57-13-6 -YARA ASIA .  is ::-->
# ('water distribution', 37)
# ('rear axle assy', 36)
# ('catalytic converter', 36)
# ('urea sensor', 34)
# ('door secondary seal', 33)
#
#  REINFORCEMENT ASSY FRONT SPRING RH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  TIE ROD ASSY .  is ::-->
# ('tube assy ', 67)
# ('pipe assy ', 67)
# ('frame assy ', 64)
# ('subframe assy', 56)
# ('rear axle assy', 54)
#
#  Front antiroll bar .  is ::-->
# ('anti roll bar ', 71)
# ('front axle beam', 67)
# ('control shaft', 58)
# ('front axle', 57)
# ('front floor', 55)
#
#  Sun visor driver side .  is ::-->
# ('driver station ', 57)
# ('pressure sensor', 56)
# ('driver seat', 56)
# ('sunvisor', 55)
# ('side valance cover', 51)
#
#  I .  is ::-->
# ('rib', 50)
# ('pin', 50)
# ('clip', 40)
# ('shim ', 40)
# ('pipe ', 40)
#
#  II .  is ::-->
# ('pinion', 50)
# ('circlip', 44)
# ('king pin', 40)
# ('oil ring', 40)
# ('rib', 40)
#
#  Mudgaurd .  is ::-->
# ('gear ', 50)
# ('mud guard', 47)
# ('dashboard ', 47)
# ('mounting washer', 43)
# ('damper ', 43)
#
#  Inner rear view mirror .  is ::-->
# ('cylinder valve', 44)
# ('roof liner', 44)
# ('rear axle beam', 44)
# ('rear floor', 44)
# ('air intake pipe', 43)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  ENGINE COOLING SYSTEM ASSY .  is ::-->
# ('air intake system', 60)
# ('engine cover', 47)
# ('engine cradle', 46)
# ('rear axle assy', 45)
# ('air processing unit', 44)
#
#  HOOK .  is ::-->
# ('yoke', 50)
# ('hose ', 50)
# ('logo', 50)
# ('horn', 50)
# ('roof', 50)
#
#  OPERATORS MANUAL & SERVICE BOOK .  is ::-->
# ('modulator valve', 45)
# ('accelerator pedal', 43)
# ('power steering gearbox', 43)
# ('starter motor', 43)
# ('door wiring harness', 42)
#
#  OPERATORS SERVICE BOOK .  is ::-->
# ('power steering gearbox', 50)
# ('breather hose', 46)
# ('steering belt', 46)
# ('starter motor', 46)
# ('side valance cover', 45)
#
#  "ENGINE MTG ARM,LH" .  is ::-->
# ('engine mount', 69)
# ('engine cover', 62)
# ('steering arm', 62)
# ('engine cradle', 59)
# ('engine hood', 56)
#
#  REINFORCEMENT ASSY FIREWALL CTR MTG BKT .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  EGR cooler assembly .  is ::-->
# ('rear axle assy', 61)
# ('catalytic converter', 53)
# ('frame assy ', 48)
# ('oil cooler', 48)
# ('rear floor', 48)
#
#  VAPOUR LINE ASSY .  is ::-->
# ('vapour hose', 67)
# ('rear axle assy', 67)
# ('pipe assy ', 56)
# ('cylinder valve', 53)
# ('power cable', 52)
#
#  DEAD PLUG (M/S SWAGELOK) .  is ::-->
# ('drain plug ', 74)
# ('dead pedal', 74)
# ('hole plug ', 67)
# ('core plug ', 67)
# ('decal ', 57)
#
#  CNG cradle .  is ::-->
# ('con rod', 59)
# ('grab handle', 57)
# ('common rail', 57)
# ('cantrail', 56)
# ('threaded pin', 55)
#
#  REINFORCEMENT ASSY LH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  ENGINE MTG ARM FRONT-RH .  is ::-->
# ('engine mount', 57)
# ('steering arm', 51)
# ('front damper', 51)
# ('engine wiring harness', 50)
# ('front axle', 48)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  FLANGE (DRAIN PLUG) .  is ::-->
# ('flanged nut', 71)
# ('finger', 67)
# ('flanged screw', 63)
# ('plate ', 55)
# ('label ', 55)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  CHILLER UNIT .  is ::-->
# ('fuel filler', 61)
# ('oil filter', 55)
# ('oil cooler', 55)
# ('instrument cluster', 53)
# ('c mount', 53)
#
#  "HOUSING ASSY,FUEL FILLER" .  is ::-->
# ('tube assy ', 57)
# ('pipe assy ', 57)
# ('differential housing', 56)
# ('wiring harness ', 54)
# ('dashboard skin', 54)
#
#  "Tigor EV FATC , ( Hardware no.  is ::-->
# ('reflector', 55)
# ('tailgate latch', 52)
# ('power latch', 50)
# ('suction hose', 48)
# ('radiator fan', 48)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#  ANTI VIBRATION SHEET ASSY UNDERBODY .  is ::-->
# ('after treatment assy', 47)
# ('battery wiring harness', 42)
# ('subframe assy', 42)
# ('anti roll bar ', 42)
# ('main wiring harness', 41)
#
#  FUEL LINES ASSY (ENGINE TO TANK) .  is ::-->
# ('tube assy ', 58)
# ('pipe assy ', 58)
# ('fuel injector', 57)
# ('frame assy ', 56)
# ('rear axle assy', 55)
#
#  PACKING .  is ::-->
# ('packing plate', 70)
# ('rubber packing', 67)
# ('parking brake', 60)
# ('pin', 60)
# ('bearing ', 57)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  REAR HALF .  is ::-->
# ('rear axle', 78)
# ('rear hub', 71)
# ('rear floor', 63)
# ('rear axle beam', 61)
# ('rear axle assy', 61)
#
#  DETENT ASSY (SHIFTER SHAFT) .  is ::-->
# ('tube assy ', 70)
# ('after treatment assy', 65)
# ('pipe assy ', 60)
# ('frame assy ', 57)
# ('rear axle assy', 56)
#
#  ENGINE COOLING SYSTEM ASSY .  is ::-->
# ('air intake system', 60)
# ('engine cover', 47)
# ('engine cradle', 46)
# ('rear axle assy', 45)
# ('air processing unit', 44)
#
#  "HEADBOX ASSY,Front" .  is ::-->
# ('tube assy ', 57)
# ('pipe assy ', 57)
# ('frame assy ', 55)
# ('rear axle assy', 54)
# ('gearbox ', 53)
#
#  COUPLING BODY .  is ::-->
# ('mounting bolt', 62)
# ('load body ', 55)
# ('spring band clamp', 53)
# ('o ring', 53)
# ('body shell', 52)
#
#  "SUPPORT,BUMPER MTG,LH" .  is ::-->
# ('stopper ', 57)
# ('spoiler', 57)
# ('suspension support', 56)
# ('supd ', 55)
# ('sunvisor', 53)
#
#  WAIST RAIL .  is ::-->
# ('waist seal ', 80)
# ('twist beam', 60)
# ('rub rail', 56)
# ('radiator', 56)
# ('tailgate', 56)
#
#  UTILITY BOX ASSY .  is ::-->
# ('first aid box', 55)
# ('tube assy ', 48)
# ('pipe assy ', 48)
# ('rear axle assy', 47)
# ('tail wiring harness', 46)
#
#  REINFORCEMENT PLATE ASSY .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  "LINK,LOCK BARREL TO LATCH,RH" .  is ::-->
# ('liner ', 67)
# ('drag link', 62)
# ('wiper link ', 57)
# ('pin', 57)
# ('clip', 50)
#
#  "LINK,OUTER HANDLE TO LATCH FRONT DOOR,RH" .  is ::-->
# ('liner ', 67)
# ('drag link', 62)
# ('wiper link ', 57)
# ('pin', 57)
# ('clip', 50)
#
#  "HEAD BOX,LH" .  is ::-->
# ('load body ', 59)
# ('glove box', 59)
# ('hand brake', 56)
# ('body shell', 56)
# ('grab handle', 53)
#
#  "PACKING,COWL MTG,REAR" .  is ::-->
# ('packing plate', 70)
# ('rubber packing', 67)
# ('parking brake', 60)
# ('pin', 60)
# ('bearing ', 57)
#
#  "CONSOLE ASSY,REAR" .  is ::-->
# ('tube assy ', 57)
# ('pipe assy ', 57)
# ('subframe assy', 56)
# ('control brake', 56)
# ('frame assy ', 55)
#
#  FUSE BOX LID WITH KNOB ASSY .  is ::-->
# ('liquid hose', 61)
# ('body shell', 55)
# ('lp hose', 53)
# ('ribbed hose', 52)
# ('storage box', 52)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
#  "CONSOLE,FRONT HOUSING" .  is ::-->
# ('condenser', 62)
# ('control panel', 60)
# ('oil cooler', 59)
# ('con rod', 57)
# ('spoiler', 57)
#
#  "BERTH STRUCTURE,PAPER HONEYCOMB ASSY" .  is ::-->
# ('rear strut', 64)
# ('front strut', 62)
# ('structural pad', 62)
# ('structural tape', 60)
# ('structural foam', 60)
#
#  "CUSHION ASSY,LOWER BERTH" .  is ::-->
# ('tube assy ', 57)
# ('pipe assy ', 57)
# ('spray suppression', 55)
# ('air suspension', 54)
# ('abs ecu', 53)
#
#  "REINFORCEMENT ASSY,LH" .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  "REINFORCEMENT,SPRING HANGER BKT,LH" .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  CONTROLLER .  is ::-->
# ('control panel', 70)
# ('connector ', 63)
# ('control shaft', 61)
# ('control brake', 61)
# ('oil cooler', 60)
#
#  "REINFORCEMENT,RH" .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  "REINFORCEMENT,LH" .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  "REINFORCEMENT,LH" .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  PEDESTAL ASSY WITH PIN & NUT .  is ::-->
# ('pipe assy ', 64)
# ('dead pedal', 61)
# ('rear axle assy', 59)
# ('brake pedal', 58)
# ('pedal ', 56)
#
#  ASSY.  is ::-->
# ('glass ', 67)
# ('tube assy ', 62)
# ('pipe assy ', 62)
# ('frame assy ', 57)
# ('boss', 50)
#
#  ASSY.  is ::-->
# ('glass ', 67)
# ('tube assy ', 62)
# ('pipe assy ', 62)
# ('frame assy ', 57)
# ('boss', 50)
#
#  (MAIN DRIVE) .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  IDLER ASSY-DIA 65 (MAIN DRIVE) .  is ::-->
# ('rear axle assy', 58)
# ('pipe assy ', 54)
# ('frame assy ', 52)
# ('air filter', 52)
# ('glass guide ', 50)
#
#  ASSY.ROCKER ARM EXHAUST-EVB .  is ::-->
# ('after treatment assy', 47)
# ('rear axle assy', 44)
# ('exhaust pipe', 42)
# ('air intake system', 42)
# ('exhaust valve ', 41)
#
#  CROSS SUPPORT .  is ::-->
# ('cross member ', 56)
# ('compressor ', 52)
# ('compression spring', 52)
# ('vapour hose', 50)
# ('front strut', 50)
#
#  HEATING & DEMISTING ASSY .  is ::-->
# ('main wiring harness', 54)
# ('pigtail wiring harness', 50)
# ('rear axle assy', 50)
# ('tail wiring harness', 49)
# ('steering sensor', 49)
#
#  Shifter fork shaft pin .  is ::-->
# ('gear shifter ', 74)
# ('shifter shaft', 70)
# ('shaft ', 67)
# ('washer ', 62)
# ('stiffener', 62)
#
#  Detainer ball .  is ::-->
# ('oil strainer', 64)
# ('wiper blade ', 58)
# ('strainer ', 57)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# ('gas balancer ', 56)
# ('inner handle', 56)
#
#  Adopter for LH/RH rear brake pipe from front brake pipe mounting bolt .  is ::-->
# ('adapter', 86)
# ('outer handle', 63)
# ('damper ', 62)
# ('adapter plate', 60)
# ('booster ', 57)
#
#  Bandage .  is ::-->
# ('handle ', 62)
# ('adapter', 57)
# ('bearing ', 57)
# ('grab handle', 56)
# ('spring band clamp', 50)
#
#  Elastic adhesive bandage .  is ::-->
# ('pneumatic pipe', 47)
# ('tailgate hinge', 47)
# ('airbag ecu', 47)
# ('auto slack adjuster', 47)
# ('driver seat', 46)
#
#  First Aid kit chart .  is ::-->
# ('first aid box', 62)
# ('cabin wiring harness', 51)
# ('cross car beam', 48)
# ('dashboard skin', 48)
# ('air filter', 48)
#
#  Fuel - Diesel .  is ::-->
# ('fuel filler', 64)
# ('fuel filter', 64)
# ('oil seal ', 53)
# ('dead pedal pedal', 52)
# ('urea hose', 50)
#
#  Dip stick .  is ::-->
# ('dipstick ', 94)
# ('sticker', 62)
# ('tail pipe', 56)
# ('driver station ', 52)
# ('pneumatic pipe', 52)
#
#  Timing chain .  is ::-->
# ('wiring harness ', 62)
# ('main wiring harness', 58)
# ('tail wiring harness', 58)
# ('trailing arm', 58)
# ('horn ring', 57)
#
#  Timing chain guide (2) Fix .  is ::-->
# ('cabin wiring harness', 58)
# ('wiring harness ', 56)
# ('tailgate hinge', 56)
# ('pigtail wiring harness', 55)
# ('main wiring harness', 54)
#
#  First synchronizer cone .  is ::-->
# ('synchro ring', 51)
# ('long runner ', 47)
# ('engine cover', 46)
# ('coolant hose', 46)
# ('inner handle', 46)
#
#  Differential cage .  is ::-->
# ('differential housing', 65)
# ('co-driver seat', 52)
# ('front axle', 52)
# ('vertical member', 50)
# ('front damper', 48)
#
#  LCRV unit .  is ::-->
# ('c mount', 62)
# ('ac duct', 50)
# ('a mount', 50)
# ('b mount', 50)
# ('front floor', 50)
#
#  Tie rod .  is ::-->
# ('stay rod', 67)
# ('stone guard', 56)
# ('egr pipe', 53)
# ('oil strainer', 53)
# ('rivet', 50)
#
#  12V supply port (I) .  is ::-->
# ('suspension support', 48)
# ('spray suppression', 44)
# ('oil sump', 43)
# ('core plug ', 42)
# ('poly belt', 42)
#
#  Open spanner .  is ::-->
# ('nylon spacer', 67)
# ('spacer plate', 67)
# ('spacer ring', 61)
# ('long runner ', 61)
# ('oil strainer', 58)
#
#  Front (crash) cross member .  is ::-->
# ('front hub', 71)
# ('front wall', 67)
# ('front seat', 67)
# ('front axle', 67)
# ('front strut', 62)
#
#  200 DIA.  is ::-->
# ('radiator fan', 42)
# ('radiator', 40)
# ('a pillar', 40)
# ('b pillar', 40)
# ('c pillar', 40)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
#  REAR HALF (CRB) .  is ::-->
# ('rear axle', 78)
# ('rear hub', 71)
# ('rear floor', 63)
# ('rear axle beam', 61)
# ('rear axle assy', 61)
#
#  SUB ASSY SUBFRAME RH (SUBFRAME) .  is ::-->
# ('subframe assy', 79)
# ('frame assy ', 67)
# ('tube assy ', 55)
# ('rubber pad', 47)
# ('rear axle assy', 47)
#
#  LOWER LINK ASSY FRONT-RH .  is ::-->
# ('wheel arch liner', 50)
# ('suspension tower', 50)
# ('frame assy ', 47)
# ('front wall', 47)
# ('wiper link ', 47)
#
#  PANHARD ROD WITH BUSH .  is ::-->
# ('anti roll bar ', 58)
# ('fan shroud', 57)
# ('con rod', 56)
# ('threaded pin', 52)
# ('mud guard', 50)
#
#  OFFER DRAWING FRONT BRAKE DISC (21 THICK) .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  OFFER DRAWING FRONT BRAKE DISC (21 THICK) .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  AAM BANJO RA WITH 4.11 (37/9) RATIO FOR .  is ::-->
# ('lambda sensor', 56)
# ('rear axle beam', 54)
# ('anti roll bar ', 48)
# ('urea tank', 48)
# ('first aid box', 48)
#
#  ASSY.  is ::-->
# ('glass ', 67)
# ('tube assy ', 62)
# ('pipe assy ', 62)
# ('frame assy ', 57)
# ('boss', 50)
#
#  ASSY.  is ::-->
# ('glass ', 67)
# ('tube assy ', 62)
# ('pipe assy ', 62)
# ('frame assy ', 57)
# ('boss', 50)
#
#  ASSY.  is ::-->
# ('glass ', 67)
# ('tube assy ', 62)
# ('pipe assy ', 62)
# ('frame assy ', 57)
# ('boss', 50)
#
#  KIT_REVERSE_GUIDING_SYSTEM_M/S_INTERFACE .  is ::-->
# ('intermediate shaft', 41)
# ('sintered bush', 38)
# ('side valance cover', 38)
# ('washer system ', 38)
# ('wiper system', 38)
#
#  ANTENNA ASSY .  is ::-->
# ('gas balancer ', 50)
# ('battery tray', 50)
# ('after treatment assy', 50)
# ('air intake system', 48)
# ('cross car beam', 46)
#
#  VENTURE GX CHASSIS HARNESS .  is ::-->
# ('cabin wiring harness', 57)
# ('cockpit wiring harness', 50)
# ('engine wiring harness', 47)
# ('battery wiring harness', 46)
# ('wiring harness ', 45)
#
#  DIS_MICROBUS_M/S_JP TOOLS(HIGHEREND) .  is ::-->
# ('discharge hose', 41)
# ('instrument panel', 39)
# ('water distribution', 37)
# ('driver station ', 36)
# ('steering column', 35)
#
#  ASSY.  is ::-->
# ('glass ', 67)
# ('tube assy ', 62)
# ('pipe assy ', 62)
# ('frame assy ', 57)
# ('boss', 50)
#
#  ASSY.SCISSORS JACK WITH 3PC HANDLE-M/S SHIVANI LO .  is ::-->
# ('ac compressor', 52)
# ('rear axle assy', 50)
# ('subframe assy', 45)
# ('lambda sensor', 45)
# ('secondary seal ', 44)
#
#  SCISSORS JACK WITH 3 PIECE HANDLE .  is ::-->
# ('ac compressor', 62)
# ('parking sensor', 52)
# ('pedal sensor', 48)
# ('sunvisor', 48)
# ('lambda sensor', 46)
#
#  ASSY ENGINE SHIELD - LHD .  is ::-->
# ('windshield ', 56)
# ('engine hood', 55)
# ('heat shield', 48)
# ('glass guide ', 48)
# ('engine wiring harness', 47)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# ASSY BUTTERFLY WINDOW RH (ASAHI) .  is ::-->
# ('window switch', 54)
# ('battery wiring harness', 52)
# ('tail wiring harness', 47)
# ('glass run mould ', 46)
# ('battery tray', 44)
#
#  ASSY PLUG-IN WINDOW COMPLETE LH .  is ::-->
# ('pigtail wiring harness', 45)
# ('window switch', 45)
# ('compression spring', 45)
# ('main wiring harness', 44)
# ('tail wiring harness', 44)
#
#  ASSY CENTER CLUSTER .  is ::-->
# ('tube assy ', 57)
# ('clutch booster', 55)
# ('rear axle assy', 55)
# ('steering sensor', 53)
# ('catalytic converter', 53)
#
#  REAR AC ASSY MICROBUS-CAD DATA .  is ::-->
# ('rear axle assy', 50)
# ('rear damper', 44)
# ('after treatment assy', 44)
# ('tube assy ', 41)
# ('cross car beam', 41)
#
#  Corner reinf RH .  is ::-->
# ('engine cover', 59)
# ('horn ring', 58)
# ('connecting rod', 55)
# ('arrestor ring', 50)
# ('condenser', 50)
#
#  Reinf subframe moiunting (between Long member outer and inner panel) .  is ::-->
# ('mounting screw', 63)
# ('mounting nut', 61)
# ('mounting washer', 56)
# ('ignition sensor', 51)
# ('subframe assy', 49)
#
#  Front upper CM reinforcement plate .  is ::-->
# ('mounting washer', 53)
# ('front strut', 53)
# ('wiper motor', 53)
# ('mounting nut', 52)
# ('front wiring harness', 51)
#
#  I .  is ::-->
# ('rib', 50)
# ('pin', 50)
# ('clip', 40)
# ('shim ', 40)
# ('pipe ', 40)
#
#  II .  is ::-->
# ('pinion', 50)
# ('circlip', 44)
# ('king pin', 40)
# ('oil ring', 40)
# ('rib', 40)
#
#  III .  is ::-->
# ('pinion', 44)
# ('circlip', 40)
# ('king pin', 36)
# ('oil ring', 36)
# ('dipstick ', 36)
#
#  IV .  is ::-->
# ('irvm ', 67)
# ('rivet', 57)
# ('rib', 40)
# ('pin', 40)
# ('clip', 33)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  Reinf .  is ::-->
# ('reinforcement ', 56)
# ('o ring', 55)
# ('rib', 50)
# ('bearing ', 50)
# ('pin', 50)
#
#  Reinf (Between L2 and L3) .  is ::-->
# ('reinforcement ', 56)
# ('o ring', 55)
# ('rib', 50)
# ('bearing ', 50)
# ('pin', 50)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  II .  is ::-->
# ('pinion', 50)
# ('circlip', 44)
# ('king pin', 40)
# ('oil ring', 40)
# ('rib', 40)
#
#  Dash reinforcement .  is ::-->
# ('dashboard skin', 61)
# ('horn ring', 56)
# ('dashboard ', 56)
# ('drag link', 56)
# ('arrestor ring', 55)
#
#  II .  is ::-->
# ('pinion', 50)
# ('circlip', 44)
# ('king pin', 40)
# ('oil ring', 40)
# ('rib', 40)
#
#  For plenum .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  Tunnel bottom reinf .  is ::-->
# ('cotton tape', 53)
# ('door panel', 48)
# ('return hose', 47)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# ('long runner ', 47)
# ('instrument panel', 46)
#
#  On tunnel .  is ::-->
# ('long runner ', 70)
# ('nylon tube', 63)
# ('instrument panel', 56)
# ('control panel', 55)
# ('bundy tube', 53)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  On tunnel .  is ::-->
# ('long runner ', 70)
# ('nylon tube', 63)
# ('instrument panel', 56)
# ('control panel', 55)
# ('bundy tube', 53)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  Tail gate sill outer .  is ::-->
# ('auto slack adjuster', 51)
# ('outer handle', 50)
# ('gear shift lever', 50)
# ('battery tray', 50)
# ('battery cable', 48)
#
#  Sill outer reinf .  is ::-->
# ('engine cover', 50)
# ('quarter trim', 50)
# ('horn ring', 48)
# ('counter shaft', 48)
# ('fuel rail', 48)
#
#  Tail gate sill inner .  is ::-->
# ('inner handle', 50)
# ('gear shift lever', 50)
# ('clutch slave cylinder', 49)
# ('tail pipe', 48)
# ('driver station ', 47)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  Cup reinf upper for strut .  is ::-->
# ('compression spring', 55)
# ('spacer ring', 54)
# ('suspension tower', 52)
# ('spring washer ', 50)
# ('brake pipe', 48)
#
#  Sill inner hat section front .  is ::-->
# ('front wiring harness', 54)
# ('front suspension', 50)
# ('driver station ', 48)
# ('traction motor', 48)
# ('front wall', 47)
#
#  Sill inner rear .  is ::-->
# ('rear wall', 58)
# ('rear bumper', 54)
# ('rear damper', 54)
# ('rear axle shaft', 53)
# ('gear shift lever', 52)
#
#  Sill reinf .  is ::-->
# ('snap ring', 53)
# ('grill ', 53)
# ('rear wall', 53)
# ('windshield ', 50)
# ('drain plug ', 50)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#  Sill reinf .  is ::-->
# ('snap ring', 53)
# ('grill ', 53)
# ('rear wall', 53)
# ('windshield ', 50)
# ('drain plug ', 50)
#
#  A plr lower .  is ::-->
# ('power cable', 55)
# ('power cable', 55)
# ('power latch', 55)
# ('parking brake lever', 53)
# ('a pillar', 53)
#
#  A plr bottom reinf (Earthing nut welded) .  is ::-->
# ('arrestor ring', 52)
# ('power steering gearbox', 50)
# ('traction motor', 50)
# ('rear bumper', 48)
# ('rear damper', 48)
#
#  Sill side outer front .  is ::-->
# ('front suspension', 59)
# ('front wall', 52)
# ('front seat', 52)
# ('side valance cover', 51)
# ('front strut', 50)
#
#  Reinf 1 sill outer .  is ::-->
# ('engine cover', 47)
# ('quarter trim', 47)
# ('counter shaft', 45)
# ('mounting screw', 44)
# ('horn ring', 44)
#
#  Reinf 3 sill outer .  is ::-->
# ('engine cover', 47)
# ('quarter trim', 47)
# ('counter shaft', 45)
# ('mounting screw', 44)
# ('horn ring', 44)
#
#  Reinf 5 sill outer .  is ::-->
# ('engine cover', 47)
# ('quarter trim', 47)
# ('counter shaft', 45)
# ('mounting screw', 44)
# ('horn ring', 44)
#
#  Sill rear reinf.bottom .  is ::-->
# ('rear suspension', 49)
# ('anti roll bar ', 46)
# ('battery wiring harness', 45)
# ('rear wall', 45)
# ('compression spring', 45)
#
#  Additional reinf .  is ::-->
# ('piston ring ', 59)
# ('ignition sensor', 52)
# ('oil ring', 50)
# ('radiator', 50)
# ('differential housing', 50)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  Additional reinf 1 .  is ::-->
# ('piston ring ', 55)
# ('ignition sensor', 48)
# ('radiator fan', 47)
# ('differential housing', 47)
# ('warning triangle', 47)
#
#  Inner reinf lower .  is ::-->
# ('power steering gearbox', 56)
# ('gear shift lever', 55)
# ('roof liner', 52)
# ('parking brake lever', 50)
# ('cabin wiring harness', 49)
#
#  A plr cant rail crash reinf .  is ::-->
# ('pigtail wiring harness', 49)
# ('parking camera', 49)
# ('tail wiring harness', 48)
# ('cabin wiring harness', 47)
# ('clutch release lever', 47)
#
#  Cant rail inner rear .  is ::-->
# ('cantrail', 57)
# ('cylinder valve', 53)
# ('rear axle beam', 53)
# ('air filter', 53)
# ('rear axle assy', 53)
#
#  Front header .  is ::-->
# ('front seat', 73)
# ('front hub', 67)
# ('front wall', 64)
# ('front wiring harness', 62)
# ('front strut', 61)
#
#  Rear header inner .  is ::-->
# ('inner handle', 69)
# ('headliner ', 62)
# ('rear axle beam', 58)
# ('rear damper', 57)
# ('driver seat', 57)
#
#  Side impact channel .  is ::-->
# ('side lamp', 57)
# ('heat shield', 53)
# ('cable tie ', 50)
# ('toe panel', 50)
# ('connecting rod', 48)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  Reinf.  is ::-->
# ('reinforcement ', 56)
# ('o ring', 55)
# ('rib', 50)
# ('bearing ', 50)
# ('pin', 50)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  Reinf.  is ::-->
# ('reinforcement ', 56)
# ('o ring', 55)
# ('rib', 50)
# ('bearing ', 50)
# ('pin', 50)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  REINFORCEMENT ASSY TOW HOOK LH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  CANOPY STRUCTURE ASSY .  is ::-->
# ('structural pad', 57)
# ('structural foam', 56)
# ('subframe assy', 53)
# ('tube assy ', 53)
# ('rear axle assy', 51)
#
#  CANOPY MTG ASSY FRONT-RH .  is ::-->
# ('main wiring harness', 47)
# ('frame assy ', 47)
# ('rear axle assy', 47)
# ('front strut', 46)
# ('front axle beam', 46)
#
#  ELECTRIC BUZZER UNIT .  is ::-->
# ('reflective tape', 51)
# ('front bumper', 50)
# ('gear shift lever', 50)
# ('steering belt', 48)
# ('reflector', 48)
#
#  OWNERS MANUAL .  is ::-->
# ('power cable', 58)
# ('power cable', 58)
# ('outer handle', 56)
# ('inner handle', 56)
# ('toe panel', 55)
#
#  REINFORCEMENT ASSY TOW HOOK LH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  REINFORCEMENT FRONT-BOTTOM-LH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  UPPER SADDLE .  is ::-->
# ('outer handle', 67)
# ('power cable', 61)
# ('power cable', 61)
# ('wiper blade ', 61)
# ('inner handle', 58)
#
#  UPPER SADDLE .  is ::-->
# ('outer handle', 67)
# ('power cable', 61)
# ('power cable', 61)
# ('wiper blade ', 61)
# ('inner handle', 58)
#
#  FUEL SUPPLY MODULE .  is ::-->
# ('fuel return hose', 53)
# ('fuel pump', 52)
# ('glass run mould ', 48)
# ('fuel sensor', 48)
# ('fuel filler', 48)
#
#  OIL MIST SEPARATOR ASSY .  is ::-->
# ('rear axle assy', 54)
# ('starter motor', 50)
# ('alternator ', 48)
# ('glass run mould ', 47)
# ('oil strainer', 46)
#
#  REINFORCEMENT ASSY REAR WALL UPPER .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  BODY SIDE ASSY OUTER-RH .  is ::-->
# ('rear axle assy', 49)
# ('high deck load body', 48)
# ('heater hose', 47)
# ('glass guide ', 47)
# ('outer handle', 46)
#
#  BODY SIDE ASSY INNER-RH .  is ::-->
# ('rear axle assy', 49)
# ('high deck load body', 48)
# ('inner handle', 46)
# ('wheel arch liner', 46)
# ('subframe assy', 44)
#
#  RHD .  is ::-->
# ('rupd ', 57)
# ('hand brake', 46)
# ('handle ', 44)
# ('grab handle', 43)
# ('garnish', 40)
#
#  WAIST REINFORCEMENT OUTER RH .  is ::-->
# ('waist seal ', 70)
# ('spring washer ', 61)
# ('twist beam', 60)
# ('thrust ring', 57)
# ('warning triangle', 54)
#
#  REAR HEADER .  is ::-->
# ('rear damper', 73)
# ('rear axle', 70)
# ('heater hose', 64)
# ('rear bumper', 64)
# ('rear hub', 63)
#
#  ASSY SHOT GUN LH .  is ::-->
# ('tube assy ', 48)
# ('rear axle assy', 47)
# ('fan shroud', 46)
# ('glass run mould ', 45)
# ('gear shift knob', 45)
#
#  Diffuser .  is ::-->
# ('stiffener', 59)
# ('buffer', 57)
# ('fuel sensor', 53)
# ('rubber buffer', 48)
# ('condenser', 47)
#
#  Diffuser .  is ::-->
# ('stiffener', 59)
# ('buffer', 57)
# ('fuel sensor', 53)
# ('rubber buffer', 48)
# ('condenser', 47)
#
#  "TIE MEMBER ASSY,UPPER" .  is ::-->
# ('cross member ', 67)
# ('crash member', 67)
# ('vertical member', 60)
# ('cable tie ', 58)
# ('tube assy ', 58)
#
#  Ace Gold - Front Turn Indicator LH .  is ::-->
# ('front wiring harness', 42)
# ('front strut', 42)
# ('front suspension', 42)
# ('clutch master cylinder', 41)
# ('radiator fan', 41)
#
#  Ace Gold Diesel BSVI .  is ::-->
# ('side valance cover', 47)
# ('heat shield', 45)
# ('wheel arch liner', 44)
# ('sintered bush', 42)
# ('flat bed load body', 42)
#
#  REINFORCEMENT LH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#  REINFORCEMENT RH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  SUPPORT REINFORCEMENT .  is ::-->
# ('spacer ring', 61)
# ('snap ring', 57)
# ('reinforcement ', 56)
# ('sensor ', 56)
# ('rear strut', 55)
#
#  REINFORCEMENT BOTTOM RH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  "PIGTAIL,STEERING WHEEL SWITCH" .  is ::-->
# ('tail pipe', 75)
# ('tail lamp', 62)
# ('tailgate hinge', 57)
# ('tailgate', 53)
# ('cantrail', 53)
#
#  "REINFORCEMENT,LH" .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  "REINFORCEMENT,BUMPER CROSS MEMBER,LH" .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  "REINFORCEMENT,RH" .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  SUPPORT INNER-RH .  is ::-->
# ('roof liner', 54)
# ('air suspension', 47)
# ('rear strut', 46)
# ('ignition sensor', 45)
# ('rear suspension', 45)
#
#  SUPPORT OUTER-RH .  is ::-->
# ('counter shaft', 55)
# ('front bumper', 50)
# ('rubber buffer', 48)
# ('rubber spacer', 48)
# ('starter motor', 48)
#
#  SUPPORT INNER .  is ::-->
# ('rear strut', 52)
# ('roof liner', 52)
# ('air suspension', 52)
# ('spacer ring', 50)
# ('intake pipe', 50)
#
#  DC TO DC CONVERTER (1.5A) .  is ::-->
# ('connector ', 52)
# ('counter shaft', 52)
# ('side valance cover', 50)
# ('catalytic converter', 49)
# ('integrated pedal', 47)
#
#  RELAY ROD ASSY .  is ::-->
# ('rear axle assy', 64)
# ('frame assy ', 58)
# ('subframe assy', 52)
# ('tube assy ', 52)
# ('pipe assy ', 52)
#
#  NOZZLE ASSY .  is ::-->
# ('tube assy ', 60)
# ('pipe assy ', 60)
# ('frame assy ', 57)
# ('rear axle assy', 56)
# ('subframe assy', 50)
#
#  RESERVIOR(1.5LITS.)  is ::-->
# ('sunvisor', 59)
# ('reflector', 56)
# ('tensioner', 56)
# ('compressor ', 53)
# ('sensor ', 53)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  HEXSCR M18X1.5X40 TS17100-10.9SS8451-8CH .  is ::-->
# ('clutch master cylinder', 26)
# ('check strap', 24)
# ('temp sensor', 24)
# ('nox sensor', 24)
# ('instrument cluster', 24)
#
#  OWNERS MANUAL .  is ::-->
# ('power cable', 58)
# ('power cable', 58)
# ('outer handle', 56)
# ('inner handle', 56)
# ('toe panel', 55)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#  ASSY.STRAP .  is ::-->
# ('subframe assy', 70)
# ('frame assy ', 70)
# ('tube assy ', 63)
# ('pipe assy ', 63)
# ('rear axle assy', 58)
#
#  OWNERS MANUAL .  is ::-->
# ('power cable', 58)
# ('power cable', 58)
# ('outer handle', 56)
# ('inner handle', 56)
# ('toe panel', 55)
#
#  PARCEL RACK ASSY .  is ::-->
# ('rear axle assy', 67)
# ('pipe assy ', 56)
# ('spacer ', 55)
# ('frame assy ', 54)
# ('nylon spacer', 50)
#
#  "TRANSITION PIECE ASSY,UCL" .  is ::-->
# ('air suspension', 57)
# ('rear suspension', 56)
# ('pipe assy ', 53)
# ('pigtail wiring harness', 51)
# ('driver station ', 51)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  ARM BLADE & NOZZLE FITMENT CO-DR M/S.  is ::-->
# ('control brake', 43)
# ('after treatment assy', 41)
# ('reflex reflector', 40)
# ('engine cradle', 38)
# ('instrument cluster', 38)
#
#  RUBEER BOOT (WHEEL BOX) .  is ::-->
# ('rubber block', 70)
# ('booster ', 67)
# ('rubber bellow', 67)
# ('rubber bush', 64)
# ('rubber hose', 64)
#
#  TOW HOOK .  is ::-->
# ('lifting hook', 60)
# ('suction hose', 50)
# ('door trim', 47)
# ('foot step', 47)
# ('motor ', 46)
#
#  ENGINE A-MTG ARM .  is ::-->
# ('engine mount', 64)
# ('engine cover', 57)
# ('steering arm', 57)
# ('engine cradle', 55)
# ('engine hood', 52)
#
#  AIR DEFLCTOR ASSY .  is ::-->
# ('reflector', 62)
# ('air filter', 59)
# ('air duct', 56)
# ('after treatment assy', 54)
# ('frame assy ', 52)
#
#  CONNECTING LINK ASSY REAR .  is ::-->
# ('connecting rod', 62)
# ('rear axle assy', 56)
# ('connector ', 47)
# ('mounting screw', 46)
# ('rubber packing', 46)
#
#  CANOPY ASSY .  is ::-->
# ('pipe assy ', 60)
# ('frame assy ', 57)
# ('subframe assy', 50)
# ('tube assy ', 50)
# ('rear axle assy', 48)
#
#  FT HARNESS DCT XM .  is ::-->
# ('front wiring harness', 59)
# ('door wiring harness', 56)
# ('cockpit wiring harness', 56)
# ('battery wiring harness', 56)
# ('floor wiring harness', 54)
#
#  REAR QUARTER ASSY INNER-LH .  is ::-->
# ('rear axle assy', 60)
# ('integrated pedal', 48)
# ('wheel arch liner', 48)
# ('quarter trim', 47)
# ('cylinder head', 46)
#
#  "BODY SIDE ASSY,INNER-FRONT-LH" .  is ::-->
# ('tube assy ', 61)
# ('pipe assy ', 61)
# ('body shell', 58)
# ('dashboard skin', 57)
# ('glass guide ', 56)
#
#  "REINFORCEMENT ASSY,CANTRAIL,LH" .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  "REINFORCEMENT ASSY,B-PILLAR,INNER-LH" .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#  ASSY TIE MEMBER COMPLETE .  is ::-->
# ('rear axle assy', 53)
# ('cross member ', 50)
# ('crash member', 50)
# ('tube assy ', 48)
# ('pipe assy ', 48)
#
#  Central Detent .  is ::-->
# ('structural tape', 55)
# ('cantrail', 55)
# ('after treatment assy', 53)
# ('reinforcement ', 52)
# ('cable tie ', 52)
#
#  "SUPPORT ASSY,RADIATOR MTG,LH" .  is ::-->
# ('pipe assy ', 67)
# ('subframe assy', 64)
# ('tube assy ', 57)
# ('frame assy ', 55)
# ('spray suppression', 55)
#
#  Coolant Line Assy .  is ::-->
# ('coolant hose', 62)
# ('tube assy ', 54)
# ('pipe assy ', 54)
# ('frame assy ', 52)
# ('rear axle assy', 52)
#
#  ASSY CROSS MBR .  is ::-->
# ('cross member ', 69)
# ('subframe assy', 59)
# ('frame assy ', 58)
# ('crash member', 54)
# ('tube assy ', 52)
#
#  MOUNTING) .  is ::-->
# ('mounting nut', 80)
# ('mounting bolt', 76)
# ('mounting screw', 73)
# ('mounting washer', 70)
# ('a mount', 67)
#
#  REINFORCEMENT FRONT-RH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  EXTENSION PIECE ASSY EXTENSION FRONT-LH .  is ::-->
# ('suspension tower', 44)
# ('front axle beam', 41)
# ('speed sensor', 39)
# ('steering wheel', 38)
# ('sunroof sensor', 38)
#
#  C-REINFORCEMENT RH .  is ::-->
# ('o ring', 67)
# ('coil spring', 59)
# ('oil ring', 57)
# ('engine cover', 56)
# ('screw', 55)
#
#  REINFORCEMENT RH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  ASSY FOR PARALLEL ROD MGT .  is ::-->
# ('glass ', 67)
# ('tube assy ', 62)
# ('pipe assy ', 62)
# ('frame assy ', 57)
# ('boss', 50)
#
#  ASSY VERTICAL SUPPORT BRKT-1 .  is ::-->
# ('vertical member', 51)
# ('after treatment assy', 46)
# ('subframe assy', 44)
# ('spray suppression', 44)
# ('tube assy ', 43)
#
#  ENGINE MTG ASSY REAR-LH .  is ::-->
# ('rear axle assy', 59)
# ('suspension tower', 51)
# ('engine mount', 51)
# ('engine wiring harness', 50)
# ('rear axle beam', 49)
#
#  ASSY.  is ::-->
# ('glass ', 67)
# ('tube assy ', 62)
# ('pipe assy ', 62)
# ('frame assy ', 57)
# ('boss', 50)
#
#  C/M FRONT .  is ::-->
# ('front hub', 67)
# ('front wall', 63)
# ('front seat', 63)
# ('front axle', 63)
# ('c mount', 62)
#
#  L-REINFORCEMENT TOP-LH .  is ::-->
# ('oil ring', 71)
# ('o ring', 67)
# ('leaf spring ', 59)
# ('coil spring', 59)
# ('leaf screen', 59)
#
#  DC TO DC CONVERTER .  is ::-->
# ('connector ', 52)
# ('counter shaft', 52)
# ('side valance cover', 50)
# ('catalytic converter', 49)
# ('integrated pedal', 47)
#
#  SUPPORT ASSY FRONT-LH .  is ::-->
# ('front strut', 56)
# ('front suspension', 54)
# ('front hub', 53)
# ('front seat', 52)
# ('subframe assy', 47)
#
#  L-REINFORCEMENT TOP-LH .  is ::-->
# ('oil ring', 71)
# ('o ring', 67)
# ('leaf spring ', 59)
# ('coil spring', 59)
# ('leaf screen', 59)
#
#  L-REINFORCEMENT BOTTOM-LH .  is ::-->
# ('oil ring', 71)
# ('o ring', 67)
# ('leaf spring ', 59)
# ('coil spring', 59)
# ('leaf screen', 59)
#
#  RELAY ARM .  is ::-->
# ('armrest', 62)
# ('rear damper', 60)
# ('trailing arm', 57)
# ('battery tray', 57)
# ('foam seal', 56)
#
#  REINFORCEMENT FRONT-BOTTOM-RH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  L-REINFORCEMENT .  is ::-->
# ('oil ring', 71)
# ('o ring', 67)
# ('leaf spring ', 59)
# ('coil spring', 59)
# ('leaf screen', 59)
#
#  Telematics .  is ::-->
# ('pneumatic pipe', 58)
# ('seat belt', 53)
# ('latch ', 53)
# ('plastic washer ', 50)
# ('waist seal ', 50)
#
#  "CAB MTG ASSY,REAR" .  is ::-->
# ('frame assy ', 64)
# ('tube assy ', 57)
# ('subframe assy', 56)
# ('rear axle assy', 54)
# ('after treatment assy', 50)
#
#  ANGLE ASSY .  is ::-->
# ('glass ', 67)
# ('gas balancer ', 55)
# ('warning triangle', 54)
# ('axle beam', 53)
# ('rear axle', 53)
#
#  REINFORCEMENT .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  CATALITIC CONVERTER ASSY .  is ::-->
# ('catalytic converter', 84)
# ('rear axle assy', 58)
# ('clutch cover', 56)
# ('clutch master cylinder', 52)
# ('water distribution', 48)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  "PIGTAIL,ENGINE LAMP" .  is ::-->
# ('tail pipe', 75)
# ('tail lamp', 62)
# ('tailgate hinge', 57)
# ('tailgate', 53)
# ('cantrail', 53)
#
#  "PIGTAIL,ALTERNATOR +VE" .  is ::-->
# ('tail pipe', 75)
# ('tail lamp', 62)
# ('tailgate hinge', 57)
# ('tailgate', 53)
# ('cantrail', 53)
#
#  CLOSE PROXIMITY MIRROR ASSY .  is ::-->
# ('rear axle assy', 49)
# ('front axle beam', 43)
# ('air processing unit', 43)
# ('front floor', 42)
# ('spring band clamp', 41)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  "PUSH ROD ASSY,SLAVE CYLINDER" .  is ::-->
# ('fan shroud', 61)
# ('tube assy ', 55)
# ('pipe assy ', 55)
# ('subframe assy', 54)
# ('frame assy ', 52)
#
#  SPEAKER 5.25 WITH RAIN COVER (BLAUPUNKT .  is ::-->
# ('spacer ', 56)
# ('spacer ring', 52)
# ('nylon spacer', 50)
# ('spacer plate', 50)
# ('rubber spacer', 48)
#
#  COOLANT LINE ASSY .  is ::-->
# ('coolant hose', 62)
# ('tube assy ', 54)
# ('pipe assy ', 54)
# ('frame assy ', 52)
# ('rear axle assy', 52)
#
#  "REINFORCEMENT ASSY,RH" .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  "REINFORCEMENT,RH" .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  Vapour line .  is ::-->
# ('vapour hose', 73)
# ('liner ', 62)
# ('roof liner', 57)
# ('wiper link ', 57)
# ('cylinder valve', 56)
#
#  FL.  is ::-->
# ('floor', 57)
# ('baffle ', 50)
# ('filter ', 50)
# ('flywheel ', 40)
# ('fog lamp', 40)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  L-REINFORCEMENT TOP-LH .  is ::-->
# ('oil ring', 71)
# ('o ring', 67)
# ('leaf spring ', 59)
# ('coil spring', 59)
# ('leaf screen', 59)
#
#  FL.  is ::-->
# ('floor', 57)
# ('baffle ', 50)
# ('filter ', 50)
# ('flywheel ', 40)
# ('fog lamp', 40)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#  FL.  is ::-->
# ('floor', 57)
# ('baffle ', 50)
# ('filter ', 50)
# ('flywheel ', 40)
# ('fog lamp', 40)
#
#  FL.  is ::-->
# ('floor', 57)
# ('baffle ', 50)
# ('filter ', 50)
# ('flywheel ', 40)
# ('fog lamp', 40)
#
#  FL.  is ::-->
# ('floor', 57)
# ('baffle ', 50)
# ('filter ', 50)
# ('flywheel ', 40)
# ('fog lamp', 40)
#
#  FL.  is ::-->
# ('floor', 57)
# ('baffle ', 50)
# ('filter ', 50)
# ('flywheel ', 40)
# ('fog lamp', 40)
#
#  RETARDER ASSY .  is ::-->
# ('frame assy ', 70)
# ('rear axle assy', 67)
# ('tube assy ', 64)
# ('subframe assy', 62)
# ('pipe assy ', 55)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  "REINFORCEMENT,BUMPER CROSS MEMBER,RH" .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  OWNERS MANUAL .  is ::-->
# ('power cable', 58)
# ('power cable', 58)
# ('outer handle', 56)
# ('inner handle', 56)
# ('toe panel', 55)
#
#  OWNERS MANUAL .  is ::-->
# ('power cable', 58)
# ('power cable', 58)
# ('outer handle', 56)
# ('inner handle', 56)
# ('toe panel', 55)
#
#  OWNERS MANUAL .  is ::-->
# ('power cable', 58)
# ('power cable', 58)
# ('outer handle', 56)
# ('inner handle', 56)
# ('toe panel', 55)
#
#  OWNERS MANUAL .  is ::-->
# ('power cable', 58)
# ('power cable', 58)
# ('outer handle', 56)
# ('inner handle', 56)
# ('toe panel', 55)
#
#  OWNERS MANUAL .  is ::-->
# ('power cable', 58)
# ('power cable', 58)
# ('outer handle', 56)
# ('inner handle', 56)
# ('toe panel', 55)
#
#  OWNERS MANUAL .  is ::-->
# ('power cable', 58)
# ('power cable', 58)
# ('outer handle', 56)
# ('inner handle', 56)
# ('toe panel', 55)
#
#  ENGINE COOLING SYSTEM .  is ::-->
# ('air intake system', 63)
# ('engine cover', 55)
# ('engine cradle', 53)
# ('coolant hose', 48)
# ('engine mount', 48)
#
#  AFTER TREATMENT SYSTEM ASSY .  is ::-->
# ('after treatment assy', 85)
# ('subframe assy', 50)
# ('air intake system', 50)
# ('frame assy ', 49)
# ('instrument cluster', 49)
#
#  "REINFORCEMENT,RH" .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  "REINFORCEMENT,RH" .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  SUPPORT ASSY WITH SPACER .  is ::-->
# ('pipe assy ', 67)
# ('subframe assy', 64)
# ('tube assy ', 57)
# ('frame assy ', 55)
# ('spray suppression', 55)
#
#  SUPPORT .  is ::-->
# ('stopper ', 57)
# ('spoiler', 57)
# ('suspension support', 56)
# ('supd ', 55)
# ('sunvisor', 53)
#
#  REINFORCEMENT .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  L-REINFORCEMENT .  is ::-->
# ('oil ring', 71)
# ('o ring', 67)
# ('leaf spring ', 59)
# ('coil spring', 59)
# ('leaf screen', 59)
#
#  REINFORCEMENT .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  REINFORCEMENT .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  REINFORCEMENT .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  L-REINFORCEMENT .  is ::-->
# ('oil ring', 71)
# ('o ring', 67)
# ('leaf spring ', 59)
# ('coil spring', 59)
# ('leaf screen', 59)
#
#  REINFORCEMENT .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  C-CHANNEL SUPPORT .  is ::-->
# ('power cable', 50)
# ('power cable', 50)
# ('outer handle', 48)
# ('ac compressor', 47)
# ('connector ', 46)
#
#  "ARMATURE,DASHBOARD DRIVER SIDE" .  is ::-->
# ('armrest', 67)
# ('alternator ', 56)
# ('adapter', 53)
# ('primary seal', 50)
# ('steering arm', 50)
#
#  Cooling System- Tata Toyo .  is ::-->
# ('tailgate hinge', 47)
# ('coolant hose', 44)
# ('air intake system', 44)
# ('washer system ', 43)
# ('control shaft', 43)
#
#  Engine oil filling neck .  is ::-->
# ('engine wiring harness', 50)
# ('oil filter', 48)
# ('engine hood', 47)
# ('engine mount', 46)
# ('steering wheel', 43)
#
#  Blow by unit (crankcase ventilation / Oil separator) .  is ::-->
# ('blow by hose', 67)
# ('b mount', 53)
# ('mounting bolt', 48)
# ('rubber bellow', 48)
# ('u bolt', 44)
#
#  Timing chain moveable guide (Fuel pump chain) .  is ::-->
# ('main wiring harness', 52)
# ('tail wiring harness', 52)
# ('cabin wiring harness', 51)
# ('engine wiring harness', 50)
# ('pigtail wiring harness', 49)
#
#  Glow plug .  is ::-->
# ('hole plug ', 67)
# ('core plug ', 67)
# ('plummer block', 55)
# ('drain plug ', 53)
# ('oil pump', 47)
#
#  Third and forth gear engaging gear shifter sleeve (on output shaft) .  is ::-->
# ('fan shroud', 63)
# ('threaded pin', 57)
# ('outer handle', 57)
# ('inner handle', 57)
# ('windshield ', 53)
#
#  Differential cage .  is ::-->
# ('differential housing', 65)
# ('co-driver seat', 52)
# ('front axle', 52)
# ('vertical member', 50)
# ('front damper', 48)
#
#  Jack .  is ::-->
# ('bracket', 55)
# ('shackle', 55)
# ('tank ', 50)
# ('lock', 50)
# ('hvac ', 50)
#
#  Centre console .  is ::-->
# ('control brake', 59)
# ('heater hose', 56)
# ('coolant hose', 54)
# ...
#
#  "REINF ASSY,REAR SEAT STRIKER MTG,RH" .  is ::-->
# ('frame assy ', 70)
# ('tube assy ', 63)
# ('pipe assy ', 63)
# ('subframe assy', 61)
# ('wiring harness ', 58)
#
#  "REINFORCEMENT,A-PILLAR,LOWER-RH" .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  "LONGITUDINAL ASSY,FRONT-INNER-RH" .  is ::-->
# ('tube assy ', 54)
# ('glass guide ', 50)
# ('glass run mould ', 50)
# ('subframe assy', 47)
# ('pipe assy ', 46)
#
#  "SCREEN RAIL ASSY,UPPER" .  is ::-->
# ('rear axle assy', 67)
# ('frame assy ', 62)
# ('leaf screen', 59)
# ('tail wiring harness', 57)
# ('pipe assy ', 56)
#
#  LONGITUDINAL EXTENSION ASSY REAR RH .  is ::-->
# ('rear axle assy', 49)
# ('suspension tower', 47)
# ('urea sensor', 43)
# ('rear axle beam', 41)
# ('tensioner', 41)
#
#  PIGTAIL;TAIL LAMP .  is ::-->
# ('tail pipe', 75)
# ('tail lamp', 62)
# ('tailgate hinge', 57)
# ('tailgate', 53)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# ('cantrail', 53)
#
#  MEMBRANE .  is ::-->
# ('brake ', 62)
# ('camera', 57)
# ('bracket', 53)
# ('long member ', 53)
# ('vertical member', 52)
#
#  MEMBRANE .  is ::-->
# ('brake ', 62)
# ('camera', 57)
# ('bracket', 53)
# ('long member ', 53)
# ('vertical member', 52)
#
#  Coupling flange .  is ::-->
# ('packing plate', 57)
# ('mounting washer', 53)
# ('mounting nut', 52)
# ('spring washer ', 50)
# ('clutch slave cylinder', 50)
#
#  TIE MEMBER ASSY;UPPER .  is ::-->
# ('cross member ', 67)
# ('crash member', 67)
# ('vertical member', 60)
# ('cable tie ', 58)
# ('tube assy ', 58)
#
#  SUBSTRUCTURE ASSY WITH FLOOR;REAR .  is ::-->
# ('subframe assy', 67)
# ('structural pad', 65)
# ('tube assy ', 62)
# ('structural foam', 62)
# ('structural tape', 56)
#
#  MAGAZINE POCKET ASSY;FRONT DOOR;LH .  is ::-->
# ('pipe assy ', 55)
# ('rear axle assy', 53)
# ('frame assy ', 47)
# ('main wiring harness', 46)
# ('air intake pipe', 46)
#
#  AC UNIT ASSY;FRONT .  is ::-->
# ('air processing unit', 58)
# ('tube assy ', 57)
# ('pipe assy ', 57)
# ('after treatment assy', 56)
# ('ac duct', 53)
#
#  "HOUSING, FRONT HALF" .  is ::-->
# ('hinge', 67)
# ('horn ring', 62)
# ('o ring', 62)
# ('shotgun', 57)
# ('coil spring', 56)
#
#  COOLING SYSTEM ASSY_24V .  is ::-->
# ('air intake system', 55)
# ('coolant hose', 46)
# ('packing plate', 44)
# ('tube assy ', 44)
# ('pipe assy ', 44)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  "CORNER,REAR WALL,BOTTOM-RH" .  is ::-->
# ('cover ', 73)
# ('connector ', 67)
# ('condenser', 67)
# ('con rod', 62)
# ('compressor ', 62)
#
#  SHOCKER ASSY REAR COMPLETE - (Tigor) .  is ::-->
# ('shock absorber ', 60)
# ('rear axle assy', 60)
# ('ac compressor', 56)
# ('rear axle shaft', 54)
# ('washer system ', 51)
#
#  REINFORCEMENT;BUMPER CROSS MEMBER;LH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  "SUPPORT ASSY,RADIATOR MTG,LH" .  is ::-->
# ('pipe assy ', 67)
# ('subframe assy', 64)
# ('tube assy ', 57)
# ('frame assy ', 55)
# ('spray suppression', 55)
#
#  Fuel line .  is ::-->
# ('fuel injector', 73)
# ('fuel tank', 67)
# ('fuel rail', 67)
# ('fuel sensor', 60)
# ('liner ', 57)
#
#  Hook Assy with Bracket .  is ::-->
# ('tube assy ', 56)
# ('pipe assy ', 56)
# ('frame assy ', 53)
# ('shock absorber ', 52)
# ('yoke', 46)
#
#  FEED LINE ASSY .  is ::-->
# ('pipe assy ', 61)
# ('frame assy ', 58)
# ('rear axle assy', 57)
# ('subframe assy', 52)
# ('tube assy ', 52)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#  FILLER ASSY WITH BREATHER PIPE .  is ::-->
# ('pipe assy ', 70)
# ('frame assy ', 67)
# ('air filter', 67)
# ('rear axle assy', 64)
# ('a pillar', 63)
#
#  "GRANIT_BLACK-CONSOLE ASSY,PANEL,TOP" .  is ::-->
# ('rear axle assy', 51)
# ('control panel', 47)
# ('back leak hose', 46)
# ('oil cooler', 46)
# ('glass run mould ', 45)
#
#  "CLRPRT_ASY_2-CONSOLE ASSY,FRONT" .  is ::-->
# ('frame assy ', 46)
# ('subframe assy', 42)
# ('ac compressor', 42)
# ('control brake', 42)
# ('tube assy ', 41)
#
#  "CLRPART_ASSY-CONSOLE ASSY,FRONT" .  is ::-->
# ('frame assy ', 46)
# ('cross car beam', 46)
# ('rear axle assy', 46)
# ('catalytic converter', 45)
# ('coolant hose', 43)
#
#  "CLRPART_ASSY-CONSOLE ASSY,MAIN BODY" .  is ::-->
# ('frame assy ', 46)
# ('cross car beam', 46)
# ('rear axle assy', 46)
# ('catalytic converter', 45)
# ('coolant hose', 43)
#
#  "GRANIT_BLACK-CONSOLE ASSY,BEZEL USB,FRON" .  is ::-->
# ('rear axle assy', 51)
# ('control panel', 47)
# ('back leak hose', 46)
# ('oil cooler', 46)
# ('glass run mould ', 45)
#
#  "SLAT_DK_GREY-ARM REST ASSY,FRONT DOOR,LH" .  is ::-->
# ('after treatment assy', 57)
# ('rear axle assy', 45)
# ('frame assy ', 44)
# ('auto slack adjuster', 44)
# ('air intake system', 42)
#
#  SCISSORS JACK ASSY .  is ::-->
# ('ac compressor', 52)
# ('rear axle assy', 50)
# ('subframe assy', 45)
# ('lambda sensor', 45)
# ('secondary seal ', 44)
#
#  WINDSCREEN ASSY .  is ::-->
# ('leaf screen', 62)
# ('pipe assy ', 58)
# ('subframe assy', 57)
# ('frame assy ', 56)
# ('wiring harness ', 55)
#
#  ANTI VIBRATION SHEET with aluminum backing .  is ::-->
# ('ventilation hose', 56)
# ('driver station ', 53)
# ('traction motor', 53)
# ('cabin wiring harness', 50)
# ('front wiring harness', 50)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  MANUAL WITH CHILLER HOSE .  is ::-->
# ('cantrail', 57)
# ('panel ', 55)
# ('urea tank', 53)
# ('handle ', 50)
# ('common rail', 47)
#
#  Telematics Control Unit with eSIM .  is ::-->
# ('control panel', 56)
# ('control shaft', 56)
# ('pneumatic tube', 49)
# ('traction motor', 49)
# ('steering column', 47)
#
#  NEUTRAL_SLVR-ASSY CONSOLE FINISHER FRONT .  is ::-->
# ('rear axle assy', 44)
# ('front axle beam', 40)
# ('inner handle', 38)
# ('control shaft', 38)
# ('cylinder valve', 37)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  USB with AUX Cable .  is ::-->
# ('hub', 67)
# ('bush', 57)
# ('tube ', 57)
# ('gusset', 44)
# ('rubber bush', 43)
#
#  REINFORCEMENT FRONT SPRING BKT FRONT-LH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  LIQUID LINE ASSY .  is ::-->
# ('liquid hose', 67)
# ('pipe assy ', 56)
# ('rear axle assy', 53)
# ('glass guide ', 52)
# ('main wiring harness', 51)
#
#  2 & 3) .  is ::-->
# ('u bolt', 22)
# ('o ring', 22)
# ('lp hose', 20)
# ('hp hose', 20)
# ('hp tube ', 20)
#
#  ADV.  is ::-->
# ('valve ', 50)
# ('load valve', 46)
# ('handle ', 44)
# ('adapter', 40)
# ('ac duct', 40)
#
#  GROMET .  is ::-->
# ('grommet', 92)
# ('armrest', 62)
# ('rivet', 55)
# ('reinforcement ', 53)
# ('gasket ', 50)
#
#  Actuator Assy (TY 24/24) RH .  is ::-->
# ('battery tray', 56)
# ('accelerator pedal', 53)
# ('alternator ', 52)
# ('cross car beam', 52)
# ('modulator valve', 50)
#
#  REINFORCEMENT RH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  "REINFORCEMENT,RH" .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  LINK;ROD ASSY .  is ::-->
# ('liner ', 67)
# ('drag link', 62)
# ('wiper link ', 57)
# ('pin', 57)
# ('clip', 50)
#
#  REINFORCEMENT LH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  "REINFORCEMENT,REAR-RH" .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  Car Jack .  is ::-->
# ('air tank', 62)
# ('camera', 57)
# ('parking camera', 55)
# ('bracket', 53)
# ('aux tank', 50)
#
#  Dip stick... .  is ::-->
# ('dipstick ', 94)
# ('sticker', 62)
# ('tail pipe', 56)
# ('driver station ', 52)
# ('pneumatic pipe', 52)
#
#  REINFORCEMENT BOTTOM LH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  ESP Unit .  is ::-->
# ('a mount', 53)
# ('b mount', 53)
# ('c mount', 53)
# ('air processing unit', 52)
# ('engine mount', 50)
#
#  Cooling Module .  is ::-->
# ('coolant hose', 62)
# ('oil cooler', 58)
# ('connecting rod', 57)
# ('con rod', 57)
# ('cylinder ', 55)
#
#  "Infotainment 8.8"" system" .  is ::-->
# ('air intake system', 65)
# ('instrument panel', 46)
# ('foam seal', 44)
# ('reinforcement ', 44)
# ('intermediate shaft', 44)
#
#  PIANO_BK_PLN-SIDE DEFLECTOR ASS .  is ::-->
# ('reflex reflector', 47)
# ('accelerator pedal', 46)
# ('reflective tape', 43)
# ('safety triangle', 43)
# ('inner handle', 42)
#
#  "PIANO_BK_PLN-ANTENNA,RADIO" .  is ::-->
# ('instrument panel', 50)
# ('parking camera', 47)
# ('air intake pipe', 46)
# ('intake manifold', 46)
# ('piston head', 45)
#
#  ENERGY ABSORBER ASSY .  is ::-->
# ('shock absorber ', 59)
# ('after treatment assy', 55)
# ('power steering gearbox', 52)
# ('steering sensor', 51)
# ('steering arm', 50)
#
#  "REINFORCEMENT,LH" .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  Timing chain upper guider... .  is ::-->
# ('inner handle', 54)
# ('tailgate hinge', 51)
# ('air intake pipe', 50)
# ('cabin wiring harness', 49)
# ('outer handle', 49)
#
#  Timing chain moveable guide (C... .  is ::-->
# ('main wiring harness', 52)
# ('tail wiring harness', 52)
# ('cabin wiring harness', 51)
# ('engine wiring harness', 50)
# ('pigtail wiring harness', 49)
#
#  Timing chain fix guide upper (... .  is ::-->
# ('inner handle', 50)
# ('pigtail wiring harness', 48)
# ('tailgate hinge', 48)
# ('cabin wiring harness', 46)
# ('outer handle', 45)
#
#  "REINF ASSY,A-PILLAR,RH" .  is ::-->
# ('frame assy ', 70)
# ('tube assy ', 63)
# ('pipe assy ', 63)
# ('subframe assy', 61)
# ('wiring harness ', 58)
#
#  PIANO_BK_PLN-HUMINITY STRIP;RH .  is ::-->
# ('ignition switch', 48)
# ('ignition sensor', 48)
# ('intake pipe', 42)
# ('nylon pipe bunch', 42)
# ('instrument panel', 42)
#
#  "Pressure Regulatory Assy, With Pressure Gauge" .  is ::-->
# ('pressure sensor', 62)
# ('rear axle assy', 58)
# ('rear damper', 51)
# ('oil pressure switch', 51)
# ('subframe assy', 49)
#
#  STRUCTURE ASSY;DASHBOARD for Side airvent ring .  is ::-->
# ('structural pad', 71)
# ('tube assy ', 70)
# ('structural foam', 69)
# ('subframe assy', 67)
# ('structural tape', 62)
#
#  DOSING CONTROLLER UNIT .  is ::-->
# ('air processing unit', 59)
# ('control shaft', 57)
# ('oil cooler', 56)
# ('mounting nut', 53)
# ('control panel', 51)
#
#  "LINKAGE ASSY,TRANSFER CASE" .  is ::-->
# ('pipe assy ', 67)
# ('frame assy ', 64)
# ('tube assy ', 57)
# ('drag link', 57)
# ('subframe assy', 56)
#
#  STUD Assy .  is ::-->
# ('tube assy ', 78)
# ('subframe assy', 64)
# ('glass guide ', 60)
# ('pipe assy ', 56)
# ('stub axle', 56)
#
#  "ENGINE SHIELDING ASSY,RH" .  is ::-->
# ('engine wiring harness', 57)
# ('engine hood', 56)
# ('main wiring harness', 55)
# ('windshield ', 52)
# ('pigtail wiring harness', 51)
#
#  "REINFORCEMENT,RH" .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  HOSE ASSY;LATCH LH TO T-CONNECTOR .  is ::-->
# ('tube assy ', 67)
# ('pipe assy ', 67)
# ('subframe assy', 64)
# ('brake hose', 63)
# ('frame assy ', 63)
#
#  SUPPORT ASSY;RH .  is ::-->
# ('pipe assy ', 67)
# ('subframe assy', 64)
# ('tube assy ', 57)
# ('frame assy ', 55)
# ('spray suppression', 55)
#
#  ENG.MTG.  is ::-->
# ('engine mount', 75)
# ('mounting bolt', 72)
# ('mounting nut', 67)
# ('a mount', 63)
# ('b mount', 63)
#
#  ASSY END CROSS MBR .  is ::-->
# ('cross member ', 67)
# ('crash member', 53)
# ('subframe assy', 52)
# ('frame assy ', 50)
# ('rear axle assy', 50)
#
#  REINFORCEMENT;RH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  SUPPORT ASSY;RADIATOR MTG;RH .  is ::-->
# ('pipe assy ', 67)
# ('subframe assy', 64)
# ('tube assy ', 57)
# ('frame assy ', 55)
# ('spray suppression', 55)
#
#  REINFORCEMENT;RH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#  REINFORCEMENT;RH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  OUTER PIECE;RH .  is ::-->
# ('egr pipe', 63)
# ('outrigger ', 60)
# ('rubber spacer', 58)
# ('side valance cover', 55)
# ('wheel cover', 55)
#
#  SUPPORT ASSY;RADIATOR MTG;RH .  is ::-->
# ('pipe assy ', 67)
# ('subframe assy', 64)
# ('tube assy ', 57)
# ('frame assy ', 55)
# ('spray suppression', 55)
#
#  REINFORCEMENT;RH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  ANTI ROLL BACK ASSY .  is ::-->
# ('anti roll bar ', 75)
# ('rear axle assy', 48)
# ('after treatment assy', 46)
# ('spacer plate', 45)
# ('synchro ring', 45)
#
#  REINFORCEMENT;RH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  GUARD BASE;FUEL TANK .  is ::-->
# ('hand brake', 60)
# ('glass guide ', 57)
# ('gas balancer ', 55)
# ('urea hose', 53)
# ('mud guard', 53)
#
#  AFTER TREATMENT SYSTEM ASSY .  is ::-->
# ('after treatment assy', 85)
# ('subframe assy', 50)
# ('air intake system', 50)
# ('frame assy ', 49)
# ('instrument cluster', 49)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  (new updated for bottom elbow) .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  .  is ::-->
# ('mounting bolt', 0)
# ('u bolt', 0)
# ('bolt ', 0)
# ('mounting washer', 0)
# ('mounting screw', 0)
#
#  ASSY GB HSG FRT+INTER+REAR DD .  is ::-->
# ('rear axle assy', 49)
# ('front seat', 44)
# ('front wiring harness', 43)
# ('front strut', 43)
# ('wheel arch liner', 43)
#
#  "REINFORCEMENT,LH" .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  RISER ASSY .  is ::-->
# ('pipe assy ', 74)
# ('frame assy ', 70)
# ('rear axle assy', 67)
# ('tube assy ', 63)
# ('subframe assy', 61)
#
#  REINFORCEMENT LH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  "EGP, ATS Sensor & EGP protective shield kit" .  is ::-->
# ('egr pipe', 55)
# ('lp hose', 40)
# ('hp hose', 40)
# ('bearing ', 40)
# ('king pin', 36)
#
#  "EGP, ATS Sensor & EGP protective shield kit" .  is ::-->
# ('egr pipe', 55)
# ('lp hose', 40)
# ('hp hose', 40)
# ('bearing ', 40)
# ('king pin', 36)
#
#  Steering system .  is ::-->
# ('steering wheel', 69)
# ('air intake system', 62)
# ('steering arm', 59)
# ('spring washer ', 57)
# ('steering belt', 57)
#
#  REINFORCEMENT ASSY .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  Vacuum diaphragm... .  is ::-->
# ('vacuum pump', 67)
# ('vacuum hose', 59)
# ('airbag ecu', 54)
# ('vacuum booster', 53)
# ('rear damper', 44)
#
#  Breather Assembly .  is ::-->
# ('washer system ', 60)
# ('subframe assy', 60)
# ('frame assy ', 59)
# ('rear axle assy', 58)
# ('tube assy ', 54)
#
#  ONE PIECE) .  is ::-->
# ('nylon pipe', 63)
# ('intake pipe', 60)
# ('egr pipe', 59)
# ('nylon spacer', 57)
# ('dowel pin', 56)
#
#  STAY COMPLETE .  is ::-->
# ('stay rod', 57)
# ('spacer plate', 56)
# ('counter shaft', 54)
# ('compressor ', 52)
# ('check strap', 50)
#
#  PACKING FOR FACE DUCT .  is ::-->
# ('packing plate', 70)
# ('rubber packing', 67)
# ('parking brake', 60)
# ('pin', 60)
# ('bearing ', 57)
#
#  HEADER ASSY;FRONT ROOF .  is ::-->
# ('frame assy ', 67)
# ('rear axle assy', 64)
# ('tube assy ', 60)
# ('pipe assy ', 60)
# ('headliner ', 60)
#
#  HOOK ASSY EXAUST LH .  is ::-->
# ('exhaust manifold', 51)
# ('exhaust valve ', 50)
# ('auto slack adjuster', 47)
# ('exhaust pipe', 45)
# ('tube assy ', 43)
#
#  Kit AIS .  is ::-->
# ('gasket ', 62)
# ('air filter', 59)
# ('air tank', 53)
# ('air duct', 53)
# ('tube assy ', 50)
#
#  REINFORCEMENT RH .  is ::-->
# ('o ring', 60)
# ('rib', 57)
# ('pin', 57)
# ('bearing ', 55)
# ('oil ring', 50)
#
#  CCC Assembly Exhaust manifold ... .  is ::-->
# ('exhaust manifold', 65)
# ('intake manifold', 46)
# ('exhaust valve ', 43)
# ('exhaust pipe', 40)
# ('glass run mould ', 38)
#
#  Housing front half cast iron .  is ::-->
# ('differential housing', 58)
# ('front suspension', 55)
# ('front wiring harness', 54)
# ('connecting rod', 48)
# ('main wiring harness', 47)
#
#  Housing rear half cast iron for parking brake .  is ::-->
# ('catalytic converter', 52)
# ('rear axle assy', 49)
# ('long runner ', 47)
# ('suspension tower', 47)
# ('differential housing', 47)
# 1955

# %%
# for line in clean_doc:
    
#     line1 = line.lower()
#     #string = line1.partition(",")[0].partition(";")[0].partition("(")[0].partition("[")[0].partition('for')[0].partition('with')[0].partition('w/o')[0].partition('offer')[0].partition('\bw\b')[0]

#     closest_match = process.extractOne(replacer(line1).lower(), fuzzydict, scorer=fuzz.token_sort_ratio)
    
#     if(closest_match[1] >= 75):
#         print(line, " is ::-->", closest_match)
#         clean_doc.remove(line)
        
# print(len(clean_doc))

# %%
clean_doc
# Out:
# ['GRP TPL 87R INTRA1100/2250WB/BSVI .',
#  'STRAP .',
#  'FRONT MTG ASSY RH .',
#  'ASSY BRKT(IP INLINE & E-BOX CONN. MTG) .',
#  '"HOUSING,FRONT-HALF" .',
#  'EXHAUST SYSTEM ASSY .',
#  'REINFORCEMENT ASSY RH .',
#  'SUPPORT SHEET BODY MTG .',
#  'STRAP ASSY .',
#  'ENGINE MTG ASSY REAR-RH .',
#  'FAN DRIVE ASSY 12 V .',
#  'HEX.',
#  'HEX.',
#  'HEX.',
#  'EXTENSION PIECE ASSY EXTENSION FRONT-RH .',
#  'C-SUPPORT CHANNEL .',
#  'RESERVOIR BOTTLE ASSY .',
#  'HEX FL SCR M6X40 TS17130-8.8-SS8451S2-Y .',
#  'REINFORCEMENT ASSY FRONT SPRING LH .',
#  'Rear lower link LH .',
#  'PLUG (STUB AXLE-TOP) .',
#  'CONTAINER ASSY .',
#  'anti .',
#  'FOR HORN .',
#  'Assy water inlet line (Water Pump to Air Compressor) .',
#  'CAB MTG CLOSING ASSY LH .',
#  'CCB Assembly .',
#  'TORSION BAR .',
#  'FUEL LINES ASSY-COMPLETE .',
#  'OFFER DRG ASSY RECEPTACLE CAP .',
#  'UNION 1/4 NPT (M/S SWAGELOK) .',
#  'Pressure gauge .',
#  'REINFORCEMENT ASSY RH .',
#  'WELD STUD M6X16 .',
#  '"REINFORCEMENT,EXHAUST BRACKET,FRONT" .',
#  '"FAN ,SHROUD & PWM ASM" .',
#  '5456 1625 2001)" .',
#  'WITH VALVES .',
#  'FUEL LINES ASSY (FWS TO ENGINE) .',
#  'FRONT HALF .',
#  'DETENT ASSY (SHIFTER SHAFT) .',
#  '"HOOK ASSY WITH BRACKET,FRONT HALF" .',
#  '"STRUCTURE ASSY,CABIN ROOF,MIDDLE" .',
#  'QUARTER TURN KNOB FUSE BOX MTG(TDCV) .',
#  'ASSY.SUPPORT(BONNET SIDE) .',
#  '"SUPPORT,BUMPER MTG,RH" .',
#  'REINFORCEMENT E/RAIL RHD .',
#  'UTILITY BOX ASSY .',
#  '"LINK,LOCK BARREL TO LATCH,LH" .',
#  '"LINK,OUTER HANDLE TO LATCH FRONT DOOR,LH" .',
#  'HEAD BOX ASSY .',
#  '"HEAD BOX,RH" .',
#  '"PACKING,COWL MTG,FRONT" .',
#  '"CONSOLE ASSY,BEZEL USB,FRONT" .',
#  '"CONSOLE,REAR" .',
#  'COOLING UNIT ASSY .',
#  '"BERTH ASSY,LOWER" .',
#  '"QUARTER TURN KNOB,FUSE BOX MTG" .',
#  '"REINFORCEMENT,SPRING HANGER BKT,RH" .',
#  'ASSY ROCKER ARM INTAKE(M/S TIMKEN) .',
#  'MANIFOLD EXHAUST .',
#  'OMS ASSY .',
#  'TALBROS) .',
#  'MANIFOLD EXHAUST END .',
#  'LOAD GUARD ASSY .',
#  'Timing chain guide locator .',
#  'Detainer plug .',
#  'Antiseptic cream .',
#  'Timing chain guide (Moveable) .',
#  'Adopter for LH/ RH rear brake pipe from front brake pipe .',
#  'Side repeater harness (LH and RH) .',
#  'Centre fascia .',
#  'HOUSING FRONT-HALF .',
#  'WITH SCOOP MTG.',
#  'SUB ASSY SUBFRAME LH (SUBFRAME) .',
#  'ASSY.REAR ANTIROLL BAR COMPLETE(OFFER DRAWING) .',
#  '(POWER) .',
#  'ASSY CAT CONVERTER {YUTAKA} (5GM) .',
#  'WITH CAP .',
#  'DEFLECTOR (VENTURE) .',
#  'REVERSE GUIDING SYSTEM CONTROLLER-M/S.INTERFACE .',
#  'ANTENNA ASSY .',
#  'KIT CDL MINDA VALEO VENTURE BSIV DICOR .',
#  'KIT IMMOBILIZER VENTURE .',
#  'SCISSORS JACK WITH 3 PIECE HANDLE .',
#  'ASSY BUTTERFLY WINDOW LH (ASAHI) .',
#  'ASSY MIDDLE CARRIAGE LH .',
#  'ASSY PLUG-IN WINDOW COMPLETE RH .',
#  'ASSY FRONT WIPER KIT -LUCAS .',
#  'Corner reinf LH .',
#  'Centre reinf .',
#  'Inner reinf .',
#  'rainforcement bkt.',
#  'rainforcement bkt.',
#  'reinforcement bkt.',
#  'rainforcement bkt.',
#  'Reinf (Between L3 and L15) .',
#  'reinf .',
#  'Shot gun .',
#  'I .',
#  'II .',
#  'Tunnel bottom reinf .',
#  'Tunnel bottom reinf .',
#  'Tunnel reinforcement panel .',
#  'Big .',
#  'Tow hook reinf .',
#  'Exhaust hanger reinf .',
#  'Reinf inner side on sill outer .',
#  'Tail gate sill inner .',
#  'Tool kit mounting .',
#  'Cup reinf lower for strut .',
#  'Bottom .',
#  'Sill inner front .',
#  'Sill reinf .',
#  'Sill reinf .',
#  'A plr inner upper .',
#  'Shot gun reinf .',
#  'Sill side outer rear .',
#  'Reinf 2 sill outer .',
#  'Reinf 4 sill outer .',
#  'Reinf between sill side front and rear .',
#  'B plr reinf betn BSO and B plr inner .',
#  'B plr lower inner reinf .',
#  'Inner reinf upper .',
#  'CCB mtg locator .',
#  'Cant rail inner front .',
#  'A plr upper reinf on cant rail .',
#  'Rear header outer .',
#  'Reinf.',
#  'Reinf.',
#  'Reinf.',
#  'TOW HOOK FRONT .',
#  'CANOPY MTG ASSY FRONT-LH .',
#  'TOW HOOK .',
#  'CONNECTING LINK .',
#  'LOWER SADDLE .',
#  'LOWER SADDLE .',
#  'NOx Univolt (Gen 4 PV Protocol) .',
#  'BODY SIDE ASSY OUTER-RH .',
#  'BODY SIDE ASSY OUTER-LH .',
#  'BODY SIDE ASSY INNER-LH .',
#  'WAIST REINFORCEMENT OUTER LH .',
#  'ASSY SHOT GUN RH .',
#  'Pigtail .',
#  'Signa Close Proximity mirror .',
#  'Ace Gold - Front Turn Indicator RH .',
#  'Ace Gold Petrol BSVI .',
#  'PLUG BUTTON FOR REINF CAB MTG FRONT SLOT 8X12 .',
#  'SUPPORT INNER-LH .',
#  'SUPPORT OUTER-LH .',
#  'PIGTAIL .',
#  'ANTI ROLL BACK ASSY .',
#  'M/S.PRABHA.',
#  'TIE MEMBER LH .',
#  '15- TS17716 .',
#  'ENGINE SHIELDING ASSY RH .',
#  'ASSY.ARM BLADE & NOZZLE FITMENT DRIVER SIDE M/S.',
#  'BCS .',
#  'Front View Mirror Assly .',
#  'TOW HOOK .',
#  '"STRAP ASSY & RUBBER,FUEL TANK MTG" .',
#  'Frame Assembly .',
#  'Fuel Supply Module .',
#  'FT HARNESS DCT XZ .',
#  '"REINFORCEMENT ASSY,CANTRAIL,RH" .',
#  '"REINFORCEMENT ASSY,B-PILLAR,INNER-RH" .',
#  '"REINFORCEMENT,TUNNEL,REAR" .',
#  '"SUPPORT ASSY,RADIATOR MTG,RH" .',
#  'Assy water inlet line (Water Pump to Air Compressor) .',
#  'EXTENSION PIECE ASSY EXTENSION FRONT-RH .',
#  'C-SUPPORT CHANNEL .',
#  'C-REINFORCEMENT LH .',
#  'ASSY FOR PARALLEL ROD MGT .',
#  'ASSY FOR PARALLEL ROD MGT .',
#  'ASSY VERTICAL SUPPORT BRKT-2 .',
#  'ENGINE MTG ASSY REAR-RH .',
#  'ENG.',
#  'L-REINFORCEMENT BOTTOM-RH .',
#  'LINK ASSY .',
#  'REINFORCEMENT FRONT-BOTTOM-RH .',
#  'REINFORCEMENT FRONT-BOTTOM-LH .',
#  'SIDE GUARD .',
#  'RESONATOR BOX ASSY .',
#  'TOW HOOK .',
#  'CATALITIC CONVERTER ASSY .',
#  '"PIGTAIL,ENGINE LAMP" .',
#  'UNIVERSAL JOINT ASSY .',
#  'SPEAKER 5.25 WITH RAIN COVER (BLAUPUNKT .',
#  '"REINFORCEMENT ASSY,RH" .',
#  'HEX.',
#  'ABS WITH AEBS SUPPORT .',
#  'HEX.',
#  'HEX.',
#  'HEX.',
#  'HEX.',
#  'HEX.',
#  'FL.',
#  'ELECTRONICS STABILITY CONTROL MODULE .',
#  'STRAP ASSY .',
#  '"REINFORCEMENT,BUMPER CROSS MEMBER,RH" .',
#  'OWNERS MANUAL .',
#  'OWNERS MANUAL .',
#  'OWNERS MANUAL .',
#  'L-REINFORCEMENT .',
#  'Cooling System .',
#  'Engine oil filling neck .',
#  'Blow by unit (crankcase ventilation / Oil separator) .',
#  'Timing chain .',
#  'Timing chain fix guide .',
#  'Third and forth gear engaging gear (on output shaft) .',
#  'Jack .',
#  'Front (crash) bracket .',
#  'Inner rear view mirror .',
#  'Fresh air inlet vent (Behind headlamp dome) RH .',
#  'Water jacket piece (on block) .',
#  'Detainer plug .',
#  'Detainer spring .',
#  'LCRV unit spring guider .',
#  'Centre console (Front side) mounting screw .',
#  'HP line .',
#  'ROF BOW EXTENSION FRONT-LH .',
#  'ROF BOW EXTENSION FRONT-LH .',
#  'ROF BOW EXTENSION FRONT-LH .',
#  'REINFORCEMENT TG HINGE MTG LH .',
#  'ROF BOW EXTENSION FRONT-LH .',
#  'REINFORCEMENT TG HINGE MTG LH .',
#  'Rear Reinforcement .',
#  'SUPPORT REINF B PLR UPPER LH .',
#  'REINF.',
#  'MEMBER RAD SUPPORT BOTTOM LH .',
#  'REINF RAD SUPPORT BOTTOM .',
#  'MEMBER RAD SUPPORT BOTTOM LH .',
#  'MEMBER RAD SUPPORT BOTTOM RH .',
#  'EXTN RAD SUPPORT UPPER LH .',
#  'EXTN RAD SUPP MTG BOTTOM RH .',
#  'EXTN RAD SUPPORT UPPER RH .',
#  'MEMBER RAD SUPPORT LH .',
#  'MEMBER RAD SUPPORT RH .',
#  'MEMBER RAD SUPPORT BOTTOM LH .',
#  'MEMBER RAD SUPPORT BOTTOM RH .',
#  'RAD SUPPORT UPPER INNER LH .',
#  'RAD SUPPORT LOWER INNER LH .',
#  'X MEM FIXING REINF LH+RH .',
#  'REINF.REAR QUARTER OUTER LH .',
#  'REINF.REAR QUARTER OUTER LH .',
#  'REINF REAR QUARTER UPPER .',
#  'REINF.REAR QUARTER OUTER LH .',
#  'ASSY REINF REAR ELR MTG .',
#  'PURGE LINE .',
#  '"CUP,SHOCK ABSORBER" .',
#  'Reinforcement Jacking Point .',
#  'Sill Outer Closing Part .',
#  'SASH TOP RR DR LH .',
#  'PNL FRAME REINFORCEMENT RR DR LH .',
#  'PNL REINFORCER LATCH RR DR LH .',
#  '"CUP, TAILGATE" .',
#  '"REINFORCEMENT,HOOD,RH" .',
#  '"REINFORCEMENT,HOOD HINGE,LH" .',
#  '"REINFORCEMENT,HOOD HINGE,RH" .',
#  '"REINFORCEMENT,HOOD STRIKER MTG" .',
#  '"REINFORCEMENT,HOOD,FRONT" .',
#  '"REINFORCEMENT,HOOD HINGE,LH" .',
#  '"REINFORCEMENT,HOOD HINGE,RH" .',
#  '"REINFORCEMENT,HOOD STRIKER MTG" .',
#  '"REINFORCEMENT,HOOD,FRONT" .',
#  'BODY SIDE OUTER REAR LH .',
#  'BODY SIDE OUTER REAR LH .',
#  'SASH FORWARD FRT DOOR LH .',
#  '"REINFORCEMENT,FRONT DOOR PANEL FRAME,LH" .',
#  'REINF ENGINE MTG LH .',
#  '"REINFORCEMENT BRACKET,FRONT-LH" .',
#  'REINF ENGINE MTG LH .',
#  'REINF DIAPHRAGM FRONT CRASH INNER FRONT .',
#  '"REINFORCEMENT BRACKET,FRONT-LH" .',
#  '"REINFORCEMENT,SUBFRAME MTG BRACKET,LH" .',
#  'REINF ENGINE MTG LH .',
#  'REINF DIAPHRAGM ENGINE MTG LH .',
#  'REINF DIAPHRAGM FRONT CRASH INNER FRONT .',
#  'REINFORCEMENT FUEL FILLER LID .',
#  'REINFORCEMENT FUEL FILLER LID .',
#  'WATER CHANNEL RHD .',
#  'WATER CHANNEL RHD .',
#  'WATER CHANNEL RHD .',
#  '"MEMBRANE,FRONT DOOR,LH" .',
#  'MAGAZINE POCKET ASSY .',
#  'EGR COOLER ASSY (M/S BORG WARNER) .',
#  'OWNERS MANUAL .',
#  '"INNER HANDEL ASSY,FRONT DOOR,LH" .',
#  'OWNERS MANUAL .',
#  'VEHICLE ELECTRONIC CONTROLLER UNIT (550654701604) 12V .',
#  'ESC TELLTALE INDICATOR .',
#  'SPEAKER 5.25 WITH RAIN COVER (BLAUPUNKT) RH .',
#  'OWNERS MANUAL .',
#  'COUPLING BODY (M36X2 M26X1.5) .',
#  'CANOPY MTG STRUCTURE ASSY .',
#  '15- TS17716 .',
#  'REINFORCEMENT DASHBOARD FRONT .',
#  'TRUST BAR .',
#  'LEAF FLAP .',
#  'SUPPORT .',
#  'SUPPORT .',
#  'NRW .',
#  'ASSY REINF FRONT MTG LH (LONG MEMBER) .',
#  '(PRIMARY BKT.)',
#  'Operation manual .',
#  'Counter weight (100% balancing) .',
#  'DOC .',
#  'SCR .',
#  'SCR+ASC .',
#  'SELECTION FOR TIPPER BODIES .',
#  'SUPPORT BOTTOM (4TH & 5TH C/M) .',
#  'GRP ID-18CUM BODY/LPK3118/BGS SUSP .',
#  'AIR PRESSURE TRANSDUCER .',
#  'MAGAZINE POCKET LH .',
#  'MAGAZINE POCKET RH .',
#  'PACKING 2.5 THK.',
#  'PACKING 5 THK.',
#  'PACKING 1.6 THK.',
#  'PACKING PAD .',
#  'CLEAT .',
#  'CLOSE COUPLED CATCON ASSY .',
#  'FLOOT MAT LH .',
#  'BEADING (FIRE WALL) .',
#  'FRONT VIEW MIRROR ASSY .',
#  'REINFORCEMENT CENTER BRG CROSS MEMBER .',
#  'EXTERNAL ANTENNA ROD .',
#  'AIR PRESSURE TRANSDUCER .',
#  'OWNERS MANUAL .',
#  'PACKING 4 THK.',
#  'NOISE SHIELD ASSY BOTTOM .',
#  'ASSY KNOB .',
#  'PITAMN ARM .',
#  'SUPPORT BTM -SPR.C/M REAR FRONT .',
#  'Gap hider plastic strip .',
#  'RETAINER RING .',
#  'OWNERS MANUAL .',
#  'Fuel Lines .',
#  'Fuel Lines .',
#  'Fuel Lines .',
#  ')[MAT-VITON] .',
#  'NEEDLE CAGE 5TH SPEED M/S INA .',
#  '280 DIA.',
#  '(REINFORCED)-CK .',
#  'FIRTEE 12X12X12 .',
#  'ALUMINIUM FOIL .',
#  'VEHICLE ELECTRONIC CONTROLLER UNIT .',
#  'OSB FOR 407 TURBO/709 TURBO (ENGLISH) .',
#  'OPERATOR`S SER.',
#  'OPERATOR`S SERVICE BOOK-709/909EX(COMBINN .',
#  '- SFC 407 PICKUP .',
#  'OPERATOR S SERVICE BOOK-LP 909 CNG .',
#  'Assy Frame .',
#  'Assy Frame .',
#  'Assy Frame .',
#  'Reinforcement .',
#  'Reinforcement .',
#  'Reinforcement .',
#  'Reinforcement .',
#  'a .',
#  'a .',
#  'a .',
#  'a .',
#  'a .',
#  'a .',
#  'COOLING SYSTEM ASSY .',
#  'LINK ROD .',
#  'AIS for Ultra 1415 vehicle with 3.3L NG BSVI .',
#  'FORK 5-R .',
#  'SHIFTER GUIDE .',
#  'MODIFICATION OF tpl EXHAUST SYSTEM WITH 18L UREA TANK ASSY .',
#  'DIFFUSER .',
#  '"LOWER SADDLE,REAR" .',
#  'AC UNIT ASSY .',
#  'STRUCTURE ASSY WITH CED .',
#  'Rear housing .',
#  'Troop carrier .',
#  'WARN INDICATOR .',
#  'OIL MIST SEPARATOR ASSY .',
#  'TC ASSY WITH BOOST PRESSURE ACTUATOR .',
#  'CARRIER HOUSING .',
#  'DIFFERENTIAL CASE .',
#  'SHIFTER FORK .',
#  'SHIFTER FORK .',
#  'TWIN CONE ASSY 1ST/2ND CONE .',
#  'INTERMEDIATE COE 1ST/2ND CONE .',
#  'ASSY.SUBSTRUCTURE RHD .',
#  'R.H.D.',
#  'Noise Shield LH .',
#  'Noise Shield LH .',
#  'REAR MTG ASSY .',
#  'ASSY TIE MEMBER(LPK1109) .',
#  'Rear Half .',
#  'Rear Half .',
#  'Front Half .',
#  'Coolant Line Assy Front .',
#  'Pressure Ring .',
#  'ROCKER ARM-OFFER DRG .',
#  'STUD CM8X40 IS1862 8.8 SS9400 .',
#  'SERRATED) .',
#  'DOSER UNIT ASSY .',
#  'STRAP ASSY WITH PIN & BOLT .',
#  'Earth Strap .',
#  'Earth Strap .',
#  'Earth Strap .',
#  'Earth Strap .',
#  'Borgwarner) .',
#  'ASSY Dash Board NARROW LHD .',
#  'ANGLE SUPPORT .',
#  'SUPPORT MIDDLE (SIDE WALL) .',
#  'ANGLE SUPPORT LH .',
#  'ASSY FRONT MIRROR .',
#  'ASSY FLR CONSOLE AIR HAND .',
#  'ASSY.SIDE SHIELDING R.H.LHD .',
#  'PACKING .',
#  'PUSH ROD ASSY WITH FORK .',
#  'UNION .',
#  '"REAR SUPPORT,REAR MTG CHASSIS SIDE" .',
#  'TIRE .',
#  'CLOSE PROXIMITY MIRROR ASSY .',
#  'INTEGRATED FILLING UNIT ASSY .',
#  'OIL MIST SEPARATOR ASSY .',
#  '"ARRESTOR ASSY,FRONT CYLINDER,RH" .',
#  '"ARRESTOR ASSY,FRONT CYLINDER,LH" .',
#  'LEG ASSY .',
#  'SUBSTRUCTURE ASSY WITH FLOOR .',
#  'OMS .',
#  'FAN (418 DIA.)',
#  'EXH.',
#  'REINFORCEMENT ASSLY SNORKEL MOUNTING TOP RH .',
#  'PLUG .',
#  '"ARRESTOR ASSY,REAR" .',
#  '"REINFORCEMENT,RH" .',
#  '"REINF, REAR WALL CENTER" .',
#  'HAT SECTION .',
#  'REINFORCEMENT TOP-RH .',
#  'CENTER CLUSTER ASSY .',
#  'LEG ASSY .',
#  'E-Viscous Fan .',
#  'CMG .',
#  'TIE ROD (325 LONG) .',
#  'Plug .',
#  '"Oil Supply Line Assy, Air Compressor" .',
#  '"HEAT SHEILD ASSY, EXHAUSTELBOW" .',
#  'RR Sliding Window Mould .',
#  'Engine Cooling System .',
#  'Engine Cooling System .',
#  'Engine Cooling System .',
#  'Front unpainted .',
#  'RH .',
#  'SHIELD .',
#  '"Holder, Parking Sensor" .',
#  'L-REINFORCEMENT LH .',
#  'Extension assembly .',
#  'SLIDE SUPPORT .',
#  'REINFORCEMENT ASSY RH .',
#  'FUSE BOX SUPPORT ASSY .',
#  'ASSY.MEGA FUSE MTG BRKT.',
#  'USB SOCKET .',
#  'USER REMOTE (NEW) .',
#  'CBCU3-E .',
#  'REAR AC .',
#  'FE LIGHT MODE .',
#  '"HOLDER,PARKING SENSOR" .',
#  'TELEMATICS CONTROL UNIT .',
#  'VEHICLE ELECTRONIC CONTROLLER UNIT .',
#  'FOR HORN .',
#  '"LINK,POP UP KNOB TO LATCH FRONT DOOR,LH" .',
#  '"LINK,POP UP KNOB TO LATCH FRONT DOOR,RH" .',
#  'BOTTOM REINFORCEMENT -RH .',
#  '"REINFORCEMENT,BUMPER CROSS MEMBER,RH" .',
#  '"REINFORCEMENT,BUMPER CROSS MEMBER,LH" .',
#  'REINFORCEMENT BUMP STOPPER .',
#  'REINFORCEMENT FRONT SPRING BKT FRONT-RH .',
#  'L-REINFORCEMENT TOP-RH .',
#  '"REINFORCEMENT,MIDDLE" .',
#  '"L-REINFORCEMENT,TOP-" .',
#  'C-REINFORCEMENT LH SMALL .',
#  'L-REINFORCEMENT Bottom -RH .',
#  'L-REINFORCEMENT TOP-RH .',
#  'BUNCH ASSY .',
#  'HOUSING ASSY .',
#  '(Reverse Gear – GB750 Helical) .',
#  'SPRING STRAP .',
#  'RESTRICTION INDICATOR .',
#  'ENGINE COOLING SYSTEM .',
#  'ASSY SERVICE INDICATOR (FLEETGUARD) .',
#  'AFTER TREATMENT SYSTEM ASSY .',
#  'AFTER TREATMENT SYSTEM ASSY .',
#  'AFTER TREATMENT SYSTEM ASSY .',
#  'RESTRICTION INDICATOR ELECTROMECHANICAL.N .',
#  'ENGINE COOLING SYSTEM .',
#  'SET-COOLING SYSTEM .',
#  'ASSY CYL.',
#  'KIT-ENGINE COOLING SYSTEM .',
#  'CARRIER HOUSING .',
#  '"REINFORCEMENT,RH" .',
#  '"REINFORCEMENT,RH" .',
#  'REINFORCEMENT BRACKET LH .',
#  'L-REINFORCEMENT .',
#  'L-REINFORCEMENT .',
#  'L-REINFORCEMENT TOP-RH .',
#  'REINFORCEMENT MIDDLE-RH .',
#  'ANGLE SUPPORT LH .',
#  '"EXTENSION PIECE ASSY,FRONT-RH" .',
#  'REFRIGERANT LIQUID LINE ISLE LPK FC .',
#  'ASSY MTG BRKT ADD ON BODY SIDE RH .',
#  '"REINFORCEMENT,FRONT" .',
#  '"REINFORCEMENT,RH" .',
#  '"REINFORCEMENT,RH" .',
#  '"REINFORCEMENT,LH" .',
#  '"L-REINFORCEMENT,BOTTOM-LH" .',
#  'SUPPORT .',
#  '"L-REINFORCEMENT,TOP-LH" .',
#  'SUPPORT ASSY .',
#  'ASSY.BALL JOINT .',
#  '"ARMATURE ASSY,DASHBOARD" .',
#  '"AIR VENT ASSY,CENTER" .',
#  '"AIR VENT ASSY,CENTER-LH" .',
#  'REINFORCEMENT FRONT-RH .',
#  'ASSY TOOLBOX (WITH SUPPORT) .',
#  '"ENGINE SHIELD,LH" .',
#  'PACKING .',
#  'PACKING .',
#  'PACKING .',
#  'PACKING .',
#  'SUPPORT ASSY .',
#  '"L-REINFORCEMENT,BOTTOM-LH " .',
#  'THROTTLE ASSLY .',
#  'ADD-DEL SHEET FOR WH EMS ADD/DEL ECN .',
#  'main ip .',
#  'Pigtail 12v ultra (Retro fitment) .',
#  'TFT Monitor Tropicool .',
#  '"GUARD,PROPELLER SHAFT" .',
#  'Urea Line Suction .',
#  'Urea Line Return .',
#  'Urea Line Pressure .',
#  'MIRROR ASSY FRONT .',
#  'SUPPORT TOP RH .',
#  'L-REINFORCEMENT .',
#  'L-REINFORCEMENT .',
#  'C-REINFORCEMENT LH .',
#  'SPRING ASSY REAR .',
#  '"REINFORCEMENT,RH" .',
#  '"REINFORCEMENT,LH" .',
#  'Reinforcement RH/LH .',
#  'Reinforcement RH/LH .',
#  'Return assly line .',
#  'Return assly line .',
#  'Return assly line .',
#  'Return assly line .',
#  'Return assly line .',
#  'Return assly line .',
#  'Return assly line .',
#  'AFTER TREATMENT SYSTEM ASSY .',
#  'PLUG .',
#  'AIR DRYER .',
#  'AFTER TREATMENT SYSTEM ASSY .',
#  'LPT 4923 BSVI Signa LM RH .',
#  'TO OVERLAP JOINT .',
#  'REINFORCEMENT BUMP STOPPER .',
#  'ASSY TOP RAIL REAR .',
#  'Cross Mbr Assy .',
#  'C-CHANNEL (FOR DOUBLE X-MEMBER ASSY) .',
#  '"SUPPORT,CROSS MEMBER MTG,BOTTOM" .',
#  '"SUPPORT ASSY,FACE SIDE PANEL,LH" .',
#  'PRIMA 5523.S LM LH .',
#  'Out trigger assly Chassis Side LH .',
#  'LM LH .',
#  '"REINFORCEMENT,CROSS MEMBER" .',
#  '"REINFORCEMENT,LH" .',
#  '"REINFORCEMENT,RH" .',
#  '"L-REINFORCEMENT,BOTT" .',
#  '"ADD ON,BODY SIDE,RH" .',
#  'REINFORCEMENT SPRING CROSS MEMBER LH .',
#  'BRKT FOR HARNESS MOUNTING TYPE D .',
#  'VEHICLE ELECTRONIC CONTROLLER UNIT .',
#  'ASSY ENG C.M (FRONT) .',
#  'SPR.',
#  'C-REINFORCEMENT LH LONG .',
#  '5 th X-mbr .',
#  '"SPEAKER 4""" .',
#  'SUPPORT ASSY LH .',
#  'REINFORCEMENT RH ( SUB STRUCTURE REAR .',
#  '"SUPPORT ASSY,AIR INTAKE PIPE" .',
#  'REINFORCEMENTRH .',
#  'REINFORCEMENTLH .',
#  'C-REINFORCEMENT LH LONG .',
#  'STABILISER BAR .',
#  'BRKT FRONT CAB SUSP LOWER RH M0 CAB .',
#  'PIVOT ARM LOWER RH .',
#  'BRKY_PIVOT_ARM_UPPER_LH .',
#  'BRKT_FRONT__CAB_SUSP_LOWER_NRH .',
#  'ASSY BRKT LATERAL S/A MTG M0 CAB NRH .',
#  'PEDESTAL ASSY WITH PIN & NUT .',
#  'SUPPORT (FOR AUX.',
#  '"REINFORCEMENT,RH_UNPAINTED" .',
#  '"L-REINFORCEMENT,TOP-RH_UNPAINTED" .',
#  'CHANNEL ASSY .',
#  'L-REINFORCEMENT TOP-RH .',
#  'L-REINFORCEMENT TOP-LH .',
#  'REINFORCEMENT MIDDLE-BOTTOM-RH .',
#  'REINFORCEMENT TOP-RH .',
#  'STRUCTURE ASSY .',
#  '"REINFORCEMENT,RH" .',
#  '"REINFORCEMENT,RH" .',
#  'C-REINFORCEMENT .',
#  'C-REINFORCEMENT .',
#  'C-REINFORCEMENT LH LONG .',
#  'REINFORCEMENTRH .',
#  'REINFORCEMENTLH .',
#  'REINFORCEMENT .',
#  'HEX FL SCR M6X10 TS17130-8.8-SS8451S2-B .',
#  'Cooling System .',
#  'CENTER FINISHER ASSY .',
#  'Aero Corner without deflector RH .',
#  'Assy Aero Corner with deflector LH .',
#  'CENTER FINISHER_7 INCH Screen .',
#  'CENTER FINISHER_7 INCH Screen .',
#  'SPRING RETAINER .',
#  'DETENT PLUG .',
#  'Ext.',
#  'Ext.',
#  'Ext.',
#  'Relay Arm .',
#  'LINK ROD .',
#  'Assy.',
#  'Assy.',
#  'with Bush .',
#  'RH .',
#  'LH .',
#  'Egp Mtg .',
#  'Assy.',
#  'Assy.',
#  '"REINFORCEMENT, TOP-LH" .',
#  'REINFORCEMENT .',
#  'REINFORCEMENT .',
#  'REINFORCEMENT .',
#  'ANTIFRETTING PASTE SKF .',
#  'UNDERBODY ASSY .',
#  'CAB MTG ASSY REAR-LH .',
#  'Signa Close Proximity mirror .',
#  'REINFORCEMENT .',
#  'REINFORCEMENT .',
#  'With Spacer RH .',
#  'With Spacer LH .',
#  'TOOL BAG (M&HCV) .',
#  'Frame .',
#  'Reinforcement RH .',
#  'SUPPORT ASSY WITH SPACER .',
#  'SUPPORT ASSY WITH SPACER .',
#  'SUPPORT ASSY WITH SPACER .',
#  'Cyl Head Semi-finished (Bought out) .',
#  'COOLANT LINE ASSY (UREA INJECTOR TO ENGINE) .',
#  'Exhaust Manifold .',
#  'with weld nut .',
#  'CONSOLE REAR .',
#  'ENGINE SHIELDING ASSY RH .',
#  '"ENGINE SHIELDING ASSY,LH" .',
#  'Assy Frame Complete .',
#  'RUBBER GROMMAT .',
#  'AFTER TREATMENT SYSTEM ASSY .',
#  'Close coupled caton .',
#  'Close coupled caton .',
#  'Assy.',
#  'ASSY EXTENSION PIECE LH .',
#  'SUBSTRUCTURE ASSY WITH FLOOR .',
#  '"FILLER NECK ASSY WITH BRACKET,TOP" .',
#  'RUBBER HANGER .',
#  'ASSY_SUBSTRUCTURE_FRONT_COMPLETE .',
#  '"TIE MEMBER ASSY,UPPER" .',
#  '"REAR CLADDING,RH" .',
#  'ABUTMENT REINFORCEMENT BRACKET-GC .',
#  'MOULD REAR SLIDING WINDOW .',
#  'Assembly Exhaust manifold with closed couple Catcon (CCC complete) .',
#  'Catalytic convertor .',
#  'Assy.',
#  '"SUPPORT ROD,RADIATOR MTG" .',
#  '"MAGAZINE POCKET, FRONT DOOR LH" .',
#  '"STUD ASSY,BATTERY MTG" .',
#  'ASSY LONGITUDINAL FRONT R .',
#  'ASSY SASH COMPLETE FR/DR R .',
#  'ASSY LONGITUDINAL REAR RH .',
#  'MEMBER ENGINE MTG UPR .',
#  'ASSY REINF FRNT LH RR CRS .',
#  'REINFORCEMENT .',
#  '"REINFORCEMENT ASSY,RH" .',
#  '"SUPPORT ASSY,FLOOR,FRONT" .',
#  '"REINFORCEMENT,LONG MEMBER,FRONT-RH" .',
#  'ABC .',
#  '(DP Sesnor) .',
#  'with Bracket , TC to Intercooler" .',
#  'OIL CHANNEL (Rear Half) .',
#  'NYLON INSERT .',
#  'Pop Up Knob Link Gromate .',
#  'Canning for LNT + cDPF .',
#  '694CC BS6 CNG Ace 750 .',
#  'BULKHEAD ENGINE D-MTG FRONT .',
#  'Buzzer Mtg brkt .',
#  'REINFORCEMENT .',
#  'REINFORCEMENT .',
#  'REINFORCEMENT(RH) .',
#  'REINFORCEMENT .',
#  'Cambox housing .',
#  'EARTH STRAP .',
#  '"LONGITUDINAL,FRONT-LH" .',
#  '"REINFORCEMENT,LONG MEMBER LH" .',
#  '"LONGITUDINAL,REAR-RH" .',
#  '"REINFORCEMENT,LONGITUDINAL,FRONT-LH" .',
#  '"REINFORCEMENT,LH" .',
#  '"REINFORCEMENT,RH" .',
#  'Winger Front Unit .',
#  'GSL ASSEMBLY .',
#  'Differential .',
#  'DGBB 6208 C3 FAG .',
#  'Chiller Unit (Heat Exchanger) .',
#  'condensor .',
#  '"CRASH ASSY,INNER,FRONT-RH" .',
#  'RUBBER MAT (For Stowage Box) .',
#  'Assy.',
#  'Assy.',
#  'ANTI VIBRATION SHEET ASSY UNDERBODY .',
#  'OIL COLLECTOR (FRONT HALF HOUSING) .',
#  'OFFER DRG ASSY RECEPTACLE CAP .',
#  'CONTAINER RESTRAINTS CONTROL MODULE .',
#  'BODY SIDE ASSY LH .',
#  'Assy Cyl Crank Case .',
#  'EXHAUST SYSTEM ASSY FRONT .',
#  'Scissor Jack .',
#  '"LONGITUDINAL FRONT,MIDDLE-LH" .',
#  'PNL LONGI FRT RR EXT REAR LH .',
#  '"SIDE SILL,INNER-FRONT-LH" .',
#  'WIPER ADD ON PART .',
#  '"GAP HIDER, AMT CONSOLE" .',
#  'FL TAP SCR C-ST 3.5X13 TS17249SS8451 S2 -Y .',
#  '"DCT, GEAR" .',
#  'ABC .',
#  'GRANIT_BLACK-ASSY CARRY HOOK .',
#  'PEPS UID REMOTE .',
#  '"HOUSING,FRONT-HALF" .',
#  '"HOUSING,REAR-HALF" .',
#  'BOTTOM RH .',
#  'ASSY TIE MEMBER COMPLETE .',
#  'FEED LINE ASSY .',
#  'CLRPART_ASSY-CONSOLE REAR .',
#  'Assy Lower Control Arm LH .',
#  'REINFORCEMENT ASSY QTR PILLAR REAR-LH .',
#  'ASSY CROSS MBR PAN HARD ROD MTG .',
#  'TOW HOOK MTG ASSY REAR STAGE II .',
#  'REINFORCEMENT ASSY A-PILLAR INNER-RH .',
#  'REAR QUARTER ASSY INNER-RH .',
#  'REINFORCEMENT WAIST FRONT DOOR OUTER-RH .',
#  'REINFORCEMENT ASSY B-PILLAR INNER-RH .',
#  'REINFORCEMENT ASSY SIDE SILL RH .',
#  'REINFORCEMENT ASSY CANTRAIL RH .',
#  'ASSY LONG MBR INR FRT LH COMPL .',
#  'FRONT HEADER ASSY .',
#  'REAR QUARTER ASSY INNER-LH .',
#  'REAR QUARTER ASSY INNER-RH .',
#  '"BODY SIDE ASSY,INNER-FRONT-LH" .',
#  '"BODY SIDE ASSY,INNER-FRONT-RH" .',
#  'CLRPRT_ASY_2-CONSOLE STRUCTURE ASSY .',
#  'CONSOLE ASSY XMA . "',
#  'EPP Pad RH (As rester behind RQT) .',
#  '"Ex.',
#  '"CARRIER ASSY,HEADLAMP MTG," .',
#  '"BARRE_GREY-CLADDING ASSY,R" .',
#  '"BARRE_GREY-CLADDING ASSY,F" .',
#  '"BARRE_GREY-CLADDING ASSY,F" .',
#  'Shedder Rear .',
#  '"REINFORCEMENT,LONG MEMBER,LH" .',
#  'NIPPLE FOR THERMOSTAT BY PASS .',
#  'SW. MARQUARDT .',
#  'HILL HOLDER SW (SPRING RETURN MARQUART) .',
#  'SUBSTRUCTURE ASSY FRONT .',
#  'TELEMATICS UNIT .',
#  'REINFORCEMENT ASSY FRONT SPRING LH .',
#  'BALANCE WEIGHT 30 GRAMS .',
#  'Assy vapor Line Underbody ( Tiago Petrol) .',
#  'Feed Line Assly Under body .',
#  'Fork 3rd 4th .',
#  'HOOK ASSY WITH BRACKET FRONT HALF .',
#  'REINFORCEMENT ASSY RH .',
#  'REINFORCEMENT RH .',
#  'REINFORCEMENT RH .',
#  'REINFORCEMENT - RH .',
#  'REINFORCEMENT RH .',
#  'REINFORCEMENT - RH .',
#  'THERMOSTAT ELEMENT .',
#  'TOOL KIT .',
#  'OIL MIST SEPARATOR MTG ASSY .',
#  'AC UNIT ASSY .',
#  'ENGINE A-MTG ARM .',
#  'PNL REINF SPRING SUSP CUP RR LH .',
#  'Coolant Line Assy .',
#  'Coolant Line Assy .',
#  'Coolant Line Assy .',
#  '"Side indicator - Prima, Signa" .',
#  '"ADD ON,BUMPER MIDDLE" .',
#  '"ADD ON,BUMPER,RH" .',
#  '"AERO CORNER ASSY,RH" .',
#  'AERO CORNER WITHOUT DEFLECTOR RH .',
#  'Cooling unit assy .',
#  'ADD ON ASSY BODY SIDE RH .',
#  '"ROCKER ARM ASSY WITH BUSH,EXHAUST" .',
#  'REAR SPRING ASSY .',
#  'KIT-COOLING SYSTEM .',
#  'COUPLING .',
#  'SELECTOR & SHIFTER FORK ASSY WITH GSL .',
#  '"REINFORCEMENT ASSY,LH" .',
#  '"REINFORCEMENT ASSY,RH" .',
#  '"PULL CUP,FRONT DOOR,RH" .',
#  'Turbo charger to intake manifo... .',
#  'LCRV unit .',
#  'LCRV unit spring .',
#  'REINFORCEMENT FRONT SPRING BKT REAR-RH .',
#  '"PIGTAIL, UREA LEVEL SENSOR" .',
#  'HOOK ASSY WITH BRACKET FRONT HALF .',
#  '"REINFORCEMENT, LH" .',
#  'SUPPORT RH .',
#  'ABS WITH AEBS SUPPORT .',
#  'ASSY.',
#  'CLEAT .',
#  'L-REINFORCEMENT TOP-RH .',
#  'L-REINFORCEMENT TOP-LH .',
#  'REINFORCEMENT RH .',
#  'TIE BAR ASSY .',
#  'TIE MEMBER ASSY .',
#  '"L-REINFORCEMENT,SUSPN,FRONT-INNER-RH" .',
#  'REINFORCEMENT RH .',
#  'REINFORCEMENT BUMPER CROSS MEMBER RH .',
#  'REINF SIDE SILL FRONT LH .',
#  'REINF JACKING POINT REAR LH .',
#  'REINF JACKING POINT REAR LH .',
#  'REINF SIDE SILL FRONT LH .',
#  'BSO CLOSER FRONT UPPER LH .',
#  'REINF SIDE SILL FRONT LH .',
#  'REINF MIDDLE .',
#  'EXHAUST HOOK .',
#  'NVH REINF FRONT .',
#  'EXHAUST HOOK .',
#  '"REINFORCEMENT BRACKET,REAR FLO..." .',
#  'TOWING HOOK .',
#  'REINFORCEMENT .',
#  'REINFORCEMENT .',
#  'JACK FIXING FRONT .',
#  'LONGITUDINAL_REAR_CENTER .',
#  'ANCHORAGE .',
#  'ANCHORAGE ANCHORAGE .',
#  '"REINFORCEMENT,FUEL TANK MTG," .',
#  'REINF MBR FRT CRASH LH & RH .',
#  '"REINFORCEMENT,PIVOT MTG BRACKE..." .',
#  '"CLOSING PIECE,REAR-LH CLOSING ..." .',
#  '"REINFORCEMENT BRACKET,RTB,LH" .',
#  'PNL REINF SPRING SUSP CUP RR L... .',
#  '"REINFORCEMENT,PIVOT MTG BRACKE..." .',
#  '"REINFORCEMENT BRACKET,RTB MTG,..." .',
#  'PNL REINF SPRING SUSP CUP RR L... .',
#  '"REINFORCEMENT,LONGITUDINAL,REA..." .',
#  'REINFORCEMENT SEAT BELT REAR-R... .',
#  '"ROD,EXHAUST MTG,REAR" .',
#  '"REINFORCEMENT PLATE,REAR SEAT ..." .',
#  'REINFORCEMENT SEAT BELT REAR-R... .',
#  '"REINFORCEMENT BRACKET REAR-LH,..." .',
#  'Reinforcement .',
#  '"REINFORCEMENT BRACKET REAR-LH,..." .',
#  'LONGITUDINAL FRONT LH .',
#  'ASSY TUNNEL LINK MTG .',
#  'REINF CAB LIFT REAR LH .',
#  '"REINF FRAME FRONT LH, RH" .',
#  '"REINFORCEMENT BRACKET REAR-LH,..." .',
#  'BRKT CONSOLE MTG .',
#  'LONGITUDINAL FRONT LH .',
#  'REINFORCEMENT FLOOR FRONT .',
#  '"REINF FRAME FRONT LH, RH" .',
#  'LONGITUDINAL FRONT LH .',
#  'XXXXXXX .',
#  'LONGITUDINAL FRONT LH 2 .',
#  'REINF CAB LIFT REAR LH .',
#  '"REINFORCEMENT,SUBFRAME MTG BRA..." .',
#  'HOUSING .',
#  '"PIGTAIL,REAR PARKING SENSOR" .',
#  'OFFER DRAWING FRONT SHOCK ABSORBER .',
#  'ASSY.PACKING .',
#  'LPO\\LP 497 4SP 3L ENG FES TO CHASSIS EARTH .',
#  'BEEPER ALARM UNIT WITH BRACKET .',
#  'DC TO DC CONVERTER .',
#  'AIR PRESSURE TRANSDUCER .',
#  'ASSY.',
#  'HYDRAULIC JACK ASSY .',
#  'ASSY REAR VIEW MIRROR OUTER RH .',
#  'RVM ASSY OUTER-RH .',
#  'TRACTION INVERTER .',
#  'JUNCTION BOX TRACTION .',
#  'CONTROLLER .',
#  'REINFORCEMENT RH .',
#  'RESILIENCE MTG .',
#  'RESILIENCE MTG .',
#  'RESILIENCE MTG .',
#  'EXHAUST SYSTEM ASSY WITH HEAT SHIELD .',
#  'BULKHEAD LONGITUDINAL REAR .',
#  'REINFORCEMENT SUSPENSION CM REAR-RH .',
#  'SUPPORT ASSY CAB MTG RH .',
#  'ENGINE MTG ASSY .',
#  'L-REINFORCEMENT TOP-RH .',
#  'L-REINFORCEMENT TOP-LH .',
#  'MUSIC SYSTEM Group ID G350662 .',
#  'ARRESTOR ASSY .',
#  'FRONT HALF .',
#  'FORK 3RD/4TH SPEED .',
#  'SHIFTER FORK 1ST/2ND SPEED .',
#  '"REINFORCEMENT,BOTTOM,RH" .',
#  '"REINFORCEMENT,LH" .',
#  '"REINFORCEMENT,RH" .',
#  'Assy Delivery Line Underbody (Tiago Petrol) .',
#  'AFTER TREATMENT SYSTEM ASSY .',
#  'VEHICLE ELECTRONIC CONTROLLER UNIT .',
#  'REINFORCEMENT BUMPER CROSS MEMBER RH .',
#  'REINFORCEMENT BUMPER CROSS MEMBER LH .',
#  'REINFORCEMENT RH .',
#  'REINFORCEMENT LH .',
#  'ANTI VIBRATION SHEET .',
#  'ANTI VIBRATION SHEET .',
#  'ANTI VIBRATION SHEET .',
#  'ANTI VIBRATION SHEET .',
#  'CLD sheet .',
#  'REINFORCEMENT BUMPER CROSS MEMBER RH .',
#  'REINFORCEMENT BUMPER CROSS MEMBER LH .',
#  'REINFORCEMENT RH .',
#  'REINFORCEMENT LH .',
#  'V ROD MGT BRKT RH .',
#  'REINFORCEMENT SHEET ASSY BOTTOM .',
#  'REINFORCEMENT FRONT-RH .',
#  'REINFORCEMENT FRONT-LH .',
#  'C-REINFORCEMENT LH .',
#  'C-REINFORCEMENT RH .',
#  'C-REINFORCEMENT LH .',
#  'Pigtail Alternattor .',
#  'VEHICLE ELECTRONIC CONTROLLER UNIT .',
#  'ASSY.',
#  'Pigtail Alternattor .',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'CONDESNER ASSY .',
#  '"ENGINE MTG ARM,FRONT" .',
#  'OFFER DRG BALL VALVE D/FEMALE 1/2IN.BSPN .',
#  'BALANCING WEIGHT 180 GRAMS .',
#  '"PLUNGER,FUEL FILLER RELEASE MODULE" .',
#  'REAR SPRING ASSY .',
#  'TORQUE ROD ASSY .',
#  'V-ROD ASSY .',
#  'SPEAKER 5.25 WITH FOAM M/S NIPPON MAKE .',
#  'EARTH STRAP .',
#  'PIGTAIL VEHICLE TRACKING SYSTEM .',
#  '.',
#  'SUPPORT REINFORCEMENT .',
#  'SUPPORT REINFORCEMENT .',
#  '.',
#  'Jack .',
#  'Thermostat housing .',
#  '"SUPPORT ASSY,ENGINE CROSS MEMBER,RH" .',
#  '5.51E+11 .',
#  'REINFORCEMENT RH .',
#  'REINFORCEMENT LH .',
#  'L-REINFORCEMENT TOP-RH .',
#  'L-REINFORCEMENT TOP-LH .',
#  'REINFORCEMENT BOTTOM RH .',
#  'REINFORCEMENT BOTTOM LH .',
#  'REINFORCEMENT .',
#  'ASSY.',
#  'REINFORCEMENT (REAR)-LH .',
#  'ASSY.',
#  'ASSY.REINFORCEMENT .',
#  '.',
#  'SLIDE SUPPORT .',
#  'ASSY.',
#  '.',
#  'ASSY.',
#  'REINFORCEMENT TOP-RH .',
#  'REINFORCEMENT( L.H.)',
#  '.',
#  'ASSY.STUD.',
#  '.',
#  'REINFORCEMENT RH .',
#  'REINFORCEMENT RH .',
#  'REINFORCEMENT LH .',
#  'REINFORCEMENT RH .',
#  'REINFORCEMENT LH .',
#  'REINFORCEMENT RH .',
#  'REINFORCEMENT LH .',
#  'ASSY.',
#  'ASSY.',
#  'ASSY.',
#  'ASSY.',
#  'REAR SPRING BRKT -(FRONT)- LH .',
#  ...]
