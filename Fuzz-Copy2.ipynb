# %%
# %%time
# need to filter first through simple string search and manual logic; then apply fuzzy matching to filter the leftovers
# like in notebook Fuzz

import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
import numpy as np
import pandas as pd
import re
from csv import reader
from fuzzywuzzy import fuzz, process

stopwords = set(stopwords.words("english"))

dictionary = pd.read_csv('E:\JS\Py\Text_similarity\Fuzzy.csv', header=None, squeeze=True).to_dict()
#sec_dict1 = pd.read_csv('E:\JS\Py\Text_similarity\Second_dict.csv', header=None, squeeze=True).to_dict()
with open('E:\JS\Py\Text_similarity\Second_dict.csv', 'r') as read_obj:
    csv_reader = reader(read_obj)
    sec_dict = list(map(tuple, csv_reader))

master_doc = []
match_doc = []

def stringsearch(string, sub_str, sub_str1, line):
    if(string.find(sub_str)!=-1 and string.find(sub_str1)!=-1):
        final_doc.append(sub_str+" "+sub_str1)
        clean_doc.remove(line)
        return (1)
        
def secondsearch(string, sub_str, line):
    #r = fuzz.token_set_ratio(string, sub_str)
    r = fuzz.token_sort_ratio(string, sub_str)
    if(r > 90):
        final_doc.append(sub_str)
        clean_doc.remove(line)
        return (1)
    
def thirdsearch(string, sub_str, line):
    r = fuzz.token_set_ratio(string, sub_str)
    #r = fuzz.token_sort_ratio(string, sub_str)
    if(r > 90):
        final_doc.append(sub_str)
        clean_doc.remove(line)
        return (1)

def listtostring(clean_line):
    return(" ".join(clean_line))

def replacer(string1):
    return(string1.replace('\bscr\b','screw').replace('\bspr\b','spring').replace('\bbd\b','band').replace('spr bd','spring band')
           .replace('\bw/h\b','wiring harness').replace('brg','bearing').replace('bkt','bracket').replace('bkt.','bracket').replace('\bwh\b','wiring harness')
           .replace('w/h','wiring harness').replace('\breinf.\b','reinforcement').replace('\breinf\b','reinforcement').replace('\bwh\b','wiring harness').replace('mtg.','mounting')
           .replace('\bmtg\b','mounting').replace('\bbrkt\b','bracket').replace('\brr\b','rear').replace('frt','front').replace('\bdr\b','door').replace('5th','fifth').replace('\bfes\b','driver station')
           .replace('reinfrocement','reinforcement').replace('mountingbracket','mounting bracket').replace('nylon pipe','nylon bunch').replace('pipe bunch','nylon bunch').replace('vent tube','vent hose').replace('\bvent\b','ventilation')
           .replace('suction tube','suction hose').replace('\bcyl\b','cylinder').replace('suction pipe','suction hose').replace('suction line','suction hose').replace('fuel return pipe','fuel return hose')
           .replace('coolant pipe','coolant hose').replace('exh','exhaust').replace('batt','battery').replace('loadbody','load body').replace('\barb\b','anti roll bar').replace('window regulator','window winding')
           .replace('pressure line','pressure hose').replace('return line','return hose').replace('gear box','gearbox').replace('shell assy','load body').replace('\bfl\b','flanged').replace('flat bed','load body').replace('high deck','load body')
           .replace('lining','liners').replace('\bgb\b','gearbox').replace('\bstg\b','steering').replace('-conn','connector').replace('\bconn\b','connector').replace('assembly','assy'))
   
#using Lemmatization
lemma = nltk.wordnet.WordNetLemmatizer()

file_docs = []
test_doc = []
test_line = []

with open('E:\JS\Py\Text_similarity\Doc5.csv', 'r', encoding="UTF-8") as inp, open('E:\JS\Py\Text_similarity\Doc3.txt', 'w') as out:
    for line in inp:
        out.write(line + '.\n')

with open ('E:\JS\Py\Text_similarity\Doc3.txt') as f:
    tokens = sent_tokenize(f.read())
    #wtokens = word_tokenize(f.read())
    for line in tokens:
        file_docs.append(line)
        

# create a clean document after removing the stop-words and generate lemmas
clean_doc = []

for line in file_docs:
    clean_line = [word for word in line.split() if word not in stopwords]
    
    for word in line.split():
        test_line.append(lemma.lemmatize(word))
    test_doc.append(listtostring(test_line))
    test_line = []
    
    #clean_doc.append(listtostring(clean_line))
    clean_doc = test_doc

final_doc=[]
init_size = len(clean_doc)
loop_size = init_size*85%

#first loop of search and filtering
while (len(clean_doc)>loop-size):
    
    for line in clean_doc:

        line1 = line.lower()
        string = line1.partition(",")[0].partition(";")[0].partition("(")[0].partition("[")[0].partition('for')[0].partition('with')[0].partition('w/o')[0].partition('offer')[0].partition('\bw\b')[0]

        for y in sec_dict:
            if (stringsearch(replacer(string.lower()),y[0].lower(),y[1].lower(), line) == 1):
                print(line, " is ::-->")
                break
        if(len(final_doc)!=0):
            print(final_doc)
        final_doc = [] 


print(len(clean_doc))
# Out:
# SUCTION LINE ASSY .  is ::-->
# ['suction hose']
# RETURN LINE ASSY .  is ::-->
# ['return hose']
# "WIRING HARNESS,AEBS FRAME (52WB) (282154621601)" .  is ::-->
# ['wiring harness ']
# "DRUM BRAKE ASSEMBLY WITH DC, RR LH (140mm)" .  is ::-->
# ['drum  brake']
# RADIATOR & INTERCOOLER ASSY .  is ::-->
# ['radiator ']
# FAN SHROUD ASSY .  is ::-->
# ['fan shroud']
# BRACKET .  is ::-->
# ['bracket ']
# "L-BRACKET,EXHAUST PIPE MTG" .  is ::-->
# ['bracket ']
# BRACKET ASSY CABLE ANCHORING SHIFT .  is ::-->
# ['bracket ']
# GEAR SHIFTER ASSYÂ (M/s Excel) .  is ::-->
# ['gear shifter ']
# WHEEL RIM ASSY WITH VALVE (205 PCD) .  is ::-->
# ['wheel rim ']
# "PIPE ASSY,JOINT TO JOINT (29WB)" .  is ::-->
# ['pipe assy ']
# Holder Parking Sensor .  is ::-->
# ['parking sensor']
# "PLATE,SPARE WHEEL MTG" .  is ::-->
# ['plate ']
# CLAMP PIPE .  is ::-->
# ['clamp ']
# PROPELLER SHAFT ASSY DRIVE .  is ::-->
# ['propeller shaft']
# PIPE BUNCH ASSY .  is ::-->
# ['nylon bunch']
# PIPE BUNCH ASSY .  is ::-->
# ['nylon bunch']
# LONG MEMBER RH .  is ::-->
# ['long member']
# HOSE .  is ::-->
# ['hose ']
# WATER FILLER PIPE AWT TO RADIATOR .  is ::-->
# ['pipe ']
# PIPE RETARDER TO ENGINE .  is ::-->
# ['pipe ']
# PIPE RADIATOR TO RETARDER .  is ::-->
# ['pipe ']
# SUPPORT BRACKET .  is ::-->
# ['bracket ']
# SUBFRAME ASSY .  is ::-->
# ['subframe assy ']
# SPACER RUBBER .  is ::-->
# ['rubber spacer']
# BRACKET MUDGUARD MTG LH .  is ::-->
# ['bracket ']
# BALATA .  is ::-->
# ['balata ']
# BALATA .  is ::-->
# ['balata ']
# DUST COVER .  is ::-->
# ['cover ']
# REFLECTIVE TAPE .  is ::-->
# ['reflective tape']
# REFLECTIVE TAPE .  is ::-->
# ['reflective tape']
# Fender Extension Assy RH .  is ::-->
# ['fender ']
# "LEAF SPRING ASSY,FRONT-RH" .  is ::-->
# ['leaf spring ']
# FLAT BED ASSY .  is ::-->
# ['load body ']
# FRONT SEAT ASSY LH 2W ODS .  is ::-->
# ['front seat']
# 100% Rear Seat with ISOFIX .  is ::-->
# ['rear seat']
# "COVER ASSY,DISPLAY,LOWER" .  is ::-->
# ['cover ']
# Clamp sunroof .  is ::-->
# ['clamp ']
# "WHEEL ARCH LINER ASSY,REAR-LH " .  is ::-->
# ['wheel arch liner']
# Rear Door Rub Rail LH .  is ::-->
# ['rub rail ']
# Rear Door Rub Rail RH .  is ::-->
# ['rub rail ']
# ALLOY PIANO JETBLACK + BRIGHT CROME T LOGO (M/S JAI HIND AUTO PVT LTD) .  is ::-->
# ['logo ']
# "BRACKET ASSY,AC PIPE MTG" .  is ::-->
# ['bracket ']
# COCKPIT ASSY .  is ::-->
# ['cockpit ']
# HEAD LINING ASSY .  is ::-->
# ['liner ']
# DUAL BRAKE VALVE WITH SWITCH .  is ::-->
# ['brake valve']
# FUEL SUCTION PIPE ASSY .  is ::-->
# ['suction hose']
# RETURN FUEL PIPE ASSY .  is ::-->
# ['pipe assy ']
# FUEL PIPE ASSY .  is ::-->
# ['pipe assy ']
# FRONT PIPE ASSY .  is ::-->
# ['pipe assy ']
# EXHAUST TAIL PIPE .  is ::-->
# ['exhaust pipe']
# HOSE .  is ::-->
# ['hose ']
# TUBE .  is ::-->
# ['tube ']
# HOSE .  is ::-->
# ['hose ']
# HOSE .  is ::-->
# ['hose ']
# SWITCH EXHAUST BRAKE FOR 3L ENGINE .  is ::-->
# ['switch ']
# WIRING HARNESS SWITCH .  is ::-->
# ['wiring harness ']
# WIRING HARNESS SCR PIGTAL .  is ::-->
# ['wiring harness ']
# PLATE .  is ::-->
# ['plate ']
# INSTRUMENT CLUSTER ASSY .  is ::-->
# ['instrument cluster']
# "LONG MEMBER, LH" .  is ::-->
# ['long member']
# "PROPELLER SHAFT ASSY,COUPLING" .  is ::-->
# ['propeller shaft']
# "PROPELLER SHAFT ASSY,MONOTRON" .  is ::-->
# ['propeller shaft']
# FUEL FILTER ASSY WITH BRACKET .  is ::-->
# ['fuel filter']
# FUEL FILTER ASSY WITH BRACKET .  is ::-->
# ['fuel filter']
# BRACKET CENTER BRG MTG .  is ::-->
# ['bracket ']
# BRACKET ASSY UREA TANK MTG .  is ::-->
# ['bracket ']
# BRAKE CHAMBER RH .  is ::-->
# ['brake chamber']
# "LONG MEMBER,LH" .  is ::-->
# ['long member']
# NYLON PIPE BUNCH ASSY .  is ::-->
# ['nylon bunch']
# WIRING HARNESS TAIL .  is ::-->
# ['wiring harness ']
# ASSY A/C COMPRESSOR TCCI Make .  is ::-->
# ['compressor ']
# SUPPORT BRACKET ASSY .  is ::-->
# ['bracket ']
# "METAL PIPE ASSY, JOINT 1 TO JOINT 2" .  is ::-->
# ['metal pipe']
# "METAL PIPE ASSY, JOINT 3 TO DDU" .  is ::-->
# ['metal pipe']
# FUEL TANK ASSY 60L .  is ::-->
# ['fuel tank']
# "WIRING HARNESS,ABS FRAME" .  is ::-->
# ['wiring harness ']
# "BRACKET,CENTER BRG MTG" .  is ::-->
# ['bracket ']
# EMS W/H CONNECTOR SUPPORT BKT .  is ::-->
# ['bracket ']
# FRAME ASSY WITH FITMENT .  is ::-->
# ['frame assy ']
# "LONG MEMBER,LH" .  is ::-->
# ['long member']
# METAL PIPE ASSY HOSE TO INT JOINT .  is ::-->
# ['hose ']
# NYLON PIPE BUNCH ASSY CABIN .  is ::-->
# ['nylon bunch']
# SUCTION NYLON TUBE FEED PUMP TO FILTER .  is ::-->
# ['nylon tube']
# SUCTION PIPE ASSY FILTER TO FIP .  is ::-->
# ['suction hose']
# RETURN LINE PIPE ENGINE TO FILTER .  is ::-->
# ['return hose']
# PIPE ASSY DPS SENSOR INTAKE .  is ::-->
# ['intake pipe']
# KIT-HEATER HOSE .  is ::-->
# ['heater hose']
# CLUTCH PEDAL ASSY WITH MTG BKT .  is ::-->
# ['clutch pedal']
# BUNDY TUBE ASSY MIDDLE .  is ::-->
# ['bundy tube']
# SUPPORT BRACKET ACCELERATOR PEDAL .  is ::-->
# ['bracket ']
# LONG MEMBER LH .  is ::-->
# ['long member']
# STUB AXLE ASSY LH .  is ::-->
# ['stub axle']
# KIT-POWER STEERING GEAR BOX .  is ::-->
# ['power steering gearbox']
# SUCTION LINE ASSY .  is ::-->
# ['suction hose']
# RETURN LINE ASSY .  is ::-->
# ['return hose']
# DASHBOARD ASSY WITH HVAC .  is ::-->
# ['dashboard ']
# DRIVER SEAT ASSY .  is ::-->
# ['driver seat']
# W/H ROOF .  is ::-->
# ['wiring harness ']
# WIRING HARNESS FLOOR .  is ::-->
# ['floor wiring harness']
# WIRING HARNESS FRONT CHASSIS .  is ::-->
# ['front wiring harness']
# WIRING HARNESS ABS FRAME 29WB .  is ::-->
# ['wiring harness ']
# BRACKET ASSY ENGINE WIRING HARNESS MTG .  is ::-->
# ['bracket ']
# FB Sticker Maxifuse assembly .  is ::-->
# ['sticker ']
# PLATE FUEL FILTER MTG .  is ::-->
# ['plate ']
# BRACKET OIL COOLER ASSY .  is ::-->
# ['bracket ']
# CLAMP ASSY EGP MTG .  is ::-->
# ['clamp ']
# DRUM BRAKE ASSY WITH DC FRONT-LH .  is ::-->
# ['drum  brake']
# PARABOLIC LEAF SPRING ASSY FRONT .  is ::-->
# ['parabolic leaf spring']
# U-BOLT .  is ::-->
# ['u bolt']
# U-BOLT .  is ::-->
# ['u bolt']
# PIPE ASSY WITH CRIMPED HOSE .  is ::-->
# ['pipe assy ']
# BRACKET ASSY EGP MTG .  is ::-->
# ['bracket ']
# REVERSE GUIDING SENSOR SYSTEM .  is ::-->
# ['sensor ']
# REVERSE PARK ASSISTANCE SENSOR .  is ::-->
# ['sensor ']
# Z-BRACKET CONNECTOR MTG .  is ::-->
# ['bracket ']
# DRUM BRAKE ASSY WITH DC FRONT-RH .  is ::-->
# ['drum  brake']
# LONG MEMBER REAR-RH .  is ::-->
# ['long member']
# BED PLATE SEMIFINISHED .  is ::-->
# ['bed plate']
# RAW PART CRANKSHAFT (INDUCTION HARDE .  is ::-->
# ['crankshaft ']
# GEAR SHIFT ASSY WITH CABLE ASSY .  is ::-->
# ['gear ']
# COUNTER SHAFT ASSY .  is ::-->
# ['counter shaft']
# SEMIFINISHED CRANKCASE EDGE .  is ::-->
# ['crankcase ']
# VACUUM PUMP ASSY .  is ::-->
# ['vacuum pump']
# "COVER ASSY WITH BUSH,REAR" .  is ::-->
# ['cover ']
# ADAPTER PLATE .  is ::-->
# ['adapter plate']
# "ADAPTER PLATE,OIL SUMP" .  is ::-->
# ['adapter plate']
# DRIVE SHAFT - NA .  is ::-->
# ['drive shaft']
# "GEAR,1ST SPEED" .  is ::-->
# ['gear ']
# "REV GEAR/SHIFTER SLEEVE,1ST/2ND SPEE" .  is ::-->
# ['sleeve ']
# "PIPE ASSY,EGR COOLER TO AIR INTAKE E" .  is ::-->
# ['pipe assy ']
# CONNECTING ROD ASSY WITH BUSH .  is ::-->
# ['connecting rod']
# FRAME ASSY .  is ::-->
# ['frame assy ']
# "SHELL ASSY,LOAD BODY" .  is ::-->
# ['load body ']
# "WIRING HARNESS,CHASSIS" .  is ::-->
# ['wiring harness ']
# "TUBELESS TYRE,FRONT" .  is ::-->
# ['tubeless tyre']
# GRANIT_BLACK-DRIVER SEAT ASSY .  is ::-->
# ['driver seat']
# "SIDE WALL ASSY,OUTER-FRONT-RH" .  is ::-->
# ['side wall']
# GRANIT_BLACK-CO-DRIVER SEAT ASSY .  is ::-->
# ['driver seat']
# FRONT WALL ASSY .  is ::-->
# ['front wall']
# PROPELLER SHAFT ASSY .  is ::-->
# ['propeller shaft']
# FUEL TANK ASSY .  is ::-->
# ['fuel tank']
# "LEAF SPRING ASSY,REAR" .  is ::-->
# ['leaf spring ']
# "SET-CLUTCH ASSY,DIA 190" .  is ::-->
# ['clutch ']
# REAR MOUNT ASSY .  is ::-->
# ['a mount']
# "HEADLAMP ASSY WITH LEVEL MOTOR,RH" .  is ::-->
# ['head lamp']
# FLOOR CARPET .  is ::-->
# ['carpet ']
# "INNER PANEL ASSY,FRT DOOR-RH,STAGE I" .  is ::-->
# ['panel ']
# ANTI ROLL BAR ASSY WITH LINK .  is ::-->
# ['anti roll bar ']
# "FLOOR,MIDDLE" .  is ::-->
# ['floor ']
# WHEEL RIM ASSY .  is ::-->
# ['wheel rim ']
# FUEL FILTER ASSY .  is ::-->
# ['fuel filter']
# SNORKEL ASSY .  is ::-->
# ['snorkel ']
# "BRACKET ASSY,CLUTCH & BRAKE PEDAL MT" .  is ::-->
# ['bracket ']
# "OUTER PANEL,FRONT DOOR,LH" .  is ::-->
# ['panel ']
# "CLRPRT_ASY_1-DOOR TRIM ASSY,FRT DR M" .  is ::-->
# ['door trim']
# CROSS MEMBER ASSY .  is ::-->
# ['cross member']
# "SIDE WALL,LH" .  is ::-->
# ['side wall']
# "SHOCK ABSORBER ASSY,REAR" .  is ::-->
# ['shock absorber ']
# ROOF .  is ::-->
# ['roof ']
# "ACCESS COVER,ENGINE" .  is ::-->
# ['cover ']
# "B-PILLAR ASSY,INNER-RH" .  is ::-->
# ['a pillar']
# STARTER CABLE .  is ::-->
# ['cable ']
# "HOSE,IC OUTLET TO PIPE" .  is ::-->
# ['hose ']
# "INSULATION,LOAD BODY COVER" .  is ::-->
# ['insulation ']
# "WHEEL ARCH ASSY,OUTER-RH" .  is ::-->
# ['wheel arch ']
# "COVER ASSY,FRONT WHEEL ARCH,LH" .  is ::-->
# ['cover ']
# "ACCESS COVER,RADIATOR" .  is ::-->
# ['cover ']
# BRACKET ASSY .  is ::-->
# ['bracket ']
# BRACKET .  is ::-->
# ['bracket ']
# OUTRIGGER ASSY FRONT-LH .  is ::-->
# ['outrigger ']
# OUTRIGGER ASSY .  is ::-->
# ['outrigger ']
# OUTRIGGER ASSY MIDDLE DOOR .  is ::-->
# ['door ']
# OUTRIGGER ASSY FRONT-LH .  is ::-->
# ['outrigger ']
# OUTRIGGER ASSY FRONT-RH .  is ::-->
# ['outrigger ']
# LONG MEMBER HUMP REAR-RH .  is ::-->
# ['long member']
# LONG MEMBER LH .  is ::-->
# ['long member']
# LONG MEMBER REAR-LH .  is ::-->
# ['long member']
# SUPPORT PLATE LH .  is ::-->
# ['plate ']
# GUSSET ASSY .  is ::-->
# ['gusset ']
# CROSS MEMBER ASSY .  is ::-->
# ['cross member']
# PACKING PLATE .  is ::-->
# ['packing plate']
# CROSS MEMBER REAR(REAR SUSPENSION) .  is ::-->
# ['cross member']
# END CROSS MEMBER .  is ::-->
# ['cross member']
# SUSPENSION SUPPORT ASSY WHEEL ARC LH .  is ::-->
# ['suspension support']
# BRACKET AIR BELLOW MTG FRONT-LH .  is ::-->
# ['bracket ']
# WHEEL ARCH MTG ASSY .  is ::-->
# ['wheel arch ']
# SUSPENSION SUPPORT ASSY WHEEL ARC LH .  is ::-->
# ['suspension support']
# BRACKET ASSY BODY MTG LH .  is ::-->
# ['bracket ']
# BRACKET ASSY AC COMPRESSOR MTG .  is ::-->
# ['bracket ']
# BRACKET ASSY ANTI ROLL BAR MTG FRONT .  is ::-->
# ['bracket ']
# SHOCK ABSORBER ASSY FRONT .  is ::-->
# ['shock absorber ']
# BOLT M20X1.5X130-10.9 .  is ::-->
# ['bolt ']
# LEVER ASSY .  is ::-->
# ['lever ']
# BRACKET CENTER BRG MTG .  is ::-->
# ['bracket ']
# BRACKET CENTER BRG MTG .  is ::-->
# ['bracket ']
# PROPELLER SHAFT ASSY COUPLING .  is ::-->
# ['propeller shaft']
# PROPELLER SHAFT ASSY DRIVE .  is ::-->
# ['propeller shaft']
# PROPELLER SHAFT ASSY COUPLING .  is ::-->
# ['propeller shaft']
# PROPELLER SHAFT ASSY DRIVE .  is ::-->
# ['propeller shaft']
# PIPE ASSY .  is ::-->
# ['pipe assy ']
# HOSE ASSY WITH O-RING NIPPLE .  is ::-->
# ['hose ']
# BRACKET ASSY .  is ::-->
# ['bracket ']
# STEERING GEAR BOX ASSY .  is ::-->
# ['steering gearbox']
# PRESSURE LINE ASSY .  is ::-->
# ['hose ']
# RETURN LINE ASSY .  is ::-->
# ['return hose']
# PITMAN ARM .  is ::-->
# ['pitman arm']
# DRAG LINK ASSY .  is ::-->
# ['drag link ']
# BRACKET ASSY RADIATOR MTG TOP-RH .  is ::-->
# ['bracket ']
# PLATE RADIATOR MTG BRACKET .  is ::-->
# ['bracket ']
# VENT TUBE AUX WATER TANK TO ENGINE .  is ::-->
# ['hose ']
# L-BRACKET .  is ::-->
# ['bracket ']
# BRACKET .  is ::-->
# ['bracket ']
# BRACKET .  is ::-->
# ['bracket ']
# FILLER PIPE RADIATOR .  is ::-->
# ['pipe ']
# PLATE FASCIA SWITCH MTG .  is ::-->
# ['plate ']
# WIRING HARNESS TAIL .  is ::-->
# ['wiring harness ']
# WIRING HARNESS PANEL .  is ::-->
# ['wiring harness ']
# WIRING HARNESS ESC .  is ::-->
# ['wiring harness ']
# OUTRIGGER ASSY COWL MTG .  is ::-->
# ['outrigger ']
# DRIVER STATION ASSY W/O PAINTED .  is ::-->
# ['driver station ']
# BRACKET .  is ::-->
# ['bracket ']
# BRACKET .  is ::-->
# ['bracket ']
# WIRING HARNESS PANEL .  is ::-->
# ['wiring harness ']
# BRACKET - Z TYPE (CABLE SHIFT) .  is ::-->
# ['bracket ']
# BRACKET ASSY AIR FILTER MTG .  is ::-->
# ['bracket ']
# BRACKETENG MTGREAR-RH .  is ::-->
# ['bracket ']
# BRACKET .  is ::-->
# ['bracket ']
# ALLOY PIANO JETBLACK + BRIGHT CROME T LOGO (M/S JAI HIND AUTO PVT LTD) .  is ::-->
# ['logo ']
# BRACKET .  is ::-->
# ['bracket ']
# GASKET .  is ::-->
# ['gasket ']
# BRACKET ASSY FUEL TANK MTG .  is ::-->
# ['bracket ']
# RUBBER PACKING .  is ::-->
# ['rubber packing']
# FUEL PIPE ASSY TANK TO FILTER .  is ::-->
# ['pipe assy ']
# PIPE ASSY WITH COUPLING NUT & FERRULE .  is ::-->
# ['pipe assy ']
# BRACKET (DAUBLE Z SHAPE) .  is ::-->
# ['bracket ']
# BRACKET FRONT GRILL MTG RH .  is ::-->
# ['bracket ']
# PROPELLER SHAFT ASSY COUPLING .  is ::-->
# ['propeller shaft']
# RADIATOR & INTERCOOLER ASSY .  is ::-->
# ['radiator ']
# CLAMP ASSY EGP MTG .  is ::-->
# ['clamp ']
# "WIRING HARNESS,REVERSE PARK ASSIST " .  is ::-->
# ['wiring harness ']
# RUBBER GROMMET .  is ::-->
# ['grommet ']
# "BRACKET ASSY,AIR FILTER MTG" .  is ::-->
# ['bracket ']
# KIT-AIR INTAKE ASSY (570609130235- Deleted) .  is ::-->
# ['air intake assy']
# EXHAUST TAIL PIPE(264249206908-not required ERC Mail) .  is ::-->
# ['exhaust pipe']
# TURBOCHARGER .  is ::-->
# ['turbocharger ']
# TEMPERATURE SENSOR .  is ::-->
# ['temp sensor']
# BEARING CONNECTING ROD UPPER .  is ::-->
# ['connecting rod']
# SWITCH EXHAUST BRAKE 24V .  is ::-->
# ['switch ']
# GEAR SHIFT LEVER ASSY WITH TURNING TUBE .  is ::-->
# ['gear shift lever']
# LONG MEMBER LH .  is ::-->
# ['long member']
# BRACKET ASSY RADIATOR MTG RH .  is ::-->
# ['bracket ']
# BRACKET ASSY LONG MEMBER .  is ::-->
# ['bracket ']
# SUPPORT ASSY ENGINE CROSS MEMBER LH .  is ::-->
# ['cross member']
# BRACKET ASSY CROSS MEMBER MTG LH .  is ::-->
# ['bracket ']
# BRACKET CENTER BRG MTG .  is ::-->
# ['bracket ']
# PROPELLER SHAFT ASSY COUPLING .  is ::-->
# ['propeller shaft']
# PIPE BUNCH ASSY .  is ::-->
# ['nylon bunch']
# EXHAUST PIPE ASSY INT .  is ::-->
# ['exhaust pipe']
# BRACKET ASSY .  is ::-->
# ['bracket ']
# BRACKET .  is ::-->
# ['bracket ']
# TUBE .  is ::-->
# ['tube ']
# HOSE Old Part Number - 570601175833 .  is ::-->
# ['hose ']
# HOSE - Old Part number - 570601175835 .  is ::-->
# ['hose ']
# BRACKET .  is ::-->
# ['bracket ']
# "DRUM BRAKE ASSEMBLY WITH DC, FRLH" .  is ::-->
# ['drum  brake']
# "DRUM BRAKE ASSEMBLY WITH DC, RRRH" .  is ::-->
# ['drum  brake']
# BRACKET WITH SPACER .  is ::-->
# ['bracket ']
# SUPPORT BKT (AIR COMP PIPE SUPPORT) .  is ::-->
# ['bracket ']
# BOLT M14X1.5X45 - 10.9 .  is ::-->
# ['bolt ']
# SWITCH DUMMY KNOB .  is ::-->
# ['switch ']
# MOUNTING PIN .  is ::-->
# ['pin ']
# BOLT M16X1.5X80 - 10.9 .  is ::-->
# ['bolt ']
# BOLT M20X1.5X70 - 10.9 .  is ::-->
# ['bolt ']
# NUT M20X1.5 - 10 ISO12126 .  is ::-->
# ['nut ']
# BRACKET ASSY APDA MTG .  is ::-->
# ['bracket ']
# HARNESS BKT TRANSMISSION .  is ::-->
# ['bracket ']
# LONG MEMBER REAR MODULE RH .  is ::-->
# ['long member']
# BOXING PLATE ASSY RH .  is ::-->
# ['plate ']
# SUPPORT PLATE RH .  is ::-->
# ['plate ']
# BOXING PLATE ASSY LH .  is ::-->
# ['plate ']
# SUPPORT PLATE LH .  is ::-->
# ['plate ']
# SUPPORT BRACKET ASSY ENGINE SIDE RH .  is ::-->
# ['bracket ']
# BASE PLATE .  is ::-->
# ['plate ']
# HEAT SHIELD ASSY .  is ::-->
# ['heat shield']
# OUTRIGGER ASSY .  is ::-->
# ['outrigger ']
# OUTRIGGER ASSY .  is ::-->
# ['outrigger ']
# BRAKE DRUM FRONT .  is ::-->
# ['brake drum ']
# "WIRING HARNESS,AEBS FRAME (45WB) G401162" .  is ::-->
# ['wiring harness ']
# "WIRING HARNESS, MAIN " .  is ::-->
# ['wiring harness ']
# "DRUM BRAKE ASSEMBLY WITH DC, FR LH (140mm)" .  is ::-->
# ['drum  brake']
# "DRUM BRAKE ASSY WITH DC,REAR-LH - TL70 (120mm)" .  is ::-->
# ['drum  brake']
# "DRUM BRAKE ASSY WITH DC,FRONT-LH - TL70 (120mm)" .  is ::-->
# ['drum  brake']
# BRACKET (Nylon pipe routing) .  is ::-->
# ['bracket ']
# TAIL PIPE (36WB) .  is ::-->
# ['tail pipe']
# "ASSY ANTI ROLL BAR,FRONT" .  is ::-->
# ['anti roll bar ']
# ANTI ROLL BAR ASSY WITH LINK .  is ::-->
# ['anti roll bar ']
# WIRING HARNESS TAIL .  is ::-->
# ['wiring harness ']
# CABLE ASSY STARTER MOTOR -VE .  is ::-->
# ['cable ']
# HOSE THERMOSTAT TO RADIATOR .  is ::-->
# ['hose ']
# ECU .  is ::-->
# ['ecu ']
# BRACKET .  is ::-->
# ['bracket ']
# PIPE ASSY .  is ::-->
# ['pipe assy ']
# BRACKET STG GEAR BOX MTG .  is ::-->
# ['bracket ']
# BALATA PACKING .  is ::-->
# ['balata ']
# COBRA BRACKET ASSY .  is ::-->
# ['bracket ']
# BRACKET ASSY FRONT SPRING HANGER REAR .  is ::-->
# ['bracket ']
# BRACKET SPRING HANGER FRONT-FRONT .  is ::-->
# ['bracket ']
# TUBELESS TYRE .  is ::-->
# ['tubeless tyre']
# CLUTCH HOSE ASSY .  is ::-->
# ['clutch hose']
# VALVE EXTENSION .  is ::-->
# ['valve ']
# LAMP STOP/TAIL - 12V .  is ::-->
# ['tail lamp']
# CLUTCH RELEASE YOKE .  is ::-->
# ['yoke ']
# RUBBER BUFFER FRONT AXLE .  is ::-->
# ['rubber buffer']
# BUMP STOPPER .  is ::-->
# ['stopper ']
# THREADED PIN .  is ::-->
# ['threaded pin']
# PIPE .  is ::-->
# ['pipe ']
# VENT HOSETHERMOSTAT TO RADIATOR .  is ::-->
# ['hose ']
# HOSETHERMOSTAT TO PIPE CONNECTOR .  is ::-->
# ['hose ']
# INSTRUMENT CLUSTER ASSY .  is ::-->
# ['instrument cluster']
# "INSULATION,HEADLINER,FRONT" .  is ::-->
# ['insulation ']
# "INSULATION,FRONT DOOR,LH" .  is ::-->
# ['insulation ']
# "INSULATION,REAR DOOR,LH" .  is ::-->
# ['insulation ']
# "INSULATION,HEADLINER,REAR - Sunroof" .  is ::-->
# ['insulation ']
# "INSULATION,FLOOR,REAR" .  is ::-->
# ['insulation ']
# FIREWALL INSULATION .  is ::-->
# ['insulation ']
# ASTRUCTURAL FOAM PAD .  is ::-->
# ['structural foam']
# ASTRUCTURAL FOAM PAD .  is ::-->
# ['structural foam']
# UREA PIPE ASSY Supply Pressure Line nylon (Old Part - 264249200129) .  is ::-->
# ['urea hose']
# CRPANHDSCREWM3X16IS7483SS8451-8C .  is ::-->
# ['screw ']
# L BRACKET(PSTG PIPE LINE) .  is ::-->
# ['bracket ']
# HEX FL BOLT M10X60 TS17130-8.8-SS8451-8C .  is ::-->
# ['bolt ']
# HEX FL BOLT M12X50TS17130 10.9SS8451-8CH .  is ::-->
# ['bolt ']
# HEXFLBOLTM6X25TS17130-8.8-SS8451S2-B (Old -11073596019) .  is ::-->
# ['bolt ']
# H/FL SCREW M5X18 TS17130-8.8-SS8451S2-Y (Old - 11343505185) .  is ::-->
# ['screw ']
# BATTERY LINK .  is ::-->
# ['battery ']
# NOX SENSOR (LPO -NAC) .  is ::-->
# ['nox sensor']
# Hose .  is ::-->
# ['hose ']
# Hose .  is ::-->
# ['hose ']
# Hose .  is ::-->
# ['hose ']
# Tube .  is ::-->
# ['tube ']
# Hose LP NAC .  is ::-->
# ['lp hose']
# Hose LP NAC .  is ::-->
# ['lp hose']
# Hose LP NAC .  is ::-->
# ['lp hose']
# Tube LP NAC .  is ::-->
# ['tube ']
# UREA PIPE ASSY 550749200197 .  is ::-->
# ['pipe assy ']
# REAR AXLE BEAM ASSY .  is ::-->
# ['rear axle beam']
# TAIL PIPE .  is ::-->
# ['tail pipe']
# HEX SCREW M10X70 IS1364P2-8.8-SS8451-8C .  is ::-->
# ['screw ']
# ASSY DIAGNOSTIC CONNECTOR PARKING BKT .  is ::-->
# ['bracket ']
# CR PAN HD SCREW M5X16 IS7483 SS8451S2-Y .  is ::-->
# ['screw ']
# RUBBER HOSE .  is ::-->
# ['rubber hose']
# Regeneration Inhibit Switch .  is ::-->
# ['switch ']
# HEX FLANGE BOLT .  is ::-->
# ['bolt ']
# BRACKET ASSY CROSS MEMBER MTG FRONT-LH .  is ::-->
# ['bracket ']
# BRACKET GB INLINE CONNECTOR MTG .  is ::-->
# ['bracket ']
# Urea Pipe Assy .  is ::-->
# ['pipe assy ']
# "Pipe Assy, urea return" .  is ::-->
# ['pipe assy ']
# Urea Pipe Assy .  is ::-->
# ['pipe assy ']
# GASKET .  is ::-->
# ['gasket ']
# BRACKET ASSY .  is ::-->
# ['bracket ']
# SUPPORT BRACKET .  is ::-->
# ['bracket ']
# Heat Shield .  is ::-->
# ['heat shield']
# Fuel injector .  is ::-->
# ['fuel injector']
# Fuel Filter .  is ::-->
# ['fuel filter']
# Air filter snorkel 1st piece .  is ::-->
# ['snorkel ']
# Air intake elbow .  is ::-->
# ['elbow ']
# Alternator .  is ::-->
# ['alternator ']
# Crank angle sensor .  is ::-->
# ['sensor ']
# Oil pressure sensor .  is ::-->
# ['pressure sensor']
# Oil pump driven gear .  is ::-->
# ['gear ']
# Oil filter .  is ::-->
# ['oil filter']
# Oil pump and oil filter housing .  is ::-->
# ['oil filter']
# Water pump housing .  is ::-->
# ['water pump']
# Engine A mount .  is ::-->
# ['engine mount']
# Engine B mount .  is ::-->
# ['engine mount']
# Engine C mount .  is ::-->
# ['engine mount']
# Clutch plate .  is ::-->
# ['plate ']
# Clutch release bearing .  is ::-->
# ['bearing ']
# Brake and Clutch pedal mounting bracket .  is ::-->
# ['bracket ']
# Clutch pedal .  is ::-->
# ['clutch pedal']
# Clutch cable holding bracket on gear box .  is ::-->
# ['bracket ']
# Front suspension .  is ::-->
# ['front suspension']
# Front suspension lower link (RH) .  is ::-->
# ['front suspension']
# Rear suspension .  is ::-->
# ['rear suspension']
# Rear coil spring LH and RH .  is ::-->
# ['oil ring']
# Front Brake Caliper Assy .  is ::-->
# ['brake caliper']
# Brake pipe from master cylinder primary port to T joint .  is ::-->
# ['brake pipe']
# Brake pipe from T connector to rear RH wheel flexible hose .  is ::-->
# ['brake hose']
# Rear brake drum RH .  is ::-->
# ['brake drum ']
# Rear anchor plate RH .  is ::-->
# ['plate ']
# Parking brake cable from parking brake lever to equalizer .  is ::-->
# ['brake cable']
# Master cylinder assembly .  is ::-->
# ['cylinder ']
# Steering column assembly .  is ::-->
# ['steering column']
# Fuel tank .  is ::-->
# ['fuel tank']
# Fuel pump with float unit .  is ::-->
# ['fuel pump']
# Exhaust silencer .  is ::-->
# ['silencer ']
# Battery mounting clamp bottom/top .  is ::-->
# ['clamp ']
# Tail lamp LH .  is ::-->
# ['tail lamp']
# Horn (single or LH) .  is ::-->
# ['horn ']
# Instrument cluster .  is ::-->
# ['instrument cluster']
# Battery positive cable .  is ::-->
# ['battery cable']
# Dashboard wiring harness .  is ::-->
# ['wiring harness ']
# Windscreen glass .  is ::-->
# ['glass ']
# Rear glass .  is ::-->
# ['glass ']
# Steering nacelle upper .  is ::-->
# ['nacelle ']
# Glove box .  is ::-->
# ['glove box']
# Cross car beam .  is ::-->
# ['car beam']
# Roof liner /Head liner .  is ::-->
# ['roof liner']
# Load body I .  is ::-->
# ['load body ']
# Front door upper hinge RH .  is ::-->
# ['door ']
# Front door window glass .  is ::-->
# ['glass ']
# Front door glass channel seal .  is ::-->
# ['seal ']
# Front door seal on body shell RH .  is ::-->
# ['seal ']
# ORVM RH .  is ::-->
# ['orvm ']
# Wiper blade (I) .  is ::-->
# ['wiper blade ']
# Windscreen washer sprinkler motor .  is ::-->
# ['washer ']
# Front upper grill .  is ::-->
# ['grill ']
# Front LH wheel arch mud liner .  is ::-->
# ['wheel arch liner']
# Front RH seat assembly .  is ::-->
# ['front seat']
# Front RH seat belt with ELR unit assembly .  is ::-->
# ['seat belt']
# Frame Assy.  is ::-->
# ['frame assy ']
# WASHER 10.5 .  is ::-->
# ['washer ']
# ASSY.BRACKET (HOSE MTG.ON REAR AXLE) .  is ::-->
# ['bracket ']
# PIPE AIR INTAKE .  is ::-->
# ['air intake pipe']
# PIPE INTERCOOLER TO TURBOCHARGER .  is ::-->
# ['pipe ']
# PIPE INTERCOOLER TO INTAKE MANIFOLD .  is ::-->
# ['intake pipe']
# "PIPE,TC TO IC" .  is ::-->
# ['pipe ']
# PIPE INTERCOOLER TO TURBOCHARGER .  is ::-->
# ['pipe ']
# Anti Roll Bar .  is ::-->
# ['anti roll bar ']
# Assy leaf spring .  is ::-->
# ['leaf spring ']
# Assy leaf spring .  is ::-->
# ['leaf spring ']
# SUCTION LINE ASSY .  is ::-->
# ['suction hose']
# RETURN LINE ASSY .  is ::-->
# ['return hose']
# "DRUM BRAKE ASSEMBLY WITH DC, RR LH (140mm)" .  is ::-->
# ['drum  brake']
# BRACKET ASSY RESERVOIR HOLDING .  is ::-->
# ['bracket ']
# "BRACKET,EXHAUST PIPE MTG" .  is ::-->
# ['bracket ']
# "BRACKET ASSY,TAIL PIPE MTG" .  is ::-->
# ['bracket ']
# GEAR SHIFTER ASSY WITH CABLE (M/s Kongsberg) .  is ::-->
# ['gear shifter ']
# WHEEL RIM ASSY WITH VALVE (205 PCD) .  is ::-->
# ['wheel rim ']
# "PIPE ASSY,JOINT TO JOINT (29WB)" .  is ::-->
# ['pipe assy ']
# Holder Parking Sensor .  is ::-->
# ['parking sensor']
# "PLATE,SPARE WHEEL MTG" .  is ::-->
# ['plate ']
# CLAMP PIPE .  is ::-->
# ['clamp ']
# BRACKET(FOR 1ST CENTRE BEARING M/S DANA) .  is ::-->
# ['bracket ']
# Metal pipe assy .  is ::-->
# ['metal pipe']
# PIPE ASSY AIR DRYER TO PURGE TANK .  is ::-->
# ['pipe assy ']
# LONG MEMBER LH .  is ::-->
# ['long member']
# Load body II .  is ::-->
# ['load body ']
# BRACKET ASSY .  is ::-->
# ['bracket ']
# PIPE RADIATOR TO RETARDER .  is ::-->
# ['pipe ']
# PIPE RETARDER TO ENGINE .  is ::-->
# ['pipe ']
# HOSE HUMP TURBOCHARGER ADAPTER TO PIPE .  is ::-->
# ['hose ']
# "LEAF SPRING ASSY,FRONT-LH" .  is ::-->
# ['leaf spring ']
# Spray Suppression 580*800 .  is ::-->
# ['spray suppression']
# Front bump stopper bracket (LH and RH) .  is ::-->
# ['bracket ']
# Spare wheel rim .  is ::-->
# ['spare wheel']
# Dashboard skin .  is ::-->
# ['dashboard skin ']
# ORVM RH .  is ::-->
# ['orvm ']
# Group No 91_Front Seat (Driver Seat) .  is ::-->
# ['front seat']
# FUEL PIPE ASSY TANK TO FILTER .  is ::-->
# ['pipe assy ']
# "Wiring Harness, ABS" .  is ::-->
# ['wiring harness ']
# "Wiring Harness, ABS" .  is ::-->
# ['wiring harness ']
# Vent hose (RADIATOR TO AUX.  is ::-->
# ['hose ']
# "PIPE ASSY,ENGINE TO AUX WATER TANK" .  is ::-->
# ['pipe assy ']
# SUPPORT BRACKET ASSY .  is ::-->
# ['bracket ']
# SUPPORT BRACKET ASSY .  is ::-->
# ['bracket ']
# Assy Intercooler pipe .  is ::-->
# ['pipe ']
# RADIATOR & INTERCOOLER ASSY .  is ::-->
# ['radiator ']
# BRACKET ASSY ENGINE MTG FRONT-LH .  is ::-->
# ['bracket ']
# WHEEL RIM ASSY WITH VALVE .  is ::-->
# ['wheel rim ']
# BELT AC COMPRESSOR .  is ::-->
# ['belt ']
# CROSS SHAFT ASSY WITH LEVER .  is ::-->
# ['shaft ']
# BRACKET .  is ::-->
# ['bracket ']
# BRACKET (CLUTCH BOOSTER MOUNTING) .  is ::-->
# ['bracket ']
# MODULATOR VALVE ABS (12V) .  is ::-->
# ['modulator valve']
# BRACKET MAXI FUSE & MIDI FUSE MTG.  is ::-->
# ['bracket ']
# HEAD LAMP LEVELLING SWITCH FOR 12V-M/S.MINDARIKA .  is ::-->
# ['switch ']
# HEAD LAMP LEVELLING SWITCH FOR 24V-M/S.MINDARIKA .  is ::-->
# ['switch ']
# BKT.  is ::-->
# ['bracket ']
# LIFTING HOOK-FRONT .  is ::-->
# ['lifting hook']
# D.A.TANK (DIA28.6)(BANCO) .  is ::-->
# ['tank ']
# COOLENT HOSE FOR CNG REGULATOR - 1000 MM .  is ::-->
# ['hose ']
# LEAF SPRING ASSY FRONT - 552932101604 .  is ::-->
# ['leaf spring ']
# BRACKET ASSY SHOCK ABSORBER MTG FRONT .  is ::-->
# ['bracket ']
# BRACKET ANTI ROLL BAR MTG .  is ::-->
# ['bracket ']
# BRACKET SPRING HANGER REAR-FRONT .  is ::-->
# ['bracket ']
# LEAF SPRING ASSY REAR - 552932401604 .  is ::-->
# ['leaf spring ']
# BUMP STOPPER ASSY .  is ::-->
# ['stopper ']
# ANTI ROLL BAR ASSY .  is ::-->
# ['anti roll bar ']
# FRONT PIPE ASSY .  is ::-->
# ['pipe assy ']
# BRKT AMBIENT SENSOR MTG .  is ::-->
# ['sensor ']
# "HEATER HOSE ASSY,ENGINE TO HVAC" .  is ::-->
# ['heater hose']
# "BRACKET ASSY,HEATER HOSE MTG" .  is ::-->
# ['bracket ']
# Assy Adaptor with tube .  is ::-->
# ['pto ']
# "BRACKET ASSY,BATTERY CUT OFF SWITCH MTG" .  is ::-->
# ['bracket ']
# "BATTERY CABLE +VE,EBCS TO MEGA FUSE" .  is ::-->
# ['battery cable']
# SPRING CLIP .  is ::-->
# ['clip ']
# LONG MEMBER ASSY FRONT-RH .  is ::-->
# ['long member']
# LONG MEMBER ASSY MIDDLE-LH .  is ::-->
# ['long member']
# LONG MEMBER ASSY FRONT-LH .  is ::-->
# ['long member']
# BRACKET ASSY VACUUM PIPE CLAMPING .  is ::-->
# ['bracket ']
# CROSS MEMBER ASSY FRONT .  is ::-->
# ['cross member']
# BATTERY TRAY ASSY .  is ::-->
# ['battery tray']
# BUMP STOPPER ASSY FRONT .  is ::-->
# ['stopper ']
# ANTI ROLL BAR ASSY WITH LINK .  is ::-->
# ['anti roll bar ']
# GUIDE PLATE ASSY REAR-LH .  is ::-->
# ['guide plate']
# FRONT AXLE ASSY .  is ::-->
# ['front axle']
# PROPELLER SHAFT ASSY .  is ::-->
# ['propeller shaft']
# TUBE ASSY ADAPTER TO REAR BRAKE HOSE LH .  is ::-->
# ['brake hose']
# TUBE ASSY T-CONN TO ADAPTER .  is ::-->
# ['adapter ']
# VACUUM PIPE ENGINE END .  is ::-->
# ['pipe ']
# PARKING BRAKE CABLE ASSY REAR-RH .  is ::-->
# ['brake cable']
# BRACKET ASSY CLAMP MTG .  is ::-->
# ['bracket ']
# LP HOSE ASSY FILTER TO ENGINE .  is ::-->
# ['lp hose']
# BATTERY CABLE +VE .  is ::-->
# ['battery cable']
# BRACKET WIRING HARNESS MTG .  is ::-->
# ['bracket ']
# FRONT FLOOR ASSY .  is ::-->
# ['front floor']
# WHEEL ARCH ASSY INNER-LH .  is ::-->
# ['wheel arch ']
# LINER REAR WALL .  is ::-->
# ['rear wall']
# KIT-LOCK SET ASSY .  is ::-->
# ['lock ']
# BELLOW ASSY WITH BOOT RING .  is ::-->
# ['bellow ']
# CLUTCH CABLE ASSY .  is ::-->
# ['clutch cable']
# LEAF SPRING ASSY FRONT .  is ::-->
# ['leaf spring ']
# GUIDE PLATE ASSY .  is ::-->
# ['guide plate']
# LEAF SPRING ASSY REAR .  is ::-->
# ['leaf spring ']
# FRONT AXLE ASSY .  is ::-->
# ['front axle']
# TUBE ASSY SPARE WHEEL CARRIER .  is ::-->
# ['spare wheel']
# PROPELLER SHAFT ASSY .  is ::-->
# ['propeller shaft']
# "BRACKET ASSY,PARKING BRAKE LEVER" .  is ::-->
# ['bracket ']
# "PARKING CABLE ASSY REAR, LH" .  is ::-->
# ['cable ']
# BOOSTER ASSY-OFFER DRG .  is ::-->
# ['booster ']
# TUBE ASSY REAR HOSE TO BRAKE ASSY LH .  is ::-->
# ['brake hose']
# TUBE ASSY TMC SECONDARY TO T-CONN .  is ::-->
# ['tube assy ']
# RUBBER BELLOW STG COLUMN .  is ::-->
# ['rubber bellow']
# STEERING GEAR BOX ASSY WITH PITMAN ARM .  is ::-->
# ['steering gearbox']
# "WIRING HARNESS ASSY,ENGINE" .  is ::-->
# ['wiring harness ']
# RELAY COVER .  is ::-->
# ['cover ']
# "WIRING HARNESS,CABIN" .  is ::-->
# ['wiring harness ']
# CLAMP JACK HANDLE .  is ::-->
# ['clamp ']
# CROSS MEMBER ASSY REAR .  is ::-->
# ['cross member']
# REAR FLOOR ASSY RH .  is ::-->
# ['rear floor']
# B-PILLAR ASSY INNER-LH .  is ::-->
# ['a pillar']
# REAR WALL ASSY .  is ::-->
# ['rear wall']
# CARPET RADIATOR ACCESS COVER .  is ::-->
# ['radiator ']
# "CARPET, FLOOR, RH" .  is ::-->
# ['carpet ']
# DASHBOARD ASSY WITH HVAC .  is ::-->
# ['dashboard ']
# LINER REAR WALL .  is ::-->
# ['rear wall']
# KIT-LOCK SET ASSY .  is ::-->
# ['lock ']
# WIPER ARM ASSY WITH BLADE DRIVER SIDE .  is ::-->
# ['wiper arm ']
# WIPER LINK ASSY WITH MOTOR .  is ::-->
# ['wiper link ']
# "KIT-SEAT BELT WITH ELR & LAP BELT, FRONT" .  is ::-->
# ['seat belt']
# OIL FILTER .  is ::-->
# ['oil filter']
# ASSY TUBE DIPSTICK .  is ::-->
# ['dipstick ']
# SPARE WHEEL CARRIER ASSY .  is ::-->
# ['spare wheel']
# "METAL PIPE ASSY,INT JOINT TO INT JOINT" .  is ::-->
# ['metal pipe']
# "HEAT SHIELD ASSY,EXHAUST SYSTEM" .  is ::-->
# ['heat shield']
# ASSY WIPER ARM & BLADE DRIVER NRW LHD .  is ::-->
# ['wiper arm ']
# DRIVER SEAT ASSY .  is ::-->
# ['driver seat']
# "KIT-SEAT BELT W ELR,LAP BELT & MS,FRONT" .  is ::-->
# ['seat belt']
# POWER STEERING GEAR BOX ASSY .  is ::-->
# ['power steering gearbox']
# PITMAN ARM .  is ::-->
# ['pitman arm']
# WIRING HARNESS ABS FRAME .  is ::-->
# ['wiring harness ']
# Z-BRACKET .  is ::-->
# ['bracket ']
# ENGAGING GEAR 5TH/REVERSE SPEED .  is ::-->
# ['gear ']
# BOSS .  is ::-->
# ['boss ']
# SUPD ASSY LH .  is ::-->
# ['supd ']
# SUPD ASSY .  is ::-->
# ['supd ']
# "PROPELLER SHAFT ASSY,REAR" .  is ::-->
# ['propeller shaft']
# FRAME ASSY WITH TOP COAT .  is ::-->
# ['frame assy ']
# "LONG MEMBER,LH" .  is ::-->
# ['long member']
# "WIRING HARNESS,ABS FRAME" .  is ::-->
# ['wiring harness ']
# "SUPD ASSY,LH" .  is ::-->
# ['supd ']
# "WIRING HARNESS,REAR CHASSIS" .  is ::-->
# ['wiring harness ']
# METAL PIPE WITH CRIMPED HOSE .  is ::-->
# ['metal pipe']
# MONOTRON PROPELLER SHAFT ASSY .  is ::-->
# ['propeller shaft']
# Assy.Cyl.Crankcase (CYL BLOCK) .  is ::-->
# ['crankcase ']
# Cam shaft gear (Exhaust) .  is ::-->
# ['cam shaft']
# Chassis wiring harness .  is ::-->
# ['wiring harness ']
# Engine wiring harness (On engine) .  is ::-->
# ['engine wiring harness']
# Flywheel .  is ::-->
# ['flywheel ']
# Gear shifter and selector cable holding bracket on gear box .  is ::-->
# ['bracket ']
# Head lamp LH .  is ::-->
# ['head lamp']
# Intake valve .  is ::-->
# ['intake valve ']
# Leaf spring rear shackle bush LH and RH .  is ::-->
# ['bush ']
# Leaf spring U bolt lower mounting plate (LH and RH) .  is ::-->
# ['mounting bolt']
# Registration plate lamp RH .  is ::-->
# ['plate ']
# Tail lamp LH .  is ::-->
# ['tail lamp']
# "HOSE,HEATER,OUTLET-HVAC TO CYL HEAD" .  is ::-->
# ['hose ']
# HEATER HOSE-HVAC TO BYPASS TUBE (INLET) .  is ::-->
# ['heater hose']
# SUPPORT BRACKET- HEATER HOSES .  is ::-->
# ['bracket ']
# SUPD HAT SECTION .  is ::-->
# ['supd ']
# HINGE PIN .  is ::-->
# ['hinge ']
# SUPD ASSY LH .  is ::-->
# ['supd ']
# U-BOLT .  is ::-->
# ['u bolt']
# PLATE FLEXIBLE MTG .  is ::-->
# ['plate ']
# SERVICE BRAKE ASSY ABS .  is ::-->
# ['brake ']
# PARKING BRAKE LEVER ASSY COMPLETE (200) .  is ::-->
# ['parking brake lever']
# HEATER HOSE ASSY .  is ::-->
# ['heater hose']
# FASCIA SWITCH .  is ::-->
# ['fascia switch']
# LONG MEMBER ASSY REAR-LH .  is ::-->
# ['long member']
# REAR FLOOR REAR .  is ::-->
# ['rear floor']
# FRONT STRUT ASSY LH-OFFER DRG .  is ::-->
# ['front strut']
# ASSY TOP ROD VERTICAL MEMBER .  is ::-->
# ['vertical member']
# ANTI ROLL BAR FRONT SUSPENSION .  is ::-->
# ['anti roll bar ']
# BUSH ANTI ROLL BAR .  is ::-->
# ['bush ']
# SHOCK ABSORBER ASSY REAR .  is ::-->
# ['shock absorber ']
# CARPET ASSY REAR WHEEL ARCH RH .  is ::-->
# ['carpet ']
# CARPET REAR WHEEL ARCH LH .  is ::-->
# ['carpet ']
# INSULATION FIREWALL .  is ::-->
# ['insulation ']
# ASSY SPACER[FOR EMER RECEPTACLE MTG] .  is ::-->
# ['spacer ']
# MALE CONNECTOR 1/4 NPT (M/S SWAGELOK) .  is ::-->
# ['connector ']
# ASSY RECEPTACLE CAP (M/S MINDA) .  is ::-->
# ['receptacle ']
# HP TUBE ASSY .  is ::-->
# ['hp tube ']
# VENTILATION HOSE (M/S.MINDA) .  is ::-->
# ['ventilation hose']
# ASSY CYLINDER +CYL VALVE(MOON) .  is ::-->
# ['cylinder ']
# VENTILATION HOSE (M/S.MINDA) .  is ::-->
# ['ventilation hose']
# HP TUBE ASSY .  is ::-->
# ['hp tube ']
# SLEEVE (FOR CNG PIPE) .  is ::-->
# ['sleeve ']
# HP TUBE ASSY .  is ::-->
# ['hp tube ']
# MALE CONNECTOR 1/4 NPT (M/S SWAGELOK) .  is ::-->
# ['connector ']
# LP HOSE ASSY HP REGULATOR TO LP FILTER .  is ::-->
# ['lp hose']
# CYLINDER CRANKCASE ASSY WITH LINER .  is ::-->
# ['cylinder ']
# VALVE SEAT INTAKE .  is ::-->
# ['valve seat ']
# VALVE SEAT INTAKE TC .  is ::-->
# ['valve seat ']
# VALVE SEAT EXHAUST .  is ::-->
# ['valve seat ']
# VALVE SEAT INSERT NORMAL-I(EXHAUST) TC .  is ::-->
# ['valve seat ']
# INTAKE VALVE TC .  is ::-->
# ['intake valve ']
# EXHAUST VALVE .  is ::-->
# ['exhaust valve']
# FUEL RAIL ASSY .  is ::-->
# ['fuel rail']
# ROTATIONAL SPEED SENSOR .  is ::-->
# ['speed sensor']
# PRESSURE/TEMPERATURE SENSOR .  is ::-->
# ['pressure sensor']
# "DECAL,REAR QUARTER,LOWER,LH" .  is ::-->
# ['decal ']
# "DECAL,REAR QUARTER,UPPER,LH" .  is ::-->
# ['decal ']
# CNG tank .  is ::-->
# ['tank ']
# CNG tank arrester strap upper LH .  is ::-->
# ['tank ']
# CNG tank arrester strap lower LH .  is ::-->
# ['tank ']
# Delivery pipe from CNG tank to intermediate adaptor .  is ::-->
# ['pipe ']
# Delivery pipe from intermediate adaptor to solenoid switch .  is ::-->
# ['pipe ']
# Pressure regulator valve .  is ::-->
# ['valve ']
# Solenoid switch .  is ::-->
# ['switch ']
# CNG RECEPTACLE .  is ::-->
# ['receptacle ']
# "FUEL RETURN PIPE ASSY,ENG TO FUEL" .  is ::-->
# ['return hose']
# "STICKER,MAXI FUSE BOX" .  is ::-->
# ['sticker ']
# Bracket assy .  is ::-->
# ['bracket ']
# PIPE UNION BOLT FLANGE TYPE .  is ::-->
# ['u bolt']
# SPACER .  is ::-->
# ['spacer ']
# SCREW (FOR A/C COMP TENSIONER) .  is ::-->
# ['screw ']
# PISTON ASSY .  is ::-->
# ['piston ']
# PISTON .  is ::-->
# ['piston ']
# AUX HOSE .  is ::-->
# ['hose ']
# RUBBER HOSE INTERCOOLER TO PIPE .  is ::-->
# ['rubber hose']
# INTERNAL CIRCLIP- 3.19 THK.  is ::-->
# ['clip ']
# INTERNAL CIRCLIP- 3.29 THK.  is ::-->
# ['clip ']
# CIRCLIP DRIVE SHAFT (2.5 THK) .  is ::-->
# ['clip ']
# EXTERNAL CIRCLIP(ENG.  is ::-->
# ['clip ']
# EXTERNAL CIRCLIP(ENG.  is ::-->
# ['clip ']
# CIRCLIP(2.46 THK) .  is ::-->
# ['clip ']
# CIRCLIP(2.62 THK) .  is ::-->
# ['clip ']
# MAGNETIC DRAIN PLUG .  is ::-->
# ['drain plug ']
# MAGNETIC DRAIN PLUG .  is ::-->
# ['drain plug ']
# BRACKET ASSY REAR LEAF SPRING .  is ::-->
# ['bracket ']
# WASHER .  is ::-->
# ['washer ']
# BRACKET ASSY ANTI ROLL BAR MTG REAR-RH .  is ::-->
# ['bracket ']
# REAR SPRING SEAT TOP .  is ::-->
# ['rear seat']
# HUB PIN FRONT .  is ::-->
# ['pin ']
# BRACKET BUNDY TUBE MTG .  is ::-->
# ['bracket ']
# SPACER RING TAIL PINION 8.90 THK.  is ::-->
# ['ring spacer']
# SPACER RING TAIL PINION 8.95 THK.  is ::-->
# ['ring spacer']
# SPACER RING TAIL PINION 9.42 THICK .  is ::-->
# ['ring spacer']
# SPACER RING TAIL PINION 9.36 THICK .  is ::-->
# ['ring spacer']
# SPACER RING TAIL PINION 9.26 THICK .  is ::-->
# ['ring spacer']
# SPACER RING TAIL PINION 9.30THICK .  is ::-->
# ['ring spacer']
# SPACER RING TAIL PINION 9.14 THICK .  is ::-->
# ['ring spacer']
# SPACER RING TAIL PINION 9.48 THK.  is ::-->
# ['ring spacer']
# SPACER RING TAIL PINION 9.46 THK.  is ::-->
# ['ring spacer']
# SPACER RING TAIL PINION 9.40 THICK .  is ::-->
# ['ring spacer']
# SPACER RING TAIL PINION 9.56 THK.  is ::-->
# ['ring spacer']
# SPACER RING TAIL PINION 9.34 THICK .  is ::-->
# ['ring spacer']
# SPACER RING TAIL PINION 9.00 THK.  is ::-->
# ['ring spacer']
# SPACER RING TAIL PINION 9.10 THICK .  is ::-->
# ['ring spacer']
# SPACER RING TAIL PINION 9.28THICK .  is ::-->
# ['ring spacer']
# SPACER RING TAIL PINION 9.16 THICK .  is ::-->
# ['ring spacer']
# SHIM (0.05 THK) .  is ::-->
# ['shim ']
# DUST COVER .  is ::-->
# ['cover ']
# BRACKET-RH FOR MTG.ABS CABLE ON LCRV BKT.-RA .  is ::-->
# ['bracket ']
# EYE BOLT .  is ::-->
# ['bolt ']
# ABS SENSOR WITH CABLE & CONNECTOR .  is ::-->
# ['sensor ']
# BRACKET ASSY EGP MTG MIDDLE .  is ::-->
# ['bracket ']
# L-BRACKET EXHAUST PIPE MTG .  is ::-->
# ['bracket ']
# SPACER UREA TANK MTG BKT .  is ::-->
# ['bracket ']
# BASE PLATE RADIATOR MTG BRACKET LH .  is ::-->
# ['bracket ']
# NEUTRAL SWITCH ASSY .  is ::-->
# ['switch ']
# HEXAGONAL KEY 8 .  is ::-->
# ['key ']
# FRONT STRUT ASSY WITH ABS RH .  is ::-->
# ['front strut']
# SPRING REAR SUSPENSION .  is ::-->
# ['rear suspension']
# COIL SPRING FRONT SUSPENSION .  is ::-->
# ['oil ring']
# "DRUM BRAKE ASSY,REAR-RH" .  is ::-->
# ['drum  brake']
# TELEMATICS ECU .  is ::-->
# ['ecu ']
# "CABLE,PDU TO HV BATTERY" .  is ::-->
# ['cable ']
# "CABLE,HV GND TRACTION MOTOR TO CHASSIS GND" .  is ::-->
# ['cable ']
# "CABLE,HV GND OBC TO CHASSIS GND" .  is ::-->
# ['cable ']
# "CABLE,HV GND BATTERY TO CHASSIS GND" .  is ::-->
# ['cable ']
# "W/H, FRONT LIMBER XZ+" .  is ::-->
# ['wiring harness ']
# "WIRING HARNESS,BATTERY CABLE XZ+, XM, XM(O)" .  is ::-->
# ['wiring harness ']
# "W/H, COCKPIT LIMBER XZ+" .  is ::-->
# ['wiring harness ']
# "W/H, FLOOR RH LIMBER XZ+" .  is ::-->
# ['wiring harness ']
# "W/H, FLOOR LH LIMBER XZ+" .  is ::-->
# ['wiring harness ']
# "W/H, EV-LV LIMBER XZ+, XM, XM(O)" .  is ::-->
# ['wiring harness ']
# "CROSS MEMBER ASSY,REAR FLOOR,MIDDLE" .  is ::-->
# ['cross member']
# "LONG MEMBER EXTENSION,FRONT-RH" .  is ::-->
# ['long member']
# "FRAME ASSY,FRONT FLOOR" .  is ::-->
# ['frame assy ']
# "COVER,BATTERY" .  is ::-->
# ['cover ']
# "WHEEL ARCH ASSY,OUTER-LH" .  is ::-->
# ['wheel arch ']
# A-MOUNT ASSY .  is ::-->
# ['a mount']
# RADIATOR SEALING ASSY RH .  is ::-->
# ['seal ']
# CONDENSER ASSY .  is ::-->
# ['condenser ']
# DRIVE SHAFT ASSY RH .  is ::-->
# ['drive shaft']
# HOSES AND CLAMP ASSEMBLY .  is ::-->
# ['clamp ']
# SUCTION PIPE COMPRESSOR END .  is ::-->
# ['suction hose']
# LIQUID TUBE ASSY HVAC INTAKE .  is ::-->
# ['tube assy ']
# SUCTION PIPE HVAC END .  is ::-->
# ['suction hose']
# HVAC UNIT ASSY XM and XM - O .  is ::-->
# ['hvac ']
# ASSY PASSENGER COMPARTMENT CARPET .  is ::-->
# ['carpet ']
# HOSE BKT .  is ::-->
# ['bracket ']
# BRACKET .  is ::-->
# ['bracket ']
# BRACKET ASSY .  is ::-->
# ['bracket ']
# TRUNKLID GARNISH ASSY BASE Without Camera Cutout XM and XM (O) .  is ::-->
# ['garnish ']
# AERO UNDER TRAY CENTER REAR .  is ::-->
# ['tray ']
# FRONT BUMPER ASSY XM and XM(O) .  is ::-->
# ['front bumper']
# COVER UNDER HOOD .  is ::-->
# ['cover ']
# SPINDLE BRAKE DRUM .  is ::-->
# ['spindle ']
# Structure_BEZEL SWITCH MTG .  is ::-->
# ['switch ']
# ALLOY WHEEL RIM .  is ::-->
# ['wheel rim ']
# HOSE ASSY .  is ::-->
# ['hose ']
# HOSE ASSY .  is ::-->
# ['hose ']
# SEALING FEM BOTTOM .  is ::-->
# ['seal ']
# RADIATOR SEALING LH .  is ::-->
# ['seal ']
# HOSE PIPE .  is ::-->
# ['hose ']
# 1.2 XETA ECU MTG BKT .  is ::-->
# ['bracket ']
# AUX WATER TANK ASSY WITH PRESSURE CAP .  is ::-->
# ['aux tank']
# TRAILING ARM RH .  is ::-->
# ['trailing arm']
# BRACKET ASSY AUX TANK MTG .  is ::-->
# ['bracket ']
# TUBE ASSY hose to rear Wc RH .  is ::-->
# ['hose ']
# VACUUM HOSE ASSLY - V pump end .  is ::-->
# ['vacuum hose']
# "CALIPER ASSY,FRONT-RH" .  is ::-->
# ['caliper ']
# "Front seat assy RH, 4W, J2 structure (XZ+)" .  is ::-->
# ['front seat']
# "Front seat assy RH, 4W, J2 structure (XM/XM(O)" .  is ::-->
# ['front seat']
# "Rear seat assy, Armrest with 2 Cup holder, 100% Fixed (XZ+)" .  is ::-->
# ['rear seat']
# "REAR WHEEL ARCH,FRONT-LH" .  is ::-->
# ['wheel arch ']
# ScuffP lateTrimAssyTrunklid .  is ::-->
# ['trim ']
# Exhaust Valve Seat Insert .  is ::-->
# ['valve seat ']
# Intake Valve seat insert .  is ::-->
# ['valve seat ']
# CARPET ASSY LUGGAGE COMPARTMENT .  is ::-->
# ['carpet ']
# CARPET ASSY REAR WHEEL ARCH LH .  is ::-->
# ['carpet ']
# INSULATION FIREWALL .  is ::-->
# ['insulation ']
# "DRUM BRAKE ASSY,REAR-LH" .  is ::-->
# ['drum  brake']
# W/H ENGINE TIAGO & TIGOR CNG ALL .  is ::-->
# ['engine wiring harness']
# W/H FRONT TIAGO CNG XT .  is ::-->
# ['front wiring harness']
# W/H FRONT TIGOR CNG XM COMMERCIAL .  is ::-->
# ['front wiring harness']
# W/H COCKPIT TIAGO CNG XZ .  is ::-->
# ['cockpit wiring harness']
# W/H COCKPIT TIGOR CNG XZ .  is ::-->
# ['cockpit wiring harness']
# W/H COCKPIT TIGOR CNG XE COMMERCIAL .  is ::-->
# ['cockpit wiring harness']
# "W/H FLOOR LH TIGOR CNG XZ, CNG XM COMMERCIAL" .  is ::-->
# ['floor wiring harness']
# CYLINDER HEAD ASSY.  is ::-->
# ['cylinder head']
# CLRPRT_ASY_3-ASSY HORN PAD AIRBAG STEERI .  is ::-->
# ['horn pad']
# CLRPRT_ASY_1-DRIVER AIRBAG ASSY .  is ::-->
# ['airbag ']
# CLRPRT_ASY_1-HORN PAD ASSY WITH DAB MODU .  is ::-->
# ['horn pad']
# LP Hose Assy ( Regulator to LP filter) .  is ::-->
# ['lp hose']
# HP tube Assy (Receptacle to T-connector) .  is ::-->
# ['hp tube ']
# HP tube assy (T-connector to U/B joint) .  is ::-->
# ['hp tube ']
# HP tube Assy (T-connector to cylinder) .  is ::-->
# ['hp tube ']
# HP Tube assy (U/B joint to Firewall Joint) .  is ::-->
# ['hp tube ']
# HP tube assy (T-connector to Regulator) .  is ::-->
# ['hp tube ']
# "LONG MEMBER ASSY,REAR-RH" .  is ::-->
# ['long member']
# "LONG MEMBER ASSY,REAR-RH" .  is ::-->
# ['long member']
# Injector .  is ::-->
# ['injector ']
# Intake Valve .  is ::-->
# ['intake valve ']
# PT Sensor .  is ::-->
# ['sensor ']
# Thrust washer .  is ::-->
# ['thrust washer']
# Front LH leaf spring .  is ::-->
# ['leaf spring ']
# Rear RH damper .  is ::-->
# ['rear damper']
# Leaf spring assembly LH .  is ::-->
# ['leaf spring ']
# Leaf spring U bolt upper guide plate with bump stopper (LH and RH) .  is ::-->
# ['u bolt']
# BRACKET ASSY WITH RIB .  is ::-->
# ['bracket ']
# HOSE .  is ::-->
# ['hose ']
# WIRING HARNESS MAIN .  is ::-->
# ['main wiring harness']
# MAIN WIRING HARNESS .  is ::-->
# ['main wiring harness']
# WIRING HARNESS REAR DOORS LH .  is ::-->
# ['door wiring harness']
# WIRING HARNESS FRONT DOORS LH .  is ::-->
# ['door wiring harness']
# "WIRING HARNESS,BATTERY +VE CABLE" .  is ::-->
# ['wiring harness ']
# "WIRING HARNESS,ENGINE TO BIW EARTH BRAID" .  is ::-->
# ['wiring harness ']
# WH TAILGATE LOWER PETROL & DIESEL XE/XM/XT .  is ::-->
# ['tailgate ']
# "WIRING HARNESS,FRONT" .  is ::-->
# ['wiring harness ']
# "TUBE ASSY, CROSS MEMBER" .  is ::-->
# ['tube assy ']
# TAB WASHER B 28 IS 8068 .  is ::-->
# ['washer ']
# "BRACKET,AC COMPRESSOR MTG" .  is ::-->
# ['bracket ']
# "CLUTCH DISC ASSY,DIA 330" .  is ::-->
# ['clutch ']
# "CLUTCH COVER ASSY,DIA 330" .  is ::-->
# ['clutch ']
# "CLUTCH COVER ASSY,DIA 330" .  is ::-->
# ['clutch ']
# IGNITION SWITCH ASSY WITH ILLU RING .  is ::-->
# ['ignition switch']
# SWITCH HEADLAMP LEVELLING .  is ::-->
# ['switch ']
# SWITCH HEAVY MODE .  is ::-->
# ['switch ']
# SPARE WHEEL CARRIER ASSY .  is ::-->
# ['spare wheel']
# SWITCH HEAVY MODE .  is ::-->
# ['switch ']
# PIPE TURBOCHARGER TO INTERCOOLER .  is ::-->
# ['pipe ']
# AIR INTAKE PIPE ASSY AIR COMP .  is ::-->
# ['air intake pipe']
# WIRING HARNESS PIGTAIL NEUTRAL SWITCH .  is ::-->
# ['pigtail wiring harness']
# FLYWHEEL ASSY WITH RING GEAR & PIN .  is ::-->
# ['flywheel ']
# BRACKET TURBOCHARGER MTG .  is ::-->
# ['bracket ']
# BRACKET CATCON MTG .  is ::-->
# ['bracket ']
# STARTER MOTOR ASSY .  is ::-->
# ['starter motor']
# OIL RETURN LINE ASSY .  is ::-->
# ['return hose']
# CONTAINER ECU ASSY .  is ::-->
# ['ecu ']
# RIBBED HOSE ASSY HFM TO TC .  is ::-->
# ['ribbed hose']
# BRACKET C-MOUNT .  is ::-->
# ['bracket ']
# CLUTCH HOUSING .  is ::-->
# ['clutch ']
# PIN (GEARBOX HOUSING JOINT) .  is ::-->
# ['pin ']
# SHIFTER SHAFT ASSY 3RD/4TH SPEED .  is ::-->
# ['shifter shaft']
# COVER ASSY FRONT .  is ::-->
# ['cover ']
# LOCK PLATE .  is ::-->
# ['plate ']
# SHIFTER LEVER ASSY .  is ::-->
# ['lever ']
# WASHER .  is ::-->
# ['washer ']
# "COVER,SHIFTER ASSY,TOP" .  is ::-->
# ['cover ']
# SELECTION FINGER TOP COVER ASSY .  is ::-->
# ['cover ']
# GUIDE PLATE .  is ::-->
# ['guide plate']
# DUST COVER .  is ::-->
# ['cover ']
# VEHICLE SPEED SENSOR .  is ::-->
# ['speed sensor']
# VACUUM BOOSTER ASSY .  is ::-->
# ['vacuum booster']
# SUPPORT BRACKET CCB .  is ::-->
# ['bracket ']
# BRACKET ASSY CLUTCH PEDAL MTG .  is ::-->
# ['bracket ']
# CLUTCH MASTER CYLINDER WITH HOSE .  is ::-->
# ['clutch master cylinder']
# SHACKLE ASSY .  is ::-->
# ['shackle ']
# U-BOLT FRONT SPRING .  is ::-->
# ['u bolt']
# LEAF SPRING ASSY REAR .  is ::-->
# ['leaf spring ']
# U-CLAMP REAR .  is ::-->
# ['clamp ']
# FRONT AXLE ASSY .  is ::-->
# ['front axle']
# HEX NUT (TAIL PINION COUPLING FLANGE) .  is ::-->
# ['nut ']
# CALIPER ASSY FRONT RH .  is ::-->
# ['caliper ']
# REAR AXLE ASSY WITH BRAKE .  is ::-->
# ['rear axle assy']
# WHEEL RIM ASSY-OFFER DRG .  is ::-->
# ['wheel rim ']
# PROPELLER SHAFT ASSY .  is ::-->
# ['propeller shaft']
# DRUM BRAKE ASSY REAR-LH .  is ::-->
# ['drum  brake']
# VACUUM PIPE ASSY .  is ::-->
# ['pipe assy ']
# PARKING BRAKE CABLE ASSY FRONT .  is ::-->
# ['brake cable']
# PARKING BRAKE CABLE ASSY REAR-RH .  is ::-->
# ['brake cable']
# TUBE ASSY T-CONN TO BRAKE HOSE FRT-RH .  is ::-->
# ['brake hose']
# TUBE ASSY T-CONN TO LCRV .  is ::-->
# ['tube assy ']
# TUBE ASSY REAR HOSE TO BRAKE ASSY RH .  is ::-->
# ['brake hose']
# TUBE ASSY TMC PRIMARY TO T-CONN .  is ::-->
# ['tube assy ']
# TUBE ASSY TMC SECONDARY TO T-CONN .  is ::-->
# ['tube assy ']
# BRACKET ASSY BRAKE PIPE MTG .  is ::-->
# ['bracket ']
# BRACKET - BRAKE PIPE CLAMPING .  is ::-->
# ['bracket ']
# STEERING COLUMN ASSY EPAS .  is ::-->
# ['steering column']
# PIPE ASSY UCL TO RADIATOR .  is ::-->
# ['pipe assy ']
# RUBBER HOSE AUX TANK TO WATER PUMP .  is ::-->
# ['rubber hose']
# PIPE ASSY THERMOSTAT TO EGR COOLER .  is ::-->
# ['egr pipe']
# HOSE EGR COOLER OUTLET .  is ::-->
# ['hose ']
# HOSE OIL COOLER OUTLET .  is ::-->
# ['hose ']
# BRACKET EGR COOLER PIPE MTG .  is ::-->
# ['bracket ']
# WIRING HARNESS CABIN .  is ::-->
# ['cabin wiring harness']
# BEZEL .  is ::-->
# ['bezel ']
# MUDGUARD .  is ::-->
# ['mud guard']
# SUCTION PIPE ASSY REAR CAB .  is ::-->
# ['suction hose']
# SPLASH GUARD ASSY WHEEL ARCH FRONT-RH .  is ::-->
# ['wheel arch ']
# FOOT STEP ASSY RH .  is ::-->
# ['foot step']
# "Bracket assy, blow by pipe" .  is ::-->
# ['bracket ']
# "Bracket Assy, Spring Hanger, Front-Rear" .  is ::-->
# ['bracket ']
# FUEL PIPE ASSY TANK TO FILTER .  is ::-->
# ['pipe assy ']
# FUEL RETURN PIPE ASSY .  is ::-->
# ['return hose']
# Combination Switch .  is ::-->
# ['combi switch']
# Fuel Level Sensor .  is ::-->
# ['fuel sensor']
# GASKET .  is ::-->
# ['gasket ']
# "SPOILER,CABIN ROOF,RH" .  is ::-->
# ['spoiler ']
# "RUBBER PAD,SPOILER,MIDDLE" .  is ::-->
# ['rubber pad']
# "OUTER BELT ASSY,FRONT DOOR,LH" .  is ::-->
# ['belt ']
# "OUTER BELT ASSY,FRONT DOOR,RH" .  is ::-->
# ['belt ']
# LATCH FLAP ASSY CENTER-RH .  is ::-->
# ['latch ']
# FUEL TANK MTG .  is ::-->
# ['fuel tank']
# "BRACKET,JUMPER CABLE MTG" .  is ::-->
# ['bracket ']
# ASSY TOP COVER .  is ::-->
# ['cover ']
# "PROPELLER SHAFT ASSY,COUPLING" .  is ::-->
# ['propeller shaft']
# "BRACKET,SPRING HANGER,REAR" .  is ::-->
# ['bracket ']
# GUSSET REAR (LONG MEMBER) .  is ::-->
# ['gusset ']
# ASSY OUTRIGGER CHASSIS SIDE WELDED LH .  is ::-->
# ['outrigger ']
# "TOE PANEL ASSY,RH" .  is ::-->
# ['toe panel']
# MOULDED ROOF LINING .  is ::-->
# ['roof liner']
# "BRACKET ASSY,ORVM MTG" .  is ::-->
# ['bracket ']
# "MOUNTING BRACKET ASSY,REAR" .  is ::-->
# ['bracket ']
# "MOUNTING BRACKET ASSY,FRONT" .  is ::-->
# ['bracket ']
# "MOUNTING BRACKET ASSY,REAR-RH" .  is ::-->
# ['bracket ']
# CLUTCH RELEASE BEARING ASSY .  is ::-->
# ['bearing ']
# "AXLE BEAM ASSY,REAR-RWD" .  is ::-->
# ['axle beam']
# REAR AXLE BEAM ASSY .  is ::-->
# ['rear axle beam']
# CROWN WHEEL .  is ::-->
# ['crown wheel']
# SPINDLE AXLE BEAM .  is ::-->
# ['spindle ']
# ASSY TOE PANEL LH RHD .  is ::-->
# ['toe panel']
# SUBFRAME ASSY .  is ::-->
# ['subframe assy ']
# ASSY COMBINATION SWITCH M0 .  is ::-->
# ['combi switch']
# "BRACKET ASSY,AERO CORNER MTG" .  is ::-->
# ['bracket ']
# "BRACKET,B-PILLAR TRIM MTG,RH" .  is ::-->
# ['bracket ']
# "SIDE WALL ASSY,OUTER-LH" .  is ::-->
# ['side wall']
# PANEL_DOOR_APERTURE_LH .  is ::-->
# ['door panel']
# BKT TOP TRIM ROOF SIDE FLAT .  is ::-->
# ['bracket ']
# "CARPET,REAR" .  is ::-->
# ['carpet ']
# "BEZEL ASSY,SWITCH BANK,RH" .  is ::-->
# ['bezel ']
# "HANDLE ASSY WITH LOCK,GLOVE BOX" .  is ::-->
# ['handle ']
# FOAM .  is ::-->
# ['foam ']
# STEERING WHEEL ASSY W/O SWITCH .  is ::-->
# ['steering wheel']
# "COVER,ECU,BOTTOM" .  is ::-->
# ['cover ']
# "COVER,DASHBOARD DRIVER SIDE,LH" .  is ::-->
# ['cover ']
# ASSY TRIM A PILLAR LH .  is ::-->
# ['pillar trim']
# ASSY TRIM QUARTER LOWER LH .  is ::-->
# ['quarter trim']
# "DEMIST VENT COVER,TOP DOOR,RH" .  is ::-->
# ['cover ']
# REFLECTIVE TAPE ASSY .  is ::-->
# ['reflective tape']
# "BRACKET ASSY,SIDE HEADBOX,LOWER-LH" .  is ::-->
# ['bracket ']
# "BRACKET ASSY,HEADBOX MTG,LH" .  is ::-->
# ['bracket ']
# "BRACKET ASSY,HEADBOX MTG,LH" .  is ::-->
# ['bracket ']
# "LOCATING PIN,HEADBOX" .  is ::-->
# ['pin ']
# "HEADLAMP ACCESS COVER,RH" .  is ::-->
# ['lamp cover']
# "FOOT STEP ASSY,FENDER,RH" .  is ::-->
# ['foot step']
# "FOOT STEP ASSY,FENDER,RH" .  is ::-->
# ['foot step']
# "GRILL ASSY,HEADLAMP,RH" .  is ::-->
# ['grill ']
# "CYLINDER ASSY,CAB TILT" .  is ::-->
# ['cylinder ']
# ASSY HEAT SHIELD COMPLETE TURBOCHARGER .  is ::-->
# ['heat shield']
# "PANEL ASSY,BERTH,LOWER-FRONT" .  is ::-->
# ['panel ']
# WASHER .  is ::-->
# ['washer ']
# STAR WASHER .  is ::-->
# ['washer ']
# "ALLIGATED CROSS MEMBER,UPPER" .  is ::-->
# ['cross member']
# ASSEMBLY BOTTOM COVER .  is ::-->
# ['cover ']
# "LONG MEMBER,RH" .  is ::-->
# ['long member']
# "PARABOLIC LEAF SPRING ASSY,FRONT FWD" .  is ::-->
# ['parabolic leaf spring']
# "PROPELLER SHAFT,FRONT" .  is ::-->
# ['propeller shaft']
# "PROPELLER SHAFT ASSY,MIDDLE" .  is ::-->
# ['propeller shaft']
# ...
# ['bracket ']
# Engine ECU mounting bracket (I) .  is ::-->
# ['bracket ']
# Engine C mount bracket on gearbox .  is ::-->
# ['bracket ']
# Front axle shaft LH .  is ::-->
# ['shaft ']
# Clutch pedal mounting bracket .  is ::-->
# ['bracket ']
# Clutch pedal .  is ::-->
# ['clutch pedal']
# Rear coil spring lower seat LH and RH .  is ::-->
# ['oil ring']
# Front knuckle assembly RH .  is ::-->
# ['knuckle ']
# Front brake calliper assembly (LH) .  is ::-->
# ['brake ']
# Brake pipe from master cylinder to ABS unit (At second point) .  is ::-->
# ['brake pipe']
# Rear brake shoe link with brake shoe adjusting mechanism LH .  is ::-->
# ['brake ']
# Parking brake lever assembly .  is ::-->
# ['parking brake lever']
# Master cylinder first piston with spring .  is ::-->
# ['piston ']
# Exhaust third pipe with post silencer mounting hanger I .  is ::-->
# ['exhaust pipe']
# Coolant no loss tank .  is ::-->
# ['tank ']
# Tail lamp RH .  is ::-->
# ['tail lamp']
# Rear Registration plate lamp .  is ::-->
# ['plate ']
# Clock spring .  is ::-->
# ['lock ']
# Rear speaker mounting housing .  is ::-->
# ['a mount']
# Roof lamp assembly (front) .  is ::-->
# ['roof ']
# Bonnet switch .  is ::-->
# ['switch ']
# Engine wiring harness bracket 1 .  is ::-->
# ['bracket ']
# Dashboard wiring harness .  is ::-->
# ['wiring harness ']
# Front wheel speed sensor RH .  is ::-->
# ['speed sensor']
# Steering nacelle upper .  is ::-->
# ['nacelle ']
# Dashboard skin .  is ::-->
# ['dashboard skin ']
# Cross car beam .  is ::-->
# ['car beam']
# 'A' pillar upper trim RH .  is ::-->
# ['pillar trim']
# 'C' pillar trim upper LH .  is ::-->
# ['pillar trim']
# Grab handle (front LH) .  is ::-->
# ['grab handle']
# Front door shell RH .  is ::-->
# ['door ']
# Front door outer opening handle holding bracket .  is ::-->
# ['bracket ']
# Front door upper hinge LH .  is ::-->
# ['door ']
# Rear door shell hinge upper RH .  is ::-->
# ['door ']
# Rear door weather strip inner .  is ::-->
# ['door ']
# Rear door shell hinge upper LH .  is ::-->
# ['door ']
# Hatchback/trunk lid inner trim .  is ::-->
# ['trim ']
# Bonnet opening cable .  is ::-->
# ['cable ']
# Front windshield washer tank .  is ::-->
# ['washer ']
# HVAC unit .  is ::-->
# ['hvac ']
# HVAC air duct (for side glass) RH .  is ::-->
# ['ac duct']
# AC compressor .  is ::-->
# ['ac compressor']
# Front logo .  is ::-->
# ['logo ']
# Insulation in between fender and body LH .  is ::-->
# ['insulation ']
# Leaf screen .  is ::-->
# ['leaf screen']
# Front wheel arch mud liner RH .  is ::-->
# ['wheel arch liner']
# Front LH seat assembly .  is ::-->
# ['front seat']
# Air filter mounting bolt .  is ::-->
# ['mounting bolt']
# Alternator mounting bolt 2 .  is ::-->
# ['mounting bolt']
# Engine A mount bracket mounting bolt on engine .  is ::-->
# ['mounting bolt']
# Engine C mount to C mount bracket nut .  is ::-->
# ['nut ']
# Gearbox mounting bolt 4 .  is ::-->
# ['mounting bolt']
# Clutch pedal bracket mounting nut .  is ::-->
# ['mounting nut ']
# Clutch pedal pivot nut .  is ::-->
# ['nut ']
# Front McPherson strut upper mounting nut (LH and RH) .  is ::-->
# ['mounting nut ']
# Rear damper upper mounting nut LH and RH .  is ::-->
# ['mounting nut ']
# Front Wheel mounting nut .  is ::-->
# ['mounting nut ']
# Front Brake pad holding clamp .  is ::-->
# ['clamp ']
# Rear Brake pipe holding clamp 1 .  is ::-->
# ['clamp ']
# Brake bleeding nipple .  is ::-->
# ['brake ']
# Parking brake cable holding bracket mounting bolt on body .  is ::-->
# ['mounting bolt']
# Steering column lower shaft lower UJ mounting bolt .  is ::-->
# ['mounting bolt']
# Fuel tank mounting bolt .  is ::-->
# ['mounting bolt']
# Fuel pipe mounting clamp 2 .  is ::-->
# ['clamp ']
# Radiator coolant drain plug .  is ::-->
# ['drain plug ']
# Coolant no loss tank mounting bolt .  is ::-->
# ['mounting bolt']
# Head lamp LH and RH mounting washer (I) .  is ::-->
# ['washer ']
# Horn mounting nut .  is ::-->
# ['mounting nut ']
# Steering wheel cover with air bag (horn pad) mounting screw .  is ::-->
# ['steering wheel']
# Rear speaker housing mounting screw .  is ::-->
# ['mounting screw ']
# Clutch pedal switch (I) mounting bolt .  is ::-->
# ['switch ']
# Engine wiring harness bracket 2 .  is ::-->
# ['bracket ']
# Dashboard wiring harness earthing point bolt .  is ::-->
# ['bolt ']
# Front wheel speed sensor (LH and RH ) mounting bolt .  is ::-->
# ['speed sensor']
# Centre console trim mounting bolt cover LH & RH rear .  is ::-->
# ['mounting bolt']
# Dashboard skin mounting nut on CCB .  is ::-->
# ['mounting nut ']
# Cross car beam front mounting bolt .  is ::-->
# ['mounting bolt']
# 'C' pillar lower trim LH and RH mounting screw .  is ::-->
# ['mounting screw ']
# Front door hinge to door mounting bolt RH .  is ::-->
# ['mounting bolt']
# Front door window glass winding mechanism mounting washer .  is ::-->
# ['washer ']
# Front door hinge to door mounting bolt LH .  is ::-->
# ['mounting bolt']
# Rear door inner opening lever mounting screw .  is ::-->
# ['mounting screw ']
# Hatchback/trunk lid latch mounting bolt .  is ::-->
# ['mounting bolt']
# Hatch back striker cover trim mounting button(I) .  is ::-->
# ['cover ']
# Bonnet opening cable holding clamp .  is ::-->
# ['clamp ']
# Wiper blade mounting nut .  is ::-->
# ['mounting nut ']
# Rear wiper motor mounting bolt .  is ::-->
# ['mounting bolt']
# HVAC high and low pressure pipe bracket mounting bolt .  is ::-->
# ['mounting bolt']
# HVAC air duct foam (on dashboard) .  is ::-->
# ['ac duct']
# Front bumper upper mounting bolt .  is ::-->
# ['mounting bolt']
# Front bumper lower grill mounting clip .  is ::-->
# ['clip ']
# Bonnet bump stopper(II) .  is ::-->
# ['stopper ']
# Front wheel arch mud liner LH and RH mounting screw .  is ::-->
# ['mounting screw ']
# Front RH seat belt anchor mounting bolt .  is ::-->
# ['mounting bolt']
# Rear LH seat belt ELR unit mounting bolt .  is ::-->
# ['mounting bolt']
# Rear seat belt stalk for RH and middle passenger mounting washer .  is ::-->
# ['seat belt']
# "DRUM BRAKE ASSY WITH DC,REAR-LH" .  is ::-->
# ['drum  brake']
# Decal 1200 .  is ::-->
# ['decal ']
# HEADLAMP ASSY RH .  is ::-->
# ['head lamp']
# "SUCTION PIPE ASSY, FILTER TO FIP" .  is ::-->
# ['suction hose']
# "DRUM BRAKE ASSY WITH DC,FRONT-RH" .  is ::-->
# ['drum  brake']
# "FLOOR MAT,MIDDLE" .  is ::-->
# ['floor ']
# DRUM BRAKE ASSY WITH DC FRONT-LH .  is ::-->
# ['drum  brake']
# "WIRING HARNESS,REVERSE PARK ASSIST" .  is ::-->
# ['wiring harness ']
# ALARM RESET SWITCH .  is ::-->
# ['switch ']
# ECU .  is ::-->
# ['ecu ']
# BRACKET ASSY BATTERY TRAY MTG .  is ::-->
# ['bracket ']
# EXHAUST PIPE ASSY FIRST .  is ::-->
# ['exhaust pipe']
# PIPE TC TO IC .  is ::-->
# ['pipe ']
# BRACKET ASSY WHEEL ARCH MTG REAR-RH .  is ::-->
# ['bracket ']
# BATTERY CABLE -VE .  is ::-->
# ['battery cable']
# STEERING GEAR BOX .  is ::-->
# ['steering gearbox']
# GUSSET TOP-LH (LIFT AXLE CROSS MEMBER) .  is ::-->
# ['gusset ']
# PRESSURE REDUCTION VALVE .  is ::-->
# ['valve ']
# SUPD ASSY LH .  is ::-->
# ['supd ']
# SUCTION PIPE ASSY FILTER TO FEED PUMP .  is ::-->
# ['suction hose']
# Wiring Harness Tail .  is ::-->
# ['wiring harness ']
# BRACKET CENTER BRG MTG .  is ::-->
# ['bracket ']
# PLATE .  is ::-->
# ['plate ']
# "W/H, FLOOR RH TIAGO MCE" .  is ::-->
# ['wiring harness ']
# PIPE ASSY WITH CRIMPED HOSE .  is ::-->
# ['pipe assy ']
# PROPELLER SHAFT ASSY COUPLING .  is ::-->
# ['propeller shaft']
# SUPD ASSY .  is ::-->
# ['supd ']
# RELAY VALVE .  is ::-->
# ['relay valve']
# Bracket Assy .  is ::-->
# ['bracket ']
# DRIVER SEAT ASSY .  is ::-->
# ['driver seat']
# "Ventilation Duct Assy, LH" .  is ::-->
# ['vent duct']
# DRUM BRAKE ASSY WITH DC REAR-RH .  is ::-->
# ['drum  brake']
# DRUM BRAKE ASSY WITH DC REAR-LH .  is ::-->
# ['drum  brake']
# WIRING HARNESS ABS FRAME .  is ::-->
# ['wiring harness ']
# "SUPD ASSY,RH" .  is ::-->
# ['supd ']
# SUPPORT BRACKET .  is ::-->
# ['bracket ']
# "CABLE,HV GND MOTOR TO CHASSIS GND" .  is ::-->
# ['cable ']
# DRUM BRAKE ASSY WITH DC REAR-LH .  is ::-->
# ['drum  brake']
# DRUM BRAKE ASSY WITH DC REAR-LH .  is ::-->
# ['drum  brake']
# PROPELLER SHAFT ASSY DRIVE .  is ::-->
# ['propeller shaft']
# WH CABIN SPACE FLOOR .  is ::-->
# ['floor ']
# PANEL ASSY TOP .  is ::-->
# ['panel ']
# AXLE BEAM ASSY .  is ::-->
# ['axle beam']
# FL BOLT M12X75 TS17130-10.9SS8457S1-BL-B .  is ::-->
# ['bolt ']
# STEERING COLUMN ASSY .  is ::-->
# ['steering column']
# WIRING HARNESS SCR UNIT .  is ::-->
# ['wiring harness ']
# WIRING HARNESS ENGINE .  is ::-->
# ['engine wiring harness']
# WIRING HARNESS PANEL .  is ::-->
# ['wiring harness ']
# HOSE .  is ::-->
# ['hose ']
# AIR SUPPLY PIPE ASSY .  is ::-->
# ['pipe assy ']
# TUBE .  is ::-->
# ['tube ']
# TUBE (ENGINE TO UREA INJ INLET) .  is ::-->
# ['tube ']
# GUSSET CROSS MEMBER BOTTOM-RH .  is ::-->
# ['gusset ']
# SUPPORT ASSY RADIATOR MTG LH .  is ::-->
# ['radiator ']
# AIR TANK ASSY WITH BKT .  is ::-->
# ['air tank']
# SUCTION PIPE ASSY FILTER TO PUMP .  is ::-->
# ['suction hose']
# ECU ABS .  is ::-->
# ['abs ecu']
# WIRING HARNESS EMS .  is ::-->
# ['wiring harness ']
# ASSY W/H DIAGNOSTIC PIGTAIL .  is ::-->
# ['pigtail wiring harness']
# EGR VALVE (HOT) .  is ::-->
# ['valve ']
# PUMP ASSY UREA DOSE .  is ::-->
# ['urea pump']
# RETURN FUEL PIPE ASSY .  is ::-->
# ['pipe assy ']
# PROPELLER SHAFT ASSY DRIVE .  is ::-->
# ['propeller shaft']
# "WIPER ARM ASSY WITH BLADE,CO-DRIVER SIDE" .  is ::-->
# ['wiper arm ']
# WIRING HARNESS SCR UNIT .  is ::-->
# ['wiring harness ']
# VENT PIPE ASSY .  is ::-->
# ['pipe assy ']
# "WIRING HARNESS,REVERSE PARK ASSIST" .  is ::-->
# ['wiring harness ']
# TAIL PIPE .  is ::-->
# ['tail pipe']
# HOSE ASSY CMC TO RESERVOIR .  is ::-->
# ['hose ']
# "PIPE ASSY,UCL TO RADIATOR" .  is ::-->
# ['pipe assy ']
# Bracket .  is ::-->
# ['bracket ']
# BUNDY TUBE ASSY LONG MEMBER .  is ::-->
# ['bundy tube']
# SUPPORT BRACKET .  is ::-->
# ['bracket ']
# FUEL PIPE ASSY .  is ::-->
# ['pipe assy ']
# Roof lining .  is ::-->
# ['roof liner']
# "OIL SUMP,UPPER-HALF" .  is ::-->
# ['oil sump ']
# "WIRING HARNESS,COCKPIT" .  is ::-->
# ['wiring harness ']
# GASKET - ROCKER ARM COVER - AL (OFFE .  is ::-->
# ['gasket ']
# HIGH PRESSURE LINE ASSY .  is ::-->
# ['hose ']
# VENT TUBE ASSY .  is ::-->
# ['hose ']
# L-BRACKET LH .  is ::-->
# ['bracket ']
# Long member LH .  is ::-->
# ['long member']
# PRE FILTER MTG BRACKET .  is ::-->
# ['bracket ']
# HP TUBE ASSY .  is ::-->
# ['hp tube ']
# BATTERY CABLE +VE .  is ::-->
# ['battery cable']
# BATTERY CABLE +VE .  is ::-->
# ['battery cable']
# SUCTION PIPE ASSY FILTER TO ENGINE .  is ::-->
# ['suction hose']
# BATTERY CABLE -VE .  is ::-->
# ['battery cable']
# WIRING HARNESS ABS FRAME .  is ::-->
# ['wiring harness ']
# SUCTION LINE ASSY .  is ::-->
# ['suction hose']
# TYRE .  is ::-->
# ['tyre ']
# POLY V-BELT-OFFER DRG .  is ::-->
# ['poly belt']
# Telematics ECU .  is ::-->
# ['ecu ']
# BATTERY TRAY ASSY .  is ::-->
# ['battery tray']
# PROPELLER SHAFT ASSY DRIVE .  is ::-->
# ['propeller shaft']
# INSULATION .  is ::-->
# ['insulation ']
# "WIRING HARNESS,SCR UNIT" .  is ::-->
# ['wiring harness ']
# LABEL TYRE PRESSURE INSTRUCTION .  is ::-->
# ['label ']
# BRACKET .  is ::-->
# ['bracket ']
# Rear axle shaft .  is ::-->
# ['rear axle shaft']
# Battery +ve Cable with engine .  is ::-->
# ['battery cable']
# BRACKET .  is ::-->
# ['bracket ']
# BRACKET .  is ::-->
# ['bracket ']
# SEPERATOR CLAMP .  is ::-->
# ['clamp ']
# "PIPE ASSY,UREA SUPPLY" .  is ::-->
# ['pipe assy ']
# DRIVER STATION ASSY WITH CED COATING .  is ::-->
# ['driver station ']
# "PROPELLER SHAFT ASSY,DRIVE" .  is ::-->
# ['propeller shaft']
# "PIPE BUNCH ASSY,CABIN" .  is ::-->
# ['nylon bunch']
# Cover plate .  is ::-->
# ['plate ']
# "PROPELLER SHAFT ASSY,DRIVE" .  is ::-->
# ['propeller shaft']
# BRACKET .  is ::-->
# ['bracket ']
# PARKING BRAKE LEVER ASSY .  is ::-->
# ['parking brake lever']
# PIANO_BK_PLN-ORVM ASSY WITH ELECTRIC ART .  is ::-->
# ['orvm ']
# "WIRING HARNESS,BATTERY +VE" .  is ::-->
# ['wiring harness ']
# "BELLOW ASSY,GEAR SHIFT LEVER" .  is ::-->
# ['bellow ']
# "WIRING HARNESS,FRONT" .  is ::-->
# ['wiring harness ']
# ASSY WH FLOOR RH XZ+/XZ+DT/XZA+/XZA+DT .  is ::-->
# ['floor ']
# "W/H, ENGINE TIAGO & TIGOR MCE PETROL MT" .  is ::-->
# ['wiring harness ']
# BRACKET .  is ::-->
# ['bracket ']
# "HOSE,THERMOSTAT COVER TO RADIATOR" .  is ::-->
# ['hose ']
# "TAIL LAMP ASSY ,TAILGATE-LH" .  is ::-->
# ['tail lamp']
# "W/H, GARNISH WITH CAMERA TIGOR..." .  is ::-->
# ['wiring harness ']
# "W/H, COCKPIT TIAGO MCE XZ" .  is ::-->
# ['wiring harness ']
# PIPE ASSY- Nylon Bunch .  is ::-->
# ['nylon bunch']
# DRAG LINK ASSY .  is ::-->
# ['drag link ']
# BATTERY SUPPORT ASSY .  is ::-->
# ['battery ']
# MASCOT ASSY .  is ::-->
# ['mascot ']
# TUBE ASSY;T-CONN TO FRONT BRAKE HOSE;LH .  is ::-->
# ['tube assy ']
# LONG MEMBER LH .  is ::-->
# ['long member']
# BRACKET .  is ::-->
# ['bracket ']
# LONG MEMBER LH .  is ::-->
# ['long member']
# PIPE ASSY .  is ::-->
# ['pipe assy ']
# Front Wiper Blades Driver Side .  is ::-->
# ['wiper blade ']
# PIPE ASSY .  is ::-->
# ['pipe assy ']
# Flywheel... .  is ::-->
# ['flywheel ']
# LONG MEMBER LH .  is ::-->
# ['long member']
# BRACKET .  is ::-->
# ['bracket ']
# SUCTION LINE ASSY .  is ::-->
# ['suction hose']
# "REAR AXLE BEAM ASSY,REAR-FWD" .  is ::-->
# ['rear axle beam']
# Battery Cable +ve .  is ::-->
# ['battery cable']
# "Bracket, FWD Axle V-Rod Mtg" .  is ::-->
# ['bracket ']
# PIPE BUNCH ASSY .  is ::-->
# ['nylon bunch']
# "WIRING HARNESS,ENGINE" .  is ::-->
# ['wiring harness ']
# Connecting rod... .  is ::-->
# ['connecting rod']
# Exhaust valve rocker arm lifte... .  is ::-->
# ['exhaust valve']
# WIRING HARNESS TAIL .  is ::-->
# ['wiring harness ']
# "WIRING HARNESS, TAIL" .  is ::-->
# ['wiring harness ']
# HIGH PRESSURE LINE ASSY .  is ::-->
# ['hose ']
# PIPE ASSY .  is ::-->
# ['pipe assy ']
# PIPE BUNCH ASSY .  is ::-->
# ['nylon bunch']
# BRACKET .  is ::-->
# ['bracket ']
# BRACKET ASSY .  is ::-->
# ['bracket ']
# LOAD BODY WITH MOUNTINGS .  is ::-->
# ['load body ']
# BRACKET .  is ::-->
# ['bracket ']
# "CARPET ASSY,FLOOR" .  is ::-->
# ['carpet ']
# PIPE BUNCH ASSY .  is ::-->
# ['nylon bunch']
# LOAD BODY WITH MOUNTINGS .  is ::-->
# ['load body ']
# BRACKET ASSY .  is ::-->
# ['bracket ']
# HOSE ASSY;LATCH LH TO T-CONNECTOR .  is ::-->
# ['hose ']
# STUB AXLE ASSY;RH (PLUMMER BLOCK) .  is ::-->
# ['stub axle']
# BRACKET ASSY .  is ::-->
# ['bracket ']
# WIRING HARNESS TAIL .  is ::-->
# ['wiring harness ']
# AIR TANK ASSY .  is ::-->
# ['air tank']
# BRACKET ASSY .  is ::-->
# ['bracket ']
# BRACKET .  is ::-->
# ['bracket ']
# HIGH PRESSURE LINE ASSY;P/CYL TO GB .  is ::-->
# ['hose ']
# PROPELLER SHAFT ASSY .  is ::-->
# ['propeller shaft']
# WIRING HARNESS;TAIL .  is ::-->
# ['wiring harness ']
# DIFFERENTIAL PINION - OFFER .  is ::-->
# ['pinion ']
# ALTERNATOR 12V 90A DICOR BSIV LTV .  is ::-->
# ['alternator ']
# METAL PIPE ASSY .  is ::-->
# ['metal pipe']
# BRACKET ASSY .  is ::-->
# ['bracket ']
# Frame Assy .  is ::-->
# ['frame assy ']
# Frame Assy .  is ::-->
# ['frame assy ']
# "WIRING HARNESS,MAIN" .  is ::-->
# ['wiring harness ']
# PIPE ASSY .  is ::-->
# ['pipe assy ']
# METAL PIPE ASSY .  is ::-->
# ['metal pipe']
# PIPE ASSY .  is ::-->
# ['pipe assy ']
# "LONG MEMBER,LH" .  is ::-->
# ['long member']
# "PROPELLER SHAFT ASSY,DRIVE" .  is ::-->
# ['propeller shaft']
# CROSS MEMBER ASSY .  is ::-->
# ['cross member']
# LONG MEMBER LH .  is ::-->
# ['long member']
# PIPE BUNCH ASSY .  is ::-->
# ['nylon bunch']
# "LONG MEMBER,LH" .  is ::-->
# ['long member']
# "BRACKET ASSY,TAIL LAMP MTG,LH" .  is ::-->
# ['bracket ']
# "PROPELLER SHAFT ASSY,DRIVE" .  is ::-->
# ['propeller shaft']
# "PROPELLER SHAFT ASSY,DRIVE" .  is ::-->
# ['propeller shaft']
# PRESSURE LINE ASSY .  is ::-->
# ['hose ']
# "LONG MEMBER,RH" .  is ::-->
# ['long member']
# "LONG MEMBER,RH" .  is ::-->
# ['long member']
# Thermostat valve... .  is ::-->
# ['valve ']
# FRAME ASSY .  is ::-->
# ['frame assy ']
# "LONG MEMBER,RH" .  is ::-->
# ['long member']
# FUEL SUCTION PIPE ASSY .  is ::-->
# ['suction hose']
# NYLON PIPE BUNCH ASSY .  is ::-->
# ['nylon bunch']
# KIT-AIR INTAKE ASSY .  is ::-->
# ['air intake assy']
# Bracket .  is ::-->
# ['bracket ']
# "CALIPER ASSY,FRONT-RH" .  is ::-->
# ['caliper ']
# FRAME ASSY .  is ::-->
# ['frame assy ']
# HINGE ASSY;FRONT DOOR;BOTTOM-LH .  is ::-->
# ['hinge ']
# BREATHER HOSE .  is ::-->
# ['breather hose']
# FUEL SUCTION PIPE ASSY .  is ::-->
# ['suction hose']
# FUEL RETURN PIPE ASSY .  is ::-->
# ['return hose']
# BUNDY TUBE ASSY LONG MEMBER .  is ::-->
# ['bundy tube']
# "WIRING HARNESS,TAIL" .  is ::-->
# ['wiring harness ']
# FRAME ASSY WITH FITMENT .  is ::-->
# ['frame assy ']
# "CABLE, HV BATT P-1 -VE TO S-BOX -VE" .  is ::-->
# ['cable ']
# EXHAUST PIPE ASSY WITH FLEX BELLOW .  is ::-->
# ['exhaust pipe']
# EXHAUST PIPE ASSY .  is ::-->
# ['exhaust pipe']
# "SPINDLE,REAR TWIST BEAM" .  is ::-->
# ['spindle ']
# 4786
# Wall time: 3min 45s

# %%
init_size
# Out:
# 37217

# %%
##second loop of search and filtering (fuzzy search)
#fuzzydict = dict((k, v.lower()) for k, v in dictionary.items())
fuzzydict = []
for x in dictionary:
    fuzzydict.append(dictionary[x].lower())

for line in clean_doc:
    
    line1 = line.lower()
    string = line1.partition(",")[0].partition(";")[0].partition("(")[0].partition("[")[0].partition('for')[0].partition('with')[0].partition('w/o')[0].partition('offer')[0].partition('\bw\b')[0]

    closest_match = process.extract(replacer(string).lower(), fuzzydict, scorer=fuzz.token_sort_ratio, limit = 5)
    
    #if(closest_match[1] >= 75):
    print(line, " is ::-->", closest_match)
    clean_doc.remove(line)

print(len(clean_doc))
# Out:
# PLUG (STUB AXLE-TOP) .  is ::--> [('hole plug ', 62), ('core plug ', 62), ('plenum', 60), ('drain plug ', 57), ('logo', 50)]
# RESILIENCE MTG .  is ::--> [('silencer', 64), ('trailing arm', 54), ('tensioner', 52), ('mounting screw ', 50), ('front wiring harness', 47)]
# "STRUCTURAL PAD,HOOD,FRONT" .  is ::--> [('structural foam', 83), ('structural tape', 69), ('rear strut', 58), ('rubber pad', 58), ('strut ', 53)]
# Assy.  is ::--> [('glass ', 67), ('tube assy ', 62), ('pipe assy ', 62), ('frame assy ', 57), ('boss', 50)]
# ADJUSTER .  is ::--> [('adapter', 67), ('outer handle', 60), ('auto slack adjuster', 59), ('washer ', 57), ('rubber pad', 56)]
# FRONT MTG ASSY LH .  is ::--> [('frame assy ', 59), ('front hub', 54), ('subframe assy', 53), ('front wall', 52), ('front seat', 52)]
# DC TO DC CONVERTER .  is ::--> [('connector ', 52), ('counter shaft', 52), ('side valance cover', 50), ('catalytic converter', 49), ('integrated pedal', 47)]
# EXHAUST SYSTEM ASSY .  is ::--> [('air intake system', 55), ('exhaust pipe', 51), ('exhaust valve ', 50), ('tube assy ', 50), ('exhaust manifold', 46)]
# REINFORCEMENT TOW HOOK MTG .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# HEX.  is ::--> [('hose ', 57), ('hinge', 50), ('washer ', 44), ('handle ', 44), ('lp hose', 40)]
# PACKING .  is ::--> [('packing plate', 70), ('rubber packing', 67), ('parking brake', 60), ('pin', 60), ('bearing ', 57)]
# FRONT SPRING ASSY .  is ::--> [('leaf spring ', 64), ('compression spring', 63), ('front suspension', 61), ('front wiring harness', 59), ('parabolic leaf spring', 58)]
# ENGINE MTG ASSY REAR-RH .  is ::--> [('rear axle assy', 59), ('suspension tower', 51), ('engine mount', 51), ('engine wiring harness', 50), ('rear axle beam', 49)]
# FAN DRIVE ASSY 12 V .  is ::--> [('after treatment assy', 51), ('pipe assy ', 50), ('driver station ', 48), ('frame assy ', 48), ('co-driver seat', 48)]
# HEX.  is ::--> [('hose ', 57), ('hinge', 50), ('washer ', 44), ('handle ', 44), ('lp hose', 40)]
# HEX.  is ::--> [('hose ', 57), ('hinge', 50), ('washer ', 44), ('handle ', 44), ('lp hose', 40)]
# HEX.  is ::--> [('hose ', 57), ('hinge', 50), ('washer ', 44), ('handle ', 44), ('lp hose', 40)]
# HEX.  is ::--> [('hose ', 57), ('hinge', 50), ('washer ', 44), ('handle ', 44), ('lp hose', 40)]
# ASSY FOR PARALLEL ROD MGT .  is ::--> [('glass ', 67), ('tube assy ', 62), ('pipe assy ', 62), ('frame assy ', 57), ('boss', 50)]
# EXTENSION PIECE ASSY EXTENSION FRONT-RH .  is ::--> [('suspension tower', 47), ('rear axle assy', 42), ('steering sensor', 41), ('front axle beam', 41), ('speed sensor', 39)]
# C-SUPPORT CHANNEL .  is ::--> [('power cable', 50), ('power cable', 50), ('outer handle', 48), ('ac compressor', 47), ('connector ', 46)]
# REINFORCEMENT FRONT-LH .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# RESERVOIR BOTTLE ASSY .  is ::--> [('rear axle assy', 63), ('washer bottle ', 59), ('battery wiring harness', 47), ('washer system ', 47), ('subframe assy', 47)]
# PACKING .  is ::--> [('packing plate', 70), ('rubber packing', 67), ('parking brake', 60), ('pin', 60), ('bearing ', 57)]
# UREA SOLUTION 32.5% 57-13-6 -YARA ASIA .  is ::--> [('rear axle assy', 36), ('catalytic converter', 36), ('urea sensor', 34), ('door secondary seal', 33), ('suction hose', 33)]
# REINFORCEMENT ASSY FRONT SPRING RH .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# TIE ROD ASSY .  is ::--> [('tube assy ', 67), ('pipe assy ', 67), ('frame assy ', 64), ('subframe assy', 56), ('rear axle assy', 54)]
# Front antiroll bar .  is ::--> [('anti roll bar ', 71), ('front axle beam', 67), ('control shaft', 58), ('front axle', 57), ('front floor', 55)]
# Front LH wheel assembly .  is ::--> [('wheel arch', 62), ('fifth wheel', 60), ('crown wheel', 60), ('wheel arch liner', 57), ('steering wheel', 55)]
# Sun visor Co-driver side .  is ::--> [('co-driver seat', 63), ('side valance cover', 57), ('driver station ', 53), ('pressure sensor', 51), ('driver seat', 51)]
# PLUG (STUB AXLE-TOP) .  is ::--> [('hole plug ', 62), ('core plug ', 62), ('plenum', 60), ('drain plug ', 57), ('logo', 50)]
# CONTAINER ASSY .
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#  is ::--> [('strainer ', 64), ('tube assy ', 61), ('pipe assy ', 61), ('frame assy ', 58), ('rear axle assy', 57)]
# Jack .  is ::--> [('bracket ', 55), ('shackle', 55), ('tank ', 50), ('lock', 50), ('hvac ', 50)]
# anti .  is ::--> [('cantrail', 67), ('nut ', 57), ('garnish', 55), ('a mount', 55), ('tank ', 50)]
# ASSY.  is ::--> [('glass ', 67), ('tube assy ', 62), ('pipe assy ', 62), ('frame assy ', 57), ('boss', 50)]
# FOR HORN .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# Assy water inlet line (Water Pump to Air Compressor) .  is ::--> [('rear axle assy', 63), ('clutch master cylinder', 56), ('inner handle', 55), ('washer system ', 53), ('plastic washer ', 51)]
# HOOK .  is ::--> [('yoke ', 50), ('hose ', 50), ('logo', 50), ('horn', 50), ('roof', 50)]
# CAB MTG CLOSING ASSY LH .  is ::--> [('spring band clamp ', 45), ('packing plate', 44), ('fascia switch', 44), ('main wiring harness', 43), ('tail wiring harness', 43)]
# "ENGINE MTG ARM,RH" .  is ::--> [('engine mount', 69), ('steering arm', 62), ('engine cover', 62), ('engine cradle', 59), ('engine hood', 56)]
# ASSY WIPER SYSTEM 24V NRW LHD .  is ::--> [('washer system ', 48), ('wiper arm ', 47), ('rear axle assy', 47), ('wiper blade ', 45), ('battery wiring harness', 43)]
# FRONT SPRING ASSY .  is ::--> [('leaf spring ', 64), ('compression spring', 63), ('front suspension', 61), ('front wiring harness', 59), ('parabolic leaf spring', 58)]
# TORSION BAR .  is ::--> [('steering arm', 61), ('trailing arm', 61), ('bearing ', 56), ('dashboard skin', 56), ('traction motor', 56)]
# FUEL LINES ASSY-COMPLETE .  is ::--> [('tube assy ', 48), ('pipe assy ', 48), ('rear axle assy', 47), ('glass run mould ', 46), ('fuel filter', 46)]
# OFFER DRG ASSY RECEPTACLE CAP .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# UNION 1/4 NPT (M/S SWAGELOK) .  is ::--> [('front suspension', 55), ('pinion', 53), ('suspension support', 52), ('mounting bolt', 46), ('tensioner', 45)]
# Pressure gauge .  is ::--> [('ac compressor', 59), ('oil pressure switch', 55), ('pressure sensor', 55), ('flanged screw', 52), ('tubeless tyre', 52)]
# ENGINE MTG ARM FRONT-RH .  is ::--> [('engine mount', 57), ('steering arm', 51), ('front damper', 51), ('engine wiring harness', 50), ('front axle', 48)]
# .
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#   is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# FLANGE (DRAIN PLUG) .  is ::--> [('flanged nut', 71), ('flanged screw', 63), ('plate ', 55), ('label ', 55), ('panel ', 55)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# WELD STUD M6X16 .  is ::--> [('foam seal', 42), ('wheel rim ', 42), ('side wall', 42), ('side lamp', 42), ('stub axle', 42)]
# "REINFORCEMENT,EXHAUST BRACKET,FRONT" .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# "FAN ,SHROUD & PWM ASM" .  is ::--> [('tank ', 57), ('foam ', 57), ('panel ', 50), ('fuel tank', 50), ('fan shroud', 46)]
# 5456 1625 2001)" .
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
#   is ::--> [('blow by hose', 15), ('anti roll bar ', 15), ('first aid box', 15), ('back leak hose', 14), ('glass run mould ', 14)]
# WITH VALVES .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# FES Assembly in white .  is ::--> [('suspension tower', 55), ('tube assy ', 54), ('pipe assy ', 54), ('steering wheel', 52), ('frame assy ', 52)]
# FUEL LINES ASSY (FWS TO ENGINE) .  is ::--> [('tube assy ', 58), ('pipe assy ', 58), ('fuel injector', 57), ('frame assy ', 56), ('rear axle assy', 55)]
# WATER BOX ASSY .  is ::--> [('rear axle assy', 64), ('tube assy ', 61), ('subframe assy', 59), ('frame assy ', 58), ('steering gearbox', 53)]
# DETENT ASSY (SHIFTER SHAFT) .  is ::--> [('tube assy ', 70), ('after treatment assy', 65), ('pipe assy ', 60), ('frame assy ', 57), ('rear axle assy', 56)]
# SHIFTING FINGER .  is ::--> [('gear shifter ', 67), ('idler shaft', 62), ('gear shift lever', 58), ('steering gearbox', 58), ('counter shaft', 57)]
# DETENT ASSY (SHIFTER SHAFT) .  is ::--> [('tube assy ', 70), ('after treatment assy', 65), ('pipe assy ', 60), ('frame assy ', 57), ('rear axle assy', 56)]
# HOSE AUX WATER TANK TO BYPASS TUBE .  is ::--> [('suspension tower', 44), ('washer bottle ', 43), ('back leak hose', 42), ('rear axle beam', 42), ('after treatment assy', 41)]
# "STRUCTURE ASSY,CABIN ROOF,MIDDLE" .  is ::--> [('tube assy ', 70), ('structural foam', 69), ('subframe assy', 67), ('structural tape', 62), ('frame assy ', 58)]
# QUARTER TURN KNOB FUSE BOX MTG(TDCV) .  is ::--> [('fuel return hose', 52), ('return hose', 49), ('quarter trim', 48), ('power steering gearbox', 42), ('starter motor', 42)]
# ASSY.SUPPORT(BONNET SIDE) .  is ::--> [('pipe assy ', 67), ('subframe assy', 64), ('tube assy ', 57), ('frame assy ', 55), ('spray suppression', 55)]
# "SUPPORT,BUMPER MTG,RH" .  is ::--> [('stopper ', 57), ('spoiler', 57), ('suspension support', 56), ('supd ', 55), ('strut ', 50)]
# UTILITY BOX ASSY .  is ::--> [('first aid box', 55), ('tube assy ', 48), ('pipe assy ', 48), ('rear axle assy', 47), ('tail wiring harness', 46)]
# REINFORCEMENT PLATE ASSY .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# "LINK,LOCK BARREL TO LATCH,RH" .  is ::--> [('liner ', 67), ('drag link', 62), ('wiper link ', 57), ('pin', 57), ('clip', 50)]
# "LINK,OUTER HANDLE TO LATCH FRONT DOOR,RH" .  is ::--> [('liner ', 67), ('drag link', 62), ('wiper link ', 57), ('pin', 57), ('clip', 50)]
# "HEAD BOX,LH" .  is ::--> [('load body ', 59), ('glove box', 59), ('hand brake', 56), ('body shell', 56), ('grab handle', 53)]
# "PACKING,COWL MTG,REAR" .  is ::--> [('packing plate', 70), ('rubber packing', 67), ('parking brake', 60), ('pin', 60), ('bearing ', 57)]
# "CONSOLE ASSY,BEZEL USB,FRONT" .  is ::--> [('tube assy ', 57), ('pipe assy ', 57), ('subframe assy', 56), ('control brake', 56), ('frame assy ', 55)]
# "CONSOLE,REAR" .  is ::--> [('condenser', 62), ('control panel', 60), ('oil cooler', 59), ('con rod', 57), ('spoiler', 57)]
# "CAP,CENTER CONSOLE,LOWER" .  is ::--> [('clamp ', 75), ('clamp ', 75), ('carpet ', 67), ('caliper', 60), ('clip', 57)]
# COOLING UNIT ASSY .  is ::--> [('air processing unit', 61), ('glass run mould ', 56), ('glass guide ', 50), ('a mount', 50), ('mounting nut ', 48)]
# "BERTH ASSY,LOWER" .  is ::--> [('tube assy ', 74), ('pipe assy ', 63), ('subframe assy', 61), ('frame assy ', 60), ('rear axle assy', 58)]
# "QUARTER TURN KNOB,FUSE BOX MTG" .  is ::--> [('quarter trim', 69), ('return hose', 57), ('battery tray', 55), ('fuel return hose', 48), ('front bumper', 48)]
# "REINFORCEMENT,SPRING HANGER BKT,RH" .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# RESTRICTION INDICATOR .  is ::--> [('traction motor', 63), ('driver station ', 57), ('door wiring harness', 50), ('ignition switch', 50), ('ignition sensor', 50)]
# EGR COOLER ASSY WITH EGR VALVE .  is ::--> [('rear axle assy', 69), ('frame assy ', 56), ('oil cooler', 56), ('glass run mould ', 53), ('catalytic converter', 53)]
# ASSY ROCKER ARM INTAKE(M/S TIMKEN) .  is ::--> [('rear axle assy', 61), ('air intake pipe', 59), ('air intake system', 56), ('steering arm', 53), ('after treatment assy', 52)]
# OMS ASSY .  is ::--> [('frame assy ', 67), ('tube assy ', 59), ('pipe assy ', 59), ('subframe assy', 57), ('ac compressor', 48)]
# TRIGGER WHEEL-MULTI TEETH(CAM SENSOR-DEL .  is ::--> [('steering wheel', 62), ('wheel arch liner', 54), ('fifth wheel', 50), ('wheel rim ', 47), ('steering belt', 47)]
# ASSY.ROCKER ARM EXHAUST-EVB .  is ::--> [('after treatment assy', 47), ('rear axle assy', 44), ('exhaust pipe', 42), ('air intake system', 42), ('exhaust valve ', 41)]
# LOAD GUARD ASSY .  is ::--> [('mud guard', 58), ('subframe assy', 57), ('frame assy ', 56), ('rear axle assy', 55), ('glass guide ', 54)]
# Cam shaft chain tensioner unit mounting bolt .  is ::--> [('mounting bolt', 46), ('mounting nut ', 43), ('ignition sensor', 41), ('air processing unit', 41), ('clutch master cylinder', 39)]
# EGR cooler coolant outlet hose clip .  is ::--> [('coolant hose', 51), ('clutch slave cylinder', 43), ('clutch master cylinder', 42), ('back leak hose', 41), ('discharge hose', 41)]
# Shifter fork shaft pin .  is ::--> [('gear shifter ', 74), ('shifter shaft', 70), ('shaft ', 67), ('washer ', 62), ('stiffener', 62)]
# Detainer spring .  is ::--> [('leaf spring ', 69), ('coil spring', 62), ('parking camera', 62), ('compression spring', 61), ('steering sensor', 60)]
# Front brake hose holding bracket RH .  is ::--> [('breather hose', 46), ('parking brake', 46), ('control brake', 46), ('brake caliper', 46), ('brake hose', 44)]
# Auto adjusting RH spring .  is ::--> [('auto slack adjuster', 60), ('spring band clamp ', 54), ('steering sensor', 51), ('cabin wiring harness', 50), ('parabolic leaf spring', 49)]
# Radiator air scoop top area mounting bolt .  is ::--> [('mounting bolt', 48), ('mounting screw ', 40), ('air processing unit', 40), ('parabolic leaf spring', 39), ('mounting nut ', 38)]
# Bandage .  is ::--> [('handle ', 62), ('adapter', 57), ('bearing ', 57), ('grab handle', 56), ('spring band clamp ', 50)]
# Elastic adhesive bandage .  is ::--> [('pneumatic pipe', 47), ('tailgate hinge', 47), ('airbag ecu', 47), ('auto slack adjuster', 47), ('driver seat', 46)]
# First Aid kit chart .  is ::--> [('first aid box', 62), ('cabin wiring harness', 51), ('dashboard skin', 48), ('air filter', 48), ('door wiring harness', 47)]
# Front door lock and unlock knob housing .  is ::--> [('differential housing', 44), ('air processing unit', 41), ('front suspension', 40), ('door wiring harness', 38), ('front hub', 38)]
# Engine oil filling cap .  is ::--> [('engine wiring harness', 51), ('engine cradle', 51), ('connecting rod', 50), ('cabin wiring harness', 48), ('engine hood', 48)]
# Blow by unit (crankcase ventilation / Oil separator) .  is ::--> [('blow by hose', 67), ('b mount', 53), ('mounting bolt', 48), ('rubber bellow', 48), ('u bolt', 44)]
# Timing chain guide (Moveable) .
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
#   is ::--> [('cabin wiring harness', 58), ('wiring harness ', 56), ('tailgate hinge', 56), ('pigtail wiring harness', 55), ('main wiring harness', 54)]
# First synchronizer cone .  is ::--> [('synchro ring', 51), ('long runner ', 47), ('coolant hose', 46), ('inner handle', 46), ('engine cover', 46)]
# Pinion tail spacer .  is ::--> [('nylon spacer', 67), ('tail pipe', 67), ('ring spacer', 62), ('rack pinion', 62), ('ignition sensor', 55)]
# Front LH wheel assembly .  is ::--> [('wheel arch', 62), ('fifth wheel', 60), ('crown wheel', 60), ('wheel arch liner', 57), ('steering wheel', 55)]
# Rear LH wheel assembly .  is ::--> [('rear axle assy', 69), ('wheel arch liner', 65), ('spare wheel', 62), ('frame assy ', 57), ('wheel arch', 57)]
# LCRV unit .  is ::--> [('c mount', 62), ('ac duct', 50), ('a mount', 50), ('b mount', 50), ('front floor', 50)]
# Tie rod .  is ::--> [('stone guard', 56), ('egr pipe', 53), ('oil strainer', 53), ('rivet ', 50), ('cable tie ', 50)]
# 12V supply port (I) .  is ::--> [('suspension support', 48), ('spray suppression', 44), ('oil sump', 43), ('core plug ', 42), ('poly belt', 42)]
# First aid kit bag .  is ::--> [('first aid box', 73), ('front axle beam', 50), ('anti roll bar ', 47), ('fascia switch', 47), ('drag link', 46)]
# Tow hook .  is ::--> [('lifting hook', 60), ('suction hose', 50), ('door trim', 47), ('foot step', 47), ('motor ', 46)]
# Centre fascia .  is ::--> [('cantrail', 57), ('control shaft', 54), ('counter shaft', 54), ('centrifuge', 52), ('gas balancer ', 48)]
# 200 DIA.  is ::--> [('radiator', 40), ('a pillar', 40), ('b pillar', 40), ('c pillar', 40), ('d pillar', 40)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# WITH SCOOP MTG.  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# LOWER LINK ASSY FRONT-RH .  is ::--> [('wheel arch liner', 50), ('suspension tower', 50), ('frame assy ', 47), ('front wall', 47), ('wiper link ', 47)]
# PANHARD ROD WITH BUSH .  is ::--> [('anti roll bar ', 58), ('fan shroud', 57), ('con rod', 56), ('threaded pin', 52), ('mud guard', 50)]
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# OFFER DRAWING FRONT BRAKE DISC (21 THICK) .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# OFFER DRAWING FRONT BRAKE DISC (21 THICK) .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# AAM BANJO RA WITH 4.11 (37/9) RATIO FOR .  is ::--> [('lambda sensor', 56), ('rear axle beam', 54), ('car beam', 50), ('anti roll bar ', 48), ('urea tank', 48)]
# ASSY.  is ::--> [('glass ', 67), ('tube assy ', 62), ('pipe assy ', 62), ('frame assy ', 57), ('boss', 50)]
# ASSY.  is ::--> [('glass ', 67), ('tube assy ', 62), ('pipe assy ', 62), ('frame assy ', 57), ('boss', 50)]
# ASSY.  is ::--> [('glass ', 67), ('tube assy ', 62), ('pipe assy ', 62), ('frame assy ', 57), ('boss', 50)]
# REVERSE GUIDING SYSTEM CONTROLLER-M/S.INTERFACE .  is ::--> [('air intake system', 44), ('clutch master cylinder', 38), ('instrument cluster', 37), ('co-driver seat', 36), ('engine wiring harness', 35)]
# ANTENNA ASSY .  is ::--> [('gas balancer ', 50), ('battery tray', 50), ('after treatment assy', 50), ('air intake system', 48), ('waist seal ', 45)]
# KIT CDL MINDA VALEO VENTURE BSIV DICOR .  is ::--> [('side valance cover', 43), ('cylinder valve', 42), ('solenoid valve', 42), ('high deck load body', 39), ('modulator valve', 38)]
# KIT IMMOBILIZER VENTURE .  is ::--> [('vertical member', 47), ('side valance cover', 44), ('instrument cluster', 44), ('air filter', 42), ('return hose', 41)]
# SCISSORS JACK WITH 3 PIECE HANDLE .  is ::--> [('ac compressor', 62), ('parking sensor', 52), ('pedal sensor', 48), ('lambda sensor', 46), ('control brake', 46)]
# ASSY.  is ::--> [('glass ', 67), ('tube assy ', 62), ('pipe assy ', 62), ('frame assy ', 57), ('boss', 50)]
# ASSY.  is ::--> [('glass ', 67), ('tube assy ', 62), ('pipe assy ', 62), ('frame assy ', 57), ('boss', 50)]
# ASSY ENGINE SHIELD - LHD .  is ::--> [('windshield ', 56), ('engine hood', 55), ('heat shield', 48), ('glass guide ', 48), ('engine wiring harness', 47)]
# ASSY BUTTERFLY WINDOW RH (ASAHI) .  is ::--> [('window switch', 54), ('battery wiring harness', 52), ('tail wiring harness', 47), ('glass run mould ', 46), ('battery tray', 44)]
# ASSY PLUG-IN WINDOW COMPLETE LH .  is ::--> [('pigtail wiring harness', 45), ('window switch', 45), ('compression spring', 45), ('main wiring harness', 44), ('tail wiring harness', 44)]
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# ASSY CENTER CLUSTER .  is ::--> [('tube assy ', 57), ('clutch booster', 55), ('rear axle assy', 55), ('steering sensor', 53), ('catalytic converter', 53)]
# ASSY FRONT WIPER KIT -LUCAS .  is ::--> [('front wiring harness', 52), ('frame assy ', 50), ('tail wiring harness', 49), ('air intake pipe', 49), ('front suspension', 48)]
# Corner reinf LH .  is ::--> [('engine cover', 59), ('horn ring', 58), ('counter shaft', 57), ('wheel cover', 54), ('coil spring', 54)]
# Centre reinf .  is ::--> [('centrifuge', 64), ('engine cover', 58), ('engine cradle', 56), ('parking camera', 54), ('steering column', 52)]
# Inner reinf .  is ::--> [('roof liner', 67), ('piston ring ', 55), ('oil ring', 53), ('cabin wiring harness', 52), ('engine cover', 52)]
# I .  is ::--> [('rib', 50), ('pin', 50), ('clip', 40), ('shim ', 40), ('pipe ', 40)]
# III .  is ::--> [('pinion', 44), ('circlip ', 40), ('oil ring', 36), ('dipstick ', 36), ('window winding ', 35)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# Reinf (Between L3 and L15) .  is ::--> [('reinforcement ', 56), ('rib', 50), ('bearing ', 50), ('pin', 50), ('steering arm', 47)]
# reinf .  is ::--> [('reinforcement ', 56), ('rib', 50), ('bearing ', 50), ('pin', 50), ('steering arm', 47)]
# Shot gun .  is ::--> [('gusset', 57), ('counter shaft', 57), ('pivot bush', 56), ('fan shroud', 56), ('stone guard', 53)]
# II .  is ::--> [('pinion', 50), ('circlip ', 44), ('oil ring', 40), ('rib', 40), ('dipstick ', 40)]
# I .  is ::--> [('rib', 50), ('pin', 50), ('clip', 40), ('shim ', 40), ('pipe ', 40)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# Tunnel bottom reinf .  is ::--> [('cotton tape', 53), ('door panel', 48), ('return hose', 47), ('long runner ', 47), ('instrument panel', 46)]
# On tunnel .  is ::--> [('long runner ', 70), ('nylon tube', 63), ('instrument panel', 56), ('control panel', 55), ('bundy tube', 53)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# On tunnel .  is ::--> [('long runner ', 70), ('nylon tube', 63), ('instrument panel', 56), ('control panel', 55), ('bundy tube', 53)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# Tail gate sill outer .  is ::--> [('auto slack adjuster', 51), ('outer handle', 50), ('gear shift lever', 50), ('battery tray', 50), ('battery cable', 48)]
# Sill outer reinf .  is ::--> [('engine cover', 50), ('quarter trim', 50), ('horn ring', 48), ('counter shaft', 48), ('fuel rail', 48)]
# Tail gate sill inner .  is ::--> [('inner handle', 50), ('gear shift lever', 50), ('clutch slave cylinder', 49), ('tail pipe', 48), ('driver station ', 47)]
# Striker reinf.  is ::--> [('oil strainer', 64), ('sticker', 60), ('ring spacer', 58), ('strainer ', 57), ('tensioner', 55)]
# Tool kit mounting .  is ::--> [('mounting nut ', 69), ('mounting bolt', 67), ('mounting screw ', 58), ('connecting rod', 52), ('piston ring ', 50)]
# C plr striker reinf .  is ::--> [('instrument cluster', 54), ('compression spring', 54), ('oil strainer', 52), ('cable tie ', 50), ('spring washer ', 50)]
# Wheel arc inner rear support .  is ::--> [('wheel arch liner', 64), ('air intake pipe', 47), ('rear axle shaft', 47), ('wheel arch', 47), ('spare wheel', 46)]
# Cup reinf lower for strut .  is ::--> [('engine cover', 59), ('rear bumper', 54), ('fuel return hose', 52), ('front bumper', 52), ('dowel pin', 50)]
# Bottom .  is ::--> [('bolt ', 60), ('motor ', 55), ('u bolt', 50), ('bonnet', 50), ('cotton tape', 47)]
# Sill inner front .  is ::--> [('front wall', 62), ('front wiring harness', 56), ('front suspension', 56), ('oil filter', 54), ('front seat', 54)]
# Sill reinf .
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#   is ::--> [('snap ring', 53), ('grill ', 53), ('rear wall', 53), ('windshield ', 50), ('drain plug ', 50)]
# Sill reinf .  is ::--> [('snap ring', 53), ('grill ', 53), ('rear wall', 53), ('windshield ', 50), ('drain plug ', 50)]
# A plr inner upper .  is ::--> [('air intake pipe', 56), ('drain plug ', 52), ('air filter', 52), ('rubber packing', 52), ('intake pipe', 50)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# Shot gun reinf .  is ::--> [('synchro ring', 54), ('reinforcement ', 52), ('counter shaft', 52), ('propeller shaft guard', 51), ('nox sensor', 50)]
# Sill side outer rear .  is ::--> [('side valance cover', 53), ('rear bumper', 52), ('rear suspension', 51), ('rear wall', 48), ('side wall', 48)]
# Reinf 2 sill outer .  is ::--> [('engine cover', 47), ('quarter trim', 47), ('counter shaft', 45), ('mounting screw ', 44), ('horn ring', 44)]
# Reinf 4 sill outer .  is ::--> [('engine cover', 47), ('quarter trim', 47), ('counter shaft', 45), ('mounting screw ', 44), ('horn ring', 44)]
# Reinf between sill side front and rear .  is ::--> [('front wiring harness', 41), ('anti roll bar ', 39), ('cabin wiring harness', 38), ('front wall', 38), ('front axle beam', 38)]
# B plr reinf betn BSO and B plr inner .  is ::--> [('inner handle', 42), ('main wiring harness', 40), ('tail wiring harness', 40), ('engine wiring harness', 39), ('spring band clamp ', 38)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# B plr lower inner reinf .  is ::--> [('parking brake lever', 52), ('power steering gearbox', 49), ('cabin wiring harness', 47), ('gear shift lever', 46), ('wheel arch liner', 46)]
# Inner reinf upper .  is ::--> [('air intake pipe', 56), ('roof liner', 52), ('wiper link ', 52), ('ring spacer', 50), ('intake pipe', 50)]
# CCB mtg locator .
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#   is ::--> [('mounting bolt', 50), ('connector ', 50), ('accelerator pedal', 50), ('cotton tape', 46), ('storage box', 46)]
# Cant rail inner front .  is ::--> [('cantrail', 55), ('front wiring harness', 54), ('control panel', 53), ('front wall', 52), ('front seat', 52)]
# A plr upper reinf on cant rail .  is ::--> [('air intake pipe', 44), ('trailing arm', 43), ('oil strainer', 43), ('pigtail wiring harness', 42), ('engine cradle', 42)]
# Rear header outer .  is ::--> [('outer handle', 69), ('rear axle beam', 58), ('heater hose', 57), ('rear bumper', 57), ('rear damper', 57)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# Reinf.  is ::--> [('reinforcement ', 56), ('rib', 50), ('bearing ', 50), ('pin', 50), ('steering arm', 47)]
# Reinf.  is ::--> [('reinforcement ', 56), ('rib', 50), ('bearing ', 50), ('pin', 50), ('steering arm', 47)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# Reinf.  is ::--> [('reinforcement ', 56), ('rib', 50), ('bearing ', 50), ('pin', 50), ('steering arm', 47)]
# Striker reinf .  is ::--> [('oil strainer', 64), ('sticker', 60), ('ring spacer', 58), ('strainer ', 57), ('tensioner', 55)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# REINFORCEMENT ASSY TOW HOOK LH .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# CANOPY STRUCTURE ASSY .  is ::--> [('structural foam', 56), ('subframe assy', 53), ('tube assy ', 53), ('rear axle assy', 51), ('structural tape', 50)]
# CANOPY MTG ASSY FRONT-RH .  is ::--> [('main wiring harness', 47), ('frame assy ', 47), ('rear axle assy', 47), ('front strut', 46), ('front axle beam', 46)]
# ELECTRIC BUZZER UNIT .  is ::--> [('reflective tape', 51), ('front bumper', 50), ('gear shift lever', 50), ('steering belt', 48), ('reflector', 48)]
# TOW HOOK .  is ::--> [('lifting hook', 60), ('suction hose', 50), ('door trim', 47), ('foot step', 47), ('motor ', 46)]
# REINFORCEMENT ASSY TOW HOOK LH .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# REINFORCEMENT FRONT-BOTTOM-LH .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# LOWER SADDLE .  is ::--> [('middle floor', 67), ('load valve', 55), ('cylinder valve', 54), ('side valance cover', 53), ('grab handle', 52)]
# LOWER SADDLE .  is ::--> [('middle floor', 67), ('load valve', 55), ('cylinder valve', 54), ('side valance cover', 53), ('grab handle', 52)]
# NOx Univolt (Gen 4 PV Protocol) .  is ::--> [('nox sensor', 57), ('pivot bush', 48), ('sunroof sensor', 48), ('intake manifold', 46), ('ventilation hose', 44)]
# Oilfillingcap .  is ::--> [('oil ring', 57), ('coil spring', 50), ('lifting hook', 48), ('snap ring', 45), ('leaf spring ', 42)]
# FRONT HEADER ASSY .  is ::--> [('frame assy ', 67), ('subframe assy', 60), ('front seat', 59), ('rear axle assy', 58), ('front wiring harness', 54)]
# BODY SIDE ASSY OUTER-RH .  is ::--> [('rear axle assy', 49), ('high deck load body', 48), ('heater hose', 47), ('glass guide ', 47), ('outer handle', 46)]
# BODY SIDE ASSY OUTER-LH .  is ::--> [('outer handle', 51), ('load body ', 50), ('rear axle assy', 49), ('flat bed load body', 49), ('glass guide ', 47)]
# BODY SIDE ASSY INNER-LH .  is ::--> [('high deck load body', 48), ('inner handle', 46), ('wheel arch liner', 46), ('subframe assy', 44), ('tube assy ', 44)]
# TIE MEMBER ASSY .  is ::--> [('cross member ', 67), ('crash member', 67), ('vertical member', 60), ('cable tie ', 58), ('tube assy ', 58)]
# WAIST REINFORCEMENT OUTER LH .  is ::--> [('waist seal ', 70), ('spring washer ', 61), ('twist beam', 60), ('thrust ring', 57), ('snap ring', 53)]
# ASSY SHOT GUN RH .  is ::--> [('subframe assy', 48), ('tube assy ', 48), ('counter shaft', 48), ('shock absorber ', 47), ('sunroof sensor', 47)]
# Diffuser .  is ::--> [('stiffener', 59), ('buffer', 57), ('fuel sensor', 53), ('rubber buffer', 48), ('condenser', 47)]
# Diffuser .  is ::--> [('stiffener', 59), ('buffer', 57), ('fuel sensor', 53), ('rubber buffer', 48), ('condenser', 47)]
# "TIE MEMBER ASSY,UPPER" .  is ::--> [('cross member ', 67), ('crash member', 67), ('vertical member', 60), ('cable tie ', 58), ('tube assy ', 58)]
# Ace Gold - Front Turn Indicator LH .  is ::--> [('front wiring harness', 42), ('front strut', 42), ('front suspension', 42), ('clutch master cylinder', 41), ('accelerator pedal', 41)]
# Ace Gold Diesel BSVI .  is ::--> [('side valance cover', 47), ('heat shield', 45), ('wheel arch liner', 44), ('sintered bush', 42), ('flat bed load body', 42)]
# REINFORCEMENT BOTTOM RH .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# "REINFORCEMENT,BUMPER CROSS MEMBER,RH" .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# PLUG BUTTON FOR REINF CAB MTG FRONT SLOT 8X12 .  is ::--> [('hole plug ', 60), ('core plug ', 60), ('drain plug ', 57), ('cotton tape', 55), ('nut plate', 50)]
# SUPPORT INNER-LH .  is ::--> [('oil sump', 50), ('air suspension', 47), ('rear strut', 46), ('roof liner', 46), ('ignition sensor', 45)]
# SUPPORT OUTER-LH .  is ::--> [('counter shaft', 55), ('instrument cluster', 53), ('vapour hose', 52), ('suction hose', 50), ('spacer plate', 50)]
# CAP (FOR BATTERY CABLE CLAMP -VE) .  is ::--> [('clamp ', 75), ('clamp ', 75), ('carpet ', 67), ('caliper', 60), ('clip', 57)]
# DC TO DC CONVERTER (1.5A) .  is ::--> [('connector ', 52), ('counter shaft', 52), ('side valance cover', 50), ('catalytic converter', 49), ('integrated pedal', 47)]
# OWNERS MANUAL .  is ::--> [('power cable', 58), ('power cable', 58), ('outer handle', 56), ('inner handle', 56), ('toe panel', 55)]
# NOZZLE ASSY .  is ::--> [('tube assy ', 60), ('pipe assy ', 60), ('frame assy ', 57), ('rear axle assy', 56), ('subframe assy', 50)]
# M/S.PRABHA.  is ::--> [('grab handle', 48), ('primary seal', 45), ('primary seal ', 45), ('parabolic leaf spring', 45), ('breather hose', 43)]
# TIE MEMBER LH .  is ::--> [('long member ', 67), ('crash member', 64), ('vertical member', 64), ('cross member ', 56), ('cable tie ', 55)]
# 15- TS17716 .  is ::--> [('twist beam', 30), ('thrust ring', 29), ('hp tube ', 24), ('lp tube ', 24), ('ac duct', 24)]
# OIL MIST SEPARATOR ASSY .  is ::--> [('rear axle assy', 54), ('starter motor', 50), ('alternator ', 48), ('glass run mould ', 47), ('oil strainer', 46)]
# OWNERS MANUAL .  is ::--> [('power cable', 58), ('power cable', 58), ('outer handle', 56), ('inner handle', 56), ('toe panel', 55)]
# ENGINE SHIELDING ASSY RH .  is ::--> [('engine wiring harness', 58), ('main wiring harness', 51), ('steering sensor', 51), ('engine hood', 51), ('wheel arch liner', 50)]
# CONDESNER ASSY .  is ::--> [('condenser', 70), ('rear axle assy', 57), ('catalytic converter', 55), ('inner handle', 54), ('subframe assy', 52)]
# ASSY.ARM BLADE & NOZZLE FITMENT DRIVER SIDE M/S.  is ::--> [('after treatment assy', 46), ('air intake system', 39), ('air intake pipe', 37), ('rear axle assy', 37), ('gear shift lever', 36)]
# ASSY.  is ::--> [('glass ', 67), ('tube assy ', 62), ('pipe assy ', 62), ('frame assy ', 57), ('boss', 50)]
# BCS .  is ::--> [('bush ', 57), ('boss', 57), ('brick', 50), ('bracket ', 40), ('gas balancer ', 40)]
# Front View Mirror Assly .  is ::--> [('frame assy ', 55), ('subframe assy', 50), ('front axle', 48), ('tube assy ', 44), ('pipe assy ', 44)]
# "STRAP ASSY & RUBBER,FUEL TANK MTG" .  is ::--> [('tube assy ', 62), ('rubber spacer', 60), ('subframe assy', 60), ('rubber pad', 59), ('rear axle assy', 58)]
# AIR DEFLCTOR ASSY .  is ::--> [('reflector', 62), ('air filter', 59), ('air duct', 56), ('after treatment assy', 54), ('frame assy ', 52)]
# CONNECTING LINK ASSY REAR .  is ::--> [('connecting rod', 62), ('rear axle assy', 56), ('connector ', 47), ('mounting screw ', 46), ('rubber packing', 46)]
# CANOPY ASSY .  is ::--> [('pipe assy ', 60), ('frame assy ', 57), ('subframe assy', 50), ('tube assy ', 50), ('rear axle assy', 48)]
# WH EMS_X445_DOM_PET_AMT .  is ::--> [('spare wheel', 35), ('foam washer ', 35), ('intermediate shaft', 34), ('washer system ', 33), ('washer bottle ', 33)]
# WH FRONT_X445_DOM_PET_AMT_ MILITARY_STD .  is ::--> [('front wiring harness', 37), ('front strut', 36), ('front seat', 33), ('foam washer ', 32), ('intermediate shaft', 32)]
# FT HARNESS DCT XM .  is ::--> [('front wiring harness', 59), ('door wiring harness', 56), ('cockpit wiring harness', 56), ('battery wiring harness', 56), ('floor wiring harness', 54)]
# WH EMS X451 DOM BSVI PETROL XM DCT .  is ::--> [('control shaft', 34), ('control brake', 34), ('steering wheel', 33), ('cut off switch', 33), ('clutch master cylinder', 32)]
# REAR QUARTER ASSY INNER-LH .  is ::--> [('rear axle assy', 60), ('integrated pedal', 48), ('wheel arch liner', 48), ('quarter trim', 47), ('cylinder head', 46)]
# "BODY SIDE ASSY,INNER-FRONT-LH" .  is ::--> [('tube assy ', 61), ('pipe assy ', 61), ('body shell', 58), ('dashboard skin', 57), ('glass guide ', 56)]
# "REINFORCEMENT ASSY,CANTRAIL,LH" .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# "REINFORCEMENT ASSY,B-PILLAR,INNER-LH" .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# ASSY TIE MEMBER COMPLETE .  is ::--> [('rear axle assy', 53), ('cross member ', 50), ('crash member', 50), ('tube assy ', 48), ('pipe assy ', 48)]
# Central Detent .  is ::--> [('structural tape', 55), ('cantrail', 55), ('after treatment assy', 53), ('cable tie ', 52), ('reinforcement ', 52)]
# "SUPPORT ASSY,RADIATOR MTG,LH" .  is ::--> [('pipe assy ', 67), ('subframe assy', 64), ('tube assy ', 57), ('frame assy ', 55), ('spray suppression', 55)]
# Coolant Line Assy .  is ::--> [('coolant hose', 62), ('tube assy ', 54), ('pipe assy ', 54), ('frame assy ', 52), ('rear axle assy', 52)]
# ASSY CROSS MBR .  is ::--> [('cross member ', 69), ('subframe assy', 59), ('frame assy ', 58), ('crash member', 54), ('tube assy ', 52)]
# EXTENSION PIECE ASSY EXTENSION FRONT-RH .  is ::--> [('suspension tower', 47), ('rear axle assy', 42), ('steering sensor', 41), ('front axle beam', 41), ('speed sensor', 39)]
# C-SUPPORT CHANNEL .  is ::--> [('power cable', 50), ('power cable', 50), ('outer handle', 48), ('ac compressor', 47), ('connector ', 46)]
# REINFORCEMENT FRONT-LH .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# ASSY FOR PARALLEL ROD MGT .  is ::--> [('glass ', 67), ('tube assy ', 62), ('pipe assy ', 62), ('frame assy ', 57), ('boss', 50)]
# ASSY VERTICAL SUPPORT BRKT-1 .  is ::--> [('vertical member', 51), ('after treatment assy', 46), ('subframe assy', 44), ('spray suppression', 44), ('tube assy ', 43)]
# ENGINE MTG ASSY REAR-LH .  is ::--> [('rear axle assy', 59), ('suspension tower', 51), ('engine mount', 51), ('engine wiring harness', 50), ('rear axle beam', 49)]
# ASSY.  is ::--> [('glass ', 67), ('tube assy ', 62), ('pipe assy ', 62), ('frame assy ', 57), ('boss', 50)]
# C/M FRONT .  is ::--> [('front hub', 67), ('front wall', 63), ('front seat', 63), ('front axle', 63), ('c mount', 62)]
# L-REINFORCEMENT TOP-LH .  is ::--> [('oil ring', 71), ('leaf spring ', 59), ('coil spring', 59), ('leaf screen', 59), ('oil strainer', 56)]
# DC TO DC CONVERTER .  is ::--> [('connector ', 52), ('counter shaft', 52), ('side valance cover', 50), ('catalytic converter', 49), ('integrated pedal', 47)]
# SUPPORT ASSY FRONT-LH .  is ::--> [('front strut', 56), ('front suspension', 54), ('front hub', 53), ('front seat', 52), ('subframe assy', 47)]
# L-REINFORCEMENT TOP-LH .  is ::--> [('oil ring', 71), ('leaf spring ', 59), ('coil spring', 59), ('leaf screen', 59), ('oil strainer', 56)]
# L-REINFORCEMENT BOTTOM-LH .  is ::--> [('oil ring', 71), ('leaf spring ', 59), ('coil spring', 59), ('leaf screen', 59), ('oil strainer', 56)]
# RELAY ARM .  is ::--> [('rear damper', 60), ('trailing arm', 57), ('battery tray', 57), ('foam seal', 56), ('wheel rim ', 56)]
# FRONT SPRING ASSY .  is ::--> [('leaf spring ', 64), ('compression spring', 63), ('front suspension', 61), ('front wiring harness', 59), ('parabolic leaf spring', 58)]
# REINFORCEMENT FRONT-BOTTOM-RH .
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#   is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# Telematics .  is ::--> [('pneumatic pipe', 58), ('seat belt', 53), ('latch ', 53), ('plastic washer ', 50), ('waist seal ', 50)]
# RESONATOR BOX ASSY .  is ::--> [('rear axle assy', 69), ('first aid box', 58), ('storage box', 55), ('suspension tower', 53), ('subframe assy', 52)]
# DC TO DC CONVERTER .  is ::--> [('connector ', 52), ('counter shaft', 52), ('side valance cover', 50), ('catalytic converter', 49), ('integrated pedal', 47)]
# CLOSE COUPLED CATCON ASSY .  is ::--> [('rear axle assy', 51), ('tube assy ', 47), ('back leak hose', 46), ('clutch slave cylinder', 43), ('outer handle', 43)]
# "PIGTAIL,ENGINE LAMP" .  is ::--> [('tail pipe', 75), ('tail lamp', 62), ('tailgate hinge', 57), ('tailgate', 53), ('cantrail', 53)]
# FRONT SPRING ASSY .  is ::--> [('leaf spring ', 64), ('compression spring', 63), ('front suspension', 61), ('front wiring harness', 59), ('parabolic leaf spring', 58)]
# CLOSE PROXIMITY MIRROR ASSY .  is ::--> [('rear axle assy', 49), ('front axle beam', 43), ('air processing unit', 43), ('front floor', 42), ('spring band clamp ', 41)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# "PUSH ROD ASSY,SLAVE CYLINDER" .  is ::--> [('fan shroud', 61), ('tube assy ', 55), ('pipe assy ', 55), ('subframe assy', 54), ('frame assy ', 52)]
# SPEAKER 5.25 WITH RAIN COVER (BLAUPUNKT .  is ::--> [('spacer ', 56), ('ring spacer', 52), ('nylon spacer', 50), ('spacer plate', 50), ('rubber spacer', 48)]
# COOLANT LINE ASSY .  is ::--> [('coolant hose', 62), ('tube assy ', 54), ('pipe assy ', 54), ('frame assy ', 52), ('rear axle assy', 52)]
# HEX.
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#   is ::--> [('hose ', 57), ('hinge', 50), ('washer ', 44), ('handle ', 44), ('lp hose', 40)]
# ABS WITH AEBS SUPPORT .  is ::--> [('abs ecu', 60), ('bush ', 57), ('boss', 57), ('glass ', 50), ('label ', 50)]
# L-REINFORCEMENT TOP-RH .  is ::--> [('oil ring', 71), ('leaf spring ', 59), ('coil spring', 59), ('leaf screen', 59), ('oil strainer', 56)]
# HEX.  is ::--> [('hose ', 57), ('hinge', 50), ('washer ', 44), ('handle ', 44), ('lp hose', 40)]
# HEX.  is ::--> [('hose ', 57), ('hinge', 50), ('washer ', 44), ('handle ', 44), ('lp hose', 40)]
# HEX.  is ::--> [('hose ', 57), ('hinge', 50), ('washer ', 44), ('handle ', 44), ('lp hose', 40)]
# HEX.  is ::--> [('hose ', 57), ('hinge', 50), ('washer ', 44), ('handle ', 44), ('lp hose', 40)]
# HEX.  is ::--> [('hose ', 57), ('hinge', 50), ('washer ', 44), ('handle ', 44), ('lp hose', 40)]
# ELECTRONICS STABILITY CONTROL MODULE .  is ::--> [('control panel', 45), ('control shaft', 45), ('door secondary seal', 44), ('reflective tape', 43), ('oil cooler', 43)]
# STRAP ASSY .  is ::--> [('subframe assy', 70), ('frame assy ', 70), ('tube assy ', 63), ('pipe assy ', 63), ('rear axle assy', 58)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# SUPPORT .  is ::--> [('stopper ', 57), ('spoiler', 57), ('suspension support', 56), ('supd ', 55), ('strut ', 50)]
# "REINFORCEMENT,BUMPER CROSS MEMBER,LH" .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# OWNERS MANUAL .  is ::--> [('power cable', 58), ('power cable', 58), ('outer handle', 56), ('inner handle', 56), ('toe panel', 55)]
# OWNERS MANUAL .  is ::--> [('power cable', 58), ('power cable', 58), ('outer handle', 56), ('inner handle', 56), ('toe panel', 55)]
# OWNERS MANUAL .  is ::--> [('power cable', 58), ('power cable', 58), ('outer handle', 56), ('inner handle', 56), ('toe panel', 55)]
# OWNERS MANUAL .  is ::--> [('power cable', 58), ('power cable', 58), ('outer handle', 56), ('inner handle', 56), ('toe panel', 55)]
# OWNERS MANUAL .  is ::--> [('power cable', 58), ('power cable', 58), ('outer handle', 56), ('inner handle', 56), ('toe panel', 55)]
# OWNERS MANUAL .  is ::--> [('power cable', 58), ('power cable', 58), ('outer handle', 56), ('inner handle', 56), ('toe panel', 55)]
# SET-COOLING SYSTEM .  is ::--> [('coolant hose', 60), ('air intake system', 57), ('foot step', 52), ('thrust ring', 48), ('steering column', 48)]
# SUPPORT ASSY WITH SPACER .  is ::--> [('pipe assy ', 67), ('subframe assy', 64), ('tube assy ', 57), ('frame assy ', 55), ('spray suppression', 55)]
# STAY ROD ASSY .  is ::--> [('frame assy ', 61), ('tube assy ', 55), ('subframe assy', 54), ('rear axle assy', 52), ('glass run mould ', 50)]
# SUPPORT .  is ::--> [('stopper ', 57), ('spoiler', 57), ('suspension support', 56), ('supd ', 55), ('strut ', 50)]
# C-CHANNEL SUPPORT .  is ::--> [('power cable', 50), ('power cable', 50), ('outer handle', 48), ('ac compressor', 47), ('connector ', 46)]
# "ARMATURE,DASHBOARD DRIVER SIDE" .  is ::--> [('alternator ', 56), ('adapter', 53), ('primary seal', 50), ('steering arm', 50), ('trailing arm', 50)]
# Cooling System- Tata Toyo .  is ::--> [('tailgate hinge', 47), ('coolant hose', 44), ('air intake system', 44), ('washer system ', 43), ('control shaft', 43)]
# Engine oil filling cap .  is ::--> [('engine wiring harness', 51), ('engine cradle', 51), ('connecting rod', 50), ('cabin wiring harness', 48), ('engine hood', 48)]
# Blow by unit (crankcase ventilation / Oil separator) .  is ::--> [('blow by hose', 67), ('b mount', 53), ('mounting bolt', 48), ('rubber bellow', 48), ('u bolt', 44)]
# Timing chain moveable guide (Fuel pump chain) .  is ::--> [('main wiring harness', 52), ('tail wiring harness', 52), ('cabin wiring harness', 51), ('engine wiring harness', 50), ('pigtail wiring harness', 49)]
# Glow plug .  is ::--> [('hole plug ', 67), ('core plug ', 67), ('plummer block', 55), ('drain plug ', 53), ('oil pump', 47)]
# Third and forth gear engaging gear shifter sleeve (on output shaft) .  is ::--> [('fan shroud', 63), ('threaded pin', 57), ('outer handle', 57), ('inner handle', 57), ('windshield ', 53)]
# Differential cage .  is ::--> [('differential housing', 65), ('co-driver seat', 52), ('front axle', 52), ('vertical member', 50), ('front damper', 48)]
# Jack .  is ::--> [('bracket ', 55), ('shackle', 55), ('tank ', 50), ('lock', 50), ('hvac ', 50)]
# Centre console .  is ::--> [('control brake', 59), ('heater hose', 56), ('coolant hose', 54), ('breather hose', 52), ('condenser', 52)]
# ...
# FILLER ASSY WITH BREATHER PIPE .  is ::--> [('pipe assy ', 70), ('frame assy ', 67), ('air filter', 67), ('rear axle assy', 64), ('a pillar', 63)]
# "GRANIT_BLACK-CONSOLE ASSY,PANEL,TOP" .  is ::--> [('rear axle assy', 51), ('control panel', 47), ('back leak hose', 46), ('oil cooler', 46), ('glass run mould ', 45)]
# "CLRPRT_ASY_2-CONSOLE ASSY,FRONT" .  is ::--> [('frame assy ', 46), ('subframe assy', 42), ('ac compressor', 42), ('control brake', 42), ('tube assy ', 41)]
# "CLRPART_ASSY-CONSOLE ASSY,FRONT" .  is ::--> [('frame assy ', 46), ('rear axle assy', 46), ('catalytic converter', 45), ('coolant hose', 43), ('spray suppression', 43)]
# "CLRPART_ASSY-CONSOLE ASSY,MAIN BODY" .  is ::--> [('frame assy ', 46), ('rear axle assy', 46), ('catalytic converter', 45), ('coolant hose', 43), ('spray suppression', 43)]
# "GRANIT_BLACK-CONSOLE ASSY,BEZEL USB,FRON" .  is ::--> [('rear axle assy', 51), ('control panel', 47), ('back leak hose', 46), ('oil cooler', 46), ('glass run mould ', 45)]
# "SLAT_DK_GREY-ARM REST ASSY,FRONT DOOR,LH" .  is ::--> [('after treatment assy', 57), ('rear axle assy', 45), ('frame assy ', 44), ('auto slack adjuster', 44), ('air intake system', 42)]
# SCISSORS JACK ASSY .  is ::--> [('ac compressor', 52), ('rear axle assy', 50), ('subframe assy', 45), ('lambda sensor', 45), ('secondary seal ', 44)]
# WINDSCREEN ASSY .  is ::--> [('leaf screen', 62), ('pipe assy ', 58), ('subframe assy', 57), ('frame assy ', 56), ('wiring harness ', 55)]
# ANTI VIBRATION SHEET with aluminum backing .  is ::--> [('ventilation hose', 56), ('driver station ', 53), ('traction motor', 53), ('cabin wiring harness', 50), ('front wiring harness', 50)]
# Strcural Pad on Wheel Base .  is ::--> [('spare wheel', 54), ('structural foam', 54), ('wheel arch', 50), ('structural tape', 49), ('wheel arch liner', 48)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# MANUAL WITH CHILLER HOSE .  is ::--> [('cantrail', 57), ('panel ', 55), ('urea tank', 53), ('handle ', 50), ('common rail', 47)]
# Telematics Control Unit with eSIM .  is ::--> [('control panel', 56), ('control shaft', 56), ('pneumatic tube', 49), ('traction motor', 49), ('steering column', 47)]
# NEUTRAL_SLVR-ASSY CONSOLE FINISHER FRONT .  is ::--> [('rear axle assy', 44), ('front axle beam', 40), ('inner handle', 38), ('control shaft', 38), ('cylinder valve', 37)]
# ASSY WH FRONT RHD 1.5 DIESEL XE .  is ::--> [('subframe assy', 41), ('steering wheel', 40), ('rear axle assy', 40), ('frame assy ', 39), ('front axle beam', 39)]
# ASSY WH FRONT RHD 1.5 DIESEL XMA .  is ::--> [('subframe assy', 40), ('rear axle assy', 39), ('frame assy ', 38), ('front wall', 38), ('front axle beam', 38)]
# ASSY WH FRONT RHD 1.2 NGTCTC PETROL XE .  is ::--> [('wheel arch liner', 37), ('connecting rod', 35), ('rear axle assy', 35), ('front wiring harness', 34), ('propeller shaft guard', 34)]
# ASSY WH FRONT RHD 1.2 NGTC PETROL XMA .  is ::--> [('propeller shaft guard', 38), ('control shaft', 36), ('front wiring harness', 35), ('connecting rod', 35), ('propeller shaft', 35)]
# ASSY WH ENGINE 1.5 CRAIL AMT DIESEL XMA/XZA+/XZA+DT .  is ::--> [('engine cradle', 38), ('after treatment assy', 37), ('rear axle assy', 34), ('tail wiring harness', 32), ('trailing arm', 32)]
# DAYTONA_GREY-KIT-OUTER HANDLE;LH .  is ::--> [('outer handle', 59), ('inner handle', 49), ('battery wiring harness', 47), ('door wiring harness', 46), ('grab handle', 45)]
# USB with AUX Cable .  is ::--> [('hub', 67), ('bush ', 57), ('tube ', 57), ('gusset', 44), ('rubber bush', 43)]
# REINFORCEMENT FRONT SPRING BKT FRONT-LH .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# shifter dog Rev-crawler .  is ::--> [('rear axle shaft', 58), ('gear shifter ', 57), ('gear shift lever', 56), ('propeller shaft guard', 50), ('engine cradle', 50)]
# REINFORCEMENT ASSY FRONT SPRING RH .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# Detent spring .  is ::--> [('leaf spring ', 67), ('steering belt', 62), ('differential housing', 61), ('piston ring ', 58), ('compression spring', 58)]
# WARNING TRIANGLE - M/S PACOLINE .  is ::--> [('tail wiring harness', 58), ('pigtail wiring harness', 55), ('steering column', 55), ('main wiring harness', 54), ('cabin wiring harness', 53)]
# Actuator Assy (TY 24/24) LH .  is ::--> [('battery tray', 56), ('accelerator pedal', 53), ('alternator ', 52), ('modulator valve', 50), ('battery', 50)]
# REINFORCEMENT RH .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# "REINFORCEMENT,RH" .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# LINK;ROD ASSY .  is ::--> [('liner ', 67), ('drag link', 62), ('wiper link ', 57), ('pin', 57), ('clip', 50)]
# REINFORCEMENT LH .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# Car Jack .  is ::--> [('air tank', 62), ('camera', 57), ('parking camera', 55), ('bracket ', 53), ('aux tank', 50)]
# RUBBER GROMMET .  is ::--> [('rubber hose', 72), ('grommet ', 67), ('rubber block', 62), ('rubber buffer', 59), ('rubber bellow', 59)]
# Engine oil filling cap... .  is ::--> [('engine wiring harness', 51), ('engine cradle', 51), ('connecting rod', 50), ('cabin wiring harness', 48), ('engine hood', 48)]
# REINFORCEMENT BOTTOM RH .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# FUEL SUCTION PIPE ASSY FILTER TO ENGINE .  is ::--> [('suction hose', 47), ('fuel return hose', 44), ('fuel filter', 44), ('engine wiring harness', 43), ('engine mount', 43)]
# THERMOSTAT ASSY .  is ::--> [('tube assy ', 58), ('frame assy ', 56), ('rear axle assy', 55), ('after treatment assy', 51), ('breather hose', 50)]
# ESP Unit .  is ::--> [('a mount', 53), ('b mount', 53), ('c mount', 53), ('air processing unit', 52), ('engine mount', 50)]
# Cooling Module .  is ::--> [('coolant hose', 62), ('oil cooler', 58), ('connecting rod', 57), ('con rod', 57), ('cylinder ', 55)]
# "CONTAINER ASSY,FATC" .  is ::--> [('strainer ', 64), ('tube assy ', 61), ('pipe assy ', 61), ('frame assy ', 58), ('rear axle assy', 57)]
# Stab Link .  is ::--> [('snap ring', 56), ('stub axle', 56), ('nylon tube', 53), ('black tape', 53), ('wiper link ', 53)]
# Shark Fin Antenna .  is ::--> [('spacer plate', 48), ('inner handle', 48), ('anti roll bar ', 47), ('counter shaft', 47), ('intermediate shaft', 46)]
# Scissor Jack .  is ::--> [('ac compressor', 64), ('parking sensor', 54), ('pedal sensor', 50), ('lambda sensor', 48), ('control brake', 48)]
# "REINFORCEMENT,RH" .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# "HIGH PRESSURE LINE ASSY,P/CYL TO GB" .  is ::--> [('rear axle assy', 54), ('return hose', 53), ('fuel return hose', 51), ('urea hose', 50), ('subframe assy', 50)]
# Timing chain upper guider... .  is ::--> [('inner handle', 54), ('tailgate hinge', 51), ('air intake pipe', 50), ('cabin wiring harness', 49), ('outer handle', 49)]
# Timing chain moveable guide (C... .  is ::--> [('main wiring harness', 52), ('tail wiring harness', 52), ('cabin wiring harness', 51), ('engine wiring harness', 50), ('pigtail wiring harness', 49)]
# Timing chain fix guide upper (... .  is ::--> [('inner handle', 50), ('pigtail wiring harness', 48), ('tailgate hinge', 48), ('cabin wiring harness', 46), ('outer handle', 45)]
# "REINF ASSY,A-PILLAR,RH" .  is ::--> [('frame assy ', 70), ('tube assy ', 63), ('pipe assy ', 63), ('subframe assy', 61), ('wiring harness ', 58)]
# PIANO_BK_PLN-HUMINITY STRIP;RH .  is ::--> [('ignition switch', 48), ('ignition sensor', 48), ('intake pipe', 42), ('nylon pipe bunch', 42), ('instrument panel', 42)]
# "Pressure Regulatory Assy, With Pressure Gauge" .  is ::--> [('pressure sensor', 62), ('rear axle assy', 58), ('rear damper', 51), ('oil pressure switch', 51), ('subframe assy', 49)]
# STRUCTURE ASSY;DASHBOARD for Side airvent ring .  is ::--> [('tube assy ', 70), ('structural foam', 69), ('subframe assy', 67), ('structural tape', 62), ('frame assy ', 58)]
# DOSING CONTROLLER UNIT .  is ::--> [('air processing unit', 59), ('control shaft', 57), ('oil cooler', 56), ('mounting nut ', 53), ('control panel', 51)]
# REAR CHASSIS 39WB .  is ::--> [('rear axle assy', 52), ('turbocharger ', 48), ('rear hub', 48), ('brake caliper', 47), ('brake chamber ', 47)]
# FRONT CHASSIS WH .  is ::--> [('front hub', 56), ('front wall', 54), ('front axle', 54), ('crown wheel', 52), ('front damper', 50)]
# ARRESTOR RING ASSY .  is ::--> [('wiring harness ', 62), ('steering sensor', 61), ('battery wiring harness', 60), ('door wiring harness', 59), ('main wiring harness', 59)]
# "ENGINE SHIELDING ASSY,RH" .  is ::--> [('engine wiring harness', 57), ('engine hood', 56), ('main wiring harness', 55), ('windshield ', 52), ('pigtail wiring harness', 51)]
# "REINFORCEMENT,RH" .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# GUIDE BRACKET ASSY .  is ::--> [('glass guide ', 62), ('tube assy ', 59), ('subframe assy', 58), ('frame assy ', 57), ('brake pipe', 57)]
# SUPPORT ASSY;LH .  is ::--> [('pipe assy ', 67), ('subframe assy', 64), ('tube assy ', 57), ('frame assy ', 55), ('spray suppression', 55)]
# FRT.  is ::--> [('front hub', 71), ('front wall', 67), ('front seat', 67), ('front axle', 67), ('front strut', 62)]
# PRESSURE REGULATOR ASSY .  is ::--> [('pressure sensor', 63), ('rear axle assy', 59), ('rear damper', 53), ('oil pressure switch', 52), ('subframe assy', 50)]
# SUPPORT ASSY;RADIATOR MTG;LH .  is ::--> [('pipe assy ', 67), ('subframe assy', 64), ('tube assy ', 57), ('frame assy ', 55), ('spray suppression', 55)]
# REINFORCEMENT;LH .
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#   is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# OUTER PIECE;RH .  is ::--> [('egr pipe', 63), ('outrigger ', 60), ('rubber spacer', 58), ('intake pipe', 55), ('side valance cover', 55)]
# SUPPORT ASSY;RADIATOR MTG;LH .  is ::--> [('pipe assy ', 67), ('subframe assy', 64), ('tube assy ', 57), ('frame assy ', 55), ('spray suppression', 55)]
# STAY ROD ASSY .  is ::--> [('frame assy ', 61), ('tube assy ', 55), ('subframe assy', 54), ('rear axle assy', 52), ('glass run mould ', 50)]
# STAY ROD ASSY .  is ::--> [('frame assy ', 61), ('tube assy ', 55), ('subframe assy', 54), ('rear axle assy', 52), ('glass run mould ', 50)]
# REINFORCEMENT;RH .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# GUARD BASE;FUEL TANK .  is ::--> [('hand brake', 60), ('glass guide ', 57), ('car beam', 56), ('gas balancer ', 55), ('urea hose', 53)]
# SILENCER ASSY WITH HOOKS .  is ::--> [('silencer', 76), ('rear axle assy', 67), ('pipe assy ', 64), ('stiffener', 55), ('tube assy ', 55)]
# REAR SPRING ASSY .  is ::--> [('leaf spring ', 67), ('spring band clamp ', 61), ('rear axle assy', 60), ('parking camera', 60), ('parabolic leaf spring', 59)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# Assy.  is ::--> [('glass ', 67), ('tube assy ', 62), ('pipe assy ', 62), ('frame assy ', 57), ('boss', 50)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# .  is ::--> [('mounting bolt', 0), ('u bolt', 0), ('bolt ', 0), ('mounting screw ', 0), ('flanged screw', 0)]
# WH CABIN .  is ::--> [('combi switch', 60), ('power cable', 53), ('power cable', 53), ('crank shaft', 53), ('crown wheel', 53)]
# WH CHASSIS .  is ::--> [('fascia switch', 52), ('plastic washer ', 50), ('wiring harness ', 50), ('wheel arch', 50), ('main wiring harness', 48)]
# ASSY GB HSG FRT+INTER+REAR DD .  is ::--> [('rear axle assy', 49), ('front seat', 44), ('front wiring harness', 43), ('front strut', 43), ('wheel arch liner', 43)]
# "REINFORCEMENT,LH" .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# RISER ASSY .  is ::--> [('pipe assy ', 74), ('frame assy ', 70), ('rear axle assy', 67), ('tube assy ', 63), ('subframe assy', 61)]
# REINFORCEMENT LH .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# "EGP, ATS Sensor & EGP protective shield kit" .  is ::--> [('egr pipe', 55), ('lp hose', 40), ('hp hose', 40), ('bearing ', 40), ('fog lamp', 36)]
# "EGP, ATS Sensor & EGP protective shield kit" .  is ::--> [('egr pipe', 55), ('lp hose', 40), ('hp hose', 40), ('bearing ', 40), ('fog lamp', 36)]
# Steering system .  is ::--> [('steering wheel', 69), ('air intake system', 62), ('steering arm', 59), ('spring washer ', 57), ('steering belt', 57)]
# Rear Mount Bracket .  is ::--> [('control brake', 65), ('brake & clutch pedal', 61), ('brake chamber ', 58), ('brake hose', 57), ('bracket ', 56)]
# REINFORCEMENT ASSY .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# Vacuum diaphragm... .  is ::--> [('vacuum pump', 67), ('vacuum hose', 59), ('airbag ecu', 54), ('vacuum booster', 53), ('rear damper', 44)]
# Accessories belt tensioner uni... .  is ::--> [('pressure sensor', 49), ('steering belt', 47), ('ac compressor', 47), ('compression spring', 46), ('suspension support', 46)]
# "BRACKET ASSY,LH" .  is ::--> [('bracket ', 74), ('frame assy ', 73), ('subframe assy', 72), ('tube assy ', 67), ('brake ', 59)]
# ONE PIECE) .  is ::--> [('nylon pipe', 63), ('intake pipe', 60), ('egr pipe', 59), ('nylon spacer', 57), ('dowel pin', 56)]
# STAY COMPLETE .  is ::--> [('spacer plate', 56), ('counter shaft', 54), ('compressor ', 52), ('check strap', 50), ('propeller shaft', 50)]
# LH ""E"" MARKED" .  is ::--> [('bed plate', 50), ('fuel tank', 50), ('brake & clutch pedal', 48), ('hand brake', 48), ('parking brake lever', 47)]
# BRACKET ASSY;CLUTCH & BRAKE PEDAL MTG .  is ::--> [('bracket ', 74), ('frame assy ', 73), ('subframe assy', 72), ('tube assy ', 67), ('brake ', 59)]
# DOG (5TH SHIFTER SHAFT) .  is ::--> [('logo', 57), ('door ', 57), ('dowel ', 50), ('door hinge', 46), ('shotgun', 40)]
# SUNVISOR ASSY WITH 2-POINT MTG;LH .  is ::--> [('subframe assy', 62), ('peps sensor', 58), ('pressure sensor', 57), ('pedal sensor', 56), ('tube assy ', 55)]
# PLUG BUTTON FOR 8 X 12 SLOT .  is ::--> [('hole plug ', 60), ('core plug ', 60), ('drain plug ', 57), ('cotton tape', 55), ('nut plate', 50)]
# ASSY.ADVANCE WARNING TRIANGLE .  is ::--> [('tail wiring harness', 62), ('pigtail wiring harness', 59), ('main wiring harness', 58), ('safety triangle', 55), ('cabin wiring harness', 53)]
# ASSY STRIKER IFB .  is ::--> [('frame assy ', 62), ('rear axle assy', 60), ('oil strainer', 57), ('tube assy ', 56), ('pipe assy ', 56)]
# FUEL SUCTION PIPE ASSY .  is ::--> [('suction hose', 71), ('fuel return hose', 63), ('fuel sensor', 55), ('fuel injector', 51), ('spray suppression', 51)]
# HOOK ASSY EXAUST LH .  is ::--> [('exhaust manifold', 51), ('exhaust valve ', 50), ('auto slack adjuster', 47), ('exhaust pipe', 45), ('tube assy ', 43)]
# Frame .  is ::--> [('frame assy ', 67), ('foam ', 67), ('brake ', 60), ('foam seal', 57), ('subframe assy', 56)]
# REINFORCEMENT LH .  is ::--> [('rib', 57), ('pin', 57), ('bearing ', 55), ('oil ring', 50), ('steering arm', 50)]
# EXHAUST PIPE ASSY WITH FLEX BELLOW .  is ::--> [('exhaust pipe', 73), ('pipe assy ', 60), ('exhaust valve ', 53), ('tube assy ', 53), ('metal pipe', 52)]
# Housing rear half cast iron .  is ::--> [('catalytic converter', 52), ('rear axle assy', 49), ('long runner ', 47), ('suspension tower', 47), ('differential housing', 47)]
# Oil Dip Stik Assy .  is ::--> [('dipstick ', 56), ('pipe assy ', 54), ('oil strainer', 48), ('first aid box', 47), ('pigtail wiring harness', 46)]
# 2088

# %%
for line in clean_doc:
    
    line1 = line.lower()
    #string = line1.partition(",")[0].partition(";")[0].partition("(")[0].partition("[")[0].partition('for')[0].partition('with')[0].partition('w/o')[0].partition('offer')[0].partition('\bw\b')[0]

    closest_match = process.extractOne(replacer(line1).lower(), fuzzydict, scorer=fuzz.token_sort_ratio)
    
    if(closest_match[1] >= 75):
        print(line, " is ::-->", closest_match)
        clean_doc.remove(line)
        
print(len(clean_doc))
# Out:
# REINFORCEMENT ASSY .  is ::--> ('reinforcement ', 84)
# REINFORCEMENT ASSY LH .  is ::--> ('reinforcement ', 76)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# C-REINFORCEMENT RH .  is ::--> ('reinforcement ', 84)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT ASSY LH .  is ::--> ('reinforcement ', 76)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REAR HALF .  is ::--> ('rear axle', 78)
# "CONSOLE ASSY,REAR" .  is ::--> ('rear axle assy', 77)
# "REINFORCEMENT ASSY,LH" .  is ::--> ('reinforcement ', 76)
# "REINFORCEMENT,LH" .  is ::--> ('reinforcement ', 90)
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# (MAIN DRIVE) .  is ::--> ('driver station ', 75)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# rainforcement bkt.  is ::--> ('reinforcement ', 76)
# rainforcement bkt.  is ::--> ('reinforcement ', 76)
# reinforcement bkt.  is ::--> ('reinforcement ', 76)
# rainforcement bkt.  is ::--> ('reinforcement ', 76)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Dash reinforcement .  is ::--> ('reinforcement ', 84)
# For plenum .  is ::--> ('plenum', 75)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT LH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# SUPPORT REINFORCEMENT .  is ::--> ('reinforcement ', 76)
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# C-REINFORCEMENT RH .  is ::--> ('reinforcement ', 84)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# L-REINFORCEMENT .  is ::--> ('reinforcement ', 93)
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# "HOLDER,PARKING SENSOR" .  is ::--> ('parking sensor', 80)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# "REINFORCEMENT ASSY,RH" .  is ::--> ('reinforcement ', 76)
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# L-REINFORCEMENT .  is ::--> ('reinforcement ', 93)
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# L-REINFORCEMENT .  is ::--> ('reinforcement ', 93)
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# Detainer plug .  is ::--> ('drain plug ', 78)
# Rear Reinforcement .  is ::--> ('reinforcement ', 84)
# "CUP,SHOCK ABSORBER" .  is ::--> ('shock absorber ', 88)
# "CUP,SHOCK ABSORBER" .  is ::--> ('shock absorber ', 88)
# "CUP, TAILGATE" .  is ::--> ('tailgate', 80)
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# "REINFORCEMENT,HOOD,RH" .  is ::--> ('reinforcement ', 76)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# "REINFORCEMENT, RH" .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT ASSY .  is ::--> ('reinforcement ', 84)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Assy Frame .  is ::--> ('frame assy ', 100)
# Assy Frame .  is ::--> ('frame assy ', 100)
# Reinforcement .  is ::--> ('reinforcement ', 100)
# Reinforcement .  is ::--> ('reinforcement ', 100)
# Reinforcement .  is ::--> ('reinforcement ', 100)
# Reinforcement .  is ::--> ('reinforcement ', 100)
# Reinforcement LH .  is ::--> ('reinforcement ', 90)
# Reinforcement LH .  is ::--> ('reinforcement ', 90)
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# SHIFTER FORK .  is ::--> ('gear shifter ', 75)
# SHIFTER FORK .  is ::--> ('gear shifter ', 75)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# Rear Half .  is ::--> ('rear axle', 78)
# REINFORCEMENT PLATE .  is ::--> ('reinforcement ', 81)
# TIRE .  is ::--> ('tyre ', 75)
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# "REINFORCEMENT,LH" .  is ::--> ('reinforcement ', 90)
# "REINFORCEMENT,LH" .  is ::--> ('reinforcement ', 90)
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT TOP-RH .  is ::--> ('reinforcement ', 79)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# "Holder, Parking Sensor" .  is ::--> ('parking sensor', 80)
# "Holder, Parking Sensor" .  is ::--> ('parking sensor', 80)
# L-REINFORCEMENT RH .  is ::--> ('reinforcement ', 84)
# REINFORCEMENT ASSY RH .  is ::--> ('reinforcement ', 76)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# "HOLDER,PARKING SENSOR" .  is ::--> ('parking sensor', 80)
# "REINFORCEMENT,MIDDLE" .  is ::--> ('reinforcement ', 79)
# "L-REINFORCEMENT,TOP-" .  is ::--> ('reinforcement ', 81)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# "REINFORCEMENT,LH" .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# L-REINFORCEMENT .  is ::--> ('reinforcement ', 93)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT LH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# "REINFORCEMENT,FRONT" .  is ::--> ('reinforcement ', 81)
# "REINFORCEMENT,LH" .  is ::--> ('reinforcement ', 90)
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# "GUARD,PROPELLER SHAFT" .  is ::--> ('propeller shaft guard', 100)
# REINFORCEMENT LH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# L-REINFORCEMENT .  is ::--> ('reinforcement ', 93)
# C-REINFORCEMENT LH .  is ::--> ('reinforcement ', 84)
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# Reinforcement RH/LH .  is ::--> ('reinforcement ', 81)
# Reinforcement RH/LH .  is ::--> ('reinforcement ', 81)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# Reinforcement LH .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# C - Reinforcement RH .  is ::--> ('reinforcement ', 84)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# ASSY TOP RAIL REAR .  is ::--> ('rear axle assy', 75)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '. "']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT LH .  is ::--> ('reinforcement ', 90)
# "REINFORCEMENT,LH" .  is ::--> ('reinforcement ', 90)
# "L-REINFORCEMENT,BOTT" .  is ::--> ('reinforcement ', 79)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# C-REINFORCEMENT RH .  is ::--> ('reinforcement ', 84)
# C-REINFORCEMENT .  is ::--> ('reinforcement ', 93)
# REINFORCEMENTLH .  is ::--> ('reinforcement ', 93)
# REINFORCEMENTRH .  is ::--> ('reinforcement ', 93)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT ASSY .  is ::--> ('reinforcement ', 84)
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# REINFORCEMENTLH .  is ::--> ('reinforcement ', 93)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT TOP-RH .  is ::--> ('reinforcement ', 79)
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# C-REINFORCEMENT .  is ::--> ('reinforcement ', 93)
# REINFORCEMENTRH .  is ::--> ('reinforcement ', 93)
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# SHIFTER FINGER .  is ::--> ('gear shifter ', 85)
# "REINFORCEMENT, TOP-LH" .
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#   is ::--> ('reinforcement ', 79)
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# "REINFORCEMENT,CROSS" .  is ::--> ('reinforcement ', 81)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# Reinforcement RH .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# "REINFORCEMENT ASSY,RH" .  is ::--> ('reinforcement ', 76)
# REINFORCEMENT(RH) .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT(LH) .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT CENTER .  is ::--> ('reinforcement ', 79)
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# REINFORCEMENT(RH) .  is ::--> ('reinforcement ', 90)
# "REINFORCEMENT,LH" .  is ::--> ('reinforcement ', 90)
# condensor .  is ::--> ('condenser', 89)
# HOSE PIPE .  is ::--> ('lp hose', 75)
# STRUCTURAL PAD .  is ::--> ('structural foam', 83)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT FRONT .  is ::--> ('reinforcement ', 81)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT ASSY LH .  is ::--> ('reinforcement ', 76)
# REINFORCEMENT LH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT LH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT - LH .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# "HEADBOX ASSY,REAR" .  is ::--> ('rear axle assy', 77)
# "REINFORCEMENT ASSY,LH" .  is ::--> ('reinforcement ', 76)
# "REINFORCEMENT, LH" .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT PLATE .  is ::--> ('reinforcement ', 81)
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# Reinforcement .  is ::--> ('reinforcement ', 100)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REAR HALF .  is ::--> ('rear axle', 78)
# "REINFORCEMENT,LH" .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# C-REINFORCEMENT LH .  is ::--> ('reinforcement ', 84)
# C-REINFORCEMENT RH .  is ::--> ('reinforcement ', 84)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# SUPPORT REINFORCEMENT .  is ::--> ('reinforcement ', 76)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# REINFORCEMENT ASSY .  is ::--> ('reinforcement ', 84)
# REINFORCEMENT (REAR)-LH .  is ::--> ('reinforcement ', 76)
# ASSY.REINFORCEMENT .  is ::--> ('reinforcement ', 84)
# REINFORCEMENT TOP-RH .  is ::--> ('reinforcement ', 79)
# REINFORCEMENT( L.H.)  is ::--> ('reinforcement ', 87)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT LH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT LH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT LH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT LH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT LH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT LH .  is ::--> ('reinforcement ', 90)
# "BUNCH ASSY,PIPE" .
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#   is ::--> ('pipe assy ', 75)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT LH .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT BRACKET .  is ::--> ('reinforcement ', 76)
# REINFORCEMENT(LH) .
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#   is ::--> ('reinforcement ', 90)
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# REINFORCEMENT(LH) .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# FOR ENGINE W/H .  is ::--> ('engine wiring harness', 91)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT LH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# AFTER TREATMENT SYSTEM ASSY .  is ::--> ('after treatment assy', 85)
# UREA PIPE ASSY .  is ::--> ('pipe assy ', 78)
# OFFER DRG CLUTCH SLAVE CYLINDER .  is ::--> ('clutch slave cylinder', 81)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# Reinforcement RH .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# "WH,ENGINE" .  is ::--> ('engine hood', 80)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WH FRONT .  is ::--> ('front hub', 82)
# AFTER TREATMENT SYSTEM ASSY .  is ::--> ('after treatment assy', 85)
# L-REINFORCEMENT .  is ::--> ('reinforcement ', 93)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Flywheel .  is ::--> ('flywheel ', 100)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Antenna wirring harness (II) .  is ::--> ('engine wiring harness', 77)
# "BUNCH ASSY,PIPE" .  is ::--> ('pipe assy ', 75)
# WHEEL RIM ASSY .  is ::--> ('wheel rim ', 78)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# "REINFORCEMENT,LH" .  is ::--> ('reinforcement ', 90)
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# Vacuum booster .  is ::--> ('vacuum booster', 100)
# "REINFORCEMENT,LH" .  is ::--> ('reinforcement ', 90)
# "REINFORCEMENT,TOP-RH" .  is ::--> ('reinforcement ', 79)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT ASSY .  is ::--> ('reinforcement ', 84)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT ASSY LH .  is ::--> ('reinforcement ', 76)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Reinforcement RH .  is ::--> ('reinforcement ', 90)
# Reinforcement RH .  is ::--> ('reinforcement ', 90)
# Reinforcement RH .  is ::--> ('reinforcement ', 90)
# Reinforcement RH .  is ::--> ('reinforcement ', 90)
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# Reinforcement RH .  is ::--> ('reinforcement ', 90)
# Reinforcement Assy RH .  is ::--> ('reinforcement ', 76)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT ASSY .  is ::--> ('reinforcement ', 84)
# O-RING .  is ::--> ('oil ring', 86)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WIRING HARNESS MAXI FUSE .  is ::--> ('main wiring harness', 84)
# PIPE .  is ::--> ('pipe ', 100)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# AFTER TREATMENT SYSTEM ASSY .  is ::--> ('after treatment assy', 85)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# Reinforcement .  is ::--> ('reinforcement ', 100)
# "Wh,ENGINE" .  is ::--> ('engine hood', 80)
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# Reinforcement RH .  is ::--> ('reinforcement ', 90)
# ECU .  is ::--> ('ecu ', 100)
# REINFORCEMENT;RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT .  is ::--> ('reinforcement ', 100)
# EXHAUST MANIFOLD .  is ::--> ('exhaust manifold', 89)
# FES ASSY .  is ::--> ('frame assy ', 78)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# "W/H, COCKPIT TIAGO MCE XE" .  is ::--> ('cockpit wiring harness', 77)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# "REINFORCEMENT,REAR-LH" .  is ::--> ('reinforcement ', 76)
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# RETURN LINE ASSY .  is ::--> ('return hose', 81)
# "PIGTAIL,COMBI SWITCH" .  is ::--> ('combi switch', 75)
# BRACKET .  is ::--> ('bracket ', 100)
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# SHIFTER SHAFT .  is ::--> ('shifter shaft', 100)
# ENG.MTG.  is ::--> ('engine mount', 75)
# REINFORCEMENT;LH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT;RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT;RH .  is ::--> ('reinforcement ', 90)
# REINFORCEMENT;RH .
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '.']
#  is ::--> ('reinforcement ', 90)
# AIR TANK ASSY .  is ::--> ('air tank', 76)
# BRACKET .  is ::--> ('bracket ', 100)
# REINFORCEMENT;RH .  is ::--> ('reinforcement ', 90)
# AFTER TREATMENT SYSTEM ASSY .  is ::--> ('after treatment assy', 85)
# Frame Assy .  is ::--> ('frame assy ', 100)
# PIPE ASSY .  is ::--> ('pipe assy ', 100)
# "REINFORCEMENT,RH" .  is ::--> ('reinforcement ', 90)
# LONG MEMBER RH .  is ::--> ('long member ', 88)
# REINFORCEMENT LH .  is ::--> ('reinforcement ', 90)
# "LONG MEMBER,LH" .  is ::--> ('long member ', 88)
# REINFORCEMENT ASSY .  is ::--> ('reinforcement ', 84)
# "LONG MEMBER,LH" .  is ::--> ('long member ', 88)
# METAL PIPE ASSY .  is ::--> ('metal pipe', 80)
# REINFORCEMENT RH .  is ::--> ('reinforcement ', 90)
# Tube Assy .  is ::--> ('tube assy ', 100)
# 4177

# %%
clean_doc
# Out:
# ['PLUG (STUB AXLE-TOP) .',
#  'GRP TPL 87R INTRA1100/2250WB/BSVI .',
#  'RESILIENCE MTG .',
#  'STRAP .',
#  '"STRUCTURAL PAD,HOOD,FRONT" .',
#  'Assy.',
#  'Assy.',
#  'REAR SPRING ASSY .',
#  'ADJUSTER .',
#  'FRONT MTG ASSY RH .',
#  'FRONT MTG ASSY LH .',
#  'ASSY BRKT(IP INLINE & E-BOX CONN. MTG) .',
#  'DC TO DC CONVERTER .',
#  '"HOUSING,FRONT-HALF" .',
#  'EXHAUST SYSTEM ASSY .',
#  'ASSY.',
#  'REINFORCEMENT TOW HOOK MTG .',
#  'SUPPORT SHEET BODY MTG .',
#  'HEX.',
#  'FL.',
#  'PACKING .',
#  'STRAP ASSY .',
#  'FRONT SPRING ASSY .',
#  'ENGINE MTG ASSY REAR-LH .',
#  'ENGINE MTG ASSY REAR-RH .',
#  'H/FL SCR M6X20-TS17130-10.9-SS8451S2-YH .',
#  'FAN DRIVE ASSY 12 V .',
#  'ALUMINIUM FOIL .',
#  'HEX.',
#  'FL.',
#  'HEX.',
#  'FL.',
#  'HEX.',
#  'FL.',
#  'HEX.',
#  'FL.',
#  'ASSY FOR PARALLEL ROD MGT .',
#  'ASSY FOR PARALLEL ROD MGT .',
#  'EXTENSION PIECE ASSY EXTENSION FRONT-RH .',
#  'REINFORCEMENT FRONT-RH .',
#  'C-SUPPORT CHANNEL .',
#  'EXTENSION PIECE ASSY EXTENSION FRONT-LH .',
#  'REINFORCEMENT FRONT-LH .',
#  '.',
#  'RESERVOIR BOTTLE ASSY .',
#  'ASSY.',
#  'PACKING .',
#  'PACKING .',
#  'UREA SOLUTION 32.5% 57-13-6 -YARA ASIA .',
#  'HEX FL SCR M6X40 TS17130-8.8-SS8451S2-Y .',
#  'REINFORCEMENT ASSY FRONT SPRING RH .',
#  'REINFORCEMENT ASSY FRONT SPRING LH .',
#  'TIE ROD ASSY .',
#  'EGR cooler assembly .',
#  'Front antiroll bar .',
#  'Rear lower link LH .',
#  'Front LH wheel assembly .',
#  'Sun visor driver side .',
#  'Sun visor Co-driver side .',
#  'I .',
#  'PLUG (STUB AXLE-TOP) .',
#  'II .',
#  'CONTAINER ASSY .',
#  'Mudgaurd .',
#  'Jack .',
#  'Inner rear view mirror .',
#  'anti .',
#  '.',
#  'ASSY.',
#  '.',
#  'FOR HORN .',
#  'ENGINE COOLING SYSTEM ASSY .',
#  'Assy water inlet line (Water Pump to Air Compressor) .',
#  'HOOK .',
#  'HOOK .',
#  'OPERATORS MANUAL & SERVICE BOOK .',
#  'CAB MTG CLOSING ASSY LH .',
#  'OPERATORS SERVICE BOOK .',
#  '"ENGINE MTG ARM,RH" .',
#  '"ENGINE MTG ARM,LH" .',
#  'ASSY WIPER SYSTEM 24V NRW LHD .',
#  'CCB Assembly .',
#  'FRONT SPRING ASSY .',
#  'REINFORCEMENT ASSY FIREWALL CTR MTG BKT .',
#  'TORSION BAR .',
#  'EGR cooler assembly .',
#  'FUEL LINES ASSY-COMPLETE .',
#  'VAPOUR LINE ASSY .',
#  'OFFER DRG ASSY RECEPTACLE CAP .',
#  'DEAD PLUG (M/S SWAGELOK) .',
#  'UNION 1/4 NPT (M/S SWAGELOK) .',
#  'CNG cradle .',
#  'Pressure gauge .',
#  'REINFORCEMENT ASSY RH .',
#  'ENGINE MTG ARM FRONT-RH .',
#  '.',
#  '.',
#  '.',
#  'FLANGE (DRAIN PLUG) .',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'POLE WHEEL FRONT .',
#  'WELD STUD M6X16 .',
#  'CHILLER UNIT .',
#  '"REINFORCEMENT,EXHAUST BRACKET,FRONT" .',
#  '"HOUSING ASSY,FUEL FILLER" .',
#  '"FAN ,SHROUD & PWM ASM" .',
#  '"Tigor EV FATC , ( Hardware no.',
#  '5456 1625 2001)" .',
#  'ANTI VIBRATION SHEET ASSY UNDERBODY .',
#  'WITH VALVES .',
#  'FES Assembly in white .',
#  'FES Assembly in white .',
#  'FUEL LINES ASSY (ENGINE TO TANK) .',
#  'FUEL LINES ASSY (FWS TO ENGINE) .',
#  'PACKING .',
#  'WATER BOX ASSY .',
#  '.',
#  'DETENT ASSY (SHIFTER SHAFT) .',
#  'SHIFTING FINGER .',
#  'SHIFTING FINGER .',
#  'CAPTIVE DETENT (SHIFTER) INA .',
#  'DETENT ASSY (SHIFTER SHAFT) .',
#  '"HOOK ASSY WITH BRACKET,FRONT HALF" .',
#  'HOSE AUX WATER TANK TO BYPASS TUBE .',
#  'ENGINE COOLING SYSTEM ASSY .',
#  '"STRUCTURE ASSY,CABIN ROOF,MIDDLE" .',
#  '"HEADBOX ASSY,Front" .',
#  'QUARTER TURN KNOB FUSE BOX MTG(TDCV) .',
#  'COUPLING BODY .',
#  'ASSY.SUPPORT(BONNET SIDE) .',
#  '"SUPPORT,BUMPER MTG,LH" .',
#  '"SUPPORT,BUMPER MTG,RH" .',
#  'REINFORCEMENT E/RAIL RHD .',
#  'UTILITY BOX ASSY .',
#  'UTILITY BOX ASSY .',
#  'REINFORCEMENT PLATE ASSY .',
#  '"LINK,LOCK BARREL TO LATCH,LH" .',
#  '"LINK,LOCK BARREL TO LATCH,RH" .',
#  '"LINK,OUTER HANDLE TO LATCH FRONT DOOR,LH" .',
#  '"LINK,OUTER HANDLE TO LATCH FRONT DOOR,RH" .',
#  'HEAD BOX ASSY .',
#  '"HEAD BOX,LH" .',
#  '"HEAD BOX,RH" .',
#  '"PACKING,COWL MTG,REAR" .',
#  '"PACKING,COWL MTG,FRONT" .',
#  '"CONSOLE ASSY,BEZEL USB,FRONT" .',
#  'FUSE BOX LID WITH KNOB ASSY .',
#  '"CONSOLE,REAR" .',
#  '"CONSOLE,FRONT HOUSING" .',
#  '"CAP,CENTER CONSOLE,LOWER" .',
#  '"CAP,DOOR TRIM,RH" .',
#  'COOLING UNIT ASSY .',
#  '"BERTH STRUCTURE,PAPER HONEYCOMB ASSY" .',
#  '"BERTH ASSY,LOWER" .',
#  '"CUSHION ASSY,LOWER BERTH" .',
#  '"QUARTER TURN KNOB,FUSE BOX MTG" .',
#  '"REINFORCEMENT,SPRING HANGER BKT,LH" .',
#  '"REINFORCEMENT,SPRING HANGER BKT,RH" .',
#  'CONTROLLER .',
#  'RESTRICTION INDICATOR .',
#  'PEDESTAL ASSY WITH PIN & NUT .',
#  'EGR COOLER ASSY WITH EGR VALVE .',
#  'ASSY.',
#  'ASSY ROCKER ARM INTAKE(M/S TIMKEN) .',
#  'ASSY.',
#  'OMS ASSY .',
#  'IDLER ASSY-DIA 65 (MAIN DRIVE) .',
#  'TRIGGER WHEEL-MULTI TEETH(CAM SENSOR-DEL .',
#  'TALBROS) .',
#  'ASSY.ROCKER ARM EXHAUST-EVB .',
#  'CROSS SUPPORT .',
#  'LOAD GUARD ASSY .',
#  'HEATING & DEMISTING ASSY .',
#  'Cam shaft chain tensioner unit mounting bolt .',
#  'Timing chain guide locator .',
#  'EGR cooler coolant outlet hose clip .',
#  'Clutch release fork locking circlip .',
#  'Shifter fork shaft pin .',
#  'Detainer ball .',
#  'Detainer spring .',
#  'Front RH and LH leaf spring mounting plane washer .',
#  'Front brake hose holding bracket RH .',
#  'Auto adjusting spring LH .',
#  'Auto adjusting RH spring .',
#  'Steering arm mounting bolt washer .',
#  'Radiator air scoop top area mounting bolt .',
#  'Antiseptic cream .',
#  'Bandage .',
#  'Gauze swab sterile .',
#  'Elastic adhesive bandage .',
#  'Absorbent cotton gauze bandage .',
#  'First Aid kit chart .',
#  'Front (crash) cross member mounting bolt .',
#  'Front door lock and unlock knob housing .',
#  'Fuel - Diesel .',
#  'Engine oil filling cap .',
#  'Engine oil filling neck .',
#  'Blow by unit (crankcase ventilation / Oil separator) .',
#  'Timing chain .',
#  'Timing chain guide (Moveable) .',
#  'Timing chain guide (2) Fix .',
#  'First synchronizer cone .',
#  'Second synchronizer cone .',
#  'Pinion tail spacer .',
#  'Differential cage .',
#  'Front LH wheel assembly .',
#  'Front RH wheel assembly .',
#  'Rear LH wheel assembly .',
#  'Rear RH wheel assembly .',
#  'LCRV unit .',
#  'LCRV unit spring .',
#  'Tie rod .',
#  'Side repeater harness (LH and RH) .',
#  '12V supply port (I) .',
#  'Wheel spanner bag .',
#  'First aid kit bag .',
#  'Open spanner .',
#  'Tow hook .',
#  'Front (crash) cross member .',
#  'Centre fascia .',
#  'COMPRESSOR MOUNTING BRACKET (SANDEN VIKAS) .',
#  '200 DIA.',
#  'ASSY.',
#  '.',
#  'HOUSING FRONT-HALF .',
#  'WITH SCOOP MTG.',
#  'SUB ASSY SUBFRAME LH (SUBFRAME) .',
#  'LOWER LINK ASSY FRONT-RH .',
#  'ASSY.',
#  'PANHARD ROD WITH BUSH .',
#  'ASSY.REAR ANTIROLL BAR COMPLETE(OFFER DRAWING) .',
#  'OFFER DRAWING FRONT BRAKE DISC (21 THICK) .',
#  'RH .',
#  'OFFER DRAWING FRONT BRAKE DISC (21 THICK) .',
#  'LH .',
#  'AAM BANJO RA WITH 4.11 (37/9) RATIO FOR .',
#  '(POWER) .',
#  'ASSY.',
#  'ASSY CAT CONVERTER {YUTAKA} (5GM) .',
#  'ASSY.',
#  'WITH CAP .',
#  'ASSY.',
#  'KIT_REVERSE_GUIDING_SYSTEM_M/S_INTERFACE .',
#  'REVERSE GUIDING SYSTEM CONTROLLER-M/S.INTERFACE .',
#  'ANTENNA ASSY .',
#  'ANTENNA ASSY .',
#  'VENTURE GX CHASSIS HARNESS .',
#  'KIT CDL MINDA VALEO VENTURE BSIV DICOR .',
#  'DIS_MICROBUS_M/S_JP TOOLS(HIGHEREND) .',
#  'KIT IMMOBILIZER VENTURE .',
#  'ASSY.',
#  'SCISSORS JACK WITH 3 PIECE HANDLE .',
#  'ASSY.SCISSORS JACK WITH 3PC HANDLE-M/S SHIVANI LO .',
#  'ASSY.',
#  'SCISSORS JACK WITH 3 PIECE HANDLE .',
#  'ASSY.',
#  'ASSY DASHBOARD CROSS MEMBER .',
#  'ASSY ENGINE SHIELD - LHD .',
#  'ASSY BUTTERFLY WINDOW LH (ASAHI) .',
#  'ASSY BUTTERFLY WINDOW RH (ASAHI) .',
#  'ASSY MIDDLE CARRIAGE LH .',
#  'ASSY PLUG-IN WINDOW COMPLETE LH .',
#  'ASSY PLUG-IN WINDOW COMPLETE RH .',
#  'ASSY CENTER CLUSTER .',
#  'REAR_WIPER_SYSTEM_MICROBUS .',
#  'ASSY FRONT WIPER KIT -LUCAS .',
#  'REAR AC ASSY MICROBUS-CAD DATA .',
#  'Corner reinf LH .',
#  'Corner reinf RH .',
#  'Centre reinf .',
#  'Reinf subframe moiunting (between Long member outer and inner panel) .',
#  'Inner reinf .',
#  'Front upper CM reinforcement plate .',
#  'I .',
#  'II .',
#  'III .',
#  'IV .',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'Reinf .',
#  'Reinf (Between L3 and L15) .',
#  'Reinf (Between L2 and L3) .',
#  'reinf .',
#  '.',
#  'Shot gun .',
#  'Wheel house front reinf .',
#  'II .',
#  'II .',
#  'I .',
#  'II .',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'Tunnel bottom reinf .',
#  'Tunnel bottom reinf .',
#  'Tunnel bottom reinf .',
#  'On tunnel .',
#  'Tunnel reinforcement panel .',
#  '.',
#  'Big .',
#  'On tunnel .',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  '.',
#  'Tow hook reinf .',
#  'Tail gate sill outer .',
#  'Exhaust hanger reinf .',
#  'Sill outer reinf .',
#  'Reinf inner side on sill outer .',
#  'Tail gate sill inner .',
#  'Tail gate sill inner .',
#  'Striker reinf.',
#  '.',
#  'Tool kit mounting .',
#  'Striker reinf .',
#  'C plr striker reinf .',
#  '.',
#  'Wheel arc inner rear support .',
#  'Wheel arc inner rear support .',
#  'Cup reinf lower for strut .',
#  'Cup reinf upper for strut .',
#  'Bottom .',
#  'Sill inner hat section front .',
#  'Sill inner front .',
#  'Sill inner rear .',
#  'Sill reinf .',
#  'Sill reinf .',
#  'Sill reinf .',
#  'Sill reinf .',
#  'A plr inner upper .',
#  'A plr lower .',
#  '.',
#  'A plr bottom reinf (Earthing nut welded) .',
#  'Shot gun reinf .',
#  'Sill side outer front .',
#  'Sill side outer rear .',
#  'Reinf 1 sill outer .',
#  'Reinf 2 sill outer .',
#  'Reinf 3 sill outer .',
#  'Reinf 4 sill outer .',
#  'Reinf 5 sill outer .',
#  'Reinf between sill side front and rear .',
#  'Sill rear reinf.bottom .',
#  'B plr reinf betn BSO and B plr inner .',
#  'Additional reinf .',
#  '.',
#  '.',
#  'B plr lower inner reinf .',
#  'Additional reinf 1 .',
#  'Inner reinf upper .',
#  'Inner reinf lower .',
#  'CCB mtg locator .',
#  'A plr cant rail crash reinf .',
#  'Cant rail inner front .',
#  'Cant rail inner rear .',
#  'A plr upper reinf on cant rail .',
#  'Front header .',
#  'Rear header outer .',
#  'Rear header inner .',
#  '.',
#  'Side impact channel .',
#  'Reinf.',
#  '.',
#  'Reinf.',
#  'Reinf.',
#  '.',
#  '.',
#  'Reinf.',
#  'Reinf.',
#  'Striker reinf .',
#  '.',
#  '.',
#  '.',
#  'REINFORCEMENT ASSY TOW HOOK LH .',
#  'TOW HOOK FRONT .',
#  'CANOPY STRUCTURE ASSY .',
#  'CANOPY MTG ASSY FRONT-LH .',
#  'CANOPY MTG ASSY FRONT-RH .',
#  'TOW HOOK .',
#  'ELECTRIC BUZZER UNIT .',
#  'OWNERS MANUAL .',
#  'TOW HOOK .',
#  'A-mount assy (Front mount) .',
#  'REINFORCEMENT ASSY TOW HOOK LH .',
#  'REINFORCEMENT FRONT-BOTTOM-RH .',
#  'REINFORCEMENT FRONT-BOTTOM-LH .',
#  'UPPER SADDLE .',
#  'LOWER SADDLE .',
#  'UPPER SADDLE .',
#  'LOWER SADDLE .',
#  'FUEL SUPPLY MODULE .',
#  'NOx Univolt (Gen 4 PV Protocol) .',
#  'OIL MIST SEPARATOR ASSY .',
#  'Oilfillingcap .',
#  'End Cap .',
#  'FRONT HEADER ASSY .',
#  'REINFORCEMENT ASSY REAR WALL UPPER .',
#  'BODY SIDE ASSY OUTER-RH .',
#  'BODY SIDE ASSY OUTER-RH .',
#  'BODY SIDE ASSY OUTER-LH .',
#  'BODY SIDE ASSY INNER-RH .',
#  'BODY SIDE ASSY INNER-LH .',
#  'RHD .',
#  'TIE MEMBER ASSY .',
#  'WAIST REINFORCEMENT OUTER RH .',
#  'WAIST REINFORCEMENT OUTER LH .',
#  'REAR HEADER .',
#  'ASSY SHOT GUN RH .',
#  'ASSY SHOT GUN LH .',
#  'Diffuser .',
#  'Diffuser .',
#  'Diffuser .',
#  'DIFFUSER .',
#  '"TIE MEMBER ASSY,UPPER" .',
#  'Signa Close Proximity mirror .',
#  'Ace Gold - Front Turn Indicator LH .',
#  'Ace Gold - Front Turn Indicator RH .',
#  'Ace Gold Diesel BSVI .',
#  'Ace Gold Petrol BSVI .',
#  'REINFORCEMENT BOTTOM RH .',
#  'REINFORCEMENT BOTTOM LH .',
#  '"REINFORCEMENT,BUMPER CROSS MEMBER,RH" .',
#  '"REINFORCEMENT,BUMPER CROSS MEMBER,LH" .',
#  'PLUG BUTTON FOR REINF CAB MTG FRONT SLOT 8X12 .',
#  'SUPPORT INNER-RH .',
#  'SUPPORT INNER-LH .',
#  'SUPPORT OUTER-RH .',
#  'SUPPORT OUTER-LH .',
#  'SUPPORT INNER .',
#  'CAP (FOR BATTERY CABLE CLAMP -VE) .',
#  'USB CHARGER 24V DUAL PORT ASSY .',
#  'DC TO DC CONVERTER (1.5A) .',
#  'O-RING 12.37X2.62 TS16220 .',
#  'OWNERS MANUAL .',
#  'RELAY ROD ASSY .',
#  'NOZZLE ASSY .',
#  'RESERVIOR(1.5LITS.)',
#  'M/S.PRABHA.',
#  '.',
#  'TIE MEMBER LH .',
#  'HEXSCR M18X1.5X40 TS17100-10.9SS8451-8CH .',
#  '15- TS17716 .',
#  'OWNERS MANUAL .',
#  'OIL MIST SEPARATOR ASSY .',
#  'ASSY.STRAP .',
#  'OWNERS MANUAL .',
#  'OWNERS MANUAL .',
#  'ENGINE SHIELDING ASSY RH .',
#  'PARCEL RACK ASSY .',
#  'CONDESNER ASSY .',
#  '"TRANSITION PIECE ASSY,UCL" .',
#  'ASSY.ARM BLADE & NOZZLE FITMENT DRIVER SIDE M/S.',
#  '.',
#  'ASSY.',
#  'ARM BLADE & NOZZLE FITMENT CO-DR M/S.',
#  'BCS .',
#  'RUBEER BOOT (WHEEL BOX) .',
#  'Front View Mirror Assly .',
#  'TOW HOOK .',
#  '"STRAP ASSY & RUBBER,FUEL TANK MTG" .',
#  'ENGINE A-MTG ARM .',
#  'AIR DEFLCTOR ASSY .',
#  'Fuel Supply Module .',
#  'CONNECTING LINK ASSY REAR .',
#  'TELEMATICS UNIT .',
#  'CANOPY ASSY .',
#  '.',
#  'WH EMS_X445_DOM_PET_AMT .',
#  'WH FRONT_X445_DOM_PET_AMT_URBAN_MONK_STD .',
#  'WH FRONT_X445_DOM_PET_AMT_ MILITARY_STD .',
#  'WH FRONT_X445_DOM_PET_AMT_ TECHY_STD / URBBAN_MONK .',
#  'FT HARNESS DCT XM .',
#  'FT HARNESS DCT XZ .',
#  'WH EMS X451 DOM BSVI PETROL XM DCT .',
#  'WH EMS X451 DOM BSVI PETROL XZ DCT .',
#  'REAR QUARTER ASSY INNER-LH .',
#  'REAR QUARTER ASSY INNER-RH .',
#  '"BODY SIDE ASSY,INNER-FRONT-LH" .',
#  '"BODY SIDE ASSY,INNER-FRONT-RH" .',
#  '"REINFORCEMENT ASSY,CANTRAIL,LH" .',
#  '"REINFORCEMENT ASSY,CANTRAIL,RH" .',
#  '"REINFORCEMENT ASSY,B-PILLAR,INNER-LH" .',
#  '"REINFORCEMENT ASSY,B-PILLAR,INNER-RH" .',
#  'ASSY TIE MEMBER COMPLETE .',
#  '"REINFORCEMENT,TUNNEL,REAR" .',
#  'Central Detent .',
#  '"SUPPORT ASSY,RADIATOR MTG,RH" .',
#  '"SUPPORT ASSY,RADIATOR MTG,LH" .',
#  'Coolant Line Assy .',
#  'Coolant Line Assy .',
#  'Assy water inlet line (Water Pump to Air Compressor) .',
#  'ASSY CROSS MBR .',
#  'ASSY.',
#  'EXTENSION PIECE ASSY EXTENSION FRONT-RH .',
#  'REINFORCEMENT FRONT-RH .',
#  'C-SUPPORT CHANNEL .',
#  'EXTENSION PIECE ASSY EXTENSION FRONT-LH .',
#  'REINFORCEMENT FRONT-LH .',
#  'OUTRIGGER ASSY FUEL TANK .',
#  'ASSY FOR PARALLEL ROD MGT .',
#  'ASSY FOR PARALLEL ROD MGT .',
#  'ASSY VERTICAL SUPPORT BRKT-1 .',
#  'ASSY VERTICAL SUPPORT BRKT-2 .',
#  'ENGINE MTG ASSY REAR-LH .',
#  'ENGINE MTG ASSY REAR-RH .',
#  'ASSY.',
#  'ENG.',
#  'C/M FRONT .',
#  'L-REINFORCEMENT TOP-RH .',
#  'L-REINFORCEMENT TOP-LH .',
#  'ENGINE COOLING SYSTEM ASSY .',
#  'DC TO DC CONVERTER .',
#  'SUPPORT ASSY FRONT-RH .',
#  'SUPPORT ASSY FRONT-LH .',
#  'L-REINFORCEMENT TOP-RH .',
#  'L-REINFORCEMENT TOP-LH .',
#  'L-REINFORCEMENT BOTTOM-RH .',
#  'L-REINFORCEMENT BOTTOM-LH .',
#  'LINK ASSY .',
#  'RELAY ARM .',
#  'PACKING .',
#  'FRONT SPRING ASSY .',
#  'FRONT SPRING ASSY .',
#  'REINFORCEMENT FRONT-BOTTOM-RH .',
#  'REINFORCEMENT FRONT-BOTTOM-LH .',
#  '.',
#  'VEHICLE ELECTRONIC CONTROLLER UNIT .',
#  'Telematics .',
#  '"CAB MTG ASSY,REAR" .',
#  'RESONATOR BOX ASSY .',
#  'ANGLE ASSY .',
#  'DC TO DC CONVERTER .',
#  'TOW HOOK .',
#  'CLOSE COUPLED CATCON ASSY .',
#  '.',
#  '"PIGTAIL,ENGINE LAMP" .',
#  'FRONT SPRING ASSY .',
#  'FRONT SPRING ASSY .',
#  'FRONT SPRING ASSY .',
#  'CLOSE PROXIMITY MIRROR ASSY .',
#  'ASSY.',
#  '.',
#  'UNIVERSAL JOINT ASSY .',
#  '"PUSH ROD ASSY,SLAVE CYLINDER" .',
#  'SPEAKER 5.25 WITH RAIN COVER (BLAUPUNKT .',
#  'SPEAKER 5.25 WITH RAIN COVER (BLAUPUNKT .',
#  'COOLANT LINE ASSY .',
#  'COOLANT LINE ASSY .',
#  'Vapour line .',
#  'HEX.',
#  'FL.',
#  'ABS WITH AEBS SUPPORT .',
#  '.',
#  'L-REINFORCEMENT TOP-RH .',
#  'L-REINFORCEMENT TOP-LH .',
#  'HEX.',
#  'FL.',
#  'HEX.',
#  'FL.',
#  'HEX.',
#  'FL.',
#  'HEX.',
#  'FL.',
#  'HEX.',
#  'FL.',
#  'ELECTRONICS STABILITY CONTROL MODULE .',
#  'RETARDER ASSY .',
#  'STRAP ASSY .',
#  '.',
#  '.',
#  '.',
#  'SUPPORT .',
#  '"REINFORCEMENT,BUMPER CROSS MEMBER,RH" .',
#  '"REINFORCEMENT,BUMPER CROSS MEMBER,LH" .',
#  'OWNERS MANUAL .',
#  'OWNERS MANUAL .',
#  'OWNERS MANUAL .',
#  'OWNERS MANUAL .',
#  'OWNERS MANUAL .',
#  'OWNERS MANUAL .',
#  'OWNERS MANUAL .',
#  'OWNERS MANUAL .',
#  'OWNERS MANUAL .',
#  'OWNERS MANUAL .',
#  'OWNERS MANUAL .',
#  'OWNERS MANUAL .',
#  'ENGINE COOLING SYSTEM .',
#  'SET-COOLING SYSTEM .',
#  'OWNERS MANUAL .',
#  'SUPPORT ASSY WITH SPACER .',
#  'SUPPORT ASSY WITH SPACER .',
#  'STAY ROD ASSY .',
#  'STAY ROD ASSY .',
#  'SUPPORT .',
#  'SUPPORT .',
#  'C-CHANNEL SUPPORT .',
#  'COOLING SYSTEM ASSY .',
#  '"ARMATURE,DASHBOARD DRIVER SIDE" .',
#  'Cooling System .',
#  'Cooling System- Tata Toyo .',
#  'Ladder frame .',
#  'Engine oil filling cap .',
#  'Engine oil filling neck .',
#  'Blow by unit (crankcase ventilation / Oil separator) .',
#  'Timing chain .',
#  'Timing chain moveable guide (Fuel pump chain) .',
#  'Timing chain fix guide .',
#  'Glow plug .',
#  'Third and forth gear engaging gear (on output shaft) .',
#  'Third and forth gear engaging gear shifter sleeve (on output shaft) .',
#  'Front sub frame .',
#  'Differential cage .',
#  '12V supply port (I) .',
#  'Jack .',
#  'Front (crash) bracket .',
#  'Centre console .',
#  'Inner rear view mirror .',
#  'Air extraction vent (on firewall) .',
#  'Fresh air inlet vent (Behind headlamp dome) RH .',
#  'Fresh air inlet vent (Behind headlamp dome) LH .',
#  'Water jacket piece (on block) .',
#  'EGR pipe from cylinder head (internally from exhaust) to EGR body mounting bolt .',
#  'Gear box assembly mounting stud .',
#  'Oil gallery .',
#  'Detainer ball .',
#  'Detainer spring .',
#  'Detainer spring .',
#  'Accelerator pedal mounting bracket mounting nut .',
#  'Wheel mounting stud LH & RH .',
#  'Wheel cap .',
#  'LCRV unit spring guider .',
#  'Radiator upper mounting bush .',
#  'Front (crash) bracket mounting bolt .',
#  'Centre console (Front side) mounting screw .',
#  'Wiper motor harness pigtail connector clip mounting screw .',
#  'Coolant .',
#  'Fuel - Diesel .',
#  'HP line .',
#  'Reinforcement Rear Wall .',
#  'ROF BOW EXTENSION FRONT-LH .',
#  'ROF BOW EXTENSION FRONT-RH .',
#  'END CAP CENTER BOW *2 .',
#  'END CAP CENTRE BOW RH .',
#  'REINFORCEMENT TG HINGE MTG LH .',
#  'REINFORCEMENT TG HINGE MTG RH .',
#  'ROF BOW EXTENSION FRONT-LH .',
#  'ROF BOW EXTENSION FRONT-RH .',
#  'END CAP CENTER BOW 2 .',
#  'END CAP CENTRE BOW RH .',
#  'ROF BOW EXTENSION FRONT-LH .',
#  'ROF BOW EXTENSION FRONT-RH .',
#  'END CAP CENTER BOW 2 .',
#  'END CAP REAR LH .',
#  'END CAP REAR RH .',
#  'REINFORCEMENT TG HINGE MTG LH .',
#  'REINFORCEMENT TG HINGE MTG RH .',
#  'ROF BOW EXTENSION FRONT-LH .',
#  'END CAP CENTER BOW *2 .',
#  'END CAP REAR LH .',
#  'REINFORCEMENT TG HINGE MTG LH .',
#  'Front reinforcement .',
#  'SUPPORT REINF B PLR UPPER LH .',
#  'REINF.',
#  'REINF.',
#  'MEMBER RAD SUPPORT LH .',
#  'MEMBER RAD SUPPORT BOTTOM LH .',
#  'MEMBER RAD SUPPORT RH .',
#  'MEMBER RAD SUPPORT BOTTOM RH .',
#  'EXTN RAD SUPP MTG BOTTOM LH .',
#  'EXTN RAD SUPP MTG BOTTOM RH .',
#  'MEMBER RAD SUPPORT LH .',
#  'MEMBER RAD SUPPORT RH .',
#  'REINF RAD SUPPORT BOTTOM .',
#  'MEMBER RAD SUPPORT LH .',
#  'MEMBER RAD SUPPORT BOTTOM LH .',
#  'MEMBER RAD SUPPORT RH .',
#  'MEMBER RAD SUPPORT BOTTOM RH .',
#  'EXTN RAD SUPP MTG BOTTOM LH .',
#  'EXTN RAD SUPPORT UPPER LH .',
#  'EXTN RAD SUPP MTG BOTTOM RH .',
#  'EXTN RAD SUPPORT UPPER RH .',
#  'SUPPORT VERTICAL FRONT .',
#  'MEMBER RAD SUPPORT LH .',
#  'MEMBER RAD SUPPORT RH .',
#  'MEMBER RAD SUPPORT BOTTOM LH .',
#  'MEMBER RAD SUPPORT BOTTOM RH .',
#  'RAD SUPPORT UPPER INNER LH .',
#  'RAD SUPPORT UPPER INNER RH .',
#  'RAD SUPPORT LOWER INNER LH .',
#  'RAD SUPPORT LOWER INNER RH .',
#  'X MEM FIXING REINF LH+RH .',
#  'X MEM SUPPORT LOWER LH+RH .',
#  'REINF.REAR QUARTER OUTER LH .',
#  'ASSY REINF REAR ELR MTG .',
#  'REINF.REAR QUARTER OUTER LH .',
#  'REINF REAR QUARTER UPPER .',
#  'ASSY REINF REAR ELR MTG .',
#  'REINF.REAR QUARTER OUTER LH .',
#  'REINF REAR QUARTER UPPER .',
#  '"REINFORCEMENT,GAS BALANCER MTG BKT,LH" .',
#  'REINF.REAR QUARTER OUTER LH .',
#  'ASSY REINF REAR ELR MTG .',
#  'PURGE LINE .',
#  '"CUP,SHOCK ABSORBER" .',
#  'Reinforcement Jacking Point .',
#  'Sill Inner Closing Part .',
#  'Sill Outer Closing Part .',
#  'Striker mounting nut plate .',
#  'CHECK REINF RR DR LH .',
#  'SASH TOP RR DR LH .',
#  'SASH FORWARD REAR DOOR LH .',
#  'PNL FRAME REINFORCEMENT RR DR LH .',
#  'PNL REINFORCER LATCH RR DR LH .',
#  'CHANNEL SEC SEAL FRT SIDE RR DOOR LH .',
#  'PNL REINFORCER LATCH RR DR LH .',
#  '"ASSY, NUT LATE T G SWITCH" .',
#  'TAIL GATE HINGE MTG .',
#  'REINF WHEELARCH FRONT LH .',
#  'REINF WHEELARCH FRONT LH .',
#  'REINF WHEELARCH FRONT LH .',
#  '"REINFORCEMENT,HOOD HINGE,LH" .',
#  '"REINFORCEMENT,HOOD HINGE,RH" .',
#  '"REINFORCEMENT,HOOD STRIKER MTG" .',
#  '"REINFORCEMENT,HOOD,FRONT" .',
#  '"REINFORCEMENT,HOOD HINGE,LH" .',
#  '"REINFORCEMENT,HOOD HINGE,RH" .',
#  '"REINFORCEMENT,HOOD STRIKER MTG" .',
#  '"REINFORCEMENT,HOOD,FRONT" .',
#  '"REINFORCEMENT,HOOD HINGE,LH" .',
#  '"REINFORCEMENT,HOOD HINGE,RH" .',
#  '"REINFORCEMENT,HOOD STRIKER MTG" .',
#  '"REINFORCEMENT,HOOD,FRONT" .',
#  '"REINFORCEMENT,HOOD HINGE,LH" .',
#  '"REINFORCEMENT,HOOD HINGE,RH" .',
#  '"REINFORCEMENT,HOOD STRIKER MTG" .',
#  '"REINFORCEMENT,HOOD,FRONT" .',
#  'EXT.',
#  'BODY SIDE OUTER REAR LH .',
#  'EXT.',
#  'BODY SIDE OUTER REAR LH .',
#  'SASH REAR FRONT DR LH .',
#  'SASH FORWARD FRT DOOR LH .',
#  'CHECK REINF FRT DR LH .',
#  '"REINFORCEMENT,FRONT DOOR PANEL FRAME,LH" .',
#  'TOP GLASS GUIDE CHANNEL WELDED FRT DR LH .',
#  'UPPER EINFORCEMENT BEAM .',
#  'REINF ENGINE MTG LH .',
#  'REINF DIAPHRAGM ENGINE MTG LH .',
#  'REINF DIAPHRAGM FRONT CRASH INNER FRONT .',
#  'REINF FRONT CRASH MBR LH .',
#  'REINF ENGINE MTG LH .',
#  'REINF DIAPHRAGM FRONT CRASH INNER FRONT .',
#  '"REINFORCEMENT BRACKET,FRONT-LH" .',
#  'REINF ENGINE MTG LH .',
#  'REINF DIAPHRAGM ENGINE MTG LH .',
#  'REINF DIAPHRAGM FRONT CRASH INNER FRONT .',
#  '"REINFORCEMENT BRACKET,FRONT-LH" .',
#  '"SUPPORT,SUBFRAME MTG BUSH,FRONT-LH" .',
#  '"REINFORCEMENT,SUBFRAME MTG BRACKET,LH" .',
#  '"REINFORCEMENT,WHEEL ARCH FRONT,INNER-LH" .',
#  'REINF ENGINE MTG LH .',
#  'REINF DIAPHRAGM ENGINE MTG LH .',
#  'REINF DIAPHRAGM FRONT CRASH INNER FRONT .',
#  'REINFORCEMENT FUEL FILLER LID .',
#  'REINFORCEMENT FUEL FILLER LID .',
#  'FUEL LID STOPER .',
#  'REINFORCEMENT FUEL FILLER LID .',
#  'WATER CHANNEL RHD .',
#  'WATER CHANNEL RHD .',
#  'REINF WATER CHANNEL LH/RH .',
#  'WATER CHANNEL RHD .',
#  'SCREEN RAIL LWR END CAP LH/RH .',
#  'REINF WIPER MTG CTR .',
#  'WATER CHANNEL RHD .',
#  '"MEMBRANE,FRONT DOOR,LH" .',
#  '"MEMBRANE,FRONT DOOR,RH" .',
#  '"CAP,DOOR HANDLE,RH" .',
#  '"CAP,DOOR HANDLE,RH" .',
#  'MAGAZINE POCKET ASSY .',
#  'MAGAZINE POCKET ASSY .',
#  'EGR COOLER ASSY (M/S BORG WARNER) .',
#  'O-RING EGR COOLER ASSY .',
#  'OWNERS MANUAL .',
#  'PRESSURE RING .',
#  'DIFFERENTIAL CASE .',
#  '"INNER HANDEL ASSY,FRONT DOOR,LH" .',
#  'OWNERS MANUAL .',
#  'VEHICLE ELECTRONIC CONTROLLER UNIT (550654701604) 12V .',
#  'HEADBOX ASSY .',
#  'ESC TELLTALE INDICATOR .',
#  'ENGINE MTG ASSY FRONT-LH .',
#  'DIFFUSER .',
#  'ASSY.STRAP WITH RUBBER(CYL.MTG) .',
#  'SPEAKER 5.25 WITH RAIN COVER (BLAUPUNKT) RH .',
#  'SPEAKER 5.25 WITH RAIN COVER (BLAUPUNKT) LH .',
#  'OWNERS MANUAL .',
#  'IGNITION COIL .',
#  'COUPLING BODY (M36X2 M26X1.5) .',
#  'Stay Rod Assy .',
#  'MUSIC SYSTEM Group ID G350662 .',
#  'AIR PRESSURE TRANSDUCER .',
#  'CANOPY STRUCTURE ASSY .',
#  'CANOPY MTG STRUCTURE ASSY .',
#  '.',
#  '.',
#  '.',
#  '15- TS17716 .',
#  'SPR.',
#  'Main WH .',
#  'ASSY.',
#  '.',
#  'ASSY.',
#  'HAT SECTION .',
#  'REINFORCEMENT DASHBOARD FRONT .',
#  '.',
#  'Assy.',
#  'Fog lamp bracket RH .',
#  'BRACKET ASSY FENDER MTG LH .',
#  'BODY ASSY .',
#  'TRUST BAR .',
#  'REINFORCEMENT BAR PANEL CENTER-FRONT .',
#  'LEAF FLAP .',
#  'TRUST BAR ASSY .',
#  'SUPPORT .',
#  'SUPPORT .',
#  'NRW .',
#  'ASSY REINF FRONT MTG LH (LONG MEMBER) .',
#  'REINFORCEMENT ASSY LONG MEMBER FRONT-RH .',
#  '(PRIMARY BKT.)',
#  '.',
#  'Operation manual .',
#  'ENGINE A-MTG ARM .',
#  'Counter weight (100% balancing) .',
#  'ASSY.',
#  '.',
#  'OPERATORS SERVICE BOOK .',
#  'DOC .',
#  'SCR+ASC .',
#  'DOC .',
#  'SCR+ASC .',
#  'SELECTION FOR TIPPER BODIES .',
#  'SELECTION FOR TIPPER BODIES .',
#  'SUPPORT BOTTOM (4TH & 5TH C/M) .',
#  'SUBSTRUCTURE ASSY .',
#  'KIT-COOLING SYSTEM .',
#  'GRP ID FOR PRIMA2525.K/39WB/16CUM .',
#  'GRP ID-18CUM BODY/LPK3118/BGS SUSP .',
#  'GRP ID-16 CUM STD BODY .',
#  'TOOL KIT .',
#  'ASSY.',
#  'VEHICLE ELECTRONIC CONTROLLER UNIT .',
#  'VEHICLE ELECTRONIC CONTROLLER UNIT .',
#  'VEHICLE ELECTRONIC CONTROLLER UNIT .',
#  'AIR PRESSURE TRANSDUCER .',
#  'USB CHARGER .',
#  'KNOB M6 .',
#  'MAGAZINE POCKET LH .',
#  'MAGAZINE POCKET LH .',
#  'MAGAZINE POCKET RH .',
#  'MAGAZINE POCKET RH .',
#  'PACKING 2.5 THK.',
#  '.',
#  'PACKING 5 THK.',
#  '.',
#  'PACKING 1.6 THK.',
#  '.',
#  'COAT HANGER .',
#  'CLEAT .',
#  'REAR SPRING ASSY .',
#  'INTEGRATED FILLING UNIT ASSY .',
#  'VENT CAP .',
#  'CLOSE COUPLED CATCON ASSY .',
#  'FLOOT MAT LH .',
#  'ASSY.SUNVISOR LH .',
#  'ASSY LID (FUEL PRIMING) .',
#  'TORSION SPRING RH .',
#  'BEADING (FIRE WALL) .',
#  'FRONT VIEW MIRROR ASSY .',
#  'FLOOT MAT RH .',
#  'REINFORCEMENT CENTER BRG CROSS MEMBER .',
#  'EXTERNAL ANTENNA BASE .',
#  'EXTERNAL ANTENNA ROD .',
#  'AIR PRESSURE TRANSDUCER .',
#  'USB CHARGER .',
#  'OWNERS MANUAL .',
#  'PACKING 4 THK.',
#  '.',
#  '.',
#  '.',
#  'NOISE SHIELD ASSY BOTTOM .',
#  'ASSY BOTTOM NOISE SHIELD .',
#  'ASSY KNOB .',
#  '.',
#  '.',
#  'RAMA (90 LTRS) .',
#  'FRONT SPRING ASSY(HIGHER CAMBER) .',
#  'FRONT SPRING ASSY (NORMAL CAMBER) .',
#  'RESERVOIR ASSY .',
#  'PACKING .',
#  'LEG ASSY .',
#  'ASSY MTG BRKT COMPLETE RH (CHASSIS SIDE) .',
#  '.',
#  'L-REINFORCEMENT TOP-RH .',
#  'L-REINFORCEMENT TOP-LH .',
#  '.',
#  'EXTENSION LONGITUDINAL LH .',
#  'UNDERBODY ASSY .',
#  'ADD.',
#  'SUPPORT BTM -SPR.C/M REAR FRONT .',
#  'CC_VAR_HL_N_0.80-10.00_MM .',
#  'WH Main .',
#  'WH Tail .',
#  'WH Main .',
#  'Gap hider plastic strip .',
#  'PU Cotton material .',
#  'SELECTOR & SHIFTER FORK ASSY WITH GSL .',
#  'RETAINER RING .',
#  'OWNERS MANUAL .',
#  'AC UNIT ASSY .',
#  'BRACKET ASSY ROOF LAMP MTG .',
#  'Return assly line .',
#  'Return assly line .',
#  'Return assly line .',
#  'Fuel Lines .',
#  'Fuel Lines .',
#  'Fuel Lines .',
#  'Fuel Lines .',
#  'Fuel Lines .',
#  'KIT-ENGINE COOLING SYSTEM .',
#  'KIT-ENGINE COOLING SYSTEM .',
#  'KIT-ENGINE COOLING SYSTEM- .',
#  ')[MAT-VITON] .',
#  'ROLLER CAGE REVERSE IDLER .',
#  'NEEDLE CAGE 5TH SPEED M/S INA .',
#  'ROLLER CAGE (26X41X26)-KCI .',
#  '280 DIA.',
#  'CL.',
#  '(REINFORCED)-CK .',
#  '.',
#  '.',
#  '.',
#  'FIRTEE 12X12X12 .',
#  'CAP W/RETAINER RING-BLACK JAIHIND .',
#  'FASTAG .',
#  'ALUMINIUM FOIL .',
#  'VEHICLE ELECTRONIC CONTROLLER UNIT .',
#  '.',
#  'OPERATOR SERVICE BOOK- 407 CITY RIDE BUSN .',
#  'OSB FOR 407 TURBO/709 TURBO (ENGLISH) .',
#  'OPERATORS SER.BOOK-LP/LPT/SFC 712/912 EXN .',
#  'OPERATOR`S SER.',
#  'BOOK-LP/LPT/SFC 410EX .',
#  'OPERATOR`S SERVICE BOOK-709/909EX(COMBINN .',
#  'O.S.B.',
#  '- SFC 407 PICKUP .',
#  'OWNER S SERVICE BOOK - LP 407 CNG BS IV .',
#  'OPERATOR S SERVICE BOOK-LP 909 CNG .',
#  'ADVANCE WARNING TRIANGLE .',
#  'Assy Frame .',
#  'Reinforcement .',
#  'Reinforcement .',
#  'a .',
#  'a .',
#  'a .',
#  'a .',
#  'a .',
#  'a .',
#  'a .',
#  'a .',
#  'a .',
#  'a .',
#  'a .',
#  'CENTER FLAP ASSY .',
#  'COOLING SYSTEM ASSY .',
#  'LEAK OFF LINE .',
#  'LINK ROD .',
#  'AIS for Ultra 1415 vehicle with 3.3L NG BSVI .',
#  '"FORK 1-2, 5-6" .',
#  'DOG 5th-R .',
#  'FORK 5-R .',
#  'FORK 3-4 .',
#  ...]
